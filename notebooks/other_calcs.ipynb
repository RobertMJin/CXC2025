# %%
import os
from flask import Flask, jsonify
from supabase import create_client, Client
from time import sleep
from datetime import datetime, timedelta

app = Flask(__name__)

SUPABASE_URL = os.environ.get("SUPABASE_URL")
SUPABASE_KEY = os.environ.get("SUPABASE_KEY")

supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)

TABLE_NAME = "v2_federato_amplitude_data"

# %%
def get_retention_events(user_id):
    """Calculate the top 5 retention events for a given user."""
    try:
        # Get user's amplitude_id
        user_response = supabase.table("user_table").select("amplitude_id").eq("user_id", user_id).execute()
        amplitude_id = user_response.data[0]["amplitude_id"]
        
        # Get all events for this user, ordered by time
        events_response = supabase.table(TABLE_NAME)\
            .select("event_type, event_time")\
            .eq("amplitude_id", amplitude_id)\
            .order("event_time", desc=False)\
            .execute()
        
        if not events_response.data:
            return []
        
        # Convert events to a list of event types
        events = [event["event_type"] for event in events_response.data]
        
        # Calculate return frequency for each event type
        event_returns = {}
        for i, event in enumerate(events[:-1]):  # Exclude last event
            # Look at the next events to see if user returns to this event
            future_events = events[i+1:]
            if event in future_events:
                event_returns[event] = event_returns.get(event, 0) + 1
        
        # Calculate return rate (returns / total occurrences)
        event_counts = {}
        for event in events:
            event_counts[event] = event_counts.get(event, 0) + 1
            
        return_rates = {}
        for event, returns in event_returns.items():
            return_rates[event] = returns / event_counts[event]
        
        # Get top 5 events by return rate (minimum 2 occurrences)
        top_events = sorted(
            [(event, rate) for event, rate in return_rates.items() 
             if event_counts[event] >= 2],  # Filter events with at least 2 occurrences
            key=lambda x: x[1],
            reverse=True
        )[:5]
        
        # Format results
        return [{"event": event, "return_rate": rate} for event, rate in top_events]
        
    except Exception as e:
        print(f"Error calculating retention events for user {user_id}: {e}")
        return []

# Update all users in the user_table with their top retention events
def update_all_users_retention_events():
    try:
        # First, add the column directly with raw SQL
        add_column_sql = """
        DO $$ 
        BEGIN 
            IF NOT EXISTS (
                SELECT 1 
                FROM information_schema.columns 
                WHERE table_name = 'user_table' 
                AND column_name = 'top_retention_events'
            ) THEN 
                ALTER TABLE user_table ADD COLUMN top_retention_events JSONB;
            END IF;
        END $$;
        """
        
        # Execute the SQL directly through a query
        supabase.table("user_table").select("*").limit(1).execute()  # Ensure connection
        supabase.postgrest.schema("public").rpc("execute_sql", {"query": add_column_sql}).execute()
        print("Added top_retention_events column if it didn't exist")
        
        # Get all user IDs
        users_response = supabase.table("user_table").select("user_id").execute()
        
        # Process each user
        for user in users_response.data:
            user_id = user["user_id"]
            top_events = get_retention_events(user_id)
            
            # Update the user's record with their top retention events
            supabase.table("user_table")\
                .update({"top_retention_events": top_events})\
                .eq("user_id", user_id)\
                .execute()
            
            print(f"Updated retention events for user {user_id}")
            
        print("Completed updating all users' retention events")
        
    except Exception as e:
        print(f"Error updating retention events: {e}")

# Execute the update
update_all_users_retention_events()
# Out:
# Added top_retention_events column if it didn't exist
# Updated retention events for user 1
# Updated retention events for user 2
# Updated retention events for user 3
# Updated retention events for user 4
# Updated retention events for user 5
# Updated retention events for user 6
# Updated retention events for user 7
# Updated retention events for user 8
# Updated retention events for user 9
# Updated retention events for user 10
# Updated retention events for user 11
# Updated retention events for user 12
# Updated retention events for user 13
# Updated retention events for user 14
# Updated retention events for user 15
# Updated retention events for user 16
# Updated retention events for user 17
# Updated retention events for user 18
# Updated retention events for user 19
# Updated retention events for user 20
# Updated retention events for user 21
# Updated retention events for user 22
# Updated retention events for user 23
# Updated retention events for user 24
# Updated retention events for user 25
# Updated retention events for user 26
# Updated retention events for user 27
# Updated retention events for user 28
# Updated retention events for user 29
# Updated retention events for user 30
# Updated retention events for user 31
# Updated retention events for user 32
# Updated retention events for user 33
# Updated retention events for user 34
# Updated retention events for user 35
# Updated retention events for user 36
# Updated retention events for user 37
# Updated retention events for user 38
# Updated retention events for user 39
# Updated retention events for user 40
# Updated retention events for user 41
# Updated retention events for user 42
# Updated retention events for user 43
# Updated retention events for user 44
# Updated retention events for user 45
# Updated retention events for user 46
# Updated retention events for user 47
# Updated retention events for user 48
# Updated retention events for user 49
# Updated retention events for user 50
# Updated retention events for user 51
# Updated retention events for user 52
# Updated retention events for user 53
# Updated retention events for user 54
# Updated retention events for user 55
# Updated retention events for user 56
# Updated retention events for user 57
# Updated retention events for user 58
# Updated retention events for user 59
# Updated retention events for user 60
# Updated retention events for user 61
# Updated retention events for user 62
# Updated retention events for user 63
# Updated retention events for user 64
# Updated retention events for user 65
# Updated retention events for user 66
# Updated retention events for user 67
# Updated retention events for user 68
# Updated retention events for user 69
# Updated retention events for user 70
# Updated retention events for user 71
# Updated retention events for user 72
# Updated retention events for user 73
# Updated retention events for user 74
# Updated retention events for user 75
# Updated retention events for user 76
# Updated retention events for user 77
# Updated retention events for user 78
# Updated retention events for user 79
# Updated retention events for user 80
# Updated retention events for user 81
# Updated retention events for user 82
# Updated retention events for user 83
# Updated retention events for user 84
# Updated retention events for user 85
# Updated retention events for user 86
# Updated retention events for user 87
# Updated retention events for user 88
# Updated retention events for user 89
# Updated retention events for user 90
# Updated retention events for user 91
# Updated retention events for user 92
# Updated retention events for user 93
# Updated retention events for user 94
# Error calculating retention events for user 95: {'code': '57014', 'details': None, 'hint': None, 'message': 'canceling statement due to statement timeout'}
# Updated retention events for user 95
# Updated retention events for user 96
# Updated retention events for user 97
# Updated retention events for user 98
# Updated retention events for user 99
# Updated retention events for user 100
# Updated retention events for user 101
# Updated retention events for user 102
# Updated retention events for user 103
# Updated retention events for user 104
# Updated retention events for user 105
# Updated retention events for user 106
# Updated retention events for user 107
# Updated retention events for user 108
# Updated retention events for user 109
# Updated retention events for user 110
# Updated retention events for user 111
# Updated retention events for user 112
# Updated retention events for user 113
# Updated retention events for user 114
# Updated retention events for user 115
# Updated retention events for user 116
# Updated retention events for user 117
# Updated retention events for user 118
# Updated retention events for user 119
# Updated retention events for user 120
# Updated retention events for user 121
# Updated retention events for user 122
# Updated retention events for user 123
# Updated retention events for user 124
# Updated retention events for user 125
# Updated retention events for user 126
# Updated retention events for user 127
# Updated retention events for user 128
# Updated retention events for user 129
# Updated retention events for user 130
# Updated retention events for user 131
# Updated retention events for user 132
# Updated retention events for user 133
# Updated retention events for user 134
# Updated retention events for user 135
# Updated retention events for user 136
# Updated retention events for user 137
# Updated retention events for user 138
# Updated retention events for user 139
# Updated retention events for user 140
# Updated retention events for user 141
# Updated retention events for user 142
# Updated retention events for user 143
# Updated retention events for user 144
# Updated retention events for user 145
# Updated retention events for user 146
# Updated retention events for user 147
# Updated retention events for user 148
# Updated retention events for user 149
# Updated retention events for user 150
# Updated retention events for user 151
# Updated retention events for user 152
# Updated retention events for user 153
# Updated retention events for user 154
# Updated retention events for user 155
# Updated retention events for user 156
# Updated retention events for user 157
# Updated retention events for user 158
# Updated retention events for user 159
# Updated retention events for user 160
# Updated retention events for user 161
# Updated retention events for user 162
# Updated retention events for user 163
# Updated retention events for user 164
# Updated retention events for user 165
# Updated retention events for user 166
# Updated retention events for user 167
# Updated retention events for user 168
# Updated retention events for user 169
# Updated retention events for user 170
# Updated retention events for user 171
# Updated retention events for user 172
# Updated retention events for user 173
# Updated retention events for user 174
# Updated retention events for user 175
# Updated retention events for user 176
# Updated retention events for user 177
# Updated retention events for user 178
# Updated retention events for user 179
# Updated retention events for user 180
# Updated retention events for user 181
# Updated retention events for user 182
# Updated retention events for user 183
# Updated retention events for user 184
# Updated retention events for user 185
# Updated retention events for user 186
# Updated retention events for user 187
# Updated retention events for user 188
# Updated retention events for user 189
# Updated retention events for user 190
# Updated retention events for user 191
# Updated retention events for user 192
# Updated retention events for user 193
# Updated retention events for user 194
# Updated retention events for user 195
# Updated retention events for user 196
# Updated retention events for user 197
# Updated retention events for user 198
# Updated retention events for user 199
# Updated retention events for user 200
# Updated retention events for user 201
# Updated retention events for user 202
# Updated retention events for user 203
# Updated retention events for user 204
# Updated retention events for user 205
# Updated retention events for user 206
# Updated retention events for user 207
# Updated retention events for user 208
# Updated retention events for user 209
# Updated retention events for user 210
# Updated retention events for user 211
# Updated retention events for user 212
# Updated retention events for user 213
# Updated retention events for user 214
# Updated retention events for user 215
# Updated retention events for user 216
# Updated retention events for user 217
# Updated retention events for user 218
# Updated retention events for user 219
# Updated retention events for user 220
# Updated retention events for user 221
# Updated retention events for user 222
# Updated retention events for user 223
# Updated retention events for user 224
# Updated retention events for user 225
# Updated retention events for user 226
# Updated retention events for user 227
# Updated retention events for user 228
# Updated retention events for user 229
# Updated retention events for user 230
# Updated retention events for user 231
# Updated retention events for user 232
# Updated retention events for user 233
# Updated retention events for user 234
# Updated retention events for user 235
# Updated retention events for user 236
# Updated retention events for user 237
# Updated retention events for user 238
# Updated retention events for user 239
# Updated retention events for user 240
# Updated retention events for user 241
# Updated retention events for user 242
# Updated retention events for user 243
# Updated retention events for user 244
# Updated retention events for user 245
# Updated retention events for user 246
# Updated retention events for user 247
# Updated retention events for user 248
# Updated retention events for user 249
# Updated retention events for user 250
# Updated retention events for user 251
# Updated retention events for user 252
# Updated retention events for user 253
# Updated retention events for user 254
# Updated retention events for user 255
# Updated retention events for user 256
# Updated retention events for user 257
# Updated retention events for user 258
# Updated retention events for user 259
# Updated retention events for user 260
# Updated retention events for user 261
# Updated retention events for user 262
# Updated retention events for user 263
# Updated retention events for user 264
# Updated retention events for user 265
# Updated retention events for user 266
# Updated retention events for user 267
# Updated retention events for user 268
# Updated retention events for user 269
# Updated retention events for user 270
# Updated retention events for user 271
# Updated retention events for user 272
# Updated retention events for user 273
# Updated retention events for user 274
# Updated retention events for user 275
# Updated retention events for user 276
# Updated retention events for user 277
# Updated retention events for user 278
# Updated retention events for user 279
# Updated retention events for user 280
# Updated retention events for user 281
# Updated retention events for user 282
# Updated retention events for user 283
# Updated retention events for user 284
# Updated retention events for user 285
# Updated retention events for user 286
# Updated retention events for user 287
# Updated retention events for user 288
# Updated retention events for user 289
# Updated retention events for user 290
# Updated retention events for user 291
# Updated retention events for user 292
# Updated retention events for user 293
# Updated retention events for user 294
# Updated retention events for user 295
# Updated retention events for user 296
# Updated retention events for user 297
# Updated retention events for user 298
# Updated retention events for user 299
# Updated retention events for user 300
# Updated retention events for user 301
# Updated retention events for user 302
# Updated retention events for user 303
# Updated retention events for user 304
# Updated retention events for user 305
# Updated retention events for user 306
# Updated retention events for user 307
# Updated retention events for user 308
# Updated retention events for user 309
# Updated retention events for user 310
# Updated retention events for user 311
# Updated retention events for user 312
# Updated retention events for user 313
# Updated retention events for user 314
# Updated retention events for user 315
# Updated retention events for user 316
# Updated retention events for user 317
# Updated retention events for user 318
# Updated retention events for user 319
# Updated retention events for user 320
# Updated retention events for user 321
# Updated retention events for user 322
# Updated retention events for user 323
# Updated retention events for user 324
# Updated retention events for user 325
# Updated retention events for user 326
# Updated retention events for user 327
# Updated retention events for user 328
# Updated retention events for user 329
# Updated retention events for user 330
# Updated retention events for user 331
# Updated retention events for user 332
# Updated retention events for user 333
# Updated retention events for user 334
# Updated retention events for user 335
# Updated retention events for user 336
# Updated retention events for user 337
# Updated retention events for user 338
# Updated retention events for user 339
# Updated retention events for user 340
# Updated retention events for user 341
# Updated retention events for user 342
# Updated retention events for user 343
# Updated retention events for user 344
# Updated retention events for user 345
# Updated retention events for user 346
# Updated retention events for user 347
# Updated retention events for user 348
# Updated retention events for user 349
# Updated retention events for user 350
# Updated retention events for user 351
# Updated retention events for user 352
# Updated retention events for user 353
# Updated retention events for user 354
# Updated retention events for user 355
# Updated retention events for user 356
# Updated retention events for user 357
# Updated retention events for user 358
# Updated retention events for user 359
# Updated retention events for user 360
# Updated retention events for user 361
# Updated retention events for user 362
# Updated retention events for user 363
# Updated retention events for user 364
# Updated retention events for user 365
# Updated retention events for user 366
# Updated retention events for user 367
# Updated retention events for user 368
# Updated retention events for user 369
# Updated retention events for user 370
# Updated retention events for user 371
# Updated retention events for user 372
# Updated retention events for user 373
# Updated retention events for user 374
# Updated retention events for user 375
# Updated retention events for user 376
# Updated retention events for user 377
# Updated retention events for user 378
# Updated retention events for user 379
# Updated retention events for user 380
# Updated retention events for user 381
# Updated retention events for user 382
# Updated retention events for user 383
# Updated retention events for user 384
# Updated retention events for user 385
# Updated retention events for user 386
# Updated retention events for user 387
# Updated retention events for user 388
# Updated retention events for user 389
# Updated retention events for user 390
# Updated retention events for user 391
# Updated retention events for user 392
# Updated retention events for user 393
# Updated retention events for user 394
# Updated retention events for user 395
# Updated retention events for user 396
# Updated retention events for user 397
# Updated retention events for user 398
# Updated retention events for user 399
# Updated retention events for user 400
# Updated retention events for user 401
# Updated retention events for user 402
# Updated retention events for user 403
# Updated retention events for user 404
# Updated retention events for user 405
# Updated retention events for user 406
# Updated retention events for user 407
# Updated retention events for user 408
# Updated retention events for user 409
# Updated retention events for user 410
# Updated retention events for user 411
# Updated retention events for user 412
# Updated retention events for user 413
# Updated retention events for user 414
# Updated retention events for user 415
# Updated retention events for user 416
# Updated retention events for user 417
# Updated retention events for user 418
# Updated retention events for user 419
# Updated retention events for user 420
# Updated retention events for user 421
# Updated retention events for user 422
# Updated retention events for user 423
# Updated retention events for user 424
# Updated retention events for user 425
# Updated retention events for user 426
# Updated retention events for user 427
# Updated retention events for user 428
# Updated retention events for user 429
# Updated retention events for user 430
# Updated retention events for user 431
# Updated retention events for user 432
# Updated retention events for user 433
# Updated retention events for user 434
# Updated retention events for user 435
# Updated retention events for user 436
# Updated retention events for user 437
# Updated retention events for user 438
# Updated retention events for user 439
# Updated retention events for user 440
# Updated retention events for user 441
# Updated retention events for user 442
# Updated retention events for user 443
# Updated retention events for user 444
# Updated retention events for user 445
# Updated retention events for user 446
# Updated retention events for user 447
# Updated retention events for user 448
# Updated retention events for user 449
# Updated retention events for user 450
# Updated retention events for user 451
# Updated retention events for user 452
# Updated retention events for user 453
# Updated retention events for user 454
# Updated retention events for user 455
# Updated retention events for user 456
# Updated retention events for user 457
# Updated retention events for user 458
# Updated retention events for user 459
# Updated retention events for user 460
# Updated retention events for user 461
# Updated retention events for user 462
# Updated retention events for user 463
# Updated retention events for user 464
# Updated retention events for user 465
# Updated retention events for user 466
# Updated retention events for user 467
# Updated retention events for user 468
# Updated retention events for user 469
# Updated retention events for user 470
# Updated retention events for user 471
# Updated retention events for user 472
# Updated retention events for user 473
# Updated retention events for user 474
# Updated retention events for user 475
# Updated retention events for user 476
# Updated retention events for user 477
# Updated retention events for user 478
# Updated retention events for user 479
# Updated retention events for user 480
# Updated retention events for user 481
# Updated retention events for user 482
# Updated retention events for user 483
# Updated retention events for user 484
# Updated retention events for user 485
# Updated retention events for user 486
# Updated retention events for user 487
# Updated retention events for user 488
# Updated retention events for user 489
# Updated retention events for user 490
# Updated retention events for user 491
# Updated retention events for user 492
# Updated retention events for user 493
# Updated retention events for user 494
# Updated retention events for user 495
# Updated retention events for user 496
# Updated retention events for user 497
# Updated retention events for user 498
# Updated retention events for user 499
# Updated retention events for user 500
# Updated retention events for user 501
# Updated retention events for user 502
# Updated retention events for user 503
# Updated retention events for user 504
# Updated retention events for user 505
# Updated retention events for user 506
# Updated retention events for user 507
# Updated retention events for user 508
# Updated retention events for user 509
# Updated retention events for user 510
# Updated retention events for user 511
# Updated retention events for user 512
# Updated retention events for user 513
# Updated retention events for user 514
# Updated retention events for user 515
# Updated retention events for user 516
# Updated retention events for user 517
# Updated retention events for user 518
# Updated retention events for user 519
# Updated retention events for user 520
# Updated retention events for user 521
# Updated retention events for user 522
# Updated retention events for user 523
# Updated retention events for user 524
# Updated retention events for user 525
# Updated retention events for user 526
# Updated retention events for user 527
# Updated retention events for user 528
# Updated retention events for user 529
# Updated retention events for user 530
# Updated retention events for user 531
# Updated retention events for user 532
# Updated retention events for user 533
# Updated retention events for user 534
# Updated retention events for user 535
# Updated retention events for user 536
# Updated retention events for user 537
# Updated retention events for user 538
# Updated retention events for user 539
# Updated retention events for user 540
# Updated retention events for user 541
# Updated retention events for user 542
# Updated retention events for user 543
# Updated retention events for user 544
# Updated retention events for user 545
# Updated retention events for user 546
# Updated retention events for user 547
# Updated retention events for user 548
# Updated retention events for user 549
# Updated retention events for user 550
# Updated retention events for user 551
# Updated retention events for user 552
# Updated retention events for user 553
# Updated retention events for user 554
# Updated retention events for user 555
# Updated retention events for user 556
# Updated retention events for user 557
# Updated retention events for user 558
# Updated retention events for user 559
# Updated retention events for user 560
# Updated retention events for user 561
# Updated retention events for user 562
# Updated retention events for user 563
# Updated retention events for user 564
# Updated retention events for user 565
# Updated retention events for user 566
# Updated retention events for user 567
# Updated retention events for user 568
# Updated retention events for user 569
# Updated retention events for user 570
# Updated retention events for user 571
# Updated retention events for user 572
# Updated retention events for user 573
# Updated retention events for user 574
# Updated retention events for user 575
# Updated retention events for user 576
# Updated retention events for user 577
# Updated retention events for user 578
# Updated retention events for user 579
# Updated retention events for user 580
# Updated retention events for user 581
# Updated retention events for user 582
# Updated retention events for user 583
# Updated retention events for user 584
# Updated retention events for user 585
# Updated retention events for user 586
# Updated retention events for user 587
# Updated retention events for user 588
# Updated retention events for user 589
# Updated retention events for user 590
# Updated retention events for user 591
# Updated retention events for user 592
# Updated retention events for user 593
# Updated retention events for user 594
# Updated retention events for user 595
# Updated retention events for user 596
# Updated retention events for user 597
# Updated retention events for user 598
# Updated retention events for user 599
# Updated retention events for user 600
# Updated retention events for user 601
# Updated retention events for user 602
# Updated retention events for user 603
# Updated retention events for user 604
# Updated retention events for user 605
# Updated retention events for user 606
# Updated retention events for user 607
# Updated retention events for user 608
# Updated retention events for user 609
# Updated retention events for user 610
# Updated retention events for user 611
# Updated retention events for user 612
# Updated retention events for user 613
# Updated retention events for user 614
# Updated retention events for user 615
# Updated retention events for user 616
# Updated retention events for user 617
# Updated retention events for user 618
# Updated retention events for user 619
# Updated retention events for user 620
# Updated retention events for user 621
# Updated retention events for user 622
# Updated retention events for user 623
# Updated retention events for user 624
# Updated retention events for user 625
# Updated retention events for user 626
# Updated retention events for user 627
# Updated retention events for user 628
# Updated retention events for user 629
# Updated retention events for user 630
# Updated retention events for user 631
# Updated retention events for user 632
# Updated retention events for user 633
# Updated retention events for user 634
# Updated retention events for user 635
# Updated retention events for user 636
# Updated retention events for user 637
# Updated retention events for user 638
# Updated retention events for user 639
# Updated retention events for user 640
# Updated retention events for user 641
# Updated retention events for user 642
# Updated retention events for user 643
# Updated retention events for user 644
# Updated retention events for user 645
# Updated retention events for user 646
# Updated retention events for user 647
# Updated retention events for user 648
# Updated retention events for user 649
# Updated retention events for user 650
# Updated retention events for user 651
# Updated retention events for user 652
# Updated retention events for user 653
# Updated retention events for user 654
# Updated retention events for user 655
# Updated retention events for user 656
# Updated retention events for user 657
# Updated retention events for user 658
# Updated retention events for user 659
# Updated retention events for user 660
# Updated retention events for user 661
# Updated retention events for user 662
# Updated retention events for user 663
# Updated retention events for user 664
# Updated retention events for user 665
# Updated retention events for user 666
# Updated retention events for user 667
# Updated retention events for user 668
# Updated retention events for user 669
# Updated retention events for user 670
# Updated retention events for user 671
# Updated retention events for user 672
# Updated retention events for user 673
# Updated retention events for user 674
# Updated retention events for user 675
# Updated retention events for user 676
# Updated retention events for user 677
# Updated retention events for user 678
# Updated retention events for user 679
# Updated retention events for user 680
# Updated retention events for user 681
# Updated retention events for user 682
# Updated retention events for user 683
# Updated retention events for user 684
# Updated retention events for user 685
# Updated retention events for user 686
# Updated retention events for user 687
# Updated retention events for user 688
# Updated retention events for user 689
# Updated retention events for user 690
# Updated retention events for user 691
# Updated retention events for user 692
# Updated retention events for user 693
# Updated retention events for user 694
# Updated retention events for user 695
# Updated retention events for user 696
# Updated retention events for user 697
# Updated retention events for user 698
# Updated retention events for user 699
# Updated retention events for user 700
# Updated retention events for user 701
# Updated retention events for user 702
# Updated retention events for user 703
# Updated retention events for user 704
# Updated retention events for user 705
# Updated retention events for user 706
# Updated retention events for user 707
# Updated retention events for user 708
# Updated retention events for user 709
# Updated retention events for user 710
# Updated retention events for user 711
# Updated retention events for user 712
# Updated retention events for user 713
# Updated retention events for user 714
# Updated retention events for user 715
# Updated retention events for user 716
# Updated retention events for user 717
# Updated retention events for user 718
# Updated retention events for user 719
# Updated retention events for user 720
# Updated retention events for user 721
# Updated retention events for user 722
# Updated retention events for user 723
# Updated retention events for user 724
# Updated retention events for user 725
# Updated retention events for user 726
# Updated retention events for user 727
# Updated retention events for user 728
# Updated retention events for user 729
# Updated retention events for user 730
# Updated retention events for user 731
# Updated retention events for user 732
# Updated retention events for user 733
# Updated retention events for user 734
# Updated retention events for user 735
# Updated retention events for user 736
# Updated retention events for user 737
# Updated retention events for user 738
# Updated retention events for user 739
# Updated retention events for user 740
# Updated retention events for user 741
# Updated retention events for user 742
# Updated retention events for user 743
# Updated retention events for user 744
# Updated retention events for user 745
# Updated retention events for user 746
# Updated retention events for user 747
# Updated retention events for user 748
# Updated retention events for user 749
# Updated retention events for user 750
# Updated retention events for user 751
# Updated retention events for user 752
# Updated retention events for user 753
# Updated retention events for user 754
# Updated retention events for user 755
# Updated retention events for user 756
# Updated retention events for user 757
# Updated retention events for user 758
# Updated retention events for user 759
# Updated retention events for user 760
# Updated retention events for user 761
# Updated retention events for user 762
# Updated retention events for user 763
# Updated retention events for user 764
# Updated retention events for user 765
# Updated retention events for user 766
# Updated retention events for user 767
# Updated retention events for user 768
# Updated retention events for user 769
# Updated retention events for user 770
# Updated retention events for user 771
# Updated retention events for user 772
# Updated retention events for user 773
# Updated retention events for user 774
# Updated retention events for user 775
# Updated retention events for user 776
# Updated retention events for user 777
# Updated retention events for user 778
# Updated retention events for user 779
# Updated retention events for user 780
# Updated retention events for user 781
# Updated retention events for user 782
# Updated retention events for user 783
# Updated retention events for user 784
# Updated retention events for user 785
# Updated retention events for user 786
# Updated retention events for user 787
# Updated retention events for user 788
# Updated retention events for user 789
# Updated retention events for user 790
# Updated retention events for user 791
# Updated retention events for user 792
# Updated retention events for user 793
# Updated retention events for user 794
# Updated retention events for user 795
# Updated retention events for user 796
# Updated retention events for user 797
# Updated retention events for user 798
# Updated retention events for user 799
# Updated retention events for user 800
# Updated retention events for user 801
# Updated retention events for user 802
# Updated retention events for user 803
# Updated retention events for user 804
# Updated retention events for user 805
# Updated retention events for user 806
# Updated retention events for user 807
# Updated retention events for user 808
# Updated retention events for user 809
# Updated retention events for user 810
# Updated retention events for user 811
# Updated retention events for user 812
# Updated retention events for user 813
# Updated retention events for user 814
# Updated retention events for user 815
# Updated retention events for user 816
# Updated retention events for user 817
# Updated retention events for user 818
# Updated retention events for user 819
# Updated retention events for user 820
# Updated retention events for user 821
# Updated retention events for user 822
# Updated retention events for user 823
# Updated retention events for user 824
# Updated retention events for user 825
# Updated retention events for user 826
# Updated retention events for user 827
# Updated retention events for user 828
# Updated retention events for user 829
# Updated retention events for user 830
# Updated retention events for user 831
# Updated retention events for user 832
# Updated retention events for user 833
# Updated retention events for user 834
# Updated retention events for user 835
# Updated retention events for user 836
# Updated retention events for user 837
# Updated retention events for user 838
# Updated retention events for user 839
# Updated retention events for user 840
# Updated retention events for user 841
# Updated retention events for user 842
# Updated retention events for user 843
# Updated retention events for user 844
# Updated retention events for user 845
# Updated retention events for user 846
# Updated retention events for user 847
# Updated retention events for user 848
# Updated retention events for user 849
# Updated retention events for user 850
# Updated retention events for user 851
# Updated retention events for user 852
# Updated retention events for user 853
# Updated retention events for user 854
# Updated retention events for user 855
# Updated retention events for user 856
# Updated retention events for user 857
# Updated retention events for user 858
# Updated retention events for user 859
# Updated retention events for user 860
# Updated retention events for user 861
# Updated retention events for user 862
# Updated retention events for user 863
# Updated retention events for user 864
# Updated retention events for user 865
# Updated retention events for user 866
# Updated retention events for user 867
# Updated retention events for user 868
# Updated retention events for user 869
# Updated retention events for user 870
# Updated retention events for user 871
# Updated retention events for user 872
# Updated retention events for user 873
# Updated retention events for user 874
# Updated retention events for user 875
# Updated retention events for user 876
# Updated retention events for user 877
# Updated retention events for user 878
# Updated retention events for user 879
# Updated retention events for user 880
# Updated retention events for user 881
# Updated retention events for user 882
# Updated retention events for user 883
# Updated retention events for user 884
# Updated retention events for user 885
# Updated retention events for user 886
# Updated retention events for user 887
# Updated retention events for user 888
# Updated retention events for user 889
# Updated retention events for user 890
# Updated retention events for user 891
# Updated retention events for user 892
# Updated retention events for user 893
# Updated retention events for user 894
# Updated retention events for user 895
# Updated retention events for user 896
# Updated retention events for user 897
# Updated retention events for user 898
# Updated retention events for user 899
# Updated retention events for user 900
# Updated retention events for user 901
# Updated retention events for user 902
# Updated retention events for user 903
# Updated retention events for user 904
# Updated retention events for user 905
# Updated retention events for user 906
# Updated retention events for user 907
# Updated retention events for user 908
# Updated retention events for user 909
# Updated retention events for user 910
# Updated retention events for user 911
# Updated retention events for user 912
# Updated retention events for user 913
# Updated retention events for user 914
# Updated retention events for user 915
# Updated retention events for user 916
# Updated retention events for user 917
# Updated retention events for user 918
# Updated retention events for user 919
# Updated retention events for user 920
# Updated retention events for user 921
# Updated retention events for user 922
# Updated retention events for user 923
# Updated retention events for user 924
# Updated retention events for user 925
# Updated retention events for user 926
# Updated retention events for user 927
# Updated retention events for user 928
# Updated retention events for user 929
# Updated retention events for user 930
# Updated retention events for user 931
# Updated retention events for user 932
# Updated retention events for user 933
# Updated retention events for user 934
# Updated retention events for user 935
# Updated retention events for user 936
# Updated retention events for user 937
# Updated retention events for user 938
# Updated retention events for user 939
# Updated retention events for user 940
# Updated retention events for user 941
# Updated retention events for user 942
# Updated retention events for user 943
# Updated retention events for user 944
# Updated retention events for user 945
# Updated retention events for user 946
# Updated retention events for user 947
# Updated retention events for user 948
# Updated retention events for user 949
# Updated retention events for user 950
# Updated retention events for user 951
# Updated retention events for user 952
# Updated retention events for user 953
# Updated retention events for user 954
# Updated retention events for user 955
# Updated retention events for user 956
# Updated retention events for user 957
# Updated retention events for user 958
# Updated retention events for user 959
# Updated retention events for user 960
# Updated retention events for user 961
# Updated retention events for user 962
# Updated retention events for user 963
# Updated retention events for user 964
# Updated retention events for user 965
# Updated retention events for user 966
# Updated retention events for user 967
# Updated retention events for user 968
# Updated retention events for user 969
# Updated retention events for user 970
# Updated retention events for user 971
# Updated retention events for user 972
# Updated retention events for user 973
# Updated retention events for user 974
# Updated retention events for user 975
# Updated retention events for user 976
# Updated retention events for user 977
# Updated retention events for user 978
# Updated retention events for user 979
# Updated retention events for user 980
# Updated retention events for user 981
# Updated retention events for user 982
# Updated retention events for user 983
# Updated retention events for user 984
# Updated retention events for user 985
# Updated retention events for user 986
# Updated retention events for user 987
# Updated retention events for user 988
# Updated retention events for user 989
# Updated retention events for user 990
# Updated retention events for user 991
# Updated retention events for user 992
# Updated retention events for user 993
# Updated retention events for user 994
# Updated retention events for user 995
# Updated retention events for user 996
# Updated retention events for user 997
# Updated retention events for user 998
# Updated retention events for user 999
# Updated retention events for user 1000
# Completed updating all users' retention events

# %%
def get_retention_events(user_id):
    """Calculate the top 5 events where users spend the most time."""
    try:
        # Get user's amplitude_id
        user_response = supabase.table("user_table").select("amplitude_id").eq("user_id", user_id).execute()
        amplitude_id = user_response.data[0]["amplitude_id"]
        
        # Get all events for this user, ordered by time
        events_response = supabase.table(TABLE_NAME)\
            .select("event_type, event_time")\
            .eq("amplitude_id", amplitude_id)\
            .order("event_time", desc=False)\
            .execute()
        
        if not events_response.data:
            return []
        
        # Calculate time spent on each event type
        event_durations = {}
        event_counts = {}
        
        for i, current_event in enumerate(events_response.data[:-1]):
            next_event = events_response.data[i + 1]
            
            # Convert string timestamps to datetime objects
            current_time = datetime.fromisoformat(current_event["event_time"].replace('Z', '+00:00'))
            next_time = datetime.fromisoformat(next_event["event_time"].replace('Z', '+00:00'))
            
            duration = (next_time - current_time).total_seconds()
            
            event_type = current_event["event_type"]
            event_durations[event_type] = event_durations.get(event_type, 0) + duration
            event_counts[event_type] = event_counts.get(event_type, 0) + 1
        
        # Calculate average duration for each event type
        avg_durations = {}
        for event_type in event_durations:
            avg_durations[event_type] = event_durations[event_type] / event_counts[event_type]
        
        # Get top 5 events by average duration (minimum 2 occurrences)
        top_events = sorted(
            [(event, duration) for event, duration in avg_durations.items() 
             if event_counts[event] >= 2],  # Filter events with at least 2 occurrences
            key=lambda x: x[1],
            reverse=True
        )[:5]
        
        # Format results (duration in seconds)
        return [{"event": event, "avg_duration": duration} for event, duration in top_events]
        
    except Exception as e:
        print(f"Error calculating retention events for user {user_id}: {e}")
        return []

# Update all users in the user_table with their top retention events
def update_all_users_retention_events():
    try:
        page_size = 1000
        last_user_id = 0
        
        while True:
            try:
                # Get next batch of users
                users_response = supabase.table("user_table")\
                    .select("user_id")\
                    .gt("user_id", last_user_id)\
                    .order("user_id")\
                    .limit(page_size)\
                    .execute()
                
                # If no more users, break
                if not users_response.data:
                    break
                
                # Process each user in this batch
                for user in users_response.data:
                    user_id = user["user_id"]
                    top_events = get_retention_events(user_id)
                    
                    # Update the user's record with their top retention events
                    supabase.table("user_table")\
                        .update({"top_retention_events": top_events})\
                        .eq("user_id", user_id)\
                        .execute()
                    
                    print(f"Updated retention events for user {user_id}")
                    last_user_id = user_id
                
                print(f"Completed batch up to user {last_user_id}")
                sleep(1)

            except Exception as batch_error:
                print(f"Batch error: {batch_error}")
                sleep(5)
                continue

        print("Completed updating all users' retention events")
        
    except Exception as e:
        print(f"Error updating retention events: {e}")

# Execute the update
update_all_users_retention_events()
# Out:
# Updated retention events for user 1
# Updated retention events for user 2
# Updated retention events for user 3
# Updated retention events for user 4
# Updated retention events for user 5
# Updated retention events for user 6
# Updated retention events for user 7
# Updated retention events for user 8
# Updated retention events for user 9
# Updated retention events for user 10
# Updated retention events for user 11
# Updated retention events for user 12
# Updated retention events for user 13
# Updated retention events for user 14
# Updated retention events for user 15
# Updated retention events for user 16
# Updated retention events for user 17
# Updated retention events for user 18
# Updated retention events for user 19
# Updated retention events for user 20
# Updated retention events for user 21
# Updated retention events for user 22
# Updated retention events for user 23
# Updated retention events for user 24
# Updated retention events for user 25
# Updated retention events for user 26
# Updated retention events for user 27
# Updated retention events for user 28
# Updated retention events for user 29
# Updated retention events for user 30
# Updated retention events for user 31
# Updated retention events for user 32
# Updated retention events for user 33
# Updated retention events for user 34
# Updated retention events for user 35
# Updated retention events for user 36
# Updated retention events for user 37
# Updated retention events for user 38
# Updated retention events for user 39
# Updated retention events for user 40
# Updated retention events for user 41
# Updated retention events for user 42
# Updated retention events for user 43
# Updated retention events for user 44
# Updated retention events for user 45
# Updated retention events for user 46
# Updated retention events for user 47
# Updated retention events for user 48
# Updated retention events for user 49
# Updated retention events for user 50
# Updated retention events for user 51
# Updated retention events for user 52
# Updated retention events for user 53
# Updated retention events for user 54
# Updated retention events for user 55
# Updated retention events for user 56
# Updated retention events for user 57
# Updated retention events for user 58

# %%
def update_user_session_metrics():
    """Add and update session metrics columns in the user_table."""
    try:
        # First, add the columns if they don't exist
        add_columns_sql = """
        DO $$ 
        BEGIN 
            -- Add average_session_time column
            IF NOT EXISTS (
                SELECT 1 FROM information_schema.columns 
                WHERE table_name = 'user_table' AND column_name = 'average_session_time'
            ) THEN 
                ALTER TABLE user_table ADD COLUMN average_session_time FLOAT;
            END IF;

            -- Add total_session_time column
            IF NOT EXISTS (
                SELECT 1 FROM information_schema.columns 
                WHERE table_name = 'user_table' AND column_name = 'total_session_time'
            ) THEN 
                ALTER TABLE user_table ADD COLUMN total_session_time FLOAT;
            END IF;

            -- Add frequency_of_sessions column
            IF NOT EXISTS (
                SELECT 1 FROM information_schema.columns 
                WHERE table_name = 'user_table' AND column_name = 'frequency_of_sessions'
            ) THEN 
                ALTER TABLE user_table ADD COLUMN frequency_of_sessions INTEGER;
            END IF;

            -- Add user_retention_30 column
            IF NOT EXISTS (
                SELECT 1 FROM information_schema.columns 
                WHERE table_name = 'user_table' AND column_name = 'user_retention_30'
            ) THEN 
                ALTER TABLE user_table ADD COLUMN user_retention_30 FLOAT;
            END IF;
        END $$;
        """
        
        # Execute the column addition
        supabase.postgrest.schema("public").rpc("execute_sql", {"query": add_columns_sql}).execute()
        print("Added new columns if they didn't exist")

        # Calculate the timestamp for 30 days ago
        thirty_days_ago = (datetime.now() - timedelta(days=30)).isoformat()

        # Process users in batches
        page_size = 1000
        last_user_id = 0
        
        while True:
            try:
                # Get next batch of users
                users_response = supabase.table("user_table")\
                    .select("user_id, amplitude_id")\
                    .gt("user_id", last_user_id)\
                    .order("user_id")\
                    .limit(page_size)\
                    .execute()
                
                if not users_response.data:
                    break
                
                # Process each user in this batch
                for user in users_response.data:
                    user_id = user["user_id"]
                    amplitude_id = user["amplitude_id"]
                    
                    # Get all events for this user in the last 30 days
                    events_response = supabase.table(TABLE_NAME)\
                        .select("event_time, session_id")\
                        .eq("amplitude_id", amplitude_id)\
                        .gte("event_time", thirty_days_ago)\
                        .order("event_time")\
                        .execute()
                    
                    if events_response.data:
                        # Group events by session
                        sessions = {}
                        for event in events_response.data:
                            session_id = event["session_id"]
                            event_time = datetime.fromisoformat(event["event_time"].replace('Z', '+00:00'))
                            
                            if session_id not in sessions:
                                sessions[session_id] = {"events": [], "duration": 0}
                            sessions[session_id]["events"].append(event_time)
                        
                        # Calculate session metrics
                        total_sessions = len(sessions)
                        total_session_time = 0
                        
                        for session in sessions.values():
                            if len(session["events"]) > 1:
                                session_duration = (max(session["events"]) - min(session["events"])).total_seconds()
                                total_session_time += session_duration
                                session["duration"] = session_duration
                        
                        # Calculate metrics
                        average_session_time = total_session_time / total_sessions if total_sessions > 0 else 0
                        frequency_of_sessions = total_sessions  # Number of sessions in past 30 days
                        
                        # Calculate retention (days active / 30 days)
                        unique_days = len(set(event_time.date() for session in sessions.values() for event_time in session["events"]))
                        user_retention_30 = unique_days / 30
                        
                        # Update user metrics
                        supabase.table("user_table")\
                            .update({
                                "average_session_time": average_session_time,
                                "total_session_time": total_session_time,
                                "frequency_of_sessions": frequency_of_sessions,
                                "user_retention_30": user_retention_30
                            })\
                            .eq("user_id", user_id)\
                            .execute()
                    
                    else:
                        # No events in last 30 days
                        supabase.table("user_table")\
                            .update({
                                "average_session_time": 0,
                                "total_session_time": 0,
                                "frequency_of_sessions": 0,
                                "user_retention_30": 0
                            })\
                            .eq("user_id", user_id)\
                            .execute()
                    
                    print(f"Updated session metrics for user {user_id}")
                    last_user_id = user_id
                
                print(f"Completed batch up to user {last_user_id}")
                sleep(1)  # Rate limiting

            except Exception as batch_error:
                print(f"Batch error: {batch_error}")
                sleep(5)  # Longer sleep on error
                continue

        print("Completed updating all users' session metrics")
        
    except Exception as e:
        print(f"Error updating session metrics: {e}")

# Execute the update
update_user_session_metrics()
# Out:
# Added new columns if they didn't exist
# Updated session metrics for user 1
# Updated session metrics for user 2
# Updated session metrics for user 3
# Updated session metrics for user 4
# Updated session metrics for user 5
# Updated session metrics for user 6
# Updated session metrics for user 7
# Updated session metrics for user 8
# Updated session metrics for user 9
# Updated session metrics for user 10
# Updated session metrics for user 11
# Updated session metrics for user 12
# Updated session metrics for user 13
# Updated session metrics for user 14
# Updated session metrics for user 15
# Updated session metrics for user 16
# Batch error: {'code': '57014', 'details': None, 'hint': None, 'message': 'canceling statement due to statement timeout'}
# Updated session metrics for user 17
# Updated session metrics for user 18
# Updated session metrics for user 19
# Updated session metrics for user 20
# Updated session metrics for user 21
# Updated session metrics for user 22
# Updated session metrics for user 23
# Updated session metrics for user 24
# Updated session metrics for user 25
# Updated session metrics for user 26
# Updated session metrics for user 27
# Updated session metrics for user 28
# Updated session metrics for user 29
# Updated session metrics for user 30
# Updated session metrics for user 31
# Updated session metrics for user 32
# Updated session metrics for user 33
# Updated session metrics for user 34
# Updated session metrics for user 35
# Updated session metrics for user 36
# Updated session metrics for user 37
# Updated session metrics for user 38
# Updated session metrics for user 39
# Updated session metrics for user 40
# Batch error: {'code': '57014', 'details': None, 'hint': None, 'message': 'canceling statement due to statement timeout'}
# Updated session metrics for user 41
# Updated session metrics for user 42
# Updated session metrics for user 43
# Updated session metrics for user 44
# Updated session metrics for user 45
# Updated session metrics for user 46
# Updated session metrics for user 47
# Updated session metrics for user 48
# Updated session metrics for user 49
# Updated session metrics for user 50
# Updated session metrics for user 51
# Updated session metrics for user 52
# Updated session metrics for user 53
# Updated session metrics for user 54
# Updated session metrics for user 55
# Updated session metrics for user 56
# Updated session metrics for user 57
# Updated session metrics for user 58
# Updated session metrics for user 59
# Updated session metrics for user 60
# Updated session metrics for user 61
# Updated session metrics for user 62
# Updated session metrics for user 63
# Updated session metrics for user 64
# Updated session metrics for user 65
# Updated session metrics for user 66
# Updated session metrics for user 67
# Updated session metrics for user 68
# Updated session metrics for user 69
# Updated session metrics for user 70
# Updated session metrics for user 71
# Updated session metrics for user 72
# Updated session metrics for user 73
# Updated session metrics for user 74
# Updated session metrics for user 75
# Updated session metrics for user 76
# Updated session metrics for user 77
# Updated session metrics for user 78
# Updated session metrics for user 79
# Updated session metrics for user 80
# Updated session metrics for user 81
# Updated session metrics for user 82
# Updated session metrics for user 83
# Updated session metrics for user 84
# Updated session metrics for user 85
# Updated session metrics for user 86
# Updated session metrics for user 87
# Updated session metrics for user 88
# Updated session metrics for user 89
# Updated session metrics for user 90
# Updated session metrics for user 91
# Updated session metrics for user 92
# Updated session metrics for user 93
# Updated session metrics for user 94
# Batch error: {'code': '57014', 'details': None, 'hint': None, 'message': 'canceling statement due to statement timeout'}
# Updated session metrics for user 95
# Updated session metrics for user 96
# Updated session metrics for user 97
# Updated session metrics for user 98
# Updated session metrics for user 99
# Updated session metrics for user 100
# Updated session metrics for user 101
# Updated session metrics for user 102
# Updated session metrics for user 103
# Updated session metrics for user 104
# Updated session metrics for user 105
# Updated session metrics for user 106
# Updated session metrics for user 107
# Updated session metrics for user 108
# Updated session metrics for user 109
# Updated session metrics for user 110
# Updated session metrics for user 111
# Updated session metrics for user 112
# Updated session metrics for user 113
# Updated session metrics for user 114
# Updated session metrics for user 115
# Updated session metrics for user 116
# Updated session metrics for user 117
# Updated session metrics for user 118
# Updated session metrics for user 119
# Updated session metrics for user 120
# Updated session metrics for user 121
# Updated session metrics for user 122
# Updated session metrics for user 123
# Updated session metrics for user 124
# Updated session metrics for user 125
# Updated session metrics for user 126
# Updated session metrics for user 127
# Updated session metrics for user 128
# Updated session metrics for user 129
# Updated session metrics for user 130
# Updated session metrics for user 131
# Updated session metrics for user 132
# Updated session metrics for user 133
# Updated session metrics for user 134
# Updated session metrics for user 135
# Updated session metrics for user 136
# Updated session metrics for user 137
# Updated session metrics for user 138
# Updated session metrics for user 139
# Updated session metrics for user 140
# Updated session metrics for user 141
# Updated session metrics for user 142
# Updated session metrics for user 143
# Updated session metrics for user 144
# Updated session metrics for user 145
# Updated session metrics for user 146
# Updated session metrics for user 147
# Updated session metrics for user 148
# Updated session metrics for user 149
# Updated session metrics for user 150
# Updated session metrics for user 151
# Updated session metrics for user 152
# Updated session metrics for user 153
# Updated session metrics for user 154
# Updated session metrics for user 155
# Updated session metrics for user 156
# Updated session metrics for user 157
# Updated session metrics for user 158
# Updated session metrics for user 159
# Updated session metrics for user 160
# Updated session metrics for user 161
# Updated session metrics for user 162
# Updated session metrics for user 163
# Updated session metrics for user 164
# Updated session metrics for user 165
# Updated session metrics for user 166
# Updated session metrics for user 167
# Updated session metrics for user 168
# Updated session metrics for user 169
# Updated session metrics for user 170
# Updated session metrics for user 171
# Updated session metrics for user 172
# Updated session metrics for user 173
# Updated session metrics for user 174
# Updated session metrics for user 175
# Updated session metrics for user 176
# Updated session metrics for user 177
# Updated session metrics for user 178
# Updated session metrics for user 179
# Updated session metrics for user 180
# Updated session metrics for user 181
# Updated session metrics for user 182
# Updated session metrics for user 183
# Updated session metrics for user 184
# Updated session metrics for user 185
# Updated session metrics for user 186
# Updated session metrics for user 187
# Updated session metrics for user 188
# Updated session metrics for user 189
# Updated session metrics for user 190
# Updated session metrics for user 191
# Updated session metrics for user 192
# Updated session metrics for user 193
# Updated session metrics for user 194
# Updated session metrics for user 195
# Updated session metrics for user 196
# Updated session metrics for user 197
# Updated session metrics for user 198
# Updated session metrics for user 199
# Updated session metrics for user 200
# Updated session metrics for user 201
# Updated session metrics for user 202
# Updated session metrics for user 203
# Updated session metrics for user 204
# Updated session metrics for user 205
# Updated session metrics for user 206
# Updated session metrics for user 207
# Updated session metrics for user 208
# Updated session metrics for user 209
# Updated session metrics for user 210
# Updated session metrics for user 211
# Updated session metrics for user 212
# Updated session metrics for user 213
# Updated session metrics for user 214
# Updated session metrics for user 215
# Updated session metrics for user 216
# Updated session metrics for user 217
# Updated session metrics for user 218
# Updated session metrics for user 219
# Updated session metrics for user 220
# Updated session metrics for user 221
# Updated session metrics for user 222
# Updated session metrics for user 223
# Updated session metrics for user 224
# Updated session metrics for user 225
# Updated session metrics for user 226
# Updated session metrics for user 227
# Updated session metrics for user 228
# Updated session metrics for user 229
# Updated session metrics for user 230
# Updated session metrics for user 231
# Updated session metrics for user 232
# Updated session metrics for user 233
# Updated session metrics for user 234
# Updated session metrics for user 235
# Updated session metrics for user 236
# Updated session metrics for user 237
# Updated session metrics for user 238
# Updated session metrics for user 239
# Updated session metrics for user 240
# Updated session metrics for user 241
# Updated session metrics for user 242
# Updated session metrics for user 243
# Updated session metrics for user 244
# Updated session metrics for user 245
# Updated session metrics for user 246
# Updated session metrics for user 247
# Updated session metrics for user 248
# Updated session metrics for user 249
# Updated session metrics for user 250
# Updated session metrics for user 251
# Updated session metrics for user 252
# Updated session metrics for user 253
# Updated session metrics for user 254
# Updated session metrics for user 255
# Updated session metrics for user 256
# Updated session metrics for user 257
# Updated session metrics for user 258
# Updated session metrics for user 259
# Updated session metrics for user 260
# Updated session metrics for user 261
# Updated session metrics for user 262
# Updated session metrics for user 263
# Updated session metrics for user 264
# Updated session metrics for user 265
# Updated session metrics for user 266
# Updated session metrics for user 267
# Updated session metrics for user 268
# Updated session metrics for user 269
# Updated session metrics for user 270
# Updated session metrics for user 271
# Updated session metrics for user 272
# Updated session metrics for user 273
# Updated session metrics for user 274
# Updated session metrics for user 275
# Updated session metrics for user 276
# Updated session metrics for user 277
# Updated session metrics for user 278
# Updated session metrics for user 279
# Updated session metrics for user 280
# Updated session metrics for user 281
# Updated session metrics for user 282
# Updated session metrics for user 283
# Updated session metrics for user 284
# Updated session metrics for user 285
# Updated session metrics for user 286
# Updated session metrics for user 287
# Updated session metrics for user 288
# Updated session metrics for user 289
# Updated session metrics for user 290
# Updated session metrics for user 291
# Updated session metrics for user 292
# Updated session metrics for user 293
# Updated session metrics for user 294
# Updated session metrics for user 295
# Updated session metrics for user 296
# Updated session metrics for user 297
# Updated session metrics for user 298
# Updated session metrics for user 299
# Updated session metrics for user 300
# Updated session metrics for user 301
# Updated session metrics for user 302
# Updated session metrics for user 303
# Updated session metrics for user 304
# Updated session metrics for user 305
# Updated session metrics for user 306
# Updated session metrics for user 307
# Updated session metrics for user 308
# Updated session metrics for user 309
# Updated session metrics for user 310
# Updated session metrics for user 311
# Updated session metrics for user 312
# Updated session metrics for user 313
# Updated session metrics for user 314
# Updated session metrics for user 315
# Updated session metrics for user 316
# Updated session metrics for user 317
# Updated session metrics for user 318
# Updated session metrics for user 319
# Updated session metrics for user 320
# Updated session metrics for user 321
# Updated session metrics for user 322
# Updated session metrics for user 323
# Updated session metrics for user 324
# Updated session metrics for user 325
# Updated session metrics for user 326
# Updated session metrics for user 327
# Updated session metrics for user 328
# Updated session metrics for user 329
# Updated session metrics for user 330
# Updated session metrics for user 331
# Updated session metrics for user 332
# Updated session metrics for user 333
# Updated session metrics for user 334
# Updated session metrics for user 335
# Updated session metrics for user 336
# Updated session metrics for user 337
# Updated session metrics for user 338
# Updated session metrics for user 339
# Updated session metrics for user 340
# Updated session metrics for user 341
# Updated session metrics for user 342
# Updated session metrics for user 343
# Updated session metrics for user 344
# Updated session metrics for user 345
# Updated session metrics for user 346
# Updated session metrics for user 347
# Updated session metrics for user 348
# Updated session metrics for user 349
# Updated session metrics for user 350
# Updated session metrics for user 351
# Updated session metrics for user 352
# Updated session metrics for user 353
# Updated session metrics for user 354
# Updated session metrics for user 355
# Updated session metrics for user 356
# Updated session metrics for user 357
# Updated session metrics for user 358
# Updated session metrics for user 359
# Updated session metrics for user 360
# Updated session metrics for user 361
# Updated session metrics for user 362
# Updated session metrics for user 363
# Updated session metrics for user 364
# Updated session metrics for user 365
# Updated session metrics for user 366
# Updated session metrics for user 367
# Updated session metrics for user 368
# Updated session metrics for user 369
# Updated session metrics for user 370
# Updated session metrics for user 371
# Updated session metrics for user 372
# Updated session metrics for user 373
# Updated session metrics for user 374
# Updated session metrics for user 375
# Updated session metrics for user 376
# Updated session metrics for user 377
# Updated session metrics for user 378
# Updated session metrics for user 379
# Updated session metrics for user 380
# Updated session metrics for user 381
# Updated session metrics for user 382
# Updated session metrics for user 383
# Updated session metrics for user 384
# Updated session metrics for user 385
# Updated session metrics for user 386
# Updated session metrics for user 387
# Updated session metrics for user 388
# Updated session metrics for user 389
# Updated session metrics for user 390
# Updated session metrics for user 391
# Updated session metrics for user 392
# Updated session metrics for user 393
# Updated session metrics for user 394
# Updated session metrics for user 395
# Updated session metrics for user 396
# Updated session metrics for user 397
# Updated session metrics for user 398
# Updated session metrics for user 399
# Updated session metrics for user 400
# Updated session metrics for user 401
# Updated session metrics for user 402
# Updated session metrics for user 403
# Updated session metrics for user 404
# Updated session metrics for user 405
# Updated session metrics for user 406
# Updated session metrics for user 407
# Updated session metrics for user 408
# Updated session metrics for user 409
# Updated session metrics for user 410
# Updated session metrics for user 411
# Updated session metrics for user 412
# Updated session metrics for user 413
# Updated session metrics for user 414
# Updated session metrics for user 415
# Updated session metrics for user 416
# Updated session metrics for user 417
# Updated session metrics for user 418
# Updated session metrics for user 419
# Updated session metrics for user 420
# Updated session metrics for user 421
# Updated session metrics for user 422
# Updated session metrics for user 423
# Updated session metrics for user 424
# Updated session metrics for user 425
# Updated session metrics for user 426
# Updated session metrics for user 427
# Updated session metrics for user 428
# Updated session metrics for user 429
# Updated session metrics for user 430
# Updated session metrics for user 431
# Updated session metrics for user 432
# Updated session metrics for user 433
# Updated session metrics for user 434
# Updated session metrics for user 435
# Updated session metrics for user 436
# Updated session metrics for user 437
# Updated session metrics for user 438
# Updated session metrics for user 439
# Updated session metrics for user 440
# Updated session metrics for user 441
# Updated session metrics for user 442
# Updated session metrics for user 443
# Updated session metrics for user 444
# Updated session metrics for user 445
# Updated session metrics for user 446
# Updated session metrics for user 447
# Updated session metrics for user 448
# Updated session metrics for user 449
# Updated session metrics for user 450
# Updated session metrics for user 451
# Updated session metrics for user 452
# Updated session metrics for user 453
# Updated session metrics for user 454
# Updated session metrics for user 455
# Updated session metrics for user 456
# Updated session metrics for user 457
# Updated session metrics for user 458
# Updated session metrics for user 459
# Updated session metrics for user 460
# Updated session metrics for user 461
# Updated session metrics for user 462
# Updated session metrics for user 463
# Updated session metrics for user 464
# Updated session metrics for user 465
# Updated session metrics for user 466
# Updated session metrics for user 467
# Updated session metrics for user 468
# Updated session metrics for user 469
# Updated session metrics for user 470
# Updated session metrics for user 471
# Updated session metrics for user 472
# Updated session metrics for user 473
# Updated session metrics for user 474
# Updated session metrics for user 475
# Updated session metrics for user 476
# Updated session metrics for user 477
# Updated session metrics for user 478
# Updated session metrics for user 479
# Updated session metrics for user 480
# Updated session metrics for user 481
# Updated session metrics for user 482
# Updated session metrics for user 483
# Updated session metrics for user 484
# Updated session metrics for user 485
# Updated session metrics for user 486
# Updated session metrics for user 487
# Updated session metrics for user 488
# Updated session metrics for user 489
# Updated session metrics for user 490
# Updated session metrics for user 491
# Updated session metrics for user 492
# Updated session metrics for user 493
# Updated session metrics for user 494
# Updated session metrics for user 495
# Updated session metrics for user 496
# Updated session metrics for user 497
# Updated session metrics for user 498
# Updated session metrics for user 499
# Updated session metrics for user 500
# Updated session metrics for user 501
# Updated session metrics for user 502
# Updated session metrics for user 503
# Updated session metrics for user 504
# Updated session metrics for user 505
# Updated session metrics for user 506
# Updated session metrics for user 507
# Updated session metrics for user 508
# Updated session metrics for user 509
# Updated session metrics for user 510
# Updated session metrics for user 511
# Updated session metrics for user 512
# Updated session metrics for user 513
# Updated session metrics for user 514
# Updated session metrics for user 515
# Updated session metrics for user 516
# Updated session metrics for user 517
# Updated session metrics for user 518
# Updated session metrics for user 519
# Updated session metrics for user 520
# Updated session metrics for user 521
# Updated session metrics for user 522
# Updated session metrics for user 523
# Updated session metrics for user 524
# Updated session metrics for user 525
# Updated session metrics for user 526
# Updated session metrics for user 527
# Updated session metrics for user 528
# Updated session metrics for user 529
# Updated session metrics for user 530
# Updated session metrics for user 531
# Updated session metrics for user 532
# Updated session metrics for user 533
# Updated session metrics for user 534
# Updated session metrics for user 535
# Updated session metrics for user 536
# Updated session metrics for user 537
# Updated session metrics for user 538
# Updated session metrics for user 539
# Updated session metrics for user 540
# Updated session metrics for user 541
# Updated session metrics for user 542
# Updated session metrics for user 543
# Updated session metrics for user 544
# Updated session metrics for user 545
# Updated session metrics for user 546
# Updated session metrics for user 547
# Updated session metrics for user 548
# Updated session metrics for user 549
# Updated session metrics for user 550
# Updated session metrics for user 551
# Updated session metrics for user 552
# Updated session metrics for user 553
# Updated session metrics for user 554
# Updated session metrics for user 555
# Updated session metrics for user 556
# Updated session metrics for user 557
# Updated session metrics for user 558
# Updated session metrics for user 559
# Updated session metrics for user 560
# Updated session metrics for user 561
# Updated session metrics for user 562
# Updated session metrics for user 563
# Updated session metrics for user 564
# Updated session metrics for user 565
# Updated session metrics for user 566
# Updated session metrics for user 567
# Updated session metrics for user 568
# Updated session metrics for user 569
# Updated session metrics for user 570
# Updated session metrics for user 571
# Updated session metrics for user 572
# Updated session metrics for user 573
# Updated session metrics for user 574
# Updated session metrics for user 575
# Updated session metrics for user 576
# Updated session metrics for user 577
# Updated session metrics for user 578
# Updated session metrics for user 579
# Updated session metrics for user 580
# Updated session metrics for user 581
# Updated session metrics for user 582
# Updated session metrics for user 583
# Updated session metrics for user 584
# Updated session metrics for user 585
# Updated session metrics for user 586
# Updated session metrics for user 587
# Updated session metrics for user 588
# Updated session metrics for user 589
# Updated session metrics for user 590
# Updated session metrics for user 591
# Updated session metrics for user 592
# Updated session metrics for user 593
# Updated session metrics for user 594
# Updated session metrics for user 595
# Updated session metrics for user 596
# Updated session metrics for user 597
# Updated session metrics for user 598
# Updated session metrics for user 599
# Updated session metrics for user 600
# Updated session metrics for user 601
# Updated session metrics for user 602
# Updated session metrics for user 603
# Updated session metrics for user 604
# Updated session metrics for user 605
# Updated session metrics for user 606
# Updated session metrics for user 607
# Updated session metrics for user 608
# Updated session metrics for user 609
# Updated session metrics for user 610
# Updated session metrics for user 611
# Updated session metrics for user 612
# Updated session metrics for user 613
# Updated session metrics for user 614
# Updated session metrics for user 615
# Updated session metrics for user 616
# Updated session metrics for user 617
# Updated session metrics for user 618
# Updated session metrics for user 619
# Updated session metrics for user 620
# Updated session metrics for user 621
# Updated session metrics for user 622
# Updated session metrics for user 623
# Updated session metrics for user 624
# Updated session metrics for user 625
# Updated session metrics for user 626
# Updated session metrics for user 627
# Updated session metrics for user 628
# Updated session metrics for user 629
# Updated session metrics for user 630
# Updated session metrics for user 631
# Updated session metrics for user 632
# Updated session metrics for user 633
# Updated session metrics for user 634
# Updated session metrics for user 635
# Updated session metrics for user 636
# Updated session metrics for user 637
# Updated session metrics for user 638
# Updated session metrics for user 639
# Updated session metrics for user 640
# Updated session metrics for user 641
# Updated session metrics for user 642
# Updated session metrics for user 643
# Updated session metrics for user 644
# Updated session metrics for user 645
# Updated session metrics for user 646
# Updated session metrics for user 647
# Updated session metrics for user 648
# Updated session metrics for user 649
# Updated session metrics for user 650
# Updated session metrics for user 651
# Updated session metrics for user 652
# Updated session metrics for user 653
# Updated session metrics for user 654
# Updated session metrics for user 655
# Updated session metrics for user 656
# Updated session metrics for user 657
# Updated session metrics for user 658
# Updated session metrics for user 659
# Updated session metrics for user 660
# Updated session metrics for user 661
# Updated session metrics for user 662
# Updated session metrics for user 663
# Updated session metrics for user 664
# Updated session metrics for user 665
# Updated session metrics for user 666
# Updated session metrics for user 667
# Updated session metrics for user 668
# Updated session metrics for user 669
# Updated session metrics for user 670
# Updated session metrics for user 671
# Updated session metrics for user 672
# Updated session metrics for user 673
# Updated session metrics for user 674
# Updated session metrics for user 675
# Updated session metrics for user 676
# Updated session metrics for user 677
# Updated session metrics for user 678
# Updated session metrics for user 679
# Updated session metrics for user 680
# Updated session metrics for user 681
# Updated session metrics for user 682
# Updated session metrics for user 683
# Updated session metrics for user 684
# Updated session metrics for user 685
# Updated session metrics for user 686
# Updated session metrics for user 687
# Updated session metrics for user 688
# Updated session metrics for user 689
# Updated session metrics for user 690
# Updated session metrics for user 691
# Updated session metrics for user 692
# Updated session metrics for user 693
# Updated session metrics for user 694
# Updated session metrics for user 695
# Updated session metrics for user 696
# Updated session metrics for user 697
# Updated session metrics for user 698
# Updated session metrics for user 699
# Updated session metrics for user 700
# Updated session metrics for user 701
# Updated session metrics for user 702
# Updated session metrics for user 703
# Updated session metrics for user 704
# Updated session metrics for user 705
# Updated session metrics for user 706
# Updated session metrics for user 707
# Updated session metrics for user 708
# Updated session metrics for user 709
# Updated session metrics for user 710
# Updated session metrics for user 711
# Updated session metrics for user 712
# Updated session metrics for user 713
# Updated session metrics for user 714
# Updated session metrics for user 715
# Updated session metrics for user 716
# Updated session metrics for user 717
# Updated session metrics for user 718
# Updated session metrics for user 719
# Updated session metrics for user 720
# Updated session metrics for user 721
# Updated session metrics for user 722
# Updated session metrics for user 723
# Updated session metrics for user 724
# Updated session metrics for user 725
# Updated session metrics for user 726
# Updated session metrics for user 727
# Updated session metrics for user 728
# Updated session metrics for user 729
# Updated session metrics for user 730
# Updated session metrics for user 731
# Updated session metrics for user 732
# Updated session metrics for user 733
# Updated session metrics for user 734
# Updated session metrics for user 735
# Updated session metrics for user 736
# Updated session metrics for user 737
# Updated session metrics for user 738
# Updated session metrics for user 739
# Updated session metrics for user 740
# Updated session metrics for user 741
# Updated session metrics for user 742
# Updated session metrics for user 743
# Updated session metrics for user 744
# Updated session metrics for user 745
# Updated session metrics for user 746
# Updated session metrics for user 747
# Updated session metrics for user 748
# Updated session metrics for user 749
# Updated session metrics for user 750
# Updated session metrics for user 751
# Updated session metrics for user 752
# Updated session metrics for user 753
# Updated session metrics for user 754
# Updated session metrics for user 755
# Updated session metrics for user 756
# Updated session metrics for user 757
# Updated session metrics for user 758
# Updated session metrics for user 759
# Updated session metrics for user 760
# Updated session metrics for user 761
# Updated session metrics for user 762
# Updated session metrics for user 763
# Updated session metrics for user 764
# Updated session metrics for user 765
# Updated session metrics for user 766
# Updated session metrics for user 767
# Updated session metrics for user 768
# Updated session metrics for user 769
# Updated session metrics for user 770
# Updated session metrics for user 771
# Updated session metrics for user 772
# Updated session metrics for user 773
# Updated session metrics for user 774
# Updated session metrics for user 775
# Updated session metrics for user 776
# Updated session metrics for user 777
# Updated session metrics for user 778
# Updated session metrics for user 779
# Updated session metrics for user 780
# Updated session metrics for user 781
# Updated session metrics for user 782
# Updated session metrics for user 783
# Updated session metrics for user 784
# Updated session metrics for user 785
# Updated session metrics for user 786
# Updated session metrics for user 787
# Updated session metrics for user 788
# Updated session metrics for user 789
# Updated session metrics for user 790
# Updated session metrics for user 791
# Updated session metrics for user 792
# Updated session metrics for user 793
# Updated session metrics for user 794
# Updated session metrics for user 795
# Updated session metrics for user 796
# Updated session metrics for user 797
# Updated session metrics for user 798
# Updated session metrics for user 799
# Updated session metrics for user 800
# Updated session metrics for user 801
# Updated session metrics for user 802
# Updated session metrics for user 803
# Updated session metrics for user 804
# Updated session metrics for user 805
# Updated session metrics for user 806
# Updated session metrics for user 807
# Updated session metrics for user 808
# Updated session metrics for user 809
# Updated session metrics for user 810
# Updated session metrics for user 811
# Updated session metrics for user 812
# Updated session metrics for user 813
# Updated session metrics for user 814
# Updated session metrics for user 815
# Updated session metrics for user 816
# Updated session metrics for user 817
# Updated session metrics for user 818
# Updated session metrics for user 819
# Updated session metrics for user 820
# Updated session metrics for user 821
# Updated session metrics for user 822
# Updated session metrics for user 823
# Updated session metrics for user 824
# Updated session metrics for user 825
# Updated session metrics for user 826
# Updated session metrics for user 827
# Updated session metrics for user 828
# Updated session metrics for user 829
# Updated session metrics for user 830
# Updated session metrics for user 831
# Updated session metrics for user 832
# Updated session metrics for user 833
# Updated session metrics for user 834
# Updated session metrics for user 835
# Updated session metrics for user 836
# Updated session metrics for user 837
# Updated session metrics for user 838
# Updated session metrics for user 839
# Updated session metrics for user 840
# Updated session metrics for user 841
# Updated session metrics for user 842
# Updated session metrics for user 843
# Updated session metrics for user 844
# Updated session metrics for user 845
# Updated session metrics for user 846
# Updated session metrics for user 847
# Updated session metrics for user 848
# Updated session metrics for user 849
# Updated session metrics for user 850
# Updated session metrics for user 851
# Updated session metrics for user 852
# Updated session metrics for user 853
# Updated session metrics for user 854
# Updated session metrics for user 855
# Updated session metrics for user 856
# Updated session metrics for user 857
# Updated session metrics for user 858
# Updated session metrics for user 859
# Updated session metrics for user 860
# Updated session metrics for user 861
# Updated session metrics for user 862
# Updated session metrics for user 863
# Updated session metrics for user 864
# Updated session metrics for user 865
# Updated session metrics for user 866
# Updated session metrics for user 867
# Updated session metrics for user 868
# Updated session metrics for user 869
# Updated session metrics for user 870
# Updated session metrics for user 871
# Updated session metrics for user 872
# Updated session metrics for user 873
# Updated session metrics for user 874
# Updated session metrics for user 875
# Updated session metrics for user 876
# Updated session metrics for user 877
# Updated session metrics for user 878
# Updated session metrics for user 879
# Updated session metrics for user 880
# Updated session metrics for user 881
# Updated session metrics for user 882
# Updated session metrics for user 883
# Updated session metrics for user 884
# Updated session metrics for user 885
# Updated session metrics for user 886
# Updated session metrics for user 887
# Updated session metrics for user 888
# Updated session metrics for user 889
# Updated session metrics for user 890
# Updated session metrics for user 891
# Updated session metrics for user 892
# Updated session metrics for user 893
# Updated session metrics for user 894
# Updated session metrics for user 895
# Updated session metrics for user 896
# Updated session metrics for user 897
# Updated session metrics for user 898
# Updated session metrics for user 899
# Updated session metrics for user 900
# Updated session metrics for user 901
# Updated session metrics for user 902
# Updated session metrics for user 903
# Updated session metrics for user 904
# Updated session metrics for user 905
# Updated session metrics for user 906
# Updated session metrics for user 907
# Updated session metrics for user 908
# Updated session metrics for user 909
# Updated session metrics for user 910
# Updated session metrics for user 911
# Updated session metrics for user 912
# Updated session metrics for user 913
# Updated session metrics for user 914
# Updated session metrics for user 915
# Updated session metrics for user 916
# Updated session metrics for user 917
# Updated session metrics for user 918
# Updated session metrics for user 919
# Updated session metrics for user 920
# Updated session metrics for user 921
# Updated session metrics for user 922
# Updated session metrics for user 923
# Updated session metrics for user 924
# Updated session metrics for user 925
# Updated session metrics for user 926
# Updated session metrics for user 927
# Updated session metrics for user 928
# Updated session metrics for user 929
# Updated session metrics for user 930
# Updated session metrics for user 931
# Updated session metrics for user 932
# Updated session metrics for user 933
# Updated session metrics for user 934
# Updated session metrics for user 935
# Updated session metrics for user 936
# Updated session metrics for user 937
# Updated session metrics for user 938
# Updated session metrics for user 939
# Updated session metrics for user 940
# Updated session metrics for user 941
# Updated session metrics for user 942
# Updated session metrics for user 943
# Updated session metrics for user 944
# Updated session metrics for user 945
# Updated session metrics for user 946
# Updated session metrics for user 947
# Updated session metrics for user 948
# Updated session metrics for user 949
# Updated session metrics for user 950
# Updated session metrics for user 951
# Updated session metrics for user 952
# Updated session metrics for user 953
# Updated session metrics for user 954
# Updated session metrics for user 955
# Updated session metrics for user 956
# Updated session metrics for user 957
# Updated session metrics for user 958
# Updated session metrics for user 959
# Updated session metrics for user 960
# Updated session metrics for user 961
# Updated session metrics for user 962
# Updated session metrics for user 963
# Updated session metrics for user 964
# Updated session metrics for user 965
# Updated session metrics for user 966
# Updated session metrics for user 967
# Updated session metrics for user 968
# Updated session metrics for user 969
# Updated session metrics for user 970
# Updated session metrics for user 971
# Updated session metrics for user 972
# Updated session metrics for user 973
# Updated session metrics for user 974
# Updated session metrics for user 975
# Updated session metrics for user 976
# Updated session metrics for user 977
# Updated session metrics for user 978
# Updated session metrics for user 979
# Updated session metrics for user 980
# Updated session metrics for user 981
# Updated session metrics for user 982
# Updated session metrics for user 983
# Updated session metrics for user 984
# Updated session metrics for user 985
# Updated session metrics for user 986
# Updated session metrics for user 987
# Updated session metrics for user 988
# Updated session metrics for user 989
# Updated session metrics for user 990
# Updated session metrics for user 991
# Updated session metrics for user 992
# Updated session metrics for user 993
# Updated session metrics for user 994
# Updated session metrics for user 995
# Updated session metrics for user 996
# Updated session metrics for user 997
# Updated session metrics for user 998
# Updated session metrics for user 999
# Updated session metrics for user 1000
# Updated session metrics for user 1001
# Updated session metrics for user 1002
# Updated session metrics for user 1003
# Updated session metrics for user 1004
# Updated session metrics for user 1005
# Updated session metrics for user 1006
# Updated session metrics for user 1007
# Updated session metrics for user 1008
# Updated session metrics for user 1009
# Updated session metrics for user 1010
# Updated session metrics for user 1011
# Updated session metrics for user 1012
# Updated session metrics for user 1013
# Updated session metrics for user 1014
# Updated session metrics for user 1015
# Updated session metrics for user 1016
# Updated session metrics for user 1017
# Updated session metrics for user 1018
# Updated session metrics for user 1019
# Updated session metrics for user 1020
# Updated session metrics for user 1021
# Updated session metrics for user 1022
# Updated session metrics for user 1023
# Updated session metrics for user 1024
# Updated session metrics for user 1025
# Updated session metrics for user 1026
# Updated session metrics for user 1027
# Updated session metrics for user 1028
# Updated session metrics for user 1029
# Updated session metrics for user 1030
# Updated session metrics for user 1031
# Updated session metrics for user 1032
# Updated session metrics for user 1033
# Updated session metrics for user 1034
# Updated session metrics for user 1035
# Updated session metrics for user 1036
# Updated session metrics for user 1037
# Updated session metrics for user 1038
# Updated session metrics for user 1039
# Updated session metrics for user 1040
# Updated session metrics for user 1041
# Updated session metrics for user 1042
# Updated session metrics for user 1043
# Updated session metrics for user 1044
# Updated session metrics for user 1045
# Updated session metrics for user 1046
# Updated session metrics for user 1047
# Updated session metrics for user 1048
# Updated session metrics for user 1049
# Updated session metrics for user 1050
# Updated session metrics for user 1051
# Updated session metrics for user 1052
# Updated session metrics for user 1053
# Updated session metrics for user 1054
# Updated session metrics for user 1055
# Updated session metrics for user 1056
# Updated session metrics for user 1057
# Updated session metrics for user 1058
# Updated session metrics for user 1059
# Updated session metrics for user 1060
# Updated session metrics for user 1061
# Updated session metrics for user 1062
# Updated session metrics for user 1063
# Updated session metrics for user 1064
# Updated session metrics for user 1065
# Updated session metrics for user 1066
# Updated session metrics for user 1067
# Updated session metrics for user 1068
# Updated session metrics for user 1069
# Updated session metrics for user 1070
# Updated session metrics for user 1071
# Updated session metrics for user 1072
# Updated session metrics for user 1073
# Updated session metrics for user 1074
# Updated session metrics for user 1075
# Updated session metrics for user 1076
# Updated session metrics for user 1077
# Updated session metrics for user 1078
# Updated session metrics for user 1079
# Updated session metrics for user 1080
# Updated session metrics for user 1081
# Updated session metrics for user 1082
# Updated session metrics for user 1083
# Updated session metrics for user 1084
# Updated session metrics for user 1085
# Updated session metrics for user 1086
# Updated session metrics for user 1087
# Updated session metrics for user 1088
# Updated session metrics for user 1089
# Updated session metrics for user 1090
# Updated session metrics for user 1091
# Updated session metrics for user 1092
# Updated session metrics for user 1093
# Updated session metrics for user 1094
# Completed batch up to user 1094
# Updated session metrics for user 1095
# Updated session metrics for user 1096
# Updated session metrics for user 1097
# Updated session metrics for user 1098
# Updated session metrics for user 1099
# Updated session metrics for user 1100
# Updated session metrics for user 1101
# Updated session metrics for user 1102
# Updated session metrics for user 1103
# Updated session metrics for user 1104
# Updated session metrics for user 1105
# Updated session metrics for user 1106
# Updated session metrics for user 1107
# Updated session metrics for user 1108
# Updated session metrics for user 1109
# Updated session metrics for user 1110
# Updated session metrics for user 1111
# Updated session metrics for user 1112
# Updated session metrics for user 1113
# Updated session metrics for user 1114
# Updated session metrics for user 1115
# Updated session metrics for user 1116
# Updated session metrics for user 1117
# Updated session metrics for user 1118
# Updated session metrics for user 1119
# Updated session metrics for user 1120
# Updated session metrics for user 1121
# Updated session metrics for user 1122
# Updated session metrics for user 1123
# Updated session metrics for user 1124
# Updated session metrics for user 1125
# Updated session metrics for user 1126
# Updated session metrics for user 1127
# Updated session metrics for user 1128
# Updated session metrics for user 1129
# Updated session metrics for user 1130
# Updated session metrics for user 1131
# Updated session metrics for user 1132
# Updated session metrics for user 1133
# Updated session metrics for user 1134
# Updated session metrics for user 1135
# Updated session metrics for user 1136
# Updated session metrics for user 1137
# Updated session metrics for user 1138
# Updated session metrics for user 1139
# Updated session metrics for user 1140
# Updated session metrics for user 1141
# Updated session metrics for user 1142
# Updated session metrics for user 1143
# Updated session metrics for user 1144
# Updated session metrics for user 1145
# Updated session metrics for user 1146
# Updated session metrics for user 1147
# Updated session metrics for user 1148
# Updated session metrics for user 1149
# Updated session metrics for user 1150
# Updated session metrics for user 1151
# Updated session metrics for user 1152
# Updated session metrics for user 1153
# Updated session metrics for user 1154
# Updated session metrics for user 1155
# Updated session metrics for user 1156
# Updated session metrics for user 1157
# Updated session metrics for user 1158
# Updated session metrics for user 1159
# Updated session metrics for user 1160
# Updated session metrics for user 1161
# Updated session metrics for user 1162
# Updated session metrics for user 1163
# Updated session metrics for user 1164
# Updated session metrics for user 1165
# Updated session metrics for user 1166
# Updated session metrics for user 1167
# Updated session metrics for user 1168
# Updated session metrics for user 1169
# Updated session metrics for user 1170
# Updated session metrics for user 1171
# Updated session metrics for user 1172
# Updated session metrics for user 1173
# Updated session metrics for user 1174
# Updated session metrics for user 1175
# Updated session metrics for user 1176
# Updated session metrics for user 1177
# Updated session metrics for user 1178
# Updated session metrics for user 1179
# Updated session metrics for user 1180
# Updated session metrics for user 1181
# Updated session metrics for user 1182
# Updated session metrics for user 1183
# Updated session metrics for user 1184
# Updated session metrics for user 1185
# Updated session metrics for user 1186
# Updated session metrics for user 1187
# Updated session metrics for user 1188
# Updated session metrics for user 1189
# Updated session metrics for user 1190
# Updated session metrics for user 1191
# Updated session metrics for user 1192
# Updated session metrics for user 1193
# Updated session metrics for user 1194
# Updated session metrics for user 1195
# Updated session metrics for user 1196
# Updated session metrics for user 1197
# Updated session metrics for user 1198
# Updated session metrics for user 1199
# Updated session metrics for user 1200
# Updated session metrics for user 1201
# Updated session metrics for user 1202
# Updated session metrics for user 1203
# Updated session metrics for user 1204
# Updated session metrics for user 1205
# Updated session metrics for user 1206
# Updated session metrics for user 1207
# Updated session metrics for user 1208
# Updated session metrics for user 1209
# Updated session metrics for user 1210
# Updated session metrics for user 1211
# Updated session metrics for user 1212
# Updated session metrics for user 1213
# Updated session metrics for user 1214
# Updated session metrics for user 1215
# Updated session metrics for user 1216
# Updated session metrics for user 1217
# Updated session metrics for user 1218
# Updated session metrics for user 1219
# Updated session metrics for user 1220
# Updated session metrics for user 1221
# Updated session metrics for user 1222
# Updated session metrics for user 1223
# Updated session metrics for user 1224
# Updated session metrics for user 1225
# Updated session metrics for user 1226
# Updated session metrics for user 1227
# Updated session metrics for user 1228
# Updated session metrics for user 1229
# Updated session metrics for user 1230
# Updated session metrics for user 1231
# Updated session metrics for user 1232
# Updated session metrics for user 1233
# Updated session metrics for user 1234
# Updated session metrics for user 1235
# Updated session metrics for user 1236
# Updated session metrics for user 1237
# Updated session metrics for user 1238
# Updated session metrics for user 1239
# Updated session metrics for user 1240
# Updated session metrics for user 1241
# Updated session metrics for user 1242
# Updated session metrics for user 1243
# Updated session metrics for user 1244
# Updated session metrics for user 1245
# Updated session metrics for user 1246
# Updated session metrics for user 1247
# Updated session metrics for user 1248
# Updated session metrics for user 1249
# Updated session metrics for user 1250
# Updated session metrics for user 1251
# Updated session metrics for user 1252
# Updated session metrics for user 1253
# Updated session metrics for user 1254
# Updated session metrics for user 1255
# Updated session metrics for user 1256
# Updated session metrics for user 1257
# Updated session metrics for user 1258
# Updated session metrics for user 1259
# Updated session metrics for user 1260
# Updated session metrics for user 1261
# Updated session metrics for user 1262
# Updated session metrics for user 1263
# Updated session metrics for user 1264
# Updated session metrics for user 1265
# Updated session metrics for user 1266
# Updated session metrics for user 1267
# Updated session metrics for user 1268
# Updated session metrics for user 1269
# Updated session metrics for user 1270
# Updated session metrics for user 1271
# Updated session metrics for user 1272
# Updated session metrics for user 1273
# Updated session metrics for user 1274
# Updated session metrics for user 1275
# Updated session metrics for user 1276
# Updated session metrics for user 1277
# Updated session metrics for user 1278
# Updated session metrics for user 1279
# Updated session metrics for user 1280
# ...
# Updated session metrics for user 16752
# Updated session metrics for user 16753
# Updated session metrics for user 16754
# Updated session metrics for user 16755
# Updated session metrics for user 16756
# Updated session metrics for user 16757
# Updated session metrics for user 16758
# Updated session metrics for user 16759
# Updated session metrics for user 16760
# Updated session metrics for user 16761
# Updated session metrics for user 16762
# Updated session metrics for user 16763
# Updated session metrics for user 16764
# Updated session metrics for user 16765
# Updated session metrics for user 16766
# Updated session metrics for user 16767
# Updated session metrics for user 16768
# Updated session metrics for user 16769
# Updated session metrics for user 16770
# Updated session metrics for user 16771
# Updated session metrics for user 16772
# Updated session metrics for user 16773
# Updated session metrics for user 16774
# Updated session metrics for user 16775
# Updated session metrics for user 16776
# Updated session metrics for user 16777
# Updated session metrics for user 16778
# Updated session metrics for user 16779
# Updated session metrics for user 16780
# Updated session metrics for user 16781
# Updated session metrics for user 16782
# Updated session metrics for user 16783
# Updated session metrics for user 16784
# Updated session metrics for user 16785
# Updated session metrics for user 16786
# Updated session metrics for user 16787
# Updated session metrics for user 16788
# Updated session metrics for user 16789
# Updated session metrics for user 16790
# Updated session metrics for user 16791
# Updated session metrics for user 16792
# Updated session metrics for user 16793
# Updated session metrics for user 16794
# Updated session metrics for user 16795
# Updated session metrics for user 16796
# Updated session metrics for user 16797
# Updated session metrics for user 16798
# Updated session metrics for user 16799
# Updated session metrics for user 16800
# Updated session metrics for user 16801
# Updated session metrics for user 16802
# Updated session metrics for user 16803
# Updated session metrics for user 16804
# Updated session metrics for user 16805
# Updated session metrics for user 16806
# Updated session metrics for user 16807
# Updated session metrics for user 16808
# Updated session metrics for user 16809
# Updated session metrics for user 16810
# Updated session metrics for user 16811
# Updated session metrics for user 16812
# Updated session metrics for user 16813
# Updated session metrics for user 16814
# Updated session metrics for user 16815
# Updated session metrics for user 16816
# Updated session metrics for user 16817
# Updated session metrics for user 16818
# Updated session metrics for user 16819
# Updated session metrics for user 16820
# Updated session metrics for user 16821
# Updated session metrics for user 16822
# Updated session metrics for user 16823
# Updated session metrics for user 16824
# Updated session metrics for user 16825
# Updated session metrics for user 16826
# Updated session metrics for user 16827
# Updated session metrics for user 16828
# Updated session metrics for user 16829
# Updated session metrics for user 16830
# Updated session metrics for user 16831
# Updated session metrics for user 16832
# Updated session metrics for user 16833
# Updated session metrics for user 16834
# Updated session metrics for user 16835
# Updated session metrics for user 16836
# Updated session metrics for user 16837
# Updated session metrics for user 16838
# Updated session metrics for user 16839
# Updated session metrics for user 16840
# Updated session metrics for user 16841
# Updated session metrics for user 16842
# Updated session metrics for user 16843
# Updated session metrics for user 16844
# Updated session metrics for user 16845
# Updated session metrics for user 16846
# Updated session metrics for user 16847
# Updated session metrics for user 16848
# Updated session metrics for user 16849
# Updated session metrics for user 16850
# Updated session metrics for user 16851
# Updated session metrics for user 16852
# Updated session metrics for user 16853
# Updated session metrics for user 16854
# Updated session metrics for user 16855
# Updated session metrics for user 16856
# Updated session metrics for user 16857
# Updated session metrics for user 16858
# Updated session metrics for user 16859
# Updated session metrics for user 16860
# Updated session metrics for user 16861
# Updated session metrics for user 16862
# Updated session metrics for user 16863
# Updated session metrics for user 16864
# Updated session metrics for user 16865
# Updated session metrics for user 16866
# Updated session metrics for user 16867
# Updated session metrics for user 16868
# Updated session metrics for user 16869
# Updated session metrics for user 16870
# Updated session metrics for user 16871
# Updated session metrics for user 16872
# Updated session metrics for user 16873
# Updated session metrics for user 16874
# Updated session metrics for user 16875
# Updated session metrics for user 16876
# Updated session metrics for user 16877
# Updated session metrics for user 16878
# Updated session metrics for user 16879
# Updated session metrics for user 16880
# Updated session metrics for user 16881
# Updated session metrics for user 16882
# Updated session metrics for user 16883
# Updated session metrics for user 16884
# Updated session metrics for user 16885
# Updated session metrics for user 16886
# Updated session metrics for user 16887
# Updated session metrics for user 16888
# Updated session metrics for user 16889
# Updated session metrics for user 16890
# Updated session metrics for user 16891
# Updated session metrics for user 16892
# Updated session metrics for user 16893
# Updated session metrics for user 16894
# Updated session metrics for user 16895
# Updated session metrics for user 16896
# Updated session metrics for user 16897
# Updated session metrics for user 16898
# Updated session metrics for user 16899
# Updated session metrics for user 16900
# Updated session metrics for user 16901
# Updated session metrics for user 16902
# Updated session metrics for user 16903
# Updated session metrics for user 16904
# Updated session metrics for user 16905
# Updated session metrics for user 16906
# Updated session metrics for user 16907
# Updated session metrics for user 16908
# Updated session metrics for user 16909
# Updated session metrics for user 16910
# Updated session metrics for user 16911
# Updated session metrics for user 16912
# Updated session metrics for user 16913
# Updated session metrics for user 16914
# Updated session metrics for user 16915
# Updated session metrics for user 16916
# Updated session metrics for user 16917
# Updated session metrics for user 16918
# Updated session metrics for user 16919
# Updated session metrics for user 16920
# Updated session metrics for user 16921
# Updated session metrics for user 16922
# Updated session metrics for user 16923
# Updated session metrics for user 16924
# Updated session metrics for user 16925
# Updated session metrics for user 16926
# Updated session metrics for user 16927
# Updated session metrics for user 16928
# Updated session metrics for user 16929
# Updated session metrics for user 16930
# Updated session metrics for user 16931
# Updated session metrics for user 16932
# Updated session metrics for user 16933
# Updated session metrics for user 16934
# Updated session metrics for user 16935
# Updated session metrics for user 16936
# Updated session metrics for user 16937
# Updated session metrics for user 16938
# Updated session metrics for user 16939
# Updated session metrics for user 16940
# Updated session metrics for user 16941
# Updated session metrics for user 16942
# Updated session metrics for user 16943
# Updated session metrics for user 16944
# Updated session metrics for user 16945
# Updated session metrics for user 16946
# Updated session metrics for user 16947
# Updated session metrics for user 16948
# Updated session metrics for user 16949
# Updated session metrics for user 16950
# Updated session metrics for user 16951
# Updated session metrics for user 16952
# Updated session metrics for user 16953
# Updated session metrics for user 16954
# Updated session metrics for user 16955
# Updated session metrics for user 16956
# Updated session metrics for user 16957
# Updated session metrics for user 16958
# Updated session metrics for user 16959
# Updated session metrics for user 16960
# Updated session metrics for user 16961
# Updated session metrics for user 16962
# Updated session metrics for user 16963
# Updated session metrics for user 16964
# Updated session metrics for user 16965
# Updated session metrics for user 16966
# Updated session metrics for user 16967
# Updated session metrics for user 16968
# Updated session metrics for user 16969
# Updated session metrics for user 16970
# Updated session metrics for user 16971
# Updated session metrics for user 16972
# Updated session metrics for user 16973
# Updated session metrics for user 16974
# Updated session metrics for user 16975
# Updated session metrics for user 16976
# Updated session metrics for user 16977
# Updated session metrics for user 16978
# Updated session metrics for user 16979
# Updated session metrics for user 16980
# Updated session metrics for user 16981
# Updated session metrics for user 16982
# Updated session metrics for user 16983
# Updated session metrics for user 16984
# Updated session metrics for user 16985
# Updated session metrics for user 16986
# Updated session metrics for user 16987
# Updated session metrics for user 16988
# Updated session metrics for user 16989
# Updated session metrics for user 16990
# Updated session metrics for user 16991
# Updated session metrics for user 16992
# Updated session metrics for user 16993
# Updated session metrics for user 16994
# Updated session metrics for user 16995
# Updated session metrics for user 16996
# Updated session metrics for user 16997
# Updated session metrics for user 16998
# Updated session metrics for user 16999
# Updated session metrics for user 17000
# Updated session metrics for user 17001
# Updated session metrics for user 17002
# Updated session metrics for user 17003
# Updated session metrics for user 17004
# Updated session metrics for user 17005
# Updated session metrics for user 17006
# Updated session metrics for user 17007
# Updated session metrics for user 17008
# Updated session metrics for user 17009
# Updated session metrics for user 17010
# Updated session metrics for user 17011
# Updated session metrics for user 17012
# Updated session metrics for user 17013
# Updated session metrics for user 17014
# Updated session metrics for user 17015
# Updated session metrics for user 17016
# Updated session metrics for user 17017
# Updated session metrics for user 17018
# Updated session metrics for user 17019
# Updated session metrics for user 17020
# Updated session metrics for user 17021
# Updated session metrics for user 17022
# Updated session metrics for user 17023
# Updated session metrics for user 17024
# Updated session metrics for user 17025
# Updated session metrics for user 17026
# Updated session metrics for user 17027
# Updated session metrics for user 17028
# Updated session metrics for user 17029
# Updated session metrics for user 17030
# Updated session metrics for user 17031
# Updated session metrics for user 17032
# Updated session metrics for user 17033
# Updated session metrics for user 17034
# Updated session metrics for user 17035
# Updated session metrics for user 17036
# Updated session metrics for user 17037
# Updated session metrics for user 17038
# Updated session metrics for user 17039
# Updated session metrics for user 17040
# Updated session metrics for user 17041
# Updated session metrics for user 17042
# Updated session metrics for user 17043
# Updated session metrics for user 17044
# Updated session metrics for user 17045
# Updated session metrics for user 17046
# Updated session metrics for user 17047
# Updated session metrics for user 17048
# Updated session metrics for user 17049
# Updated session metrics for user 17050
# Updated session metrics for user 17051
# Updated session metrics for user 17052
# Updated session metrics for user 17053
# Updated session metrics for user 17054
# Updated session metrics for user 17055
# Updated session metrics for user 17056
# Updated session metrics for user 17057
# Updated session metrics for user 17058
# Updated session metrics for user 17059
# Updated session metrics for user 17060
# Updated session metrics for user 17061
# Updated session metrics for user 17062
# Updated session metrics for user 17063
# Updated session metrics for user 17064
# Updated session metrics for user 17065
# Updated session metrics for user 17066
# Updated session metrics for user 17067
# Updated session metrics for user 17068
# Updated session metrics for user 17069
# Updated session metrics for user 17070
# Updated session metrics for user 17071
# Updated session metrics for user 17072
# Updated session metrics for user 17073
# Updated session metrics for user 17074
# Updated session metrics for user 17075
# Updated session metrics for user 17076
# Updated session metrics for user 17077
# Updated session metrics for user 17078
# Updated session metrics for user 17079
# Updated session metrics for user 17080
# Updated session metrics for user 17081
# Updated session metrics for user 17082
# Updated session metrics for user 17083
# Updated session metrics for user 17084
# Updated session metrics for user 17085
# Completed batch up to user 17085
# Updated session metrics for user 17086
# Updated session metrics for user 17087
# Updated session metrics for user 17088
# Updated session metrics for user 17089
# Updated session metrics for user 17090
# Updated session metrics for user 17091
# Updated session metrics for user 17092
# Updated session metrics for user 17093
# Updated session metrics for user 17094
# Updated session metrics for user 17095
# Updated session metrics for user 17096
# Updated session metrics for user 17097
# Updated session metrics for user 17098
# Updated session metrics for user 17099
# Updated session metrics for user 17100
# Updated session metrics for user 17101
# Updated session metrics for user 17102
# Updated session metrics for user 17103
# Updated session metrics for user 17104
# Updated session metrics for user 17105
# Updated session metrics for user 17106
# Updated session metrics for user 17107
# Updated session metrics for user 17108
# Updated session metrics for user 17109
# Updated session metrics for user 17110
# Updated session metrics for user 17111
# Updated session metrics for user 17112
# Updated session metrics for user 17113
# Updated session metrics for user 17114
# Updated session metrics for user 17115
# Updated session metrics for user 17116
# Updated session metrics for user 17117
# Updated session metrics for user 17118
# Updated session metrics for user 17119
# Updated session metrics for user 17120
# Updated session metrics for user 17121
# Updated session metrics for user 17122
# Updated session metrics for user 17123
# Updated session metrics for user 17124
# Updated session metrics for user 17125
# Updated session metrics for user 17126
# Updated session metrics for user 17127
# Updated session metrics for user 17128
# Updated session metrics for user 17129
# Updated session metrics for user 17130
# Updated session metrics for user 17131
# Updated session metrics for user 17132
# Updated session metrics for user 17133
# Updated session metrics for user 17134
# Updated session metrics for user 17135
# Updated session metrics for user 17136
# Updated session metrics for user 17137
# Updated session metrics for user 17138
# Updated session metrics for user 17139
# Updated session metrics for user 17140
# Updated session metrics for user 17141
# Updated session metrics for user 17142
# Updated session metrics for user 17143
# Updated session metrics for user 17144
# Updated session metrics for user 17145
# Updated session metrics for user 17146
# Updated session metrics for user 17147
# Updated session metrics for user 17148
# Updated session metrics for user 17149
# Updated session metrics for user 17150
# Updated session metrics for user 17151
# Updated session metrics for user 17152
# Updated session metrics for user 17153
# Updated session metrics for user 17154
# Updated session metrics for user 17155
# Updated session metrics for user 17156
# Updated session metrics for user 17157
# Updated session metrics for user 17158
# Completed batch up to user 17158
# Completed updating all users' session metrics

# %%
def update_user_active_periods():
    """Add and update top 5 daily active time periods for each user."""
    try:
        # First, add the column if it doesn't exist
        add_column_sql = """
        DO $$ 
        BEGIN 
            IF NOT EXISTS (
                SELECT 1 FROM information_schema.columns 
                WHERE table_name = 'user_table' AND column_name = 'daily_active_periods'
            ) THEN 
                ALTER TABLE user_table ADD COLUMN daily_active_periods JSONB;
            END IF;
        END $$;
        """
        
        # Execute the column addition
        supabase.postgrest.schema("public").rpc("execute_sql", {"query": add_column_sql}).execute()
        print("Added daily_active_periods column if it didn't exist")

        # Process users in batches
        page_size = 1000
        last_user_id = 0
        
        while True:
            try:
                # Get next batch of users
                users_response = supabase.table("user_table")\
                    .select("user_id, amplitude_id")\
                    .gt("user_id", last_user_id)\
                    .order("user_id")\
                    .limit(page_size)\
                    .execute()
                
                if not users_response.data:
                    break
                
                # Process each user in this batch
                for user in users_response.data:
                    user_id = user["user_id"]
                    amplitude_id = user["amplitude_id"]
                    
                    # Get all events for this user
                    events_response = supabase.table(TABLE_NAME)\
                        .select("event_time")\
                        .eq("amplitude_id", amplitude_id)\
                        .execute()
                    
                    if events_response.data:
                        # Initialize hour counters
                        hour_counts = {str(i).zfill(2): 0 for i in range(24)}
                        
                        # Count events by hour
                        for event in events_response.data:
                            event_time = datetime.fromisoformat(event["event_time"].replace('Z', '+00:00'))
                            hour = str(event_time.hour).zfill(2)
                            hour_counts[hour] += 1
                        
                        # Get only hours with events
                        active_hours = [(hour, count) for hour, count in hour_counts.items() if count > 0]
                        
                        # Sort by count and get top 5
                        top_5_periods = sorted(active_hours, key=lambda x: x[1], reverse=True)[:5]
                        
                        # Format the results
                        active_periods = [
                            {
                                "hour": hour,
                                "count": count,
                                "period": f"{hour}:00-{str((int(hour) + 1) % 24).zfill(2)}:00"
                            }
                            for hour, count in top_5_periods
                        ]
                        
                        # Update user metrics
                        supabase.table("user_table")\
                            .update({"daily_active_periods": active_periods})\
                            .eq("user_id", user_id)\
                            .execute()
                    
                    else:
                        # No events
                        supabase.table("user_table")\
                            .update({"daily_active_periods": []})\
                            .eq("user_id", user_id)\
                            .execute()
                    
                    print(f"Updated active periods for user {user_id}")
                    last_user_id = user_id
                
                print(f"Completed batch up to user {last_user_id}")
                sleep(1)  # Rate limiting

            except Exception as batch_error:
                print(f"Batch error: {batch_error}")
                sleep(5)  # Longer sleep on error
                continue

        print("Completed updating all users' active periods")
        
    except Exception as e:
        print(f"Error updating active periods: {e}")

# Execute the update
update_user_active_periods()
# Out:
# Added daily_active_periods column if it didn't exist
# Batch error: {'code': 'PGRST204', 'details': None, 'hint': None, 'message': "Could not find the 'daily_active_periods' column of 'user_table' in the schema cache"}
# Updated active periods for user 1
# Updated active periods for user 2
# Updated active periods for user 3
# Updated active periods for user 4
# Updated active periods for user 5
# Updated active periods for user 6
# Updated active periods for user 7
# Updated active periods for user 8
# Updated active periods for user 9
# Updated active periods for user 10
# Updated active periods for user 11
# Updated active periods for user 12
# Updated active periods for user 13
# Updated active periods for user 14
# Updated active periods for user 15
# Updated active periods for user 16
# Updated active periods for user 17
# Updated active periods for user 18
# Updated active periods for user 19
# Updated active periods for user 20
# Updated active periods for user 21
# Updated active periods for user 22
# Updated active periods for user 23
# Updated active periods for user 24
# Updated active periods for user 25
# Updated active periods for user 26
# Updated active periods for user 27
# Updated active periods for user 28
# Updated active periods for user 29
# Updated active periods for user 30
# Updated active periods for user 31
# Updated active periods for user 32
# Updated active periods for user 33
# Updated active periods for user 34
# Updated active periods for user 35
# Updated active periods for user 36
# Updated active periods for user 37
# Updated active periods for user 38
# Updated active periods for user 39
# Updated active periods for user 40
# Updated active periods for user 41
# Updated active periods for user 42
# Updated active periods for user 43
# Updated active periods for user 44
# Updated active periods for user 45
# Updated active periods for user 46
# Updated active periods for user 47
# Updated active periods for user 48
# Updated active periods for user 49
# Updated active periods for user 50
# Updated active periods for user 51
# Updated active periods for user 52
# Updated active periods for user 53
# Updated active periods for user 54
# Updated active periods for user 55
# Updated active periods for user 56
# Updated active periods for user 57
# Updated active periods for user 58
# Updated active periods for user 59
# Updated active periods for user 60
# Updated active periods for user 61
# Updated active periods for user 62
# Updated active periods for user 63
# Updated active periods for user 64
# Updated active periods for user 65
# Updated active periods for user 66
# Updated active periods for user 67
# Updated active periods for user 68
# Updated active periods for user 69
# Updated active periods for user 70
# Updated active periods for user 71
# Updated active periods for user 72
# Updated active periods for user 73
# Updated active periods for user 74
# Updated active periods for user 75
# Updated active periods for user 76
# Updated active periods for user 77
# Updated active periods for user 78
# Updated active periods for user 79
# Updated active periods for user 80
# Updated active periods for user 81
# Updated active periods for user 82
# Updated active periods for user 83
# Updated active periods for user 84
# Updated active periods for user 85
# Updated active periods for user 86
# Updated active periods for user 87
# Updated active periods for user 88
# Updated active periods for user 89
# Updated active periods for user 90
# Updated active periods for user 91
# Updated active periods for user 92
# Updated active periods for user 93
# Updated active periods for user 94
# Updated active periods for user 95
# Updated active periods for user 96
# Updated active periods for user 97
# Updated active periods for user 98
# Updated active periods for user 99
# Updated active periods for user 100
# Updated active periods for user 101
# Updated active periods for user 102
# Updated active periods for user 103
# Updated active periods for user 104
# Updated active periods for user 105
# Updated active periods for user 106
# Updated active periods for user 107
# Updated active periods for user 108
# Updated active periods for user 109
# Updated active periods for user 110
# Updated active periods for user 111
# Updated active periods for user 112
# Updated active periods for user 113
# Updated active periods for user 114
# Updated active periods for user 115
# Updated active periods for user 116
# Updated active periods for user 117
# Updated active periods for user 118
# Updated active periods for user 119
# Updated active periods for user 120
# Updated active periods for user 121
# Updated active periods for user 122
# Updated active periods for user 123
# Updated active periods for user 124
# Updated active periods for user 125
# Updated active periods for user 126
# Updated active periods for user 127
# Updated active periods for user 128
# Updated active periods for user 129
# Updated active periods for user 130
# Updated active periods for user 131
# Updated active periods for user 132
# Updated active periods for user 133
# Updated active periods for user 134
# Updated active periods for user 135
# Updated active periods for user 136
# Updated active periods for user 137
# Updated active periods for user 138
# Updated active periods for user 139
# Updated active periods for user 140
# Updated active periods for user 141
# Updated active periods for user 142
# Updated active periods for user 143
# Updated active periods for user 144
# Updated active periods for user 145
# Updated active periods for user 146
# Updated active periods for user 147
# Updated active periods for user 148
# Updated active periods for user 149
# Updated active periods for user 150
# Updated active periods for user 151
# Updated active periods for user 152
# Updated active periods for user 153
# Updated active periods for user 154
# Updated active periods for user 155
# Updated active periods for user 156
# Updated active periods for user 157
# Updated active periods for user 158
# Updated active periods for user 159
# Updated active periods for user 160
# Updated active periods for user 161
# Updated active periods for user 162
# Updated active periods for user 163
# Updated active periods for user 164
# Updated active periods for user 165
# Updated active periods for user 166
# Updated active periods for user 167
# Updated active periods for user 168
# Updated active periods for user 169
# Updated active periods for user 170
# Updated active periods for user 171
# Updated active periods for user 172
# Updated active periods for user 173
# Updated active periods for user 174
# Updated active periods for user 175
# Updated active periods for user 176
# Updated active periods for user 177
# Updated active periods for user 178
# Updated active periods for user 179
# Updated active periods for user 180
# Updated active periods for user 181
# Updated active periods for user 182
# Updated active periods for user 183
# Updated active periods for user 184
# Updated active periods for user 185
# Updated active periods for user 186
# Updated active periods for user 187
# Updated active periods for user 188
# Updated active periods for user 189
# Updated active periods for user 190
# Updated active periods for user 191
# Updated active periods for user 192
# Updated active periods for user 193
# Updated active periods for user 194
# Updated active periods for user 195
# Updated active periods for user 196
# Updated active periods for user 197
# Updated active periods for user 198
# Updated active periods for user 199
# Updated active periods for user 200
# Updated active periods for user 201
# Updated active periods for user 202
# Updated active periods for user 203
# Updated active periods for user 204
# Updated active periods for user 205
# Updated active periods for user 206
# Updated active periods for user 207
# Updated active periods for user 208
# Updated active periods for user 209
# Updated active periods for user 210
# Updated active periods for user 211
# Updated active periods for user 212
# Updated active periods for user 213
# Updated active periods for user 214
# Updated active periods for user 215
# Updated active periods for user 216
# Updated active periods for user 217
# Updated active periods for user 218
# Updated active periods for user 219
# Updated active periods for user 220
# Updated active periods for user 221
# Updated active periods for user 222
# Updated active periods for user 223
# Updated active periods for user 224
# Updated active periods for user 225
# Updated active periods for user 226
# Updated active periods for user 227
# Updated active periods for user 228
# Updated active periods for user 229
# Updated active periods for user 230
# Updated active periods for user 231
# Updated active periods for user 232
# Updated active periods for user 233
# Updated active periods for user 234
# Updated active periods for user 235
# Updated active periods for user 236
# Updated active periods for user 237
# Updated active periods for user 238
# Updated active periods for user 239
# Updated active periods for user 240
# Updated active periods for user 241
# Updated active periods for user 242
# Updated active periods for user 243
# Updated active periods for user 244
# Updated active periods for user 245
# Updated active periods for user 246
# Updated active periods for user 247
# Updated active periods for user 248
# Updated active periods for user 249
# Updated active periods for user 250
# Updated active periods for user 251
# Updated active periods for user 252
# Updated active periods for user 253
# Updated active periods for user 254
# Updated active periods for user 255
# Updated active periods for user 256
# Updated active periods for user 257
# Updated active periods for user 258
# Updated active periods for user 259
# Updated active periods for user 260
# Updated active periods for user 261
# Updated active periods for user 262
# Updated active periods for user 263
# Updated active periods for user 264
# Updated active periods for user 265
# Updated active periods for user 266
# Updated active periods for user 267
# Updated active periods for user 268
# Updated active periods for user 269
# Updated active periods for user 270
# Updated active periods for user 271
# Updated active periods for user 272
# Updated active periods for user 273
# Updated active periods for user 274
# Updated active periods for user 275
# Updated active periods for user 276
# Updated active periods for user 277
# Updated active periods for user 278
# Updated active periods for user 279
# Updated active periods for user 280
# Updated active periods for user 281
# Updated active periods for user 282
# Updated active periods for user 283
# Updated active periods for user 284
# Updated active periods for user 285
# Updated active periods for user 286
# Updated active periods for user 287
# Updated active periods for user 288
# Updated active periods for user 289
# Updated active periods for user 290
# Updated active periods for user 291
# Updated active periods for user 292
# Updated active periods for user 293
# Updated active periods for user 294
# Updated active periods for user 295
# Updated active periods for user 296
# Updated active periods for user 297
# Updated active periods for user 298
# Updated active periods for user 299
# Updated active periods for user 300
# Updated active periods for user 301
# Updated active periods for user 302
# Updated active periods for user 303
# Updated active periods for user 304
# Updated active periods for user 305
# Updated active periods for user 306
# Updated active periods for user 307
# Updated active periods for user 308
# Updated active periods for user 309
# Updated active periods for user 310
# Updated active periods for user 311
# Updated active periods for user 312
# Updated active periods for user 313
# Updated active periods for user 314
# Updated active periods for user 315
# Updated active periods for user 316
# Updated active periods for user 317
# Updated active periods for user 318
# Updated active periods for user 319
# Updated active periods for user 320
# Updated active periods for user 321
# Updated active periods for user 322
# Updated active periods for user 323
# Updated active periods for user 324
# Updated active periods for user 325
# Updated active periods for user 326
# Updated active periods for user 327
# Updated active periods for user 328
# Updated active periods for user 329
# Updated active periods for user 330
# Updated active periods for user 331
# Updated active periods for user 332
# Updated active periods for user 333
# Updated active periods for user 334
# Updated active periods for user 335
# Updated active periods for user 336
# Updated active periods for user 337
# Updated active periods for user 338
# Updated active periods for user 339
# Updated active periods for user 340
# Updated active periods for user 341
# Updated active periods for user 342
# Updated active periods for user 343
# Updated active periods for user 344
# Updated active periods for user 345
# Updated active periods for user 346
# Updated active periods for user 347
# Updated active periods for user 348
# Updated active periods for user 349
# Updated active periods for user 350
# Updated active periods for user 351
# Updated active periods for user 352
# Updated active periods for user 353
# Updated active periods for user 354
# Updated active periods for user 355
# Updated active periods for user 356
# Updated active periods for user 357
# Updated active periods for user 358
# Updated active periods for user 359
# Updated active periods for user 360
# Updated active periods for user 361
# Updated active periods for user 362
# Updated active periods for user 363
# Updated active periods for user 364
# Updated active periods for user 365
# Updated active periods for user 366
# Updated active periods for user 367
# Updated active periods for user 368
# Updated active periods for user 369
# Updated active periods for user 370
# Updated active periods for user 371
# Updated active periods for user 372
# Updated active periods for user 373
# Updated active periods for user 374
# Updated active periods for user 375
# Updated active periods for user 376
# Updated active periods for user 377
# Updated active periods for user 378
# Updated active periods for user 379
# Updated active periods for user 380
# Updated active periods for user 381
# Updated active periods for user 382
# Updated active periods for user 383
# Updated active periods for user 384
# Updated active periods for user 385
# Updated active periods for user 386
# Updated active periods for user 387
# Updated active periods for user 388
# Updated active periods for user 389
# Updated active periods for user 390
# Updated active periods for user 391
# Updated active periods for user 392
# Updated active periods for user 393
# Updated active periods for user 394
# Updated active periods for user 395
# Updated active periods for user 396
# Updated active periods for user 397
# Updated active periods for user 398
# Updated active periods for user 399
# Updated active periods for user 400
# Updated active periods for user 401
# Updated active periods for user 402
# Updated active periods for user 403
# Updated active periods for user 404
# Updated active periods for user 405
# Updated active periods for user 406
# Updated active periods for user 407
# Updated active periods for user 408
# Updated active periods for user 409
# Updated active periods for user 410
# Updated active periods for user 411
# Updated active periods for user 412
# Updated active periods for user 413
# Updated active periods for user 414
# Updated active periods for user 415
# Updated active periods for user 416
# Updated active periods for user 417
# Updated active periods for user 418
# Updated active periods for user 419
# Updated active periods for user 420
# Updated active periods for user 421
# Updated active periods for user 422
# Updated active periods for user 423
# Updated active periods for user 424
# Updated active periods for user 425
# Updated active periods for user 426
# Updated active periods for user 427
# Updated active periods for user 428
# Updated active periods for user 429
# Updated active periods for user 430
# Updated active periods for user 431
# Updated active periods for user 432
# Updated active periods for user 433
# Updated active periods for user 434
# Updated active periods for user 435
# Updated active periods for user 436
# Updated active periods for user 437
# Updated active periods for user 438
# Updated active periods for user 439
# Updated active periods for user 440
# Updated active periods for user 441
# Updated active periods for user 442
# Updated active periods for user 443
# Updated active periods for user 444
# Updated active periods for user 445
# Updated active periods for user 446
# Updated active periods for user 447
# Updated active periods for user 448
# Updated active periods for user 449
# Updated active periods for user 450
# Updated active periods for user 451
# Updated active periods for user 452
# Updated active periods for user 453
# Updated active periods for user 454
# Updated active periods for user 455
# Updated active periods for user 456
# Updated active periods for user 457
# Updated active periods for user 458
# Updated active periods for user 459
# Updated active periods for user 460
# Updated active periods for user 461
# Updated active periods for user 462
# Updated active periods for user 463
# Updated active periods for user 464
# Updated active periods for user 465
# Updated active periods for user 466
# Updated active periods for user 467
# Updated active periods for user 468
# Updated active periods for user 469
# Updated active periods for user 470
# Updated active periods for user 471
# Updated active periods for user 472
# Updated active periods for user 473
# Updated active periods for user 474
# Updated active periods for user 475
# Updated active periods for user 476
# Updated active periods for user 477
# Updated active periods for user 478
# Updated active periods for user 479
# Updated active periods for user 480
# Updated active periods for user 481
# Updated active periods for user 482
# Updated active periods for user 483
# Updated active periods for user 484
# Updated active periods for user 485
# Updated active periods for user 486
# Updated active periods for user 487
# Updated active periods for user 488
# Updated active periods for user 489
# Updated active periods for user 490
# Updated active periods for user 491
# Updated active periods for user 492
# Updated active periods for user 493
# Updated active periods for user 494
# Updated active periods for user 495
# Updated active periods for user 496
# Updated active periods for user 497
# Updated active periods for user 498
# Updated active periods for user 499
# Updated active periods for user 500
# Updated active periods for user 501
# Updated active periods for user 502
# Updated active periods for user 503
# Updated active periods for user 504
# Updated active periods for user 505
# Updated active periods for user 506
# Updated active periods for user 507
# Updated active periods for user 508
# Updated active periods for user 509
# Updated active periods for user 510
# Updated active periods for user 511
# Updated active periods for user 512
# Updated active periods for user 513
# Updated active periods for user 514
# Updated active periods for user 515
# Updated active periods for user 516
# Updated active periods for user 517
# Updated active periods for user 518
# Updated active periods for user 519
# Updated active periods for user 520
# Updated active periods for user 521
# Updated active periods for user 522
# Updated active periods for user 523
# Updated active periods for user 524
# Updated active periods for user 525
# Updated active periods for user 526
# Updated active periods for user 527
# Updated active periods for user 528
# Updated active periods for user 529
# Updated active periods for user 530
# Updated active periods for user 531
# Updated active periods for user 532
# Updated active periods for user 533
# Updated active periods for user 534
# Updated active periods for user 535
# Updated active periods for user 536
# Updated active periods for user 537
# Updated active periods for user 538
# Updated active periods for user 539
# Updated active periods for user 540
# Updated active periods for user 541
# Updated active periods for user 542
# Updated active periods for user 543
# Updated active periods for user 544
# Updated active periods for user 545
# Updated active periods for user 546
# Updated active periods for user 547
# Updated active periods for user 548
# Updated active periods for user 549
# Updated active periods for user 550
# Updated active periods for user 551
# Updated active periods for user 552
# Updated active periods for user 553
# Updated active periods for user 554
# Updated active periods for user 555
# Updated active periods for user 556
# Updated active periods for user 557
# Updated active periods for user 558
# Updated active periods for user 559
# Updated active periods for user 560
# Updated active periods for user 561
# Updated active periods for user 562
# Updated active periods for user 563
# Updated active periods for user 564
# Updated active periods for user 565
# Updated active periods for user 566
# Updated active periods for user 567
# Updated active periods for user 568
# Updated active periods for user 569
# Updated active periods for user 570
# Updated active periods for user 571
# Updated active periods for user 572
# Updated active periods for user 573
# Updated active periods for user 574
# Updated active periods for user 575
# Updated active periods for user 576
# Updated active periods for user 577
# Updated active periods for user 578
# Updated active periods for user 579
# Updated active periods for user 580
# Updated active periods for user 581
# Updated active periods for user 582
# Updated active periods for user 583
# Updated active periods for user 584
# Updated active periods for user 585
# Updated active periods for user 586
# Updated active periods for user 587
# Updated active periods for user 588
# Updated active periods for user 589
# Updated active periods for user 590
# Updated active periods for user 591
# Updated active periods for user 592
# Updated active periods for user 593
# Updated active periods for user 594
# Updated active periods for user 595
# Updated active periods for user 596
# Updated active periods for user 597
# Updated active periods for user 598
# Updated active periods for user 599
# Updated active periods for user 600
# Updated active periods for user 601
# Updated active periods for user 602
# Updated active periods for user 603
# Updated active periods for user 604
# Updated active periods for user 605
# Updated active periods for user 606
# Updated active periods for user 607
# Updated active periods for user 608
# Updated active periods for user 609
# Updated active periods for user 610
# Updated active periods for user 611
# Updated active periods for user 612
# Updated active periods for user 613
# Updated active periods for user 614
# Updated active periods for user 615
# Updated active periods for user 616
# Updated active periods for user 617
# Updated active periods for user 618
# Updated active periods for user 619
# Updated active periods for user 620
# Updated active periods for user 621
# Updated active periods for user 622
# Updated active periods for user 623
# Updated active periods for user 624
# Updated active periods for user 625
# Updated active periods for user 626
# Updated active periods for user 627
# Updated active periods for user 628
# Updated active periods for user 629
# Updated active periods for user 630
# Updated active periods for user 631
# Updated active periods for user 632
# Updated active periods for user 633
# Updated active periods for user 634
# Updated active periods for user 635
# Updated active periods for user 636
# Updated active periods for user 637
# Updated active periods for user 638
# Updated active periods for user 639
# Updated active periods for user 640
# Updated active periods for user 641
# Updated active periods for user 642
# Updated active periods for user 643
# Updated active periods for user 644
# Updated active periods for user 645
# Updated active periods for user 646
# Updated active periods for user 647
# Updated active periods for user 648
# Updated active periods for user 649
# Updated active periods for user 650
# Updated active periods for user 651
# Updated active periods for user 652
# Updated active periods for user 653
# Updated active periods for user 654
# Updated active periods for user 655
# Updated active periods for user 656
# Updated active periods for user 657
# Updated active periods for user 658
# Updated active periods for user 659
# Updated active periods for user 660
# Updated active periods for user 661
# Updated active periods for user 662
# Updated active periods for user 663
# Updated active periods for user 664
# Updated active periods for user 665
# Updated active periods for user 666
# Updated active periods for user 667
# Updated active periods for user 668
# Updated active periods for user 669
# Updated active periods for user 670
# Updated active periods for user 671
# Updated active periods for user 672
# Updated active periods for user 673
# Updated active periods for user 674
# Updated active periods for user 675
# Updated active periods for user 676
# Updated active periods for user 677
# Updated active periods for user 678
# Updated active periods for user 679
# Updated active periods for user 680
# Updated active periods for user 681
# Updated active periods for user 682
# Updated active periods for user 683
# Updated active periods for user 684
# Updated active periods for user 685
# Updated active periods for user 686
# Updated active periods for user 687
# Updated active periods for user 688
# Updated active periods for user 689
# Updated active periods for user 690
# Updated active periods for user 691
# Updated active periods for user 692
# Updated active periods for user 693
# Updated active periods for user 694
# Updated active periods for user 695
# Updated active periods for user 696
# Updated active periods for user 697
# Updated active periods for user 698
# Updated active periods for user 699
# Updated active periods for user 700
# Updated active periods for user 701
# Updated active periods for user 702
# Updated active periods for user 703
# Updated active periods for user 704
# Updated active periods for user 705
# Updated active periods for user 706
# Updated active periods for user 707
# Updated active periods for user 708
# Updated active periods for user 709
# Updated active periods for user 710
# Updated active periods for user 711
# Updated active periods for user 712
# Updated active periods for user 713
# Updated active periods for user 714
# Updated active periods for user 715
# Updated active periods for user 716
# Updated active periods for user 717
# Updated active periods for user 718
# Updated active periods for user 719
# Updated active periods for user 720
# Updated active periods for user 721
# Updated active periods for user 722
# Updated active periods for user 723
# Updated active periods for user 724
# Updated active periods for user 725
# Updated active periods for user 726
# Updated active periods for user 727
# Updated active periods for user 728
# Updated active periods for user 729
# Updated active periods for user 730
# Updated active periods for user 731
# Updated active periods for user 732
# Updated active periods for user 733
# Updated active periods for user 734
# Updated active periods for user 735
# Updated active periods for user 736
# Updated active periods for user 737
# Updated active periods for user 738
# Updated active periods for user 739
# Updated active periods for user 740
# Updated active periods for user 741
# Updated active periods for user 742
# Updated active periods for user 743
# Updated active periods for user 744
# Updated active periods for user 745
# Updated active periods for user 746
# Updated active periods for user 747
# Updated active periods for user 748
# Updated active periods for user 749
# Updated active periods for user 750
# Updated active periods for user 751
# Updated active periods for user 752
# Updated active periods for user 753
# Updated active periods for user 754
# Updated active periods for user 755
# Updated active periods for user 756
# Updated active periods for user 757
# Updated active periods for user 758
# Updated active periods for user 759
# Updated active periods for user 760
# Updated active periods for user 761
# Updated active periods for user 762
# Updated active periods for user 763
# Updated active periods for user 764
# Updated active periods for user 765
# Updated active periods for user 766
# Updated active periods for user 767
# Updated active periods for user 768
# Updated active periods for user 769
# Updated active periods for user 770
# Updated active periods for user 771
# Updated active periods for user 772
# Updated active periods for user 773
# Updated active periods for user 774
# Updated active periods for user 775
# Updated active periods for user 776
# Updated active periods for user 777
# Updated active periods for user 778
# Updated active periods for user 779
# Updated active periods for user 780
# Updated active periods for user 781
# Updated active periods for user 782
# Updated active periods for user 783
# Updated active periods for user 784
# Updated active periods for user 785
# Updated active periods for user 786
# Updated active periods for user 787
# Updated active periods for user 788
# Updated active periods for user 789
# Updated active periods for user 790
# Updated active periods for user 791
# Updated active periods for user 792
# Updated active periods for user 793
# Updated active periods for user 794
# Updated active periods for user 795
# Updated active periods for user 796
# Updated active periods for user 797
# Updated active periods for user 798
# Updated active periods for user 799
# Updated active periods for user 800
# Updated active periods for user 801
# Updated active periods for user 802
# Updated active periods for user 803
# Updated active periods for user 804
# Updated active periods for user 805
# Updated active periods for user 806
# Updated active periods for user 807
# Updated active periods for user 808
# Updated active periods for user 809
# Updated active periods for user 810
# Updated active periods for user 811
# Updated active periods for user 812
# Updated active periods for user 813
# Updated active periods for user 814
# Updated active periods for user 815
# Updated active periods for user 816
# Updated active periods for user 817
# Updated active periods for user 818
# Updated active periods for user 819
# Updated active periods for user 820
# Updated active periods for user 821
# Updated active periods for user 822
# Updated active periods for user 823
# Updated active periods for user 824
# Updated active periods for user 825
# Updated active periods for user 826
# Updated active periods for user 827
# Updated active periods for user 828
# Updated active periods for user 829
# Updated active periods for user 830
# Updated active periods for user 831
# Updated active periods for user 832
# Updated active periods for user 833
# Updated active periods for user 834
# Updated active periods for user 835
# Updated active periods for user 836
# Updated active periods for user 837
# Updated active periods for user 838
# Updated active periods for user 839
# Updated active periods for user 840
# Updated active periods for user 841
# Updated active periods for user 842
# Updated active periods for user 843
# Updated active periods for user 844
# Updated active periods for user 845
# Updated active periods for user 846
# Updated active periods for user 847
# Updated active periods for user 848
# Updated active periods for user 849
# Updated active periods for user 850
# Updated active periods for user 851
# Updated active periods for user 852
# Updated active periods for user 853
# Updated active periods for user 854
# Updated active periods for user 855
# Updated active periods for user 856
# Updated active periods for user 857
# Updated active periods for user 858
# Updated active periods for user 859
# Updated active periods for user 860
# Updated active periods for user 861
# Updated active periods for user 862
# Updated active periods for user 863
# Updated active periods for user 864
# Updated active periods for user 865
# Updated active periods for user 866
# Updated active periods for user 867
# Updated active periods for user 868
# Updated active periods for user 869
# Updated active periods for user 870
# Updated active periods for user 871
# Updated active periods for user 872
# Updated active periods for user 873
# Updated active periods for user 874
# Updated active periods for user 875
# Updated active periods for user 876
# Updated active periods for user 877
# Updated active periods for user 878
# Updated active periods for user 879
# Updated active periods for user 880
# Updated active periods for user 881
# Updated active periods for user 882
# Updated active periods for user 883
# Updated active periods for user 884
# Updated active periods for user 885
# Updated active periods for user 886
# Updated active periods for user 887
# Updated active periods for user 888
# Updated active periods for user 889
# Updated active periods for user 890
# Updated active periods for user 891
# Updated active periods for user 892
# Updated active periods for user 893
# Updated active periods for user 894
# Updated active periods for user 895
# Updated active periods for user 896
# Updated active periods for user 897
# Updated active periods for user 898
# Updated active periods for user 899
# Updated active periods for user 900
# Updated active periods for user 901
# Updated active periods for user 902
# Updated active periods for user 903
# Updated active periods for user 904
# Updated active periods for user 905
# Updated active periods for user 906
# Updated active periods for user 907
# Updated active periods for user 908
# Updated active periods for user 909
# Updated active periods for user 910
# Updated active periods for user 911
# Updated active periods for user 912
# Updated active periods for user 913
# Updated active periods for user 914
# Updated active periods for user 915
# Updated active periods for user 916
# Updated active periods for user 917
# Updated active periods for user 918
# Updated active periods for user 919
# Updated active periods for user 920
# Updated active periods for user 921
# Updated active periods for user 922
# Updated active periods for user 923
# Updated active periods for user 924
# Updated active periods for user 925
# Updated active periods for user 926
# Updated active periods for user 927
# Updated active periods for user 928
# Updated active periods for user 929
# Updated active periods for user 930
# Updated active periods for user 931
# Updated active periods for user 932
# Updated active periods for user 933
# Updated active periods for user 934
# Updated active periods for user 935
# Updated active periods for user 936
# Updated active periods for user 937
# Updated active periods for user 938
# Updated active periods for user 939
# Updated active periods for user 940
# Updated active periods for user 941
# Updated active periods for user 942
# Updated active periods for user 943
# Updated active periods for user 944
# Updated active periods for user 945
# Updated active periods for user 946
# Updated active periods for user 947
# Updated active periods for user 948
# Updated active periods for user 949
# Updated active periods for user 950
# Updated active periods for user 951
# Updated active periods for user 952
# Updated active periods for user 953
# Updated active periods for user 954
# Updated active periods for user 955
# Updated active periods for user 956
# Updated active periods for user 957
# Updated active periods for user 958
# Updated active periods for user 959
# Updated active periods for user 960
# Updated active periods for user 961
# Updated active periods for user 962
# Updated active periods for user 963
# Updated active periods for user 964
# Updated active periods for user 965
# Updated active periods for user 966
# Updated active periods for user 967
# Updated active periods for user 968
# Updated active periods for user 969
# Updated active periods for user 970
# Updated active periods for user 971
# Updated active periods for user 972
# Updated active periods for user 973
# Updated active periods for user 974
# Updated active periods for user 975
# Updated active periods for user 976
# Updated active periods for user 977
# Updated active periods for user 978
# Updated active periods for user 979
# Updated active periods for user 980
# Updated active periods for user 981
# Updated active periods for user 982
# Updated active periods for user 983
# Updated active periods for user 984
# Updated active periods for user 985
# Updated active periods for user 986
# Updated active periods for user 987
# Updated active periods for user 988
# Updated active periods for user 989
# Updated active periods for user 990
# Updated active periods for user 991
# Updated active periods for user 992
# Updated active periods for user 993
# Updated active periods for user 994
# Updated active periods for user 995
# Updated active periods for user 996
# Updated active periods for user 997
# Updated active periods for user 998
# Updated active periods for user 999
# Updated active periods for user 1000
# Completed batch up to user 1000
# Updated active periods for user 1001
# Updated active periods for user 1002
# Updated active periods for user 1003
# Updated active periods for user 1004
# Updated active periods for user 1005
# Updated active periods for user 1006
# Updated active periods for user 1007
# Updated active periods for user 1008
# Updated active periods for user 1009
# Updated active periods for user 1010
# Updated active periods for user 1011
# Updated active periods for user 1012
# Updated active periods for user 1013
# Updated active periods for user 1014
# Updated active periods for user 1015
# Updated active periods for user 1016
# Updated active periods for user 1017
# Updated active periods for user 1018
# Updated active periods for user 1019
# Updated active periods for user 1020
# Updated active periods for user 1021
# Updated active periods for user 1022
# Updated active periods for user 1023
# Updated active periods for user 1024
# Updated active periods for user 1025
# Updated active periods for user 1026
# Updated active periods for user 1027
# Updated active periods for user 1028
# Updated active periods for user 1029
# Updated active periods for user 1030
# Updated active periods for user 1031
# Updated active periods for user 1032
# Updated active periods for user 1033
# Updated active periods for user 1034
# Updated active periods for user 1035
# Updated active periods for user 1036
# Updated active periods for user 1037
# Updated active periods for user 1038
# Updated active periods for user 1039
# Updated active periods for user 1040
# Updated active periods for user 1041
# Updated active periods for user 1042
# Updated active periods for user 1043
# Updated active periods for user 1044
# Updated active periods for user 1045
# Updated active periods for user 1046
# Updated active periods for user 1047
# Updated active periods for user 1048
# Updated active periods for user 1049
# Updated active periods for user 1050
# Updated active periods for user 1051
# Updated active periods for user 1052
# Updated active periods for user 1053
# Updated active periods for user 1054
# Updated active periods for user 1055
# Updated active periods for user 1056
# Updated active periods for user 1057
# Updated active periods for user 1058
# Updated active periods for user 1059
# Updated active periods for user 1060
# Updated active periods for user 1061
# Updated active periods for user 1062
# Updated active periods for user 1063
# Updated active periods for user 1064
# Updated active periods for user 1065
# Updated active periods for user 1066
# Updated active periods for user 1067
# Updated active periods for user 1068
# Updated active periods for user 1069
# Updated active periods for user 1070
# Updated active periods for user 1071
# Updated active periods for user 1072
# Updated active periods for user 1073
# Updated active periods for user 1074
# Updated active periods for user 1075
# Updated active periods for user 1076
# Updated active periods for user 1077
# Updated active periods for user 1078
# Updated active periods for user 1079
# Updated active periods for user 1080
# Updated active periods for user 1081
# Updated active periods for user 1082
# Updated active periods for user 1083
# Updated active periods for user 1084
# Updated active periods for user 1085
# Updated active periods for user 1086
# Updated active periods for user 1087
# Updated active periods for user 1088
# Updated active periods for user 1089
# Updated active periods for user 1090
# Updated active periods for user 1091
# Updated active periods for user 1092
# Updated active periods for user 1093
# Updated active periods for user 1094
# Updated active periods for user 1095
# Updated active periods for user 1096
# Updated active periods for user 1097
# Updated active periods for user 1098
# Updated active periods for user 1099
# Updated active periods for user 1100
# Updated active periods for user 1101
# Updated active periods for user 1102
# Updated active periods for user 1103
# Updated active periods for user 1104
# Updated active periods for user 1105
# Updated active periods for user 1106
# Updated active periods for user 1107
# Updated active periods for user 1108
# Updated active periods for user 1109
# Updated active periods for user 1110
# Updated active periods for user 1111
# Updated active periods for user 1112
# Updated active periods for user 1113
# Updated active periods for user 1114
# Updated active periods for user 1115
# Updated active periods for user 1116
# Updated active periods for user 1117
# Updated active periods for user 1118
# Updated active periods for user 1119
# Updated active periods for user 1120
# Updated active periods for user 1121
# Updated active periods for user 1122
# Updated active periods for user 1123
# Updated active periods for user 1124
# Updated active periods for user 1125
# Updated active periods for user 1126
# Updated active periods for user 1127
# Updated active periods for user 1128
# Updated active periods for user 1129
# Updated active periods for user 1130
# Updated active periods for user 1131
# Updated active periods for user 1132
# Updated active periods for user 1133
# Updated active periods for user 1134
# Updated active periods for user 1135
# Updated active periods for user 1136
# Updated active periods for user 1137
# Updated active periods for user 1138
# Updated active periods for user 1139
# Updated active periods for user 1140
# Updated active periods for user 1141
# Updated active periods for user 1142
# Updated active periods for user 1143
# Updated active periods for user 1144
# Updated active periods for user 1145
# Updated active periods for user 1146
# Updated active periods for user 1147
# Updated active periods for user 1148
# Updated active periods for user 1149
# Updated active periods for user 1150
# Updated active periods for user 1151
# Updated active periods for user 1152
# Updated active periods for user 1153
# Updated active periods for user 1154
# Updated active periods for user 1155
# Updated active periods for user 1156
# Updated active periods for user 1157
# Updated active periods for user 1158
# Updated active periods for user 1159
# Updated active periods for user 1160
# Updated active periods for user 1161
# Updated active periods for user 1162
# Updated active periods for user 1163
# Updated active periods for user 1164
# Updated active periods for user 1165
# Updated active periods for user 1166
# Updated active periods for user 1167
# Updated active periods for user 1168
# Updated active periods for user 1169
# Updated active periods for user 1170
# Updated active periods for user 1171
# Updated active periods for user 1172
# Updated active periods for user 1173
# Updated active periods for user 1174
# Updated active periods for user 1175
# Updated active periods for user 1176
# Updated active periods for user 1177
# Updated active periods for user 1178
# Updated active periods for user 1179
# Updated active periods for user 1180
# Updated active periods for user 1181
# Updated active periods for user 1182
# Updated active periods for user 1183
# Updated active periods for user 1184
# Updated active periods for user 1185
# Updated active periods for user 1186
# Updated active periods for user 1187
# Updated active periods for user 1188
# Updated active periods for user 1189
# Updated active periods for user 1190
# Updated active periods for user 1191
# Updated active periods for user 1192
# Updated active periods for user 1193
# Updated active periods for user 1194
# Updated active periods for user 1195
# Updated active periods for user 1196
# Updated active periods for user 1197
# Updated active periods for user 1198
# Updated active periods for user 1199
# Updated active periods for user 1200
# Updated active periods for user 1201
# Updated active periods for user 1202
# Updated active periods for user 1203
# Updated active periods for user 1204
# Updated active periods for user 1205
# Updated active periods for user 1206
# Updated active periods for user 1207
# Updated active periods for user 1208
# Updated active periods for user 1209
# Updated active periods for user 1210
# Updated active periods for user 1211
# Updated active periods for user 1212
# Updated active periods for user 1213
# Updated active periods for user 1214
# Updated active periods for user 1215
# Updated active periods for user 1216
# Updated active periods for user 1217
# Updated active periods for user 1218
# Updated active periods for user 1219
# Updated active periods for user 1220
# Updated active periods for user 1221
# Updated active periods for user 1222
# Updated active periods for user 1223
# Updated active periods for user 1224
# Updated active periods for user 1225
# Updated active periods for user 1226
# Updated active periods for user 1227
# Updated active periods for user 1228
# Updated active periods for user 1229
# Updated active periods for user 1230
# Updated active periods for user 1231
# Updated active periods for user 1232
# Updated active periods for user 1233
# Updated active periods for user 1234
# Updated active periods for user 1235
# Updated active periods for user 1236
# Updated active periods for user 1237
# Updated active periods for user 1238
# Updated active periods for user 1239
# Updated active periods for user 1240
# Updated active periods for user 1241
# Updated active periods for user 1242
# Updated active periods for user 1243
# Updated active periods for user 1244
# Updated active periods for user 1245
# Updated active periods for user 1246
# Updated active periods for user 1247
# Updated active periods for user 1248
# Updated active periods for user 1249
# Updated active periods for user 1250
# Updated active periods for user 1251
# Updated active periods for user 1252
# Updated active periods for user 1253
# Updated active periods for user 1254
# Updated active periods for user 1255
# Updated active periods for user 1256
# Updated active periods for user 1257
# Updated active periods for user 1258
# Updated active periods for user 1259
# Updated active periods for user 1260
# Updated active periods for user 1261
# Updated active periods for user 1262
# Updated active periods for user 1263
# Updated active periods for user 1264
# Updated active periods for user 1265
# Updated active periods for user 1266
# Updated active periods for user 1267
# Updated active periods for user 1268
# Updated active periods for user 1269
# Updated active periods for user 1270
# Updated active periods for user 1271
# Updated active periods for user 1272
# Updated active periods for user 1273
# Updated active periods for user 1274
# Updated active periods for user 1275
# Updated active periods for user 1276
# Updated active periods for user 1277
# Updated active periods for user 1278
# Updated active periods for user 1279
# Updated active periods for user 1280
# Updated active periods for user 1281
# Updated active periods for user 1282
# Updated active periods for user 1283
# Updated active periods for user 1284
# Updated active periods for user 1285
# Updated active periods for user 1286
# Updated active periods for user 1287
# Updated active periods for user 1288
# Updated active periods for user 1289
# Updated active periods for user 1290
# Updated active periods for user 1291
# Updated active periods for user 1292
# Updated active periods for user 1293
# Updated active periods for user 1294
# Updated active periods for user 1295
# Updated active periods for user 1296
# Updated active periods for user 1297
# Updated active periods for user 1298
# Updated active periods for user 1299
# Updated active periods for user 1300
# Updated active periods for user 1301
# Updated active periods for user 1302
# Updated active periods for user 1303
# Updated active periods for user 1304
# Updated active periods for user 1305
# Updated active periods for user 1306
# Updated active periods for user 1307
# Updated active periods for user 1308
# Updated active periods for user 1309
# Updated active periods for user 1310
# Updated active periods for user 1311
# Updated active periods for user 1312
# Updated active periods for user 1313
# Updated active periods for user 1314
# Updated active periods for user 1315
# Updated active periods for user 1316
# Updated active periods for user 1317
# Updated active periods for user 1318
# Updated active periods for user 1319
# Updated active periods for user 1320
# ...
# Updated active periods for user 16741
# Updated active periods for user 16742
# Updated active periods for user 16743
# Updated active periods for user 16744
# Updated active periods for user 16745
# Updated active periods for user 16746
# Updated active periods for user 16747
# Updated active periods for user 16748
# Updated active periods for user 16749
# Updated active periods for user 16750
# Updated active periods for user 16751
# Updated active periods for user 16752
# Updated active periods for user 16753
# Updated active periods for user 16754
# Updated active periods for user 16755
# Updated active periods for user 16756
# Updated active periods for user 16757
# Updated active periods for user 16758
# Updated active periods for user 16759
# Updated active periods for user 16760
# Updated active periods for user 16761
# Updated active periods for user 16762
# Updated active periods for user 16763
# Updated active periods for user 16764
# Updated active periods for user 16765
# Updated active periods for user 16766
# Updated active periods for user 16767
# Updated active periods for user 16768
# Updated active periods for user 16769
# Updated active periods for user 16770
# Updated active periods for user 16771
# Updated active periods for user 16772
# Updated active periods for user 16773
# Updated active periods for user 16774
# Updated active periods for user 16775
# Updated active periods for user 16776
# Updated active periods for user 16777
# Updated active periods for user 16778
# Updated active periods for user 16779
# Updated active periods for user 16780
# Updated active periods for user 16781
# Updated active periods for user 16782
# Updated active periods for user 16783
# Updated active periods for user 16784
# Updated active periods for user 16785
# Updated active periods for user 16786
# Updated active periods for user 16787
# Updated active periods for user 16788
# Updated active periods for user 16789
# Updated active periods for user 16790
# Updated active periods for user 16791
# Updated active periods for user 16792
# Updated active periods for user 16793
# Updated active periods for user 16794
# Updated active periods for user 16795
# Updated active periods for user 16796
# Updated active periods for user 16797
# Updated active periods for user 16798
# Updated active periods for user 16799
# Updated active periods for user 16800
# Updated active periods for user 16801
# Updated active periods for user 16802
# Updated active periods for user 16803
# Updated active periods for user 16804
# Updated active periods for user 16805
# Updated active periods for user 16806
# Updated active periods for user 16807
# Updated active periods for user 16808
# Updated active periods for user 16809
# Updated active periods for user 16810
# Updated active periods for user 16811
# Updated active periods for user 16812
# Updated active periods for user 16813
# Updated active periods for user 16814
# Updated active periods for user 16815
# Updated active periods for user 16816
# Updated active periods for user 16817
# Updated active periods for user 16818
# Updated active periods for user 16819
# Updated active periods for user 16820
# Updated active periods for user 16821
# Updated active periods for user 16822
# Updated active periods for user 16823
# Updated active periods for user 16824
# Updated active periods for user 16825
# Updated active periods for user 16826
# Updated active periods for user 16827
# Updated active periods for user 16828
# Updated active periods for user 16829
# Updated active periods for user 16830
# Updated active periods for user 16831
# Updated active periods for user 16832
# Updated active periods for user 16833
# Updated active periods for user 16834
# Updated active periods for user 16835
# Updated active periods for user 16836
# Updated active periods for user 16837
# Updated active periods for user 16838
# Updated active periods for user 16839
# Updated active periods for user 16840
# Updated active periods for user 16841
# Updated active periods for user 16842
# Updated active periods for user 16843
# Updated active periods for user 16844
# Updated active periods for user 16845
# Updated active periods for user 16846
# Updated active periods for user 16847
# Updated active periods for user 16848
# Updated active periods for user 16849
# Updated active periods for user 16850
# Updated active periods for user 16851
# Updated active periods for user 16852
# Updated active periods for user 16853
# Updated active periods for user 16854
# Updated active periods for user 16855
# Updated active periods for user 16856
# Updated active periods for user 16857
# Updated active periods for user 16858
# Updated active periods for user 16859
# Updated active periods for user 16860
# Updated active periods for user 16861
# Updated active periods for user 16862
# Updated active periods for user 16863
# Updated active periods for user 16864
# Updated active periods for user 16865
# Updated active periods for user 16866
# Updated active periods for user 16867
# Updated active periods for user 16868
# Updated active periods for user 16869
# Updated active periods for user 16870
# Updated active periods for user 16871
# Updated active periods for user 16872
# Updated active periods for user 16873
# Updated active periods for user 16874
# Updated active periods for user 16875
# Updated active periods for user 16876
# Updated active periods for user 16877
# Updated active periods for user 16878
# Updated active periods for user 16879
# Updated active periods for user 16880
# Updated active periods for user 16881
# Updated active periods for user 16882
# Updated active periods for user 16883
# Updated active periods for user 16884
# Updated active periods for user 16885
# Updated active periods for user 16886
# Updated active periods for user 16887
# Updated active periods for user 16888
# Updated active periods for user 16889
# Updated active periods for user 16890
# Updated active periods for user 16891
# Updated active periods for user 16892
# Updated active periods for user 16893
# Updated active periods for user 16894
# Updated active periods for user 16895
# Updated active periods for user 16896
# Updated active periods for user 16897
# Updated active periods for user 16898
# Updated active periods for user 16899
# Updated active periods for user 16900
# Updated active periods for user 16901
# Updated active periods for user 16902
# Updated active periods for user 16903
# Updated active periods for user 16904
# Updated active periods for user 16905
# Updated active periods for user 16906
# Updated active periods for user 16907
# Updated active periods for user 16908
# Updated active periods for user 16909
# Updated active periods for user 16910
# Updated active periods for user 16911
# Updated active periods for user 16912
# Updated active periods for user 16913
# Updated active periods for user 16914
# Updated active periods for user 16915
# Updated active periods for user 16916
# Updated active periods for user 16917
# Updated active periods for user 16918
# Updated active periods for user 16919
# Updated active periods for user 16920
# Updated active periods for user 16921
# Updated active periods for user 16922
# Updated active periods for user 16923
# Updated active periods for user 16924
# Updated active periods for user 16925
# Updated active periods for user 16926
# Updated active periods for user 16927
# Updated active periods for user 16928
# Updated active periods for user 16929
# Updated active periods for user 16930
# Updated active periods for user 16931
# Updated active periods for user 16932
# Updated active periods for user 16933
# Updated active periods for user 16934
# Updated active periods for user 16935
# Updated active periods for user 16936
# Updated active periods for user 16937
# Updated active periods for user 16938
# Updated active periods for user 16939
# Updated active periods for user 16940
# Updated active periods for user 16941
# Updated active periods for user 16942
# Updated active periods for user 16943
# Updated active periods for user 16944
# Updated active periods for user 16945
# Updated active periods for user 16946
# Updated active periods for user 16947
# Updated active periods for user 16948
# Updated active periods for user 16949
# Updated active periods for user 16950
# Updated active periods for user 16951
# Updated active periods for user 16952
# Updated active periods for user 16953
# Updated active periods for user 16954
# Updated active periods for user 16955
# Updated active periods for user 16956
# Updated active periods for user 16957
# Updated active periods for user 16958
# Updated active periods for user 16959
# Updated active periods for user 16960
# Updated active periods for user 16961
# Updated active periods for user 16962
# Updated active periods for user 16963
# Updated active periods for user 16964
# Updated active periods for user 16965
# Updated active periods for user 16966
# Updated active periods for user 16967
# Updated active periods for user 16968
# Updated active periods for user 16969
# Updated active periods for user 16970
# Updated active periods for user 16971
# Updated active periods for user 16972
# Updated active periods for user 16973
# Updated active periods for user 16974
# Updated active periods for user 16975
# Updated active periods for user 16976
# Updated active periods for user 16977
# Updated active periods for user 16978
# Updated active periods for user 16979
# Updated active periods for user 16980
# Updated active periods for user 16981
# Updated active periods for user 16982
# Updated active periods for user 16983
# Updated active periods for user 16984
# Updated active periods for user 16985
# Updated active periods for user 16986
# Updated active periods for user 16987
# Updated active periods for user 16988
# Updated active periods for user 16989
# Updated active periods for user 16990
# Updated active periods for user 16991
# Completed batch up to user 16991
# Updated active periods for user 16992
# Updated active periods for user 16993
# Updated active periods for user 16994
# Updated active periods for user 16995
# Updated active periods for user 16996
# Updated active periods for user 16997
# Updated active periods for user 16998
# Updated active periods for user 16999
# Updated active periods for user 17000
# Updated active periods for user 17001
# Updated active periods for user 17002
# Updated active periods for user 17003
# Updated active periods for user 17004
# Updated active periods for user 17005
# Updated active periods for user 17006
# Updated active periods for user 17007
# Updated active periods for user 17008
# Updated active periods for user 17009
# Updated active periods for user 17010
# Updated active periods for user 17011
# Updated active periods for user 17012
# Updated active periods for user 17013
# Updated active periods for user 17014
# Updated active periods for user 17015
# Updated active periods for user 17016
# Updated active periods for user 17017
# Updated active periods for user 17018
# Updated active periods for user 17019
# Updated active periods for user 17020
# Updated active periods for user 17021
# Updated active periods for user 17022
# Updated active periods for user 17023
# Updated active periods for user 17024
# Updated active periods for user 17025
# Updated active periods for user 17026
# Updated active periods for user 17027
# Updated active periods for user 17028
# Updated active periods for user 17029
# Updated active periods for user 17030
# Updated active periods for user 17031
# Updated active periods for user 17032
# Updated active periods for user 17033
# Updated active periods for user 17034
# Updated active periods for user 17035
# Updated active periods for user 17036
# Updated active periods for user 17037
# Updated active periods for user 17038
# Updated active periods for user 17039
# Updated active periods for user 17040
# Updated active periods for user 17041
# Updated active periods for user 17042
# Updated active periods for user 17043
# Updated active periods for user 17044
# Updated active periods for user 17045
# Updated active periods for user 17046
# Updated active periods for user 17047
# Updated active periods for user 17048
# Updated active periods for user 17049
# Updated active periods for user 17050
# Updated active periods for user 17051
# Updated active periods for user 17052
# Updated active periods for user 17053
# Updated active periods for user 17054
# Updated active periods for user 17055
# Updated active periods for user 17056
# Updated active periods for user 17057
# Updated active periods for user 17058
# Updated active periods for user 17059
# Updated active periods for user 17060
# Updated active periods for user 17061
# Updated active periods for user 17062
# Updated active periods for user 17063
# Updated active periods for user 17064
# Updated active periods for user 17065
# Updated active periods for user 17066
# Updated active periods for user 17067
# Updated active periods for user 17068
# Updated active periods for user 17069
# Updated active periods for user 17070
# Updated active periods for user 17071
# Updated active periods for user 17072
# Updated active periods for user 17073
# Updated active periods for user 17074
# Updated active periods for user 17075
# Updated active periods for user 17076
# Updated active periods for user 17077
# Updated active periods for user 17078
# Updated active periods for user 17079
# Updated active periods for user 17080
# Updated active periods for user 17081
# Updated active periods for user 17082
# Updated active periods for user 17083
# Updated active periods for user 17084
# Updated active periods for user 17085
# Updated active periods for user 17086
# Updated active periods for user 17087
# Updated active periods for user 17088
# Updated active periods for user 17089
# Updated active periods for user 17090
# Updated active periods for user 17091
# Updated active periods for user 17092
# Updated active periods for user 17093
# Updated active periods for user 17094
# Updated active periods for user 17095
# Updated active periods for user 17096
# Updated active periods for user 17097
# Updated active periods for user 17098
# Updated active periods for user 17099
# Updated active periods for user 17100
# Updated active periods for user 17101
# Updated active periods for user 17102
# Updated active periods for user 17103
# Updated active periods for user 17104
# Updated active periods for user 17105
# Updated active periods for user 17106
# Updated active periods for user 17107
# Updated active periods for user 17108
# Updated active periods for user 17109
# Updated active periods for user 17110
# Updated active periods for user 17111
# Updated active periods for user 17112
# Updated active periods for user 17113
# Updated active periods for user 17114
# Updated active periods for user 17115
# Updated active periods for user 17116
# Updated active periods for user 17117
# Updated active periods for user 17118
# Updated active periods for user 17119
# Updated active periods for user 17120
# Updated active periods for user 17121
# Updated active periods for user 17122
# Updated active periods for user 17123
# Updated active periods for user 17124
# Updated active periods for user 17125
# Updated active periods for user 17126
# Updated active periods for user 17127
# Updated active periods for user 17128
# Updated active periods for user 17129
# Updated active periods for user 17130
# Updated active periods for user 17131
# Updated active periods for user 17132
# Updated active periods for user 17133
# Updated active periods for user 17134
# Updated active periods for user 17135
# Updated active periods for user 17136
# Updated active periods for user 17137
# Updated active periods for user 17138
# Updated active periods for user 17139
# Updated active periods for user 17140
# Updated active periods for user 17141
# Updated active periods for user 17142
# Updated active periods for user 17143
# Updated active periods for user 17144
# Updated active periods for user 17145
# Updated active periods for user 17146
# Updated active periods for user 17147
# Updated active periods for user 17148
# Updated active periods for user 17149
# Updated active periods for user 17150
# Updated active periods for user 17151
# Updated active periods for user 17152
# Updated active periods for user 17153
# Updated active periods for user 17154
# Updated active periods for user 17155
# Updated active periods for user 17156
# Updated active periods for user 17157
# Updated active periods for user 17158
# Completed batch up to user 17158
# Completed updating all users' active periods

# %%
# Query to get session times for all users
query_response = supabase.table("user_table_refined").select("average_session_time").execute()

# Filter out None values and collect all session times
session_times = [
    user["average_session_time"] 
    for user in query_response.data 
    if user["average_session_time"] is not None
]

if session_times:
    # Calculate statistics
    total_users = len(session_times)
    overall_average = sum(session_times) / total_users
    max_duration = max(session_times)
    
    # Convert all times to minutes
    average_minutes = overall_average / 60
    max_minutes = max_duration / 60
    
    # Calculate median
    sorted_times = sorted(session_times)
    median = sorted_times[len(sorted_times) // 2]
    median_minutes = median / 60
    
    # Calculate 25th and 75th percentiles
    p25 = sorted_times[len(sorted_times) // 4] / 60
    p75 = sorted_times[len(sorted_times) * 3 // 4] / 60

    print("\nSession Time Statistics:")
    print("--------------------------------")
    print(f"Number of Users: {total_users:,}")  # Add comma separator for large numbers
    print(f"Average Session Duration: {average_minutes:.2f} minutes")
    print(f"Maximum Session Duration: {max_minutes:.2f} minutes")
    print(f"Median Session Duration: {median_minutes:.2f} minutes")
    print(f"25th Percentile: {p25:.2f} minutes")
    print(f"75th Percentile: {p75:.2f} minutes")
    print("--------------------------------")
else:
    print("No session time data available")
# Out:
# Session Time Statistics:
# --------------------------------
# Number of Users: 1,675
# Average Session Duration: 2.78 minutes
# Maximum Session Duration: 104.15 minutes
# Median Session Duration: 0.00 minutes
# 25th Percentile: 0.00 minutes
# 75th Percentile: 0.04 minutes
# --------------------------------

# %%
# Query to get total session times for all users
query_response = supabase.table("user_table_refined").select("total_session_time").execute()

# Filter out None values and collect all total session times
session_times = [
    user["total_session_time"] 
    for user in query_response.data 
    if user["total_session_time"] is not None
]

if session_times:
    # Calculate statistics
    total_users = len(session_times)
    overall_average = sum(session_times) / total_users
    max_duration = max(session_times)
    
    # Convert all times to hours for better readability
    average_hours = overall_average / 3600  # Convert seconds to hours
    max_hours = max_duration / 3600
    
    # Calculate median
    sorted_times = sorted(session_times)
    median = sorted_times[len(sorted_times) // 2]
    median_hours = median / 3600
    
    # Calculate 25th and 75th percentiles
    p25 = sorted_times[len(sorted_times) // 4] / 3600
    p75 = sorted_times[len(sorted_times) * 3 // 4] / 3600

    print("\nTotal Session Time Statistics:")
    print("--------------------------------")
    print(f"Number of Users: {total_users:,}")  # Add comma separator for large numbers
    print(f"Average Total Time: {average_hours:.2f} hours")
    print(f"Maximum Total Time: {max_hours:.2f} hours")
    print(f"Median Total Time: {median_hours:.2f} hours")
    print(f"25th Percentile: {p25:.2f} hours")
    print(f"75th Percentile: {p75:.2f} hours")
    print("--------------------------------")
else:
    print("No total session time data available")
# Out:
# Total Session Time Statistics:
# --------------------------------
# Number of Users: 1,675
# Average Total Time: 0.73 hours
# Maximum Total Time: 26.75 hours
# Median Total Time: 0.00 hours
# 25th Percentile: 0.00 hours
# 75th Percentile: 0.00 hours
# --------------------------------

# %%
# Query to get session frequencies for all users
query_response = supabase.table("user_table_refined").select("frequency_of_sessions").execute()

# Filter out None values and collect all frequencies
session_frequencies = [
    user["frequency_of_sessions"] 
    for user in query_response.data 
    if user["frequency_of_sessions"] is not None
]

if session_frequencies:
    # Calculate statistics
    total_users = len(session_frequencies)
    overall_average = sum(session_frequencies) / total_users
    max_frequency = max(session_frequencies)
    
    # Calculate median
    sorted_frequencies = sorted(session_frequencies)
    median = sorted_frequencies[len(sorted_frequencies) // 2]
    
    # Calculate 25th and 75th percentiles
    p25 = sorted_frequencies[len(sorted_frequencies) // 4]
    p75 = sorted_frequencies[len(sorted_frequencies) * 3 // 4]

    print("\nSession Frequency Statistics (30-day period):")
    print("--------------------------------")
    print(f"Number of Users: {total_users:,}")  # Add comma separator for large numbers
    print(f"Average Sessions per User: {overall_average:.1f}")
    print(f"Maximum Sessions: {max_frequency}")
    print(f"Median Sessions: {median}")
    print(f"25th Percentile: {p25}")
    print(f"75th Percentile: {p75}")
    print("--------------------------------")
    
    # Calculate distribution buckets
    print("\nSession Frequency Distribution:")
    print("--------------------------------")
    ranges = [(0, 1), (2, 5), (6, 10), (11, 20), (21, 30), (31, float('inf'))]
    for start, end in ranges:
        if end == float('inf'):
            count = sum(1 for f in session_frequencies if f >= start)
            percentage = (count / total_users) * 100
            print(f"{start}+ sessions: {count:,} users ({percentage:.1f}%)")
        else:
            count = sum(1 for f in session_frequencies if start <= f <= end)
            percentage = (count / total_users) * 100
            print(f"{start}-{end} sessions: {count:,} users ({percentage:.1f}%)")
    print("--------------------------------")
else:
    print("No session frequency data available")
# Out:
# Session Frequency Statistics (30-day period):
# --------------------------------
# Number of Users: 1,675
# Average Sessions per User: 4.2
# Maximum Sessions: 104
# Median Sessions: 0
# 25th Percentile: 0
# 75th Percentile: 1
# --------------------------------
#
# Session Frequency Distribution:
# --------------------------------
# 0-1 sessions: 1,296 users (77.4%)
# 2-5 sessions: 99 users (5.9%)
# 6-10 sessions: 52 users (3.1%)
# 11-20 sessions: 91 users (5.4%)
# 21-30 sessions: 61 users (3.6%)
# 31+ sessions: 76 users (4.5%)
# --------------------------------

# %%
# Query to get 30-day retention rates for all users
query_response = supabase.table("user_table_refined").select("user_retention_30").execute()

# Filter out None values and collect all retention rates
retention_rates = [
    user["user_retention_30"] 
    for user in query_response.data 
    if user["user_retention_30"] is not None
]

if retention_rates:
    # Calculate statistics
    total_users = len(retention_rates)
    overall_average = sum(retention_rates) / total_users
    max_retention = max(retention_rates)
    
    # Calculate median
    sorted_rates = sorted(retention_rates)
    median = sorted_rates[len(sorted_rates) // 2]
    
    # Calculate 25th and 75th percentiles
    p25 = sorted_rates[len(sorted_rates) // 4]
    p75 = sorted_rates[len(sorted_rates) * 3 // 4]

    print("\n30-Day Retention Statistics:")
    print("--------------------------------")
    print(f"Number of Users: {total_users:,}")
    print(f"Average Retention Rate: {overall_average:.1%}")
    print(f"Maximum Retention Rate: {max_retention:.1%}")
    print(f"Median Retention Rate: {median:.1%}")
    print(f"25th Percentile: {p25:.1%}")
    print(f"75th Percentile: {p75:.1%}")
    print("--------------------------------")
    
    # Calculate distribution buckets
    print("\nRetention Rate Distribution:")
    print("--------------------------------")
    ranges = [(0, 0.1), (0.1, 0.3), (0.3, 0.5), (0.5, 0.7), (0.7, 0.9), (0.9, 1.0)]
    for start, end in ranges:
        count = sum(1 for r in retention_rates if start <= r <= end)
        percentage = (count / total_users) * 100
        print(f"{start*100:.0f}%-{end*100:.0f}%: {count:,} users ({percentage:.1f}%)")
    print("--------------------------------")
else:
    print("No retention rate data available")
# Out:
# 30-Day Retention Statistics:
# --------------------------------
# Number of Users: 1,675
# Average Retention Rate: 1.9%
# Maximum Retention Rate: 16.7%
# Median Retention Rate: 0.0%
# 25th Percentile: 0.0%
# 75th Percentile: 3.3%
# --------------------------------
#
# Retention Rate Distribution:
# --------------------------------
# 0%-10%: 1,644 users (98.1%)
# 10%-30%: 177 users (10.6%)
# 30%-50%: 0 users (0.0%)
# 50%-70%: 0 users (0.0%)
# 70%-90%: 0 users (0.0%)
# 90%-100%: 0 users (0.0%)
# --------------------------------

# %%
# Query to get daily active periods for all users
query_response = supabase.table("user_table_refined").select("daily_active_periods").execute()

# Flatten all periods and count occurrences
period_counts = {}
for user in query_response.data:
    if user["daily_active_periods"]:  # Check if not None or empty
        # Count each unique period only once per user
        user_periods = set(period["hour"] for period in user["daily_active_periods"])
        for period in user_periods:
            period_counts[period] = period_counts.get(period, 0) + 1

# Get top 5 most common periods
top_5_periods = sorted(
    period_counts.items(),
    key=lambda x: x[1],  # Sort by count
    reverse=True
)[:5]

# Calculate percentage of users for each period
total_users = len([u for u in query_response.data if u["daily_active_periods"]])

print("\nTop 5 Most Active Time Periods:")
print("--------------------------------")
for hour, count in top_5_periods:
    percentage = (count / total_users) * 100 if total_users > 0 else 0
    # Format the time period
    start_hour = int(hour)
    end_hour = (start_hour + 1) % 24
    period = f"{str(start_hour).zfill(2)}:00-{str(end_hour).zfill(2)}:00"
    
    print(f"Time Period: {period}")
    print(f"Number of Users: {count:,}")
    print(f"Percentage of Users: {percentage:.1f}%")
    print("--------------------------------")

# %%
# Query to get daily active periods for all users
query_response = supabase.table("user_table_refined").select("daily_active_periods").execute()

# Flatten all periods and count occurrences
period_counts = {}
for user in query_response.data:
    if user["daily_active_periods"]:  # Check if not None or empty
        # Count each unique period only once per user
        user_periods = set(period["hour"] for period in user["daily_active_periods"])
        for period in user_periods:
            period_counts[period] = period_counts.get(period, 0) + 1

# Get top 10 most common periods
top_10_periods = sorted(
    period_counts.items(),
    key=lambda x: x[1],  # Sort by count
    reverse=True
)[:10]

# Calculate percentage of users for each period
total_users = len([u for u in query_response.data if u["daily_active_periods"]])

print("\nTop 10 Most Active Time Periods:")
print("--------------------------------")
for hour, count in top_10_periods:
    percentage = (count / total_users) * 100 if total_users > 0 else 0
    # Format the time period
    start_hour = int(hour)
    end_hour = (start_hour + 1) % 24
    period = f"{str(start_hour).zfill(2)}:00-{str(end_hour).zfill(2)}:00"
    
    print(f"Time Period: {period}")
    print(f"Number of Users: {count:,}")
    print(f"Percentage of Users: {percentage:.1f}%")
    print("--------------------------------")
# Out:
# Top 10 Most Active Time Periods:
# --------------------------------
# Time Period: 15:00-16:00
# Number of Users: 757
# Percentage of Users: 45.2%
# --------------------------------
# Time Period: 19:00-20:00
# Number of Users: 717
# Percentage of Users: 42.8%
# --------------------------------
# Time Period: 14:00-15:00
# Number of Users: 709
# Percentage of Users: 42.3%
# --------------------------------
# Time Period: 16:00-17:00
# Number of Users: 693
# Percentage of Users: 41.4%
# --------------------------------
# Time Period: 18:00-19:00
# Number of Users: 671
# Percentage of Users: 40.1%
# --------------------------------
# Time Period: 17:00-18:00
# Number of Users: 653
# Percentage of Users: 39.0%
# --------------------------------
# Time Period: 20:00-21:00
# Number of Users: 597
# Percentage of Users: 35.6%
# --------------------------------
# Time Period: 13:00-14:00
# Number of Users: 486
# Percentage of Users: 29.0%
# --------------------------------
# Time Period: 21:00-22:00
# Number of Users: 449
# Percentage of Users: 26.8%
# --------------------------------
# Time Period: 22:00-23:00
# Number of Users: 264
# Percentage of Users: 15.8%
# --------------------------------
