# %%
# import psycopg2
# from dotenv import load_dotenv
# import os

# # Load environment variables from .env
# load_dotenv()

# # Fetch variables
# USER = os.getenv("USER")
# PASSWORD = os.getenv("PASSWORD")
# HOST = os.getenv("HOST")
# PORT = os.getenv("PORT")
# DBNAME = os.getenv("DBNAME")

# # Connect to the database
# try:
#     connection = psycopg2.connect(
#         user=USER, password=PASSWORD, host=HOST, port=PORT, dbname=DBNAME
#     )
#     print(
#         "Connection successful as user: ",
#         USER,
#         "on database: ",
#         DBNAME,
#         "password: ",
#         PASSWORD,
#     )
#     # Create a cursor to execute SQL queries
#     cursor = connection.cursor()
#     # Example query
#     cursor.execute("SELECT NOW();")
#     result = cursor.fetchone()
#     print("Current Time:", result)
#     # Close the cursor and connection
#     cursor.close()
#     connection.close()
#     print("Connection closed.")

# except Exception as e:
#     print(f"Failed to connect: {e}")

# %%
# import os
# from supabase import create_client, Client
# from dotenv import load_dotenv

# # Load environment variables from .env
# load_dotenv()

# try:
#     # Initialize Supabase client
#     supabase: Client = create_client(
#         supabase_url=os.getenv("SUPABASE_URL"), supabase_key=os.getenv("SUPABASE_KEY")
#     )

#     # Test the connection with a simple query
#     response = supabase.table("test").select("*").limit(1).execute()
#     print("Connection successful!")
#     print("Sample data:", response.data)

# except Exception as e:
#     print(f"Failed to connect: {e}")
# Out:
# Connection successful!
# Sample data: [{'id': 56, 'created_at': '2025-02-14T07:36:15+00:00'}]

# %%
# %%time
import ijson
import pandas as pd
from pathlib import Path

file_path = f"/Users/krish/Projects/CxC_Data/2024/amplitude_export_chunk_1_anonymized.json"

# non-empty columns
columns_keep = [
    "$insert_id",
    "amplitude_id",
    "app",
    "city",
    "client_event_time",
    "client_upload_time",
    "country",
    "data",
    "data_type",
    "device_family",
    "device_id",
    "device_type",
    "dma",
    "event_id",
    "event_properties",
    "event_time",
    "event_type",
    "language",
    "library",
    "os_name",
    "os_version",
    "platform",
    "processed_time",
    "region",
    "server_received_time",
    "server_upload_time",
    "session_id",
    "user_id",
    "user_properties",
    "uuid",
]

with open(file_path, "r") as f:
    # Get just the first item from the JSON file
    objects = ijson.items(f, "item")
    first_row = next(objects)
    
    # Convert to DataFrame and select desired columns
    df = pd.DataFrame([first_row])
    df = df[columns_keep]
    
    print("First row of data:")
    print(df)
# Out:
# First row of data:
#                              $insert_id  amplitude_id     app       city  \
# 0  b5aa91c6-ac17-4bfe-8def-df50869540b0  857540442426  591532  Covington
#
#             client_event_time          client_upload_time        country  \
# 0  2024-06-14 23:06:34.898000  2024-06-14 23:06:35.998000  United States
#
#                                                 data data_type device_family  \
# 0  {'path': '/2/httpapi', 'group_first_event': {}...     event       Windows
#
#    ... os_version platform              processed_time   region  \
# 0  ...        125      Web  2024-06-14 23:06:36.809000  Georgia
#
#          server_received_time          server_upload_time     session_id  \
# 0  2024-06-14 23:06:35.998000  2024-06-14 23:06:36.007000  1718399623706
#
#                                 user_id  \
# 0  01708ccf-437b-44ed-b5a0-2fed8f7761d3
#
#                                      user_properties  \
# 0  {'initial_utm_medium': 'EMPTY', 'initial_refer...
#
#                                    uuid
# 0  f10e3860-18f7-4e43-93d9-29bda5edb636
#
# [1 rows x 30 columns]
# CPU times: user 8.57 ms, sys: 5.63 ms, total: 14.2 ms
# Wall time: 14.6 ms

# %%
# %%time
import ijson
import pandas as pd
import json
from pathlib import Path

file_path = f"/Users/krish/Projects/CxC_Data/2024/amplitude_export_chunk_1_anonymized.json"

# Important columns with their preprocessing requirements
columns_keep = {
    # PDNP (Probably Doesn't Need Preprocessing)
    'uuid': {'type': 'PDNP'},  # Added as primary interaction ID
    'amplitude_id': {'type': 'PDNP'},
    'app': {'type': 'PDNP'},
    'data_type': {'type': 'PDNP'},
    'device_family': {'type': 'PDNP'},
    'device_id': {'type': 'PDNP'},
    'device_type': {'type': 'PDNP'},
    'event_type': {'type': 'PDNP'},
    'language': {'type': 'PDNP'},
    'os_name': {'type': 'PDNP'},
    'platform': {'type': 'PDNP'},
    
    # PNP (Probably Needs Preprocessing)
    'data': {'type': 'PNP'},
    'dma': {'type': 'PNP'},
    'event_id': {'type': 'PNP'},
    'event_properties': {'type': 'PNP'},
    'user_properties': {'type': 'PNP'},
    
    # Location fields
    'city': {'type': 'location'},
    'country': {'type': 'location'},
    'region': {'type': 'location'},
    
    # Time and Session
    'event_time': {'type': 'time'},
    'session_id': {'type': 'session'}
}

def preprocess_row(row):
    # Convert row to DataFrame for easier handling
    df = pd.DataFrame([row])
    
    # 1. Basic null check for PDNP fields
    pdnp_columns = [col for col, info in columns_keep.items() if info['type'] == 'PDNP']
    if df[pdnp_columns].isnull().any(axis=1).iloc[0]:
        print("Row dropped: Missing values in PDNP fields")
        return None
    
    # 2. Validate UUID format
    uuid = df['uuid'].iloc[0]
    if not isinstance(uuid, str) or len(uuid.split('-')) != 5:
        print("Row dropped: Invalid UUID format")
        return None
    
    # 3. Location validation
    if df['country'].iloc[0] == "United States":
        if pd.isnull(df['dma'].iloc[0]):
            print("Row dropped: Missing DMA for US location")
            return None
    
    # 4. Validate event_id is numeric
    try:
        event_id = int(df['event_id'].iloc[0])
        if event_id <= 0:
            print("Row dropped: Invalid event_id")
            return None
    except (ValueError, TypeError):
        print("Row dropped: Non-numeric event_id")
        return None
    
    # 5. Validate event_properties and user_properties are proper JSON
    for prop_field in ['event_properties', 'user_properties']:
        if not isinstance(df[prop_field].iloc[0], dict):
            print(f"Row dropped: Invalid {prop_field} format")
            return None
    
    # 6. Validate data field
    if not isinstance(df['data'].iloc[0], dict):
        print("Row dropped: Invalid data format")
        return None
    
    # 7. Validate session_id is numeric
    try:
        session_id = int(df['session_id'].iloc[0])
        if session_id <= 0:
            print("Row dropped: Invalid session_id")
            return None
    except (ValueError, TypeError):
        print("Row dropped: Non-numeric session_id")
        return None
    
    # 8. Validate event_time format
    try:
        pd.to_datetime(df['event_time'].iloc[0])
    except (ValueError, TypeError):
        print("Row dropped: Invalid event_time format")
        return None
    
    return df[columns_keep.keys()]

# Read and process the first row
with open(file_path, "r") as f:
    objects = ijson.items(f, "item")
    first_row = next(objects)
    
    # Process the row
    processed_df = preprocess_row(first_row)
    
    if processed_df is not None:
        print("\nProcessed row:")
        print(processed_df)
    else:
        print("\nRow was filtered out due to preprocessing criteria")
# Out:
# Processed row:
#                                    uuid  amplitude_id     app data_type  \
# 0  f10e3860-18f7-4e43-93d9-29bda5edb636  857540442426  591532     event
#
#   device_family                             device_id device_type  \
# 0       Windows  449d7b98-0a1c-4f2d-bbe6-9b889d4d8e27     Windows
#
#                      event_type language os_name  ...  \
# 0  account-lines::widget:render  English  Chrome  ...
#
#                                                 data          dma event_id  \
# 0  {'path': '/2/httpapi', 'group_first_event': {}...  Atlanta, GA     8247
#
#                                     event_properties  \
# 0  {'displayName': 'Policy Detail Card - EX', 'id...
#
#                                      user_properties       city  \
# 0  {'initial_utm_medium': 'EMPTY', 'initial_refer...  Covington
#
#          country   region                  event_time     session_id
# 0  United States  Georgia  2024-06-14 23:06:34.898000  1718399623706
#
# [1 rows x 21 columns]
# CPU times: user 9.2 ms, sys: 3.13 ms, total: 12.3 ms
# Wall time: 12.2 ms

# %%
# %%time
import ijson
import pandas as pd
import json
from pathlib import Path
from supabase import create_client, Client
from dotenv import load_dotenv
import os

file_path = f"/Users/krish/Projects/CxC_Data/2024/amplitude_export_chunk_1_anonymized.json"

# Important columns with their Supabase types
columns_keep = {
    # UUID fields
    'id': {'type': 'uuid', 'source': 'uuid'},  # Primary key from uuid field
    'device_id': {'type': 'uuid'},
    
    # Integer fields
    'amplitude_id': {'type': 'int8'},
    'app': {'type': 'int8'},
    'event_id': {'type': 'int8'},
    'session_id': {'type': 'int8'},
    
    # Text fields
    'city': {'type': 'text'},
    'country': {'type': 'text'},
    'data_type': {'type': 'text'},
    'device_family': {'type': 'text'},
    'device_type': {'type': 'text'},
    'dma': {'type': 'text'},
    'event_type': {'type': 'text'},
    'language': {'type': 'text'},
    'os_name': {'type': 'text'},
    'platform': {'type': 'text'},
    'region': {'type': 'text'},
    
    # JSON fields
    'data': {'type': 'json'},
    'event_properties': {'type': 'json'},
    'user_properties': {'type': 'json'},
    
    # Timestamp field
    'event_time': {'type': 'timestamp'},
}

def clean_user_properties(props):
    """Convert 'EMPTY' string values to None in user_properties and remove trackingVersion"""
    if not isinstance(props, dict):
        return props
    
    cleaned = {}
    for key, value in props.items():
        # Skip trackingVersion field
        if key == 'trackingVersion':
            continue
            
        if isinstance(value, str) and value == "EMPTY":
            cleaned[key] = None
        elif isinstance(value, list):
            cleaned[key] = value  # Preserve lists (like roles) as is
        else:
            cleaned[key] = value
    return cleaned

def clean_empty_objects(data):
    """Convert empty nested objects to None in data column"""
    if not isinstance(data, dict):
        return data
    
    cleaned = {}
    for key, value in data.items():
        if isinstance(value, dict) and len(value) == 0:
            cleaned[key] = None
        else:
            cleaned[key] = value
    return cleaned

def is_empty_value(val):
    """Check if a value should be considered empty"""
    if pd.isna(val):  # Checks for None and NaN
        return True
    if isinstance(val, str) and val.strip() == "":  # Empty strings or whitespace
        return True
    if val == "None":  # String "None"
        return True
    if isinstance(val, (dict, list)) and len(val) == 0:  # Empty collections
        return True
    return False

def preprocess_row(row):
    # Convert row to DataFrame for easier handling
    df = pd.DataFrame([row])
    
    # Create id from uuid
    df['id'] = df['uuid']

    # Clean user_properties before validation
    if 'user_properties' in df.columns:
        df['user_properties'] = df['user_properties'].apply(clean_user_properties)
    
    # Clean data column before validation
    if 'data' in df.columns:
        df['data'] = df['data'].apply(clean_empty_objects)
    
    # Type validations
    for col, info in columns_keep.items():
        # Get the value for the current column
        val = df[col].iloc[0]
        
        # Check for empty values based on column type
        if is_empty_value(val):
            print(f"Row dropped: Empty value in {col}")
            return None
            
        # Handle special case for id field
        if col == 'id' and info['source'] == 'uuid':
            continue
            
        # UUID validation
        if info['type'] == 'uuid':
            if not isinstance(val, str) or len(val.split('-')) != 5:
                print(f"Row dropped: Invalid UUID format for {col}")
                return None
        
        # Integer validation
        elif info['type'] == 'int8':
            try:
                df[col] = pd.to_numeric(df[col], downcast='integer')
                if df[col].iloc[0] <= 0:
                    print(f"Row dropped: Invalid value for {col}")
                    return None
            except (ValueError, TypeError):
                print(f"Row dropped: Non-numeric {col}")
                return None
        
        # JSON validation
        elif info['type'] == 'json':
            if not isinstance(val, dict):
                print(f"Row dropped: Invalid JSON format for {col}")
                return None
            if len(val) == 0:
                print(f"Row dropped: Empty JSON object in {col}")
                return None
        
        # Text validation
        elif info['type'] == 'text':
            if not isinstance(val, str):
                df[col] = str(val)  # Convert to string if possible
            if len(df[col].iloc[0].strip()) == 0:
                print(f"Row dropped: Empty text in {col}")
                return None
        
        # Timestamp validation
        elif info['type'] == 'timestamp':
            try:
                df[col] = pd.to_datetime(df[col])
            except (ValueError, TypeError):
                print(f"Row dropped: Invalid timestamp for {col}")
                return None
    
    # Location validation for US entries
    if df['country'].iloc[0] == "United States":
        if pd.isnull(df['dma'].iloc[0]) or df['dma'].iloc[0].strip() == "":
            print("Row dropped: Missing DMA for US location")
            return None
    
    return df[columns_keep.keys()]

# Read and process the first row
with open(file_path, "r") as f:
    objects = ijson.items(f, "item")
    first_row = next(objects)
    
    # Process the row
    processed_df = preprocess_row(first_row)
    
    if processed_df is not None:
        print("\nProcessed row:")
        print(processed_df)
        print("\nCleaned user_properties:")
        print(json.dumps(processed_df['user_properties'].iloc[0], indent=2))
        print("\nCleaned data:")
        print(json.dumps(processed_df['data'].iloc[0], indent=2))
    else:
        print("\nRow was filtered out due to preprocessing criteria")
# Out:
# Processed row:
#                                      id                             device_id  \
# 0  f10e3860-18f7-4e43-93d9-29bda5edb636  449d7b98-0a1c-4f2d-bbe6-9b889d4d8e27
#
#    amplitude_id     app  event_id     session_id       city        country  \
# 0  857540442426  591532      8247  1718399623706  Covington  United States
#
#   data_type device_family  ...          dma                    event_type  \
# 0     event       Windows  ...  Atlanta, GA  account-lines::widget:render
#
#   language os_name platform   region  \
# 0  English  Chrome      Web  Georgia
#
#                                                 data  \
# 0  {'path': '/2/httpapi', 'group_first_event': No...
#
#                                     event_properties  \
# 0  {'displayName': 'Policy Detail Card - EX', 'id...
#
#                                      user_properties              event_time
# 0  {'initial_utm_medium': None, 'initial_referrin... 2024-06-14 23:06:34.898
#
# [1 rows x 21 columns]
#
# Cleaned user_properties:
# {
#   "initial_utm_medium": null,
#   "initial_referring_domain": null,
#   "initial_utm_content": null,
#   "roles": [
#     "underwriter"
#   ],
#   "isInternalUser": "False",
#   "initial_utm_campaign": null,
#   "initial_twclid": null,
#   "initial_gclid": null,
#   "hostname": "customer_tozrg.federato.ai",
#   "initial_utm_source": null,
#   "initial_dclid": null,
#   "initial_wbraid": null,
#   "initial_fbclid": null,
#   "initial_utm_id": null,
#   "initial_referrer": null,
#   "initial_gbraid": null,
#   "initial_utm_term": null,
#   "initial_msclkid": null,
#   "initial_ttclid": null,
#   "initial_ko_click_id": null
# }
#
# Cleaned data:
# {
#   "path": "/2/httpapi",
#   "group_first_event": null,
#   "group_ids": null
# }
# CPU times: user 10.4 ms, sys: 2.78 ms, total: 13.2 ms
# Wall time: 13.3 ms

# %%
# %%time
import os
from dotenv import load_dotenv

# Force reload environment variables
os.environ.clear()  # Clear any existing env vars
load_dotenv(override=True)  # Force override

# Print env vars (safely)
print("Current Supabase settings:")
print("URL exists:", os.getenv("SUPABASE_URL") is not None)
print("URL starts with:", os.getenv("SUPABASE_URL")[:20] + "..." if os.getenv("SUPABASE_URL") else "None")
print("Key exists:", os.getenv("SUPABASE_KEY") is not None)
print("Key starts with:", os.getenv("SUPABASE_KEY")[:20] + "..." if os.getenv("SUPABASE_KEY") else "None")

# Initialize Supabase client with fresh credentials
supabase: Client = create_client(
    supabase_url=os.getenv("SUPABASE_URL"),
    supabase_key=os.getenv("SUPABASE_KEY")
)

try:
    # Test connection
    print("\nTesting connection...")
    test_response = supabase.table("test").select("*").limit(1).execute()
    print("Connected to project with data:", test_response.data)
    
except Exception as e:
    print(f"\nError occurred:")
    print(f"Type: {type(e)}")
    print(f"Message: {str(e)}")
# Out:
# Current Supabase settings:
# URL exists: True
# URL starts with: https://vumfmxacputb...
# Key exists: True
# Key starts with: eyJhbGciOiJIUzI1NiIs...
#
# Testing connection...
#
# Error occurred:
# Type: <class 'postgrest.exceptions.APIError'>
# Message: {'code': '42P01', 'details': None, 'hint': None, 'message': 'relation "public.test" does not exist'}
# CPU times: user 48.6 ms, sys: 11.8 ms, total: 60.4 ms
# Wall time: 444 ms

# %%
# %%time
import ijson
import pandas as pd
import json
from pathlib import Path
from supabase import create_client, Client
from dotenv import load_dotenv
import os

file_path = f"/Users/krish/Projects/CxC_Data/2024/amplitude_export_chunk_1_anonymized.json"

# Important columns with their Supabase types
columns_keep = {
    # UUID fields
    'id': {'type': 'uuid', 'source': 'uuid', 'nullable': False},  
    'device_id': {'type': 'uuid', 'nullable': False},
    
    # Integer fields
    'amplitude_id': {'type': 'int8', 'nullable': False},
    'app': {'type': 'int8', 'nullable': False},
    'event_id': {'type': 'int8', 'nullable': False},
    'session_id': {'type': 'int8', 'nullable': False},
    
    # Text fields - some allowed to be null
    'city': {'type': 'text', 'nullable': True},
    'country': {'type': 'text', 'nullable': False},
    'data_type': {'type': 'text', 'nullable': False},
    'device_family': {'type': 'text', 'nullable': True},
    'device_type': {'type': 'text', 'nullable': True},
    'dma': {'type': 'text', 'nullable': True},
    'event_type': {'type': 'text', 'nullable': False},
    'language': {'type': 'text', 'nullable': False},
    'os_name': {'type': 'text', 'nullable': False},
    'platform': {'type': 'text', 'nullable': False},
    'region': {'type': 'text', 'nullable': False},
    
    # JSON fields
    'data': {'type': 'json', 'nullable': False},
    'user_properties': {'type': 'json', 'nullable': True},
    
    # Timestamp field
    'event_time': {'type': 'timestamp', 'nullable': False},
}

def clean_user_properties(props):
    """Convert 'EMPTY' string values to None in user_properties and remove trackingVersion"""
    if not isinstance(props, dict):
        return props
    
    cleaned = {}
    for key, value in props.items():
        # Skip trackingVersion field
        if key == 'trackingVersion':
            continue
            
        if isinstance(value, str) and value == "EMPTY":
            cleaned[key] = None
        elif isinstance(value, list):
            cleaned[key] = value  # Preserve lists (like roles) as is
        else:
            cleaned[key] = value
    return cleaned

def clean_empty_objects(data):
    """Convert empty nested objects to None in data column"""
    if not isinstance(data, dict):
        return data
    
    cleaned = {}
    for key, value in data.items():
        if isinstance(value, dict) and len(value) == 0:
            cleaned[key] = None
        else:
            cleaned[key] = value
    return cleaned

def is_empty_value(val):
    """Check if a value should be considered empty"""
    if pd.isna(val):  # Checks for None and NaN
        return True
    if isinstance(val, str) and val.strip() == "":  # Empty strings or whitespace
        return True
    if val == "None":  # String "None"
        return True
    if isinstance(val, (dict, list)) and len(val) == 0:  # Empty collections
        return True
    return False

def preprocess_row(row):
    # Convert row to DataFrame for easier handling
    df = pd.DataFrame([row])
    
    # Create id from uuid
    df['id'] = df['uuid']

    # Clean user_properties before validation
    if 'user_properties' in df.columns:
        df['user_properties'] = df['user_properties'].apply(clean_user_properties)
    
    # Clean data column before validation
    if 'data' in df.columns:
        df['data'] = df['data'].apply(clean_empty_objects)
    
    # Type validations
    for col, info in columns_keep.items():
        # Get the value for the current column
        val = df[col].iloc[0]
        
        # Skip empty value check for nullable fields
        if not info['nullable']:
            if is_empty_value(val):
                print(f"Row dropped: Empty value in non-nullable field {col}")
                return None
            
        # Handle special case for id field
        if col == 'id' and info['source'] == 'uuid':
            continue
            
        # UUID validation
        if info['type'] == 'uuid':
            if not isinstance(val, str) or len(val.split('-')) != 5:
                print(f"Row dropped: Invalid UUID format for {col}")
                return None
        
        # Integer validation
        elif info['type'] == 'int8':
            try:
                df[col] = pd.to_numeric(df[col], downcast='integer')
                if df[col].iloc[0] <= 0:
                    print(f"Row dropped: Invalid value for {col}")
                    return None
            except (ValueError, TypeError):
                print(f"Row dropped: Non-numeric {col}")
                return None
        
        # JSON validation
        elif info['type'] == 'json':
            if not info['nullable']:
                if not isinstance(val, dict):
                    print(f"Row dropped: Invalid JSON format for {col}")
                    return None
                if len(val) == 0:
                    print(f"Row dropped: Empty JSON object in {col}")
                    return None
            elif val is not None:  # For nullable JSON fields, validate only if not None
                if not isinstance(val, dict):
                    print(f"Row dropped: Invalid JSON format for {col}")
                    return None
        
        # Text validation
        elif info['type'] == 'text':
            if not info['nullable']:
                if not isinstance(val, str):
                    df[col] = str(val)  # Convert to string if possible
                if len(df[col].iloc[0].strip()) == 0:
                    print(f"Row dropped: Empty text in non-nullable field {col}")
                    return None
            elif val is not None:  # For nullable text fields, validate only if not None
                if not isinstance(val, str):
                    df[col] = str(val)
        
        # Timestamp validation
        elif info['type'] == 'timestamp':
            try:
                df[col] = pd.to_datetime(df[col])
            except (ValueError, TypeError):
                print(f"Row dropped: Invalid timestamp for {col}")
                return None
    
    # Location validation for US entries
    # if df['country'].iloc[0] == "United States":
    #     if pd.isnull(df['dma'].iloc[0]) or df['dma'].iloc[0].strip() == "":
    #         print("Row dropped: Missing DMA for US location")
    #         return None
    
    return df[columns_keep.keys()]

# Initialize Supabase client
load_dotenv()
supabase: Client = create_client(
    supabase_url=os.getenv("SUPABASE_URL"),
    supabase_key=os.getenv("SUPABASE_KEY")
)

# Process rows in batches
batch_size = 1000  # Adjust based on your needs
processed_rows = []
total_rows = 0
valid_rows = 0
error_rows = 0

with open(file_path, "r") as f:
    objects = ijson.items(f, "item")
    
    for row in objects:
        total_rows += 1
        
        # Process the row
        processed_df = preprocess_row(row)
        
        if processed_df is not None:
            # Convert timestamp to ISO format - fixed version
            processed_df['event_time'] = processed_df['event_time'].iloc[0].strftime('%Y-%m-%dT%H:%M:%S.%fZ')
            
            # Convert row to dictionary
            row_dict = processed_df.iloc[0].to_dict()
            processed_rows.append(row_dict)
            valid_rows += 1
            
            # When batch is full, insert into Supabase
            if len(processed_rows) >= batch_size:
                try:
                    response = supabase.table('federato_amplitude_data').insert(processed_rows).execute()
                    print(f"\nInserted batch of {len(processed_rows)} rows")
                    processed_rows = []  # Clear the batch
                except Exception as e:
                    print(f"\nError inserting batch: {e}")
                    error_rows += len(processed_rows)
                    processed_rows = []  # Clear the batch even if there's an error
        else:
            error_rows += 1
        
        # Print progress
        if total_rows % 1000 == 0:
            print(f"\nProgress: Processed {total_rows} rows")
            print(f"Valid rows: {valid_rows}")
            print(f"Error rows: {error_rows}")

# Insert any remaining rows
if processed_rows:
    try:
        response = supabase.table('federato_amplitude_data').insert(processed_rows).execute()
        print(f"\nInserted final batch of {len(processed_rows)} rows")
    except Exception as e:
        print(f"\nError inserting final batch: {e}")
        error_rows += len(processed_rows)

# Print final statistics
print("\nProcessing complete!")
print(f"Total rows processed: {total_rows}")
print(f"Valid rows inserted: {valid_rows}")
print(f"Error rows: {error_rows}")
# Out:
# Inserted batch of 1000 rows
#
# Progress: Processed 1000 rows
# Valid rows: 1000
# Error rows: 0
#
# Inserted batch of 1000 rows
#
# Progress: Processed 2000 rows
# Valid rows: 2000
# Error rows: 0
#
# Inserted batch of 1000 rows
#
# Progress: Processed 3000 rows
# Valid rows: 3000
# Error rows: 0
#
# Inserted batch of 1000 rows
#
# Progress: Processed 4000 rows
# Valid rows: 4000
# Error rows: 0
#
# Inserted batch of 1000 rows
#
# Progress: Processed 5000 rows
# Valid rows: 5000
# Error rows: 0
#
# Inserted batch of 1000 rows
#
# Progress: Processed 6000 rows
# Valid rows: 6000
# Error rows: 0
#
# Inserted batch of 1000 rows
#
# Progress: Processed 7000 rows
# Valid rows: 7000
# Error rows: 0
#
# Inserted batch of 1000 rows
#
# Progress: Processed 8000 rows
# Valid rows: 8000
# Error rows: 0
#
# Inserted batch of 1000 rows
#
# Progress: Processed 9000 rows
# Valid rows: 9000
# Error rows: 0
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
#
# Progress: Processed 10000 rows
# Valid rows: 9998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 11000 rows
# Valid rows: 10998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 12000 rows
# Valid rows: 11998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 13000 rows
# Valid rows: 12998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 14000 rows
# Valid rows: 13998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 15000 rows
# Valid rows: 14998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 16000 rows
# Valid rows: 15998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 17000 rows
# Valid rows: 16998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 18000 rows
# Valid rows: 17998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 19000 rows
# Valid rows: 18998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 20000 rows
# Valid rows: 19998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 21000 rows
# Valid rows: 20998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 22000 rows
# Valid rows: 21998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 23000 rows
# Valid rows: 22998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 24000 rows
# Valid rows: 23998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 25000 rows
# Valid rows: 24998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 26000 rows
# Valid rows: 25998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 27000 rows
# Valid rows: 26998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 28000 rows
# Valid rows: 27998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 29000 rows
# Valid rows: 28998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 30000 rows
# Valid rows: 29998
# Error rows: 2
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
#
# Progress: Processed 31000 rows
# Valid rows: 30997
# Error rows: 3
#
# Inserted batch of 1000 rows
#
# Progress: Processed 32000 rows
# Valid rows: 31997
# Error rows: 3
#
# Inserted batch of 1000 rows
#
# Progress: Processed 33000 rows
# Valid rows: 32997
# Error rows: 3
#
# Inserted batch of 1000 rows
#
# Progress: Processed 34000 rows
# Valid rows: 33997
# Error rows: 3
#
# Inserted batch of 1000 rows
#
# Progress: Processed 35000 rows
# Valid rows: 34997
# Error rows: 3
#
# Inserted batch of 1000 rows
#
# Progress: Processed 36000 rows
# Valid rows: 35997
# Error rows: 3
#
# Inserted batch of 1000 rows
#
# Progress: Processed 37000 rows
# Valid rows: 36997
# Error rows: 3
#
# Inserted batch of 1000 rows
#
# Progress: Processed 38000 rows
# Valid rows: 37997
# Error rows: 3
#
# Inserted batch of 1000 rows
#
# Progress: Processed 39000 rows
# Valid rows: 38997
# Error rows: 3
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
#
# Progress: Processed 40000 rows
# Valid rows: 39996
# Error rows: 4
#
# Inserted batch of 1000 rows
#
# Progress: Processed 41000 rows
# Valid rows: 40996
# Error rows: 4
#
# Inserted batch of 1000 rows
#
# Progress: Processed 42000 rows
# Valid rows: 41996
# Error rows: 4
#
# Inserted batch of 1000 rows
#
# Progress: Processed 43000 rows
# Valid rows: 42996
# Error rows: 4
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
#
# Progress: Processed 44000 rows
# Valid rows: 43995
# Error rows: 5
#
# Inserted batch of 1000 rows
#
# Progress: Processed 45000 rows
# Valid rows: 44995
# Error rows: 5
#
# Inserted batch of 1000 rows
#
# Progress: Processed 46000 rows
# Valid rows: 45995
# Error rows: 5
#
# Inserted batch of 1000 rows
#
# Progress: Processed 47000 rows
# Valid rows: 46995
# Error rows: 5
#
# Inserted batch of 1000 rows
#
# Progress: Processed 48000 rows
# Valid rows: 47995
# Error rows: 5
#
# Inserted batch of 1000 rows
#
# Progress: Processed 49000 rows
# Valid rows: 48995
# Error rows: 5
#
# Inserted batch of 1000 rows
#
# Progress: Processed 50000 rows
# Valid rows: 49995
# Error rows: 5
#
# Inserted batch of 1000 rows
#
# Progress: Processed 51000 rows
# Valid rows: 50995
# Error rows: 5
#
# Inserted batch of 1000 rows
#
# Progress: Processed 52000 rows
# Valid rows: 51995
# Error rows: 5
#
# Inserted batch of 1000 rows
#
# Progress: Processed 53000 rows
# Valid rows: 52995
# Error rows: 5
#
# Inserted batch of 1000 rows
#
# Progress: Processed 54000 rows
# Valid rows: 53995
# Error rows: 5
#
# Inserted batch of 1000 rows
#
# Progress: Processed 55000 rows
# Valid rows: 54995
# Error rows: 5
#
# Inserted batch of 1000 rows
#
# Progress: Processed 56000 rows
# Valid rows: 55995
# Error rows: 5
#
# Inserted batch of 1000 rows
#
# Progress: Processed 57000 rows
# Valid rows: 56995
# Error rows: 5
#
# Inserted batch of 1000 rows
#
# Progress: Processed 58000 rows
# Valid rows: 57995
# Error rows: 5
#
# Inserted batch of 1000 rows
#
# Progress: Processed 59000 rows
# Valid rows: 58995
# Error rows: 5
#
# Inserted batch of 1000 rows
#
# Progress: Processed 60000 rows
# Valid rows: 59995
# Error rows: 5
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
#
# Progress: Processed 61000 rows
# Valid rows: 60994
# Error rows: 6
#
# Inserted batch of 1000 rows
#
# Progress: Processed 62000 rows
# Valid rows: 61994
# Error rows: 6
#
# Inserted batch of 1000 rows
#
# Progress: Processed 63000 rows
# Valid rows: 62994
# Error rows: 6
#
# Inserted batch of 1000 rows
#
# Progress: Processed 64000 rows
# Valid rows: 63994
# Error rows: 6
#
# Inserted batch of 1000 rows
#
# Progress: Processed 65000 rows
# Valid rows: 64994
# Error rows: 6
#
# Inserted batch of 1000 rows
#
# Progress: Processed 66000 rows
# Valid rows: 65994
# Error rows: 6
#
# Inserted batch of 1000 rows
#
# Progress: Processed 67000 rows
# Valid rows: 66994
# Error rows: 6
#
# Inserted batch of 1000 rows
#
# Progress: Processed 68000 rows
# Valid rows: 67994
# Error rows: 6
#
# Inserted batch of 1000 rows
#
# Progress: Processed 69000 rows
# Valid rows: 68994
# Error rows: 6
#
# Inserted batch of 1000 rows
#
# Progress: Processed 70000 rows
# Valid rows: 69994
# Error rows: 6
#
# Inserted batch of 1000 rows
#
# Progress: Processed 71000 rows
# Valid rows: 70994
# Error rows: 6
#
# Inserted batch of 1000 rows
#
# Progress: Processed 72000 rows
# Valid rows: 71994
# Error rows: 6
#
# Inserted batch of 1000 rows
#
# Progress: Processed 73000 rows
# Valid rows: 72994
# Error rows: 6
#
# Inserted batch of 1000 rows
#
# Progress: Processed 74000 rows
# Valid rows: 73994
# Error rows: 6
#
# Inserted batch of 1000 rows
#
# Progress: Processed 75000 rows
# Valid rows: 74994
# Error rows: 6
#
# Inserted batch of 1000 rows
#
# Progress: Processed 76000 rows
# Valid rows: 75994
# Error rows: 6
#
# Inserted batch of 1000 rows
#
# Progress: Processed 77000 rows
# Valid rows: 76994
# Error rows: 6
#
# Inserted batch of 1000 rows
#
# Progress: Processed 78000 rows
# Valid rows: 77994
# Error rows: 6
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
#
# Progress: Processed 79000 rows
# Valid rows: 78993
# Error rows: 7
#
# Inserted batch of 1000 rows
#
# Progress: Processed 80000 rows
# Valid rows: 79993
# Error rows: 7
#
# Inserted batch of 1000 rows
#
# Progress: Processed 81000 rows
# Valid rows: 80993
# Error rows: 7
#
# Inserted batch of 1000 rows
#
# Progress: Processed 82000 rows
# Valid rows: 81993
# Error rows: 7
#
# Inserted batch of 1000 rows
#
# Progress: Processed 83000 rows
# Valid rows: 82993
# Error rows: 7
#
# Inserted batch of 1000 rows
#
# Progress: Processed 84000 rows
# Valid rows: 83993
# Error rows: 7
#
# Inserted batch of 1000 rows
# Row dropped: Empty value in non-nullable field region
# Row dropped: Invalid value for event_id
#
# Progress: Processed 85000 rows
# Valid rows: 84991
# Error rows: 9
#
# Inserted batch of 1000 rows
#
# Progress: Processed 86000 rows
# Valid rows: 85991
# Error rows: 9
#
# Inserted batch of 1000 rows
#
# Progress: Processed 87000 rows
# Valid rows: 86991
# Error rows: 9
#
# Inserted batch of 1000 rows
#
# Progress: Processed 88000 rows
# Valid rows: 87991
# Error rows: 9
#
# Inserted batch of 1000 rows
# Row dropped: Empty value in non-nullable field region
#
# Progress: Processed 89000 rows
# Valid rows: 88990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 90000 rows
# Valid rows: 89990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 91000 rows
# Valid rows: 90990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 92000 rows
# Valid rows: 91990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 93000 rows
# Valid rows: 92990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 94000 rows
# Valid rows: 93990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 95000 rows
# Valid rows: 94990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 96000 rows
# Valid rows: 95990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 97000 rows
# Valid rows: 96990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 98000 rows
# Valid rows: 97990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 99000 rows
# Valid rows: 98990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 100000 rows
# Valid rows: 99990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 101000 rows
# Valid rows: 100990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 102000 rows
# Valid rows: 101990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 103000 rows
# Valid rows: 102990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 104000 rows
# Valid rows: 103990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 105000 rows
# Valid rows: 104990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 106000 rows
# Valid rows: 105990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 107000 rows
# Valid rows: 106990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 108000 rows
# Valid rows: 107990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 109000 rows
# Valid rows: 108990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 110000 rows
# Valid rows: 109990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 111000 rows
# Valid rows: 110990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 112000 rows
# Valid rows: 111990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 113000 rows
# Valid rows: 112990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 114000 rows
# Valid rows: 113990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 115000 rows
# Valid rows: 114990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 116000 rows
# Valid rows: 115990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 117000 rows
# Valid rows: 116990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 118000 rows
# Valid rows: 117990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 119000 rows
# Valid rows: 118990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 120000 rows
# Valid rows: 119990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 121000 rows
# Valid rows: 120990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 122000 rows
# Valid rows: 121990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 123000 rows
# Valid rows: 122990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 124000 rows
# Valid rows: 123990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 125000 rows
# Valid rows: 124990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 126000 rows
# Valid rows: 125990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 127000 rows
# Valid rows: 126990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 128000 rows
# Valid rows: 127990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 129000 rows
# Valid rows: 128990
# Error rows: 10
#
# Inserted batch of 1000 rows
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
#
# Progress: Processed 130000 rows
# Valid rows: 129946
# Error rows: 54
#
# Inserted batch of 1000 rows
#
# Progress: Processed 131000 rows
# Valid rows: 130946
# Error rows: 54
#
# Inserted batch of 1000 rows
#
# Progress: Processed 132000 rows
# Valid rows: 131946
# Error rows: 54
#
# Inserted batch of 1000 rows
#
# Progress: Processed 133000 rows
# Valid rows: 132946
# Error rows: 54
#
# Inserted batch of 1000 rows
#
# Progress: Processed 134000 rows
# Valid rows: 133946
# Error rows: 54
#
# Inserted batch of 1000 rows
#
# Progress: Processed 135000 rows
# Valid rows: 134946
# Error rows: 54
#
# Inserted batch of 1000 rows
#
# Progress: Processed 136000 rows
# Valid rows: 135946
# Error rows: 54
#
# Inserted batch of 1000 rows
#
# Progress: Processed 137000 rows
# Valid rows: 136946
# Error rows: 54
#
# Inserted batch of 1000 rows
#
# Progress: Processed 138000 rows
# Valid rows: 137946
# Error rows: 54
#
# Inserted batch of 1000 rows
#
# Progress: Processed 139000 rows
# Valid rows: 138946
# Error rows: 54
#
# Inserted batch of 1000 rows
#
# Progress: Processed 140000 rows
# Valid rows: 139946
# Error rows: 54
#
# Inserted batch of 1000 rows
#
# Progress: Processed 141000 rows
# Valid rows: 140946
# Error rows: 54
#
# Inserted batch of 1000 rows
#
# Progress: Processed 142000 rows
# Valid rows: 141946
# Error rows: 54
#
# Inserted batch of 1000 rows
#
# Progress: Processed 143000 rows
# Valid rows: 142946
# Error rows: 54
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
#
# Progress: Processed 144000 rows
# Valid rows: 143945
# Error rows: 55
#
# Inserted batch of 1000 rows
#
# Progress: Processed 145000 rows
# Valid rows: 144945
# Error rows: 55
#
# Inserted batch of 1000 rows
#
# Progress: Processed 146000 rows
# Valid rows: 145945
# Error rows: 55
#
# Inserted batch of 1000 rows
#
# Progress: Processed 147000 rows
# Valid rows: 146945
# Error rows: 55
#
# Inserted batch of 1000 rows
#
# Progress: Processed 148000 rows
# Valid rows: 147945
# Error rows: 55
#
# Inserted batch of 1000 rows
#
# Progress: Processed 149000 rows
# Valid rows: 148945
# Error rows: 55
#
# Inserted batch of 1000 rows
#
# Progress: Processed 150000 rows
# Valid rows: 149945
# Error rows: 55
#
# Inserted batch of 1000 rows
#
# Progress: Processed 151000 rows
# Valid rows: 150945
# Error rows: 55
#
# Inserted batch of 1000 rows
#
# Progress: Processed 152000 rows
# Valid rows: 151945
# Error rows: 55
#
# Inserted batch of 1000 rows
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
#
# Progress: Processed 153000 rows
# Valid rows: 152905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 154000 rows
# Valid rows: 153905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 155000 rows
# Valid rows: 154905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 156000 rows
# Valid rows: 155905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 157000 rows
# Valid rows: 156905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 158000 rows
# Valid rows: 157905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 159000 rows
# Valid rows: 158905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 160000 rows
# Valid rows: 159905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 161000 rows
# Valid rows: 160905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 162000 rows
# Valid rows: 161905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 163000 rows
# Valid rows: 162905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 164000 rows
# Valid rows: 163905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 165000 rows
# Valid rows: 164905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 166000 rows
# Valid rows: 165905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 167000 rows
# Valid rows: 166905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 168000 rows
# Valid rows: 167905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 169000 rows
# Valid rows: 168905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 170000 rows
# Valid rows: 169905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 171000 rows
# Valid rows: 170905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 172000 rows
# Valid rows: 171905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 173000 rows
# Valid rows: 172905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 174000 rows
# Valid rows: 173905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 175000 rows
# Valid rows: 174905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 176000 rows
# Valid rows: 175905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 177000 rows
# Valid rows: 176905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 178000 rows
# Valid rows: 177905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 179000 rows
# Valid rows: 178905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 180000 rows
# Valid rows: 179905
# Error rows: 95
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
#
# Progress: Processed 181000 rows
# Valid rows: 180901
# Error rows: 99
#
# Inserted batch of 1000 rows
#
# Progress: Processed 182000 rows
# Valid rows: 181901
# Error rows: 99
#
# Inserted batch of 1000 rows
#
# Progress: Processed 183000 rows
# Valid rows: 182901
# Error rows: 99
#
# Inserted batch of 1000 rows
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
#
# Progress: Processed 184000 rows
# Valid rows: 183824
# Error rows: 176
#
# Inserted batch of 1000 rows
#
# Progress: Processed 185000 rows
# Valid rows: 184824
# Error rows: 176
#
# Inserted batch of 1000 rows
#
# Progress: Processed 186000 rows
# Valid rows: 185824
# Error rows: 176
#
# Inserted batch of 1000 rows
#
# Progress: Processed 187000 rows
# Valid rows: 186824
# Error rows: 176
#
# Inserted batch of 1000 rows
#
# Progress: Processed 188000 rows
# Valid rows: 187824
# Error rows: 176
# Row dropped: Invalid value for event_id
#
# Inserted batch of 1000 rows
#
# Progress: Processed 189000 rows
# Valid rows: 188823
# Error rows: 177
#
# Inserted batch of 1000 rows
#
# Progress: Processed 190000 rows
# Valid rows: 189823
# Error rows: 177
#
# Inserted batch of 1000 rows
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
#
# Progress: Processed 191000 rows
# Valid rows: 190790
# Error rows: 210
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
#
# Inserted batch of 1000 rows
#
# Progress: Processed 192000 rows
# Valid rows: 191749
# Error rows: 251
#
# Inserted batch of 1000 rows
#
# Progress: Processed 193000 rows
# Valid rows: 192749
# Error rows: 251
#
# Inserted batch of 1000 rows
# Row dropped: Empty value in non-nullable field region
#
# Progress: Processed 194000 rows
# Valid rows: 193748
# Error rows: 252
# Row dropped: Empty value in non-nullable field region
#
# Inserted batch of 1000 rows
#
# Progress: Processed 195000 rows
# Valid rows: 194747
# Error rows: 253
#
# Inserted batch of 1000 rows
#
# Progress: Processed 196000 rows
# Valid rows: 195747
# Error rows: 253
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
#
# Progress: Processed 197000 rows
# Valid rows: 196742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 198000 rows
# Valid rows: 197742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 199000 rows
# Valid rows: 198742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 200000 rows
# Valid rows: 199742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 201000 rows
# Valid rows: 200742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 202000 rows
# Valid rows: 201742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 203000 rows
# Valid rows: 202742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 204000 rows
# Valid rows: 203742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 205000 rows
# Valid rows: 204742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 206000 rows
# Valid rows: 205742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 207000 rows
# Valid rows: 206742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 208000 rows
# Valid rows: 207742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 209000 rows
# Valid rows: 208742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 210000 rows
# Valid rows: 209742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 211000 rows
# Valid rows: 210742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 212000 rows
# Valid rows: 211742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 213000 rows
# Valid rows: 212742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 214000 rows
# Valid rows: 213742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 215000 rows
# Valid rows: 214742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 216000 rows
# Valid rows: 215742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 217000 rows
# Valid rows: 216742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 218000 rows
# Valid rows: 217742
# Error rows: 258
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
#
# Progress: Processed 219000 rows
# Valid rows: 218741
# Error rows: 259
#
# Inserted batch of 1000 rows
#
# Progress: Processed 220000 rows
# Valid rows: 219741
# Error rows: 259
#
# Inserted batch of 1000 rows
#
# Progress: Processed 221000 rows
# Valid rows: 220741
# Error rows: 259
#
# Inserted batch of 1000 rows
#
# Progress: Processed 222000 rows
# Valid rows: 221741
# Error rows: 259
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
#
# Progress: Processed 223000 rows
# Valid rows: 222739
# Error rows: 261
#
# Inserted batch of 1000 rows
#
# Progress: Processed 224000 rows
# Valid rows: 223739
# Error rows: 261
#
# Inserted batch of 1000 rows
#
# Progress: Processed 225000 rows
# Valid rows: 224739
# Error rows: 261
#
# Inserted batch of 1000 rows
#
# Progress: Processed 226000 rows
# Valid rows: 225739
# Error rows: 261
#
# Inserted batch of 1000 rows
#
# Progress: Processed 227000 rows
# Valid rows: 226739
# Error rows: 261
#
# Inserted batch of 1000 rows
#
# Progress: Processed 228000 rows
# Valid rows: 227739
# Error rows: 261
#
# Inserted batch of 1000 rows
#
# Progress: Processed 229000 rows
# Valid rows: 228739
# Error rows: 261
#
# Inserted batch of 1000 rows
#
# Progress: Processed 230000 rows
# Valid rows: 229739
# Error rows: 261
#
# Inserted batch of 1000 rows
#
# Progress: Processed 231000 rows
# Valid rows: 230739
# Error rows: 261
#
# Inserted batch of 1000 rows
#
# Progress: Processed 232000 rows
# Valid rows: 231739
# Error rows: 261
#
# Inserted batch of 1000 rows
#
# Progress: Processed 233000 rows
# Valid rows: 232739
# Error rows: 261
#
# Inserted batch of 1000 rows
#
# Progress: Processed 234000 rows
# Valid rows: 233739
# Error rows: 261
#
# Inserted batch of 1000 rows
#
# Progress: Processed 235000 rows
# Valid rows: 234739
# Error rows: 261
#
# Inserted batch of 1000 rows
#
# Progress: Processed 236000 rows
# Valid rows: 235739
# Error rows: 261
#
# Inserted batch of 1000 rows
#
# Progress: Processed 237000 rows
# Valid rows: 236739
# Error rows: 261
#
# Inserted batch of 1000 rows
#
# Progress: Processed 238000 rows
# Valid rows: 237739
# Error rows: 261
#
# Inserted batch of 1000 rows
#
# Progress: Processed 239000 rows
# Valid rows: 238739
# Error rows: 261
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
#
# Progress: Processed 240000 rows
# Valid rows: 239738
# Error rows: 262
#
# Inserted batch of 1000 rows
#
# Progress: Processed 241000 rows
# Valid rows: 240738
# Error rows: 262
#
# Inserted batch of 1000 rows
#
# Progress: Processed 242000 rows
# Valid rows: 241738
# Error rows: 262
#
# Inserted batch of 1000 rows
#
# Progress: Processed 243000 rows
# Valid rows: 242738
# Error rows: 262
#
# Inserted batch of 1000 rows
#
# Progress: Processed 244000 rows
# Valid rows: 243738
# Error rows: 262
#
# Inserted batch of 1000 rows
#
# Progress: Processed 245000 rows
# Valid rows: 244738
# Error rows: 262
#
# Inserted batch of 1000 rows
#
# Progress: Processed 246000 rows
# Valid rows: 245738
# Error rows: 262
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
#
# Progress: Processed 247000 rows
# Valid rows: 246732
# Error rows: 268
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
#
# Inserted batch of 1000 rows
#
# Progress: Processed 248000 rows
# Valid rows: 247729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 249000 rows
# Valid rows: 248729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 250000 rows
# Valid rows: 249729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 251000 rows
# Valid rows: 250729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 252000 rows
# Valid rows: 251729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 253000 rows
# Valid rows: 252729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 254000 rows
# Valid rows: 253729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 255000 rows
# Valid rows: 254729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 256000 rows
# Valid rows: 255729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 257000 rows
# Valid rows: 256729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 258000 rows
# Valid rows: 257729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 259000 rows
# Valid rows: 258729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 260000 rows
# Valid rows: 259729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 261000 rows
# Valid rows: 260729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 262000 rows
# Valid rows: 261729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 263000 rows
# Valid rows: 262729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 264000 rows
# Valid rows: 263729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 265000 rows
# Valid rows: 264729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 266000 rows
# Valid rows: 265729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 267000 rows
# Valid rows: 266729
# Error rows: 271
#
# Inserted batch of 1000 rows
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
#
# Progress: Processed 268000 rows
# Valid rows: 267711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 269000 rows
# Valid rows: 268711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 270000 rows
# Valid rows: 269711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 271000 rows
# Valid rows: 270711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 272000 rows
# Valid rows: 271711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 273000 rows
# Valid rows: 272711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 274000 rows
# Valid rows: 273711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 275000 rows
# Valid rows: 274711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 276000 rows
# Valid rows: 275711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 277000 rows
# Valid rows: 276711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 278000 rows
# Valid rows: 277711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 279000 rows
# Valid rows: 278711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 280000 rows
# Valid rows: 279711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 281000 rows
# Valid rows: 280711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 282000 rows
# Valid rows: 281711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 283000 rows
# Valid rows: 282711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 284000 rows
# Valid rows: 283711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 285000 rows
# Valid rows: 284711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 286000 rows
# Valid rows: 285711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 287000 rows
# Valid rows: 286711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 288000 rows
# Valid rows: 287711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 289000 rows
# Valid rows: 288711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 290000 rows
# Valid rows: 289711
# Error rows: 289
# Row dropped: Invalid value for event_id
#
# Inserted batch of 1000 rows
#
# Progress: Processed 291000 rows
# Valid rows: 290710
# Error rows: 290
#
# Inserted batch of 1000 rows
#
# Progress: Processed 292000 rows
# Valid rows: 291710
# Error rows: 290
#
# Inserted batch of 1000 rows
#
# Progress: Processed 293000 rows
# Valid rows: 292710
# Error rows: 290
#
# Inserted batch of 1000 rows
#
# Progress: Processed 294000 rows
# Valid rows: 293710
# Error rows: 290
#
# Inserted batch of 1000 rows
#
# Progress: Processed 295000 rows
# Valid rows: 294710
# Error rows: 290
#
# Inserted batch of 1000 rows
#
# Progress: Processed 296000 rows
# Valid rows: 295710
# Error rows: 290
#
# Inserted batch of 1000 rows
#
# Progress: Processed 297000 rows
# Valid rows: 296710
# Error rows: 290
#
# Inserted batch of 1000 rows
#
# Progress: Processed 298000 rows
# Valid rows: 297710
# Error rows: 290
#
# Inserted batch of 1000 rows
#
# Progress: Processed 299000 rows
# Valid rows: 298710
# Error rows: 290
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
#
# Progress: Processed 300000 rows
# Valid rows: 299708
# Error rows: 292
#
# Inserted batch of 1000 rows
#
# Progress: Processed 301000 rows
# Valid rows: 300708
# Error rows: 292
#
# Inserted batch of 1000 rows
#
# Progress: Processed 302000 rows
# Valid rows: 301708
# Error rows: 292
#
# Inserted batch of 1000 rows
#
# Progress: Processed 303000 rows
# Valid rows: 302708
# Error rows: 292
#
# Inserted batch of 1000 rows
# Row dropped: Empty value in non-nullable field region
#
# Progress: Processed 304000 rows
# Valid rows: 303707
# Error rows: 293
#
# Inserted batch of 1000 rows
#
# Progress: Processed 305000 rows
# Valid rows: 304707
# Error rows: 293
#
# Inserted batch of 1000 rows
#
# Progress: Processed 306000 rows
# Valid rows: 305707
# Error rows: 293
#
# Inserted batch of 1000 rows
#
# Progress: Processed 307000 rows
# Valid rows: 306707
# Error rows: 293
#
# Inserted batch of 1000 rows
#
# Progress: Processed 308000 rows
# Valid rows: 307707
# Error rows: 293
#
# Inserted batch of 1000 rows
#
# Progress: Processed 309000 rows
# Valid rows: 308707
# Error rows: 293
#
# Inserted batch of 1000 rows
#
# Progress: Processed 310000 rows
# Valid rows: 309707
# Error rows: 293
#
# Inserted batch of 1000 rows
#
# Progress: Processed 311000 rows
# Valid rows: 310707
# Error rows: 293
#
# Inserted batch of 1000 rows
#
# Progress: Processed 312000 rows
# Valid rows: 311707
# Error rows: 293
#
# Inserted batch of 1000 rows
#
# Progress: Processed 313000 rows
# Valid rows: 312707
# Error rows: 293
#
# Inserted batch of 1000 rows
#
# Progress: Processed 314000 rows
# Valid rows: 313707
# Error rows: 293
#
# Inserted batch of 1000 rows
#
# Progress: Processed 315000 rows
# Valid rows: 314707
# Error rows: 293
#
# Inserted batch of 1000 rows
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Invalid value for event_id
#
# Progress: Processed 316000 rows
# Valid rows: 315697
# Error rows: 303
#
# Inserted batch of 1000 rows
#
# Progress: Processed 317000 rows
# Valid rows: 316697
# Error rows: 303
#
# Inserted batch of 1000 rows
#
# Progress: Processed 318000 rows
# Valid rows: 317697
# Error rows: 303
#
# Inserted batch of 1000 rows
#
# Progress: Processed 319000 rows
# Valid rows: 318697
# Error rows: 303
#
# Inserted batch of 1000 rows
#
# Progress: Processed 320000 rows
# Valid rows: 319697
# Error rows: 303
#
# Inserted batch of 1000 rows
#
# Progress: Processed 321000 rows
# Valid rows: 320697
# Error rows: 303
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
#
# Progress: Processed 322000 rows
# Valid rows: 321691
# Error rows: 309
#
# Inserted batch of 1000 rows
#
# Progress: Processed 323000 rows
# Valid rows: 322691
# Error rows: 309
#
# Inserted batch of 1000 rows
#
# Progress: Processed 324000 rows
# Valid rows: 323691
# Error rows: 309
#
# Inserted batch of 1000 rows
#
# Progress: Processed 325000 rows
# Valid rows: 324691
# Error rows: 309
#
# Inserted batch of 1000 rows
#
# Progress: Processed 326000 rows
# Valid rows: 325691
# Error rows: 309
#
# Inserted batch of 1000 rows
#
# Progress: Processed 327000 rows
# Valid rows: 326691
# Error rows: 309
#
# Inserted batch of 1000 rows
#
# Progress: Processed 328000 rows
# Valid rows: 327691
# Error rows: 309
#
# Inserted batch of 1000 rows
#
# Progress: Processed 329000 rows
# Valid rows: 328691
# Error rows: 309
#
# Inserted batch of 1000 rows
#
# Progress: Processed 330000 rows
# Valid rows: 329691
# Error rows: 309
#
# Inserted batch of 1000 rows
#
# Progress: Processed 331000 rows
# Valid rows: 330691
# Error rows: 309
#
# Inserted batch of 1000 rows
#
# Progress: Processed 332000 rows
# Valid rows: 331691
# Error rows: 309
#
# Inserted batch of 1000 rows
#
# Progress: Processed 333000 rows
# Valid rows: 332691
# Error rows: 309
#
# Inserted batch of 1000 rows
#
# Progress: Processed 334000 rows
# Valid rows: 333691
# Error rows: 309
#
# ...
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
#
# Progress: Processed 746000 rows
# Valid rows: 745656
# Error rows: 344
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
#
# Inserted batch of 1000 rows
#
# Progress: Processed 747000 rows
# Valid rows: 746647
# Error rows: 353
#
# Inserted batch of 1000 rows
#
# Progress: Processed 748000 rows
# Valid rows: 747647
# Error rows: 353
#
# Inserted batch of 1000 rows
#
# Progress: Processed 749000 rows
# Valid rows: 748647
# Error rows: 353
#
# Inserted batch of 1000 rows
#
# Progress: Processed 750000 rows
# Valid rows: 749647
# Error rows: 353
#
# Inserted batch of 1000 rows
#
# Progress: Processed 751000 rows
# Valid rows: 750647
# Error rows: 353
#
# Inserted batch of 1000 rows
#
# Progress: Processed 752000 rows
# Valid rows: 751647
# Error rows: 353
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
#
# Progress: Processed 753000 rows
# Valid rows: 752642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 754000 rows
# Valid rows: 753642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 755000 rows
# Valid rows: 754642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 756000 rows
# Valid rows: 755642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 757000 rows
# Valid rows: 756642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 758000 rows
# Valid rows: 757642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 759000 rows
# Valid rows: 758642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 760000 rows
# Valid rows: 759642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 761000 rows
# Valid rows: 760642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 762000 rows
# Valid rows: 761642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 763000 rows
# Valid rows: 762642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 764000 rows
# Valid rows: 763642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 765000 rows
# Valid rows: 764642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 766000 rows
# Valid rows: 765642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 767000 rows
# Valid rows: 766642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 768000 rows
# Valid rows: 767642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 769000 rows
# Valid rows: 768642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 770000 rows
# Valid rows: 769642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 771000 rows
# Valid rows: 770642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 772000 rows
# Valid rows: 771642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 773000 rows
# Valid rows: 772642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 774000 rows
# Valid rows: 773642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 775000 rows
# Valid rows: 774642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 776000 rows
# Valid rows: 775642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 777000 rows
# Valid rows: 776642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 778000 rows
# Valid rows: 777642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 779000 rows
# Valid rows: 778642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 780000 rows
# Valid rows: 779642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 781000 rows
# Valid rows: 780642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 782000 rows
# Valid rows: 781642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 783000 rows
# Valid rows: 782642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 784000 rows
# Valid rows: 783642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 785000 rows
# Valid rows: 784642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 786000 rows
# Valid rows: 785642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 787000 rows
# Valid rows: 786642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 788000 rows
# Valid rows: 787642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 789000 rows
# Valid rows: 788642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 790000 rows
# Valid rows: 789642
# Error rows: 358
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
#
# Progress: Processed 791000 rows
# Valid rows: 790641
# Error rows: 359
#
# Inserted batch of 1000 rows
#
# Progress: Processed 792000 rows
# Valid rows: 791641
# Error rows: 359
#
# Inserted batch of 1000 rows
#
# Progress: Processed 793000 rows
# Valid rows: 792641
# Error rows: 359
#
# Inserted batch of 1000 rows
#
# Progress: Processed 794000 rows
# Valid rows: 793641
# Error rows: 359
#
# Inserted batch of 1000 rows
#
# Progress: Processed 795000 rows
# Valid rows: 794641
# Error rows: 359
#
# Inserted batch of 1000 rows
#
# Progress: Processed 796000 rows
# Valid rows: 795641
# Error rows: 359
#
# Inserted batch of 1000 rows
#
# Progress: Processed 797000 rows
# Valid rows: 796641
# Error rows: 359
#
# Inserted batch of 1000 rows
#
# Progress: Processed 798000 rows
# Valid rows: 797641
# Error rows: 359
#
# Inserted batch of 1000 rows
#
# Progress: Processed 799000 rows
# Valid rows: 798641
# Error rows: 359
#
# Inserted batch of 1000 rows
#
# Progress: Processed 800000 rows
# Valid rows: 799641
# Error rows: 359
#
# Inserted batch of 1000 rows
#
# Progress: Processed 801000 rows
# Valid rows: 800641
# Error rows: 359
#
# Inserted batch of 1000 rows
#
# Progress: Processed 802000 rows
# Valid rows: 801641
# Error rows: 359
#
# Inserted batch of 1000 rows
#
# Progress: Processed 803000 rows
# Valid rows: 802641
# Error rows: 359
#
# Inserted batch of 1000 rows
#
# Progress: Processed 804000 rows
# Valid rows: 803641
# Error rows: 359
#
# Inserted batch of 1000 rows
#
# Progress: Processed 805000 rows
# Valid rows: 804641
# Error rows: 359
#
# Inserted batch of 1000 rows
#
# Progress: Processed 806000 rows
# Valid rows: 805641
# Error rows: 359
#
# Inserted batch of 1000 rows
#
# Progress: Processed 807000 rows
# Valid rows: 806641
# Error rows: 359
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
#
# Progress: Processed 808000 rows
# Valid rows: 807640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 809000 rows
# Valid rows: 808640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 810000 rows
# Valid rows: 809640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 811000 rows
# Valid rows: 810640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 812000 rows
# Valid rows: 811640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 813000 rows
# Valid rows: 812640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 814000 rows
# Valid rows: 813640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 815000 rows
# Valid rows: 814640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 816000 rows
# Valid rows: 815640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 817000 rows
# Valid rows: 816640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 818000 rows
# Valid rows: 817640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 819000 rows
# Valid rows: 818640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 820000 rows
# Valid rows: 819640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 821000 rows
# Valid rows: 820640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 822000 rows
# Valid rows: 821640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 823000 rows
# Valid rows: 822640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 824000 rows
# Valid rows: 823640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 825000 rows
# Valid rows: 824640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 826000 rows
# Valid rows: 825640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 827000 rows
# Valid rows: 826640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 828000 rows
# Valid rows: 827640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 829000 rows
# Valid rows: 828640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 830000 rows
# Valid rows: 829640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 831000 rows
# Valid rows: 830640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 832000 rows
# Valid rows: 831640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 833000 rows
# Valid rows: 832640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 834000 rows
# Valid rows: 833640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 835000 rows
# Valid rows: 834640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 836000 rows
# Valid rows: 835640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 837000 rows
# Valid rows: 836640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 838000 rows
# Valid rows: 837640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 839000 rows
# Valid rows: 838640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 840000 rows
# Valid rows: 839640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 841000 rows
# Valid rows: 840640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 842000 rows
# Valid rows: 841640
# Error rows: 360
# Row dropped: Invalid value for event_id
#
# Inserted batch of 1000 rows
#
# Progress: Processed 843000 rows
# Valid rows: 842639
# Error rows: 361
#
# Inserted batch of 1000 rows
#
# Progress: Processed 844000 rows
# Valid rows: 843639
# Error rows: 361
#
# Inserted batch of 1000 rows
#
# Progress: Processed 845000 rows
# Valid rows: 844639
# Error rows: 361
#
# Inserted batch of 1000 rows
#
# Progress: Processed 846000 rows
# Valid rows: 845639
# Error rows: 361
#
# Inserted batch of 1000 rows
#
# Progress: Processed 847000 rows
# Valid rows: 846639
# Error rows: 361
#
# Inserted batch of 1000 rows
#
# Progress: Processed 848000 rows
# Valid rows: 847639
# Error rows: 361
#
# Inserted batch of 1000 rows
#
# Progress: Processed 849000 rows
# Valid rows: 848639
# Error rows: 361
#
# Inserted batch of 1000 rows
#
# Progress: Processed 850000 rows
# Valid rows: 849639
# Error rows: 361
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
# Row dropped: Empty value in non-nullable field region
#
# Progress: Processed 851000 rows
# Valid rows: 850637
# Error rows: 363
#
# Inserted batch of 1000 rows
#
# Progress: Processed 852000 rows
# Valid rows: 851637
# Error rows: 363
#
# Inserted batch of 1000 rows
#
# Progress: Processed 853000 rows
# Valid rows: 852637
# Error rows: 363
#
# Inserted batch of 1000 rows
#
# Progress: Processed 854000 rows
# Valid rows: 853637
# Error rows: 363
#
# Inserted batch of 1000 rows
#
# Progress: Processed 855000 rows
# Valid rows: 854637
# Error rows: 363
#
# Inserted batch of 1000 rows
#
# Progress: Processed 856000 rows
# Valid rows: 855637
# Error rows: 363
#
# Inserted batch of 1000 rows
#
# Progress: Processed 857000 rows
# Valid rows: 856637
# Error rows: 363
#
# Inserted batch of 1000 rows
#
# Progress: Processed 858000 rows
# Valid rows: 857637
# Error rows: 363
#
# Inserted batch of 1000 rows
#
# Progress: Processed 859000 rows
# Valid rows: 858637
# Error rows: 363
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
#
# Inserted batch of 1000 rows
#
# Progress: Processed 860000 rows
# Valid rows: 859634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 861000 rows
# Valid rows: 860634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 862000 rows
# Valid rows: 861634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 863000 rows
# Valid rows: 862634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 864000 rows
# Valid rows: 863634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 865000 rows
# Valid rows: 864634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 866000 rows
# Valid rows: 865634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 867000 rows
# Valid rows: 866634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 868000 rows
# Valid rows: 867634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 869000 rows
# Valid rows: 868634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 870000 rows
# Valid rows: 869634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 871000 rows
# Valid rows: 870634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 872000 rows
# Valid rows: 871634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 873000 rows
# Valid rows: 872634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 874000 rows
# Valid rows: 873634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 875000 rows
# Valid rows: 874634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 876000 rows
# Valid rows: 875634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 877000 rows
# Valid rows: 876634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 878000 rows
# Valid rows: 877634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 879000 rows
# Valid rows: 878634
# Error rows: 366
# Row dropped: Invalid value for event_id
#
# Inserted batch of 1000 rows
#
# Progress: Processed 880000 rows
# Valid rows: 879633
# Error rows: 367
#
# Inserted batch of 1000 rows
#
# Progress: Processed 881000 rows
# Valid rows: 880633
# Error rows: 367
#
# Inserted batch of 1000 rows
#
# Progress: Processed 882000 rows
# Valid rows: 881633
# Error rows: 367
#
# Inserted batch of 1000 rows
#
# Progress: Processed 883000 rows
# Valid rows: 882633
# Error rows: 367
#
# Inserted final batch of 660 rows
#
# Processing complete!
# Total rows processed: 883027
# Valid rows inserted: 882660
# Error rows: 367
# CPU times: user 28min 28s, sys: 29.2 s, total: 28min 58s
# Wall time: 39min 11s

# %%
# %%time
# import ijson
# from pathlib import Path

# file_path = "/Users/krish/Projects/CxC_Data/new_amplitude_export_2025.json"

# # Initialize counters
# total_rows = 0
# event_rows = 0
# non_event_rows = 0

# with open(file_path, "r") as f:
#     objects = ijson.items(f, "item")
    
#     for row in objects:
#         total_rows += 1
        
#         # Check data_type
#         if row.get('data_type') == 'event':
#             event_rows += 1
#         else:
#             non_event_rows += 1
#             print(f"Found non-event data_type: {row.get('data_type')}")
        
#         # Print progress every 10000 rows
#         if total_rows % 10000 == 0:
#             print(f"\nProgress: Processed {total_rows} rows")
#             print(f"Events: {event_rows}")
#             print(f"Non-events: {non_event_rows}")

# # Print final statistics
# print("\nProcessing complete!")
# print(f"Total rows processed: {total_rows}")
# print(f"Event rows: {event_rows}")
# print(f"Non-event rows: {non_event_rows}")
# print(f"Percentage events: {(event_rows/total_rows)*100:.2f}%")
# Out:
# Progress: Processed 10000 rows
# Events: 10000
# Non-events: 0
#
# Progress: Processed 20000 rows
# Events: 20000
# Non-events: 0
#
# Progress: Processed 30000 rows
# Events: 30000
# Non-events: 0
#
# Progress: Processed 40000 rows
# Events: 40000
# Non-events: 0
#
# Progress: Processed 50000 rows
# Events: 50000
# Non-events: 0
#
# Progress: Processed 60000 rows
# Events: 60000
# Non-events: 0
#
# Progress: Processed 70000 rows
# Events: 70000
# Non-events: 0
#
# Progress: Processed 80000 rows
# Events: 80000
# Non-events: 0
#
# Progress: Processed 90000 rows
# Events: 90000
# Non-events: 0
#
# Progress: Processed 100000 rows
# Events: 100000
# Non-events: 0
#
# Progress: Processed 110000 rows
# Events: 110000
# Non-events: 0
#
# Progress: Processed 120000 rows
# Events: 120000
# Non-events: 0
#
# Progress: Processed 130000 rows
# Events: 130000
# Non-events: 0
#
# Progress: Processed 140000 rows
# Events: 140000
# Non-events: 0
#
# Progress: Processed 150000 rows
# Events: 150000
# Non-events: 0
#
# Progress: Processed 160000 rows
# Events: 160000
# Non-events: 0
#
# Progress: Processed 170000 rows
# Events: 170000
# Non-events: 0
#
# Progress: Processed 180000 rows
# Events: 180000
# Non-events: 0
#
# Progress: Processed 190000 rows
# Events: 190000
# Non-events: 0
#
# Progress: Processed 200000 rows
# Events: 200000
# Non-events: 0
#
# Progress: Processed 210000 rows
# Events: 210000
# Non-events: 0
#
# Progress: Processed 220000 rows
# Events: 220000
# Non-events: 0
#
# Progress: Processed 230000 rows
# Events: 230000
# Non-events: 0
#
# Progress: Processed 240000 rows
# Events: 240000
# Non-events: 0
#
# Progress: Processed 250000 rows
# Events: 250000
# Non-events: 0
#
# Progress: Processed 260000 rows
# Events: 260000
# Non-events: 0
#
# Progress: Processed 270000 rows
# Events: 270000
# Non-events: 0
#
# Progress: Processed 280000 rows
# Events: 280000
# Non-events: 0
#
# Progress: Processed 290000 rows
# Events: 290000
# Non-events: 0
#
# Progress: Processed 300000 rows
# Events: 300000
# Non-events: 0
#
# Progress: Processed 310000 rows
# Events: 310000
# Non-events: 0
#
# Progress: Processed 320000 rows
# Events: 320000
# Non-events: 0
#
# Progress: Processed 330000 rows
# Events: 330000
# Non-events: 0
#
# Progress: Processed 340000 rows
# Events: 340000
# Non-events: 0
#
# Progress: Processed 350000 rows
# Events: 350000
# Non-events: 0
#
# Progress: Processed 360000 rows
# Events: 360000
# Non-events: 0
#
# Progress: Processed 370000 rows
# Events: 370000
# Non-events: 0
#
# Progress: Processed 380000 rows
# Events: 380000
# Non-events: 0
#
# Progress: Processed 390000 rows
# Events: 390000
# Non-events: 0
#
# Progress: Processed 400000 rows
# Events: 400000
# Non-events: 0
#
# Progress: Processed 410000 rows
# Events: 410000
# Non-events: 0
#
# Progress: Processed 420000 rows
# Events: 420000
# Non-events: 0
#
# Progress: Processed 430000 rows
# Events: 430000
# Non-events: 0
#
# Progress: Processed 440000 rows
# Events: 440000
# Non-events: 0
#
# Progress: Processed 450000 rows
# Events: 450000
# Non-events: 0
#
# Progress: Processed 460000 rows
# Events: 460000
# Non-events: 0
#
# Progress: Processed 470000 rows
# Events: 470000
# Non-events: 0
#
# Progress: Processed 480000 rows
# Events: 480000
# Non-events: 0
#
# Progress: Processed 490000 rows
# Events: 490000
# Non-events: 0
#
# Progress: Processed 500000 rows
# Events: 500000
# Non-events: 0
#
# Progress: Processed 510000 rows
# Events: 510000
# Non-events: 0
#
# Progress: Processed 520000 rows
# Events: 520000
# Non-events: 0
#
# Progress: Processed 530000 rows
# Events: 530000
# Non-events: 0
#
# Progress: Processed 540000 rows
# Events: 540000
# Non-events: 0
#
# Progress: Processed 550000 rows
# Events: 550000
# Non-events: 0
#
# Progress: Processed 560000 rows
# Events: 560000
# Non-events: 0
#
# Progress: Processed 570000 rows
# Events: 570000
# Non-events: 0
#
# Progress: Processed 580000 rows
# Events: 580000
# Non-events: 0
#
# Progress: Processed 590000 rows
# Events: 590000
# Non-events: 0
#
# Progress: Processed 600000 rows
# Events: 600000
# Non-events: 0
#
# Progress: Processed 610000 rows
# Events: 610000
# Non-events: 0
#
# Progress: Processed 620000 rows
# Events: 620000
# Non-events: 0
#
# Progress: Processed 630000 rows
# Events: 630000
# Non-events: 0
#
# Progress: Processed 640000 rows
# Events: 640000
# Non-events: 0
#
# Progress: Processed 650000 rows
# Events: 650000
# Non-events: 0
#
# Progress: Processed 660000 rows
# Events: 660000
# Non-events: 0
#
# Progress: Processed 670000 rows
# Events: 670000
# Non-events: 0
#
# Progress: Processed 680000 rows
# Events: 680000
# Non-events: 0
#
# Progress: Processed 690000 rows
# Events: 690000
# Non-events: 0
#
# Progress: Processed 700000 rows
# Events: 700000
# Non-events: 0
#
# Progress: Processed 710000 rows
# Events: 710000
# Non-events: 0
#
# Progress: Processed 720000 rows
# Events: 720000
# Non-events: 0
#
# Progress: Processed 730000 rows
# Events: 730000
# Non-events: 0
#
# Progress: Processed 740000 rows
# Events: 740000
# Non-events: 0
#
# Progress: Processed 750000 rows
# Events: 750000
# Non-events: 0
#
# Progress: Processed 760000 rows
# Events: 760000
# Non-events: 0
#
# Progress: Processed 770000 rows
# Events: 770000
# Non-events: 0
#
# Progress: Processed 780000 rows
# Events: 780000
# Non-events: 0
#
# Progress: Processed 790000 rows
# Events: 790000
# Non-events: 0
#
# Progress: Processed 800000 rows
# Events: 800000
# Non-events: 0
#
# Progress: Processed 810000 rows
# Events: 810000
# Non-events: 0
#
# Progress: Processed 820000 rows
# Events: 820000
# Non-events: 0
#
# Progress: Processed 830000 rows
# Events: 830000
# Non-events: 0
#
# Progress: Processed 840000 rows
# Events: 840000
# Non-events: 0
#
# Progress: Processed 850000 rows
# Events: 850000
# Non-events: 0
#
# Progress: Processed 860000 rows
# Events: 860000
# Non-events: 0
#
# Progress: Processed 870000 rows
# Events: 870000
# Non-events: 0
#
# Progress: Processed 880000 rows
# Events: 880000
# Non-events: 0
#
# Progress: Processed 890000 rows
# Events: 890000
# Non-events: 0
#
# Progress: Processed 900000 rows
# Events: 900000
# Non-events: 0
#
# Progress: Processed 910000 rows
# Events: 910000
# Non-events: 0
#
# Progress: Processed 920000 rows
# Events: 920000
# Non-events: 0
#
# Progress: Processed 930000 rows
# Events: 930000
# Non-events: 0
#
# Progress: Processed 940000 rows
# Events: 940000
# Non-events: 0
#
# Progress: Processed 950000 rows
# Events: 950000
# Non-events: 0
#
# Progress: Processed 960000 rows
# Events: 960000
# Non-events: 0
#
# Progress: Processed 970000 rows
# Events: 970000
# Non-events: 0
#
# Progress: Processed 980000 rows
# Events: 980000
# Non-events: 0
#
# Progress: Processed 990000 rows
# Events: 990000
# Non-events: 0
#
# Progress: Processed 1000000 rows
# Events: 1000000
# Non-events: 0
#
# Progress: Processed 1010000 rows
# Events: 1010000
# Non-events: 0
#
# Progress: Processed 1020000 rows
# Events: 1020000
# Non-events: 0
#
# Progress: Processed 1030000 rows
# Events: 1030000
# Non-events: 0
#
# Progress: Processed 1040000 rows
# Events: 1040000
# Non-events: 0
#
# Progress: Processed 1050000 rows
# Events: 1050000
# Non-events: 0
#
# Progress: Processed 1060000 rows
# Events: 1060000
# Non-events: 0
#
# Progress: Processed 1070000 rows
# Events: 1070000
# Non-events: 0
#
# Progress: Processed 1080000 rows
# Events: 1080000
# Non-events: 0
#
# Progress: Processed 1090000 rows
# Events: 1090000
# Non-events: 0
#
# Progress: Processed 1100000 rows
# Events: 1100000
# Non-events: 0
#
# Progress: Processed 1110000 rows
# Events: 1110000
# Non-events: 0
#
# Progress: Processed 1120000 rows
# Events: 1120000
# Non-events: 0
#
# Progress: Processed 1130000 rows
# Events: 1130000
# Non-events: 0
#
# Progress: Processed 1140000 rows
# Events: 1140000
# Non-events: 0
#
# Progress: Processed 1150000 rows
# Events: 1150000
# Non-events: 0
#
# Progress: Processed 1160000 rows
# Events: 1160000
# Non-events: 0
#
# Progress: Processed 1170000 rows
# Events: 1170000
# Non-events: 0
#
# Progress: Processed 1180000 rows
# Events: 1180000
# Non-events: 0
#
# Progress: Processed 1190000 rows
# Events: 1190000
# Non-events: 0
#
# Progress: Processed 1200000 rows
# Events: 1200000
# Non-events: 0
#
# Progress: Processed 1210000 rows
# Events: 1210000
# Non-events: 0
#
# Progress: Processed 1220000 rows
# Events: 1220000
# Non-events: 0
#
# Progress: Processed 1230000 rows
# Events: 1230000
# Non-events: 0
#
# Progress: Processed 1240000 rows
# Events: 1240000
# Non-events: 0
#
# Progress: Processed 1250000 rows
# Events: 1250000
# Non-events: 0
#
# Progress: Processed 1260000 rows
# Events: 1260000
# Non-events: 0
#
# Progress: Processed 1270000 rows
# Events: 1270000
# Non-events: 0
#
# Progress: Processed 1280000 rows
# Events: 1280000
# Non-events: 0
#
# Progress: Processed 1290000 rows
# Events: 1290000
# Non-events: 0
#
# Progress: Processed 1300000 rows
# Events: 1300000
# Non-events: 0
#
# Progress: Processed 1310000 rows
# Events: 1310000
# Non-events: 0
#
# Progress: Processed 1320000 rows
# Events: 1320000
# Non-events: 0
#
# Progress: Processed 1330000 rows
# Events: 1330000
# Non-events: 0
#
# Progress: Processed 1340000 rows
# Events: 1340000
# Non-events: 0
#
# Progress: Processed 1350000 rows
# Events: 1350000
# Non-events: 0
#
# Progress: Processed 1360000 rows
# Events: 1360000
# Non-events: 0
#
# Progress: Processed 1370000 rows
# Events: 1370000
# Non-events: 0
#
# Progress: Processed 1380000 rows
# Events: 1380000
# Non-events: 0
#
# Progress: Processed 1390000 rows
# Events: 1390000
# Non-events: 0
#
# Progress: Processed 1400000 rows
# Events: 1400000
# Non-events: 0
#
# Progress: Processed 1410000 rows
# Events: 1410000
# Non-events: 0
#
# Progress: Processed 1420000 rows
# Events: 1420000
# Non-events: 0
#
# Progress: Processed 1430000 rows
# Events: 1430000
# Non-events: 0
#
# Progress: Processed 1440000 rows
# Events: 1440000
# Non-events: 0
#
# Progress: Processed 1450000 rows
# Events: 1450000
# Non-events: 0
#
# Progress: Processed 1460000 rows
# Events: 1460000
# Non-events: 0
#
# Progress: Processed 1470000 rows
# Events: 1470000
# Non-events: 0
#
# Progress: Processed 1480000 rows
# Events: 1480000
# Non-events: 0
#
# Progress: Processed 1490000 rows
# Events: 1490000
# Non-events: 0
#
# Progress: Processed 1500000 rows
# Events: 1500000
# Non-events: 0
#
# Progress: Processed 1510000 rows
# Events: 1510000
# Non-events: 0
#
# Progress: Processed 1520000 rows
# Events: 1520000
# Non-events: 0
#
# Progress: Processed 1530000 rows
# Events: 1530000
# Non-events: 0
#
# Progress: Processed 1540000 rows
# Events: 1540000
# Non-events: 0
#
# Progress: Processed 1550000 rows
# Events: 1550000
# Non-events: 0
#
# Progress: Processed 1560000 rows
# Events: 1560000
# Non-events: 0
#
# Progress: Processed 1570000 rows
# Events: 1570000
# Non-events: 0
#
# Progress: Processed 1580000 rows
# Events: 1580000
# Non-events: 0
#
# Progress: Processed 1590000 rows
# Events: 1590000
# Non-events: 0
#
# Progress: Processed 1600000 rows
# Events: 1600000
# Non-events: 0
#
# Progress: Processed 1610000 rows
# Events: 1610000
# Non-events: 0
#
# Progress: Processed 1620000 rows
# Events: 1620000
# Non-events: 0
#
# Progress: Processed 1630000 rows
# Events: 1630000
# Non-events: 0
#
# Progress: Processed 1640000 rows
# Events: 1640000
# Non-events: 0
#
# Progress: Processed 1650000 rows
# Events: 1650000
# Non-events: 0
#
# Progress: Processed 1660000 rows
# Events: 1660000
# Non-events: 0
#
# Progress: Processed 1670000 rows
# Events: 1670000
# Non-events: 0
#
# Progress: Processed 1680000 rows
# Events: 1680000
# Non-events: 0
#
# Progress: Processed 1690000 rows
# Events: 1690000
# Non-events: 0
#
# Progress: Processed 1700000 rows
# Events: 1700000
# Non-events: 0
#
# Progress: Processed 1710000 rows
# Events: 1710000
# Non-events: 0
#
# Progress: Processed 1720000 rows
# Events: 1720000
# Non-events: 0
#
# Progress: Processed 1730000 rows
# Events: 1730000
# Non-events: 0
#
# Progress: Processed 1740000 rows
# Events: 1740000
# Non-events: 0
#
# Progress: Processed 1750000 rows
# Events: 1750000
# Non-events: 0
#
# Progress: Processed 1760000 rows
# Events: 1760000
# Non-events: 0
#
# Progress: Processed 1770000 rows
# Events: 1770000
# Non-events: 0
#
# Progress: Processed 1780000 rows
# Events: 1780000
# Non-events: 0
#
# Progress: Processed 1790000 rows
# Events: 1790000
# Non-events: 0
#
# Progress: Processed 1800000 rows
# Events: 1800000
# Non-events: 0
#
# Progress: Processed 1810000 rows
# Events: 1810000
# Non-events: 0
#
# Progress: Processed 1820000 rows
# Events: 1820000
# Non-events: 0
#
# Progress: Processed 1830000 rows
# Events: 1830000
# Non-events: 0
#
# Progress: Processed 1840000 rows
# Events: 1840000
# Non-events: 0
#
# Progress: Processed 1850000 rows
# Events: 1850000
# Non-events: 0
#
# Processing complete!
# Total rows processed: 1850109
# Event rows: 1850109
# Non-event rows: 0
# Percentage events: 100.00%
# CPU times: user 36.3 s, sys: 3.19 s, total: 39.5 s
# Wall time: 40.3 s

# %%
# %%time
import ijson
import pandas as pd
import json
from pathlib import Path
from supabase import create_client, Client
from dotenv import load_dotenv
import os
from glob import glob

# Get all chunk files
base_path = "/Users/krish/Projects/CxC_Data/2024/"
file_pattern = "amplitude_export_chunk_*_anonymized.json"
file_paths = sorted(glob(os.path.join(base_path, file_pattern)))

print(f"Found {len(file_paths)} files to process:")
for file_path in file_paths:
    print(f"- {os.path.basename(file_path)}")

# Important columns with their Supabase types
columns_keep = {
    # UUID fields
    'id': {'type': 'uuid', 'source': 'uuid', 'nullable': False},  
    'device_id': {'type': 'uuid', 'nullable': False},
    
    # Integer fields
    'amplitude_id': {'type': 'int8', 'nullable': False},
    'app': {'type': 'int8', 'nullable': False},
    'event_id': {'type': 'int8', 'nullable': False},
    'session_id': {'type': 'int8', 'nullable': False},
    
    # Text fields - some allowed to be null
    'city': {'type': 'text', 'nullable': True},
    'country': {'type': 'text', 'nullable': False},
    'device_family': {'type': 'text', 'nullable': True},
    'device_type': {'type': 'text', 'nullable': True},
    'dma': {'type': 'text', 'nullable': True},
    'event_type': {'type': 'text', 'nullable': False},
    'language': {'type': 'text', 'nullable': False},
    'os_name': {'type': 'text', 'nullable': False},
    'platform': {'type': 'text', 'nullable': False},
    'region': {'type': 'text', 'nullable': False},
    
    # JSON fields
    'user_properties': {'type': 'json', 'nullable': True},
    
    # Timestamp field
    'event_time': {'type': 'timestamp', 'nullable': False},
}

def clean_user_properties(props):
    """Convert 'EMPTY' string values to None in user_properties and remove trackingVersion"""
    if not isinstance(props, dict):
        return props
    
    cleaned = {}
    for key, value in props.items():
        # Skip trackingVersion field
        if key == 'trackingVersion':
            continue
            
        if isinstance(value, str) and value == "EMPTY":
            cleaned[key] = None
        elif isinstance(value, list):
            cleaned[key] = value  # Preserve lists (like roles) as is
        else:
            cleaned[key] = value
    return cleaned

def clean_empty_objects(data):
    """Convert empty nested objects to None in data column"""
    if not isinstance(data, dict):
        return data
    
    cleaned = {}
    for key, value in data.items():
        if isinstance(value, dict) and len(value) == 0:
            cleaned[key] = None
        else:
            cleaned[key] = value
    return cleaned

def is_empty_value(val):
    """Check if a value should be considered empty"""
    if pd.isna(val):  # Checks for None and NaN
        return True
    if isinstance(val, str) and val.strip() == "":  # Empty strings or whitespace
        return True
    if val == "None":  # String "None"
        return True
    if isinstance(val, (dict, list)) and len(val) == 0:  # Empty collections
        return True
    return False

def preprocess_row(row):
    # Convert row to DataFrame for easier handling
    df = pd.DataFrame([row])
    
    # Create id from uuid
    df['id'] = df['uuid']

    # Clean user_properties before validation
    if 'user_properties' in df.columns:
        df['user_properties'] = df['user_properties'].apply(clean_user_properties)
    
    # # Clean data column before validation
    # if 'data' in df.columns:
    #     df['data'] = df['data'].apply(clean_empty_objects)
    
    # Type validations
    for col, info in columns_keep.items():
        # Get the value for the current column
        val = df[col].iloc[0]
        
        # Skip empty value check for nullable fields
        if not info['nullable']:
            if is_empty_value(val):
                print(f"Row dropped: Empty value in non-nullable field {col}")
                return None
            
        # Handle special case for id field
        if col == 'id' and info['source'] == 'uuid':
            continue
            
        # UUID validation
        if info['type'] == 'uuid':
            if not isinstance(val, str) or len(val.split('-')) != 5:
                print(f"Row dropped: Invalid UUID format for {col}")
                return None
        
        # Integer validation
        elif info['type'] == 'int8':
            try:
                df[col] = pd.to_numeric(df[col], downcast='integer')
                if df[col].iloc[0] <= 0:
                    print(f"Row dropped: Invalid value for {col}")
                    return None
            except (ValueError, TypeError):
                print(f"Row dropped: Non-numeric {col}")
                return None
        
        # JSON validation
        elif info['type'] == 'json':
            if not info['nullable']:
                if not isinstance(val, dict):
                    print(f"Row dropped: Invalid JSON format for {col}")
                    return None
                if len(val) == 0:
                    print(f"Row dropped: Empty JSON object in {col}")
                    return None
            elif val is not None:  # For nullable JSON fields, validate only if not None
                if not isinstance(val, dict):
                    print(f"Row dropped: Invalid JSON format for {col}")
                    return None
        
        # Text validation
        elif info['type'] == 'text':
            if not info['nullable']:
                if not isinstance(val, str):
                    df[col] = str(val)  # Convert to string if possible
                if len(df[col].iloc[0].strip()) == 0:
                    print(f"Row dropped: Empty text in non-nullable field {col}")
                    return None
            elif val is not None:  # For nullable text fields, validate only if not None
                if not isinstance(val, str):
                    df[col] = str(val)
        
        # Timestamp validation
        elif info['type'] == 'timestamp':
            try:
                df[col] = pd.to_datetime(df[col])
            except (ValueError, TypeError):
                print(f"Row dropped: Invalid timestamp for {col}")
                return None
    
    # Location validation for US entries
    # if df['country'].iloc[0] == "United States":
    #     if pd.isnull(df['dma'].iloc[0]) or df['dma'].iloc[0].strip() == "":
    #         print("Row dropped: Missing DMA for US location")
    #         return None
    
    return df[columns_keep.keys()]

# Initialize Supabase client
os.environ.clear()
load_dotenv(override=True)
supabase: Client = create_client(
    supabase_url=os.getenv("SUPABASE_URL"),
    supabase_key=os.getenv("SUPABASE_KEY")
)

# Process files one by one
batch_size = 1000
grand_total_rows = 0
grand_valid_rows = 0
grand_error_rows = 0

for file_path in file_paths:
    print(f"\nProcessing file: {os.path.basename(file_path)}")
    processed_rows = []
    total_rows = 0
    valid_rows = 0
    error_rows = 0

    with open(file_path, "r") as f:
        objects = ijson.items(f, "item")
        
        for row in objects:
            total_rows += 1
            
            # Process the row
            processed_df = preprocess_row(row)
            
            if processed_df is not None:
                # Convert timestamp to ISO format
                processed_df['event_time'] = processed_df['event_time'].iloc[0].strftime('%Y-%m-%dT%H:%M:%S.%fZ')
                
                # Convert row to dictionary
                row_dict = processed_df.iloc[0].to_dict()
                processed_rows.append(row_dict)
                valid_rows += 1
                
                # When batch is full, insert into Supabase
                if len(processed_rows) >= batch_size:
                    try:
                        response = supabase.table('v2_federato_amplitude_data').insert(processed_rows).execute()
                        print(f"Inserted batch of {len(processed_rows)} rows")
                        processed_rows = []  # Clear the batch
                    except Exception as e:
                        print(f"Error inserting batch: {e}")
                        error_rows += len(processed_rows)
                        processed_rows = []  # Clear the batch even if there's an error
            else:
                error_rows += 1
            
            # Print progress
            if total_rows % 1000 == 0:
                print(f"Progress: Processed {total_rows} rows")
                print(f"Valid rows: {valid_rows}")
                print(f"Error rows: {error_rows}")

    # Insert any remaining rows for this file
    if processed_rows:
        try:
            response = supabase.table('v2_federato_amplitude_data').insert(processed_rows).execute()
            print(f"Inserted final batch of {len(processed_rows)} rows")
        except Exception as e:
            print(f"Error inserting final batch: {e}")
            error_rows += len(processed_rows)

    # Print statistics for this file
    print(f"\nFile {os.path.basename(file_path)} complete!")
    print(f"Total rows processed: {total_rows}")
    print(f"Valid rows inserted: {valid_rows}")
    print(f"Error rows: {error_rows}")
    
    # Update grand totals
    grand_total_rows += total_rows
    grand_valid_rows += valid_rows
    grand_error_rows += error_rows

# Print final statistics for all files
print("\nAll files processing complete!")
print(f"Grand total rows processed: {grand_total_rows}")
print(f"Grand total valid rows inserted: {grand_valid_rows}")
print(f"Grand total error rows: {grand_error_rows}")
# Out:
# Found 16 files to process:
# - amplitude_export_chunk_10_anonymized.json
# - amplitude_export_chunk_11_anonymized.json
# - amplitude_export_chunk_12_anonymized.json
# - amplitude_export_chunk_13_anonymized.json
# - amplitude_export_chunk_14_anonymized.json
# - amplitude_export_chunk_15_anonymized.json
# - amplitude_export_chunk_16_anonymized.json
# - amplitude_export_chunk_1_anonymized.json
# - amplitude_export_chunk_2_anonymized.json
# - amplitude_export_chunk_3_anonymized.json
# - amplitude_export_chunk_4_anonymized.json
# - amplitude_export_chunk_5_anonymized.json
# - amplitude_export_chunk_6_anonymized.json
# - amplitude_export_chunk_7_anonymized.json
# - amplitude_export_chunk_8_anonymized.json
# - amplitude_export_chunk_9_anonymized.json
#
# Processing file: amplitude_export_chunk_10_anonymized.json
# Inserted batch of 1000 rows
# Progress: Processed 1000 rows
# Valid rows: 1000
# Error rows: 0
# Inserted batch of 1000 rows
# Progress: Processed 2000 rows
# Valid rows: 2000
# Error rows: 0
# Inserted batch of 1000 rows
# Progress: Processed 3000 rows
# Valid rows: 3000
# Error rows: 0
# Inserted batch of 1000 rows
# Progress: Processed 4000 rows
# Valid rows: 4000
# Error rows: 0
# Inserted batch of 1000 rows
# Progress: Processed 5000 rows
# Valid rows: 5000
# Error rows: 0
# Inserted batch of 1000 rows
# Progress: Processed 6000 rows
# Valid rows: 6000
# Error rows: 0
# Inserted batch of 1000 rows
# Progress: Processed 7000 rows
# Valid rows: 7000
# Error rows: 0
# Inserted batch of 1000 rows
# Progress: Processed 8000 rows
# Valid rows: 8000
# Error rows: 0
# Inserted batch of 1000 rows
# Progress: Processed 9000 rows
# Valid rows: 9000
# Error rows: 0
# Inserted batch of 1000 rows
# Progress: Processed 10000 rows
# Valid rows: 10000
# Error rows: 0
# Inserted batch of 1000 rows
# Progress: Processed 11000 rows
# Valid rows: 11000
# Error rows: 0
# Inserted batch of 1000 rows
# Progress: Processed 12000 rows
# Valid rows: 12000
# Error rows: 0
# Inserted batch of 1000 rows
# Progress: Processed 13000 rows
# Valid rows: 13000
# Error rows: 0
# Inserted batch of 1000 rows
# Progress: Processed 14000 rows
# Valid rows: 14000
# Error rows: 0
# Inserted batch of 1000 rows
# Progress: Processed 15000 rows
# Valid rows: 15000
# Error rows: 0
# Inserted batch of 1000 rows
# Progress: Processed 16000 rows
# Valid rows: 16000
# Error rows: 0
# Inserted batch of 1000 rows
# Progress: Processed 17000 rows
# Valid rows: 17000
# Error rows: 0
# Inserted batch of 1000 rows
# Progress: Processed 18000 rows
# Valid rows: 18000
# Error rows: 0
# Inserted batch of 1000 rows
# Progress: Processed 19000 rows
# Valid rows: 19000
# Error rows: 0
# Inserted batch of 1000 rows
# Progress: Processed 20000 rows
# Valid rows: 20000
# Error rows: 0
# Inserted batch of 1000 rows
# Progress: Processed 21000 rows
# Valid rows: 21000
# Error rows: 0
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Progress: Processed 22000 rows
# Valid rows: 21986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 23000 rows
# Valid rows: 22986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 24000 rows
# Valid rows: 23986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 25000 rows
# Valid rows: 24986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 26000 rows
# Valid rows: 25986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 27000 rows
# Valid rows: 26986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 28000 rows
# Valid rows: 27986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 29000 rows
# Valid rows: 28986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 30000 rows
# Valid rows: 29986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 31000 rows
# Valid rows: 30986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 32000 rows
# Valid rows: 31986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 33000 rows
# Valid rows: 32986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 34000 rows
# Valid rows: 33986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 35000 rows
# Valid rows: 34986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 36000 rows
# Valid rows: 35986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 37000 rows
# Valid rows: 36986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 38000 rows
# Valid rows: 37986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 39000 rows
# Valid rows: 38986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 40000 rows
# Valid rows: 39986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 41000 rows
# Valid rows: 40986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 42000 rows
# Valid rows: 41986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 43000 rows
# Valid rows: 42986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 44000 rows
# Valid rows: 43986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 45000 rows
# Valid rows: 44986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 46000 rows
# Valid rows: 45986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 47000 rows
# Valid rows: 46986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 48000 rows
# Valid rows: 47986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 49000 rows
# Valid rows: 48986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 50000 rows
# Valid rows: 49986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 51000 rows
# Valid rows: 50986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 52000 rows
# Valid rows: 51986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 53000 rows
# Valid rows: 52986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 54000 rows
# Valid rows: 53986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 55000 rows
# Valid rows: 54986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 56000 rows
# Valid rows: 55986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 57000 rows
# Valid rows: 56986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 58000 rows
# Valid rows: 57986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 59000 rows
# Valid rows: 58986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 60000 rows
# Valid rows: 59986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 61000 rows
# Valid rows: 60986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 62000 rows
# Valid rows: 61986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 63000 rows
# Valid rows: 62986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 64000 rows
# Valid rows: 63986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 65000 rows
# Valid rows: 64986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 66000 rows
# Valid rows: 65986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 67000 rows
# Valid rows: 66986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 68000 rows
# Valid rows: 67986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 69000 rows
# Valid rows: 68986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 70000 rows
# Valid rows: 69986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 71000 rows
# Valid rows: 70986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 72000 rows
# Valid rows: 71986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 73000 rows
# Valid rows: 72986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 74000 rows
# Valid rows: 73986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 75000 rows
# Valid rows: 74986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 76000 rows
# Valid rows: 75986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 77000 rows
# Valid rows: 76986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 78000 rows
# Valid rows: 77986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 79000 rows
# Valid rows: 78986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 80000 rows
# Valid rows: 79986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 81000 rows
# Valid rows: 80986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 82000 rows
# Valid rows: 81986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 83000 rows
# Valid rows: 82986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 84000 rows
# Valid rows: 83986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 85000 rows
# Valid rows: 84986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 86000 rows
# Valid rows: 85986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 87000 rows
# Valid rows: 86986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 88000 rows
# Valid rows: 87986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 89000 rows
# Valid rows: 88986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 90000 rows
# Valid rows: 89986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 91000 rows
# Valid rows: 90986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 92000 rows
# Valid rows: 91986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 93000 rows
# Valid rows: 92986
# Error rows: 14
# Inserted batch of 1000 rows
# Progress: Processed 94000 rows
# Valid rows: 93986
# Error rows: 14
# Inserted batch of 1000 rows
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Progress: Processed 95000 rows
# Valid rows: 94953
# Error rows: 47
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Inserted batch of 1000 rows
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Progress: Processed 96000 rows
# Valid rows: 95817
# Error rows: 183
# Inserted batch of 1000 rows
# Progress: Processed 97000 rows
# Valid rows: 96817
# Error rows: 183
# Inserted batch of 1000 rows
# Progress: Processed 98000 rows
# Valid rows: 97817
# Error rows: 183
# Inserted batch of 1000 rows
# Progress: Processed 99000 rows
# Valid rows: 98817
# Error rows: 183
# Inserted batch of 1000 rows
# Progress: Processed 100000 rows
# Valid rows: 99817
# Error rows: 183
# Inserted batch of 1000 rows
# Progress: Processed 101000 rows
# Valid rows: 100817
# Error rows: 183
# Inserted batch of 1000 rows
# Progress: Processed 102000 rows
# Valid rows: 101817
# Error rows: 183
# Inserted batch of 1000 rows
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Progress: Processed 103000 rows
# Valid rows: 102772
# Error rows: 228
# Inserted batch of 1000 rows
# Progress: Processed 104000 rows
# Valid rows: 103772
# Error rows: 228
# Inserted batch of 1000 rows
# Progress: Processed 105000 rows
# Valid rows: 104772
# Error rows: 228
# Inserted batch of 1000 rows
# Progress: Processed 106000 rows
# Valid rows: 105772
# Error rows: 228
# Inserted batch of 1000 rows
# Progress: Processed 107000 rows
# Valid rows: 106772
# Error rows: 228
# Inserted batch of 1000 rows
# Progress: Processed 108000 rows
# Valid rows: 107772
# Error rows: 228
# Inserted batch of 1000 rows
# Progress: Processed 109000 rows
# Valid rows: 108772
# Error rows: 228
# Inserted batch of 1000 rows
# Progress: Processed 110000 rows
# Valid rows: 109772
# Error rows: 228
# Inserted batch of 1000 rows
# Progress: Processed 111000 rows
# Valid rows: 110772
# Error rows: 228
# Inserted batch of 1000 rows
# Progress: Processed 112000 rows
# Valid rows: 111772
# Error rows: 228
# Inserted batch of 1000 rows
# Progress: Processed 113000 rows
# Valid rows: 112772
# Error rows: 228
# Inserted batch of 1000 rows
# Progress: Processed 114000 rows
# Valid rows: 113772
# Error rows: 228
# Inserted batch of 1000 rows
# Progress: Processed 115000 rows
# Valid rows: 114772
# Error rows: 228
# Inserted batch of 1000 rows
# Progress: Processed 116000 rows
# Valid rows: 115772
# Error rows: 228
# Inserted batch of 1000 rows
# Progress: Processed 117000 rows
# Valid rows: 116772
# Error rows: 228
# Inserted batch of 1000 rows
# Progress: Processed 118000 rows
# Valid rows: 117772
# Error rows: 228
# Inserted batch of 1000 rows
# Progress: Processed 119000 rows
# Valid rows: 118772
# Error rows: 228
# Inserted batch of 1000 rows
# Progress: Processed 120000 rows
# Valid rows: 119772
# Error rows: 228
# Inserted batch of 1000 rows
# Progress: Processed 121000 rows
# Valid rows: 120772
# Error rows: 228
# Inserted batch of 1000 rows
# Progress: Processed 122000 rows
# Valid rows: 121772
# Error rows: 228
# Inserted batch of 1000 rows
# Progress: Processed 123000 rows
# Valid rows: 122772
# Error rows: 228
# Inserted batch of 1000 rows
# Progress: Processed 124000 rows
# Valid rows: 123772
# Error rows: 228
# Inserted batch of 1000 rows
# Progress: Processed 125000 rows
# Valid rows: 124772
# Error rows: 228
# Inserted batch of 1000 rows
# Progress: Processed 126000 rows
# Valid rows: 125772
# Error rows: 228
# Inserted batch of 1000 rows
# Progress: Processed 127000 rows
# Valid rows: 126772
# Error rows: 228
# Inserted batch of 1000 rows
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Progress: Processed 128000 rows
# Valid rows: 127760
# Error rows: 240
# Inserted batch of 1000 rows
# Progress: Processed 129000 rows
# Valid rows: 128760
# Error rows: 240
# Inserted batch of 1000 rows
# Progress: Processed 130000 rows
# Valid rows: 129760
# Error rows: 240
# Inserted batch of 1000 rows
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Progress: Processed 131000 rows
# Valid rows: 130686
# Error rows: 314
# Inserted batch of 1000 rows
# Progress: Processed 132000 rows
# Valid rows: 131686
# Error rows: 314
# Inserted batch of 1000 rows
# Progress: Processed 133000 rows
# Valid rows: 132686
# Error rows: 314
# Inserted batch of 1000 rows
# Progress: Processed 134000 rows
# Valid rows: 133686
# Error rows: 314
# Inserted batch of 1000 rows
# Progress: Processed 135000 rows
# Valid rows: 134686
# Error rows: 314
# Inserted batch of 1000 rows
# Progress: Processed 136000 rows
# Valid rows: 135686
# Error rows: 314
# Inserted batch of 1000 rows
# Progress: Processed 137000 rows
# Valid rows: 136686
# Error rows: 314
# Inserted batch of 1000 rows
# Progress: Processed 138000 rows
# Valid rows: 137686
# Error rows: 314
# Inserted batch of 1000 rows
# Progress: Processed 139000 rows
# Valid rows: 138686
# Error rows: 314
# Inserted batch of 1000 rows
# Progress: Processed 140000 rows
# Valid rows: 139686
# Error rows: 314
# Inserted batch of 1000 rows
# Progress: Processed 141000 rows
# Valid rows: 140686
# Error rows: 314
# Inserted batch of 1000 rows
# Progress: Processed 142000 rows
# Valid rows: 141686
# Error rows: 314
# Inserted batch of 1000 rows
# Progress: Processed 143000 rows
# Valid rows: 142686
# Error rows: 314
# Inserted batch of 1000 rows
# Progress: Processed 144000 rows
# Valid rows: 143686
# Error rows: 314
# Inserted batch of 1000 rows
# Progress: Processed 145000 rows
# Valid rows: 144686
# Error rows: 314
# Inserted batch of 1000 rows
# Progress: Processed 146000 rows
# Valid rows: 145686
# Error rows: 314
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Inserted batch of 1000 rows
# Progress: Processed 147000 rows
# Valid rows: 146651
# Error rows: 349
# Inserted batch of 1000 rows
# Progress: Processed 148000 rows
# Valid rows: 147651
# Error rows: 349
# Inserted batch of 1000 rows
# Progress: Processed 149000 rows
# Valid rows: 148651
# Error rows: 349
# Inserted batch of 1000 rows
# Progress: Processed 150000 rows
# Valid rows: 149651
# Error rows: 349
# Inserted batch of 1000 rows
# Progress: Processed 151000 rows
# Valid rows: 150651
# Error rows: 349
# Inserted batch of 1000 rows
# Progress: Processed 152000 rows
# Valid rows: 151651
# Error rows: 349
# Inserted batch of 1000 rows
# Progress: Processed 153000 rows
# Valid rows: 152651
# Error rows: 349
# Inserted batch of 1000 rows
# Progress: Processed 154000 rows
# Valid rows: 153651
# Error rows: 349
# Inserted batch of 1000 rows
# Progress: Processed 155000 rows
# Valid rows: 154651
# Error rows: 349
# Inserted batch of 1000 rows
# Progress: Processed 156000 rows
# Valid rows: 155651
# Error rows: 349
# Inserted batch of 1000 rows
# Progress: Processed 157000 rows
# Valid rows: 156651
# Error rows: 349
# Inserted batch of 1000 rows
# Progress: Processed 158000 rows
# Valid rows: 157651
# Error rows: 349
# Inserted batch of 1000 rows
# Progress: Processed 159000 rows
# Valid rows: 158651
# Error rows: 349
# Inserted batch of 1000 rows
# Progress: Processed 160000 rows
# Valid rows: 159651
# Error rows: 349
# Inserted batch of 1000 rows
# Progress: Processed 161000 rows
# Valid rows: 160651
# Error rows: 349
# Inserted batch of 1000 rows
# Progress: Processed 162000 rows
# Valid rows: 161651
# Error rows: 349
# Inserted batch of 1000 rows
# Progress: Processed 163000 rows
# Valid rows: 162651
# Error rows: 349
# Inserted batch of 1000 rows
# Progress: Processed 164000 rows
# Valid rows: 163651
# Error rows: 349
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Inserted batch of 1000 rows
# Progress: Processed 165000 rows
# Valid rows: 164633
# Error rows: 367
# Inserted batch of 1000 rows
# Progress: Processed 166000 rows
# Valid rows: 165633
# Error rows: 367
# Inserted batch of 1000 rows
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Progress: Processed 167000 rows
# Valid rows: 166577
# Error rows: 423
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Inserted batch of 1000 rows
# Progress: Processed 168000 rows
# Valid rows: 167557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 169000 rows
# Valid rows: 168557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 170000 rows
# Valid rows: 169557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 171000 rows
# Valid rows: 170557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 172000 rows
# Valid rows: 171557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 173000 rows
# Valid rows: 172557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 174000 rows
# Valid rows: 173557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 175000 rows
# Valid rows: 174557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 176000 rows
# Valid rows: 175557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 177000 rows
# Valid rows: 176557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 178000 rows
# Valid rows: 177557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 179000 rows
# Valid rows: 178557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 180000 rows
# Valid rows: 179557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 181000 rows
# Valid rows: 180557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 182000 rows
# Valid rows: 181557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 183000 rows
# Valid rows: 182557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 184000 rows
# Valid rows: 183557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 185000 rows
# Valid rows: 184557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 186000 rows
# Valid rows: 185557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 187000 rows
# Valid rows: 186557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 188000 rows
# Valid rows: 187557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 189000 rows
# Valid rows: 188557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 190000 rows
# Valid rows: 189557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 191000 rows
# Valid rows: 190557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 192000 rows
# Valid rows: 191557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 193000 rows
# Valid rows: 192557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 194000 rows
# Valid rows: 193557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 195000 rows
# Valid rows: 194557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 196000 rows
# Valid rows: 195557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 197000 rows
# Valid rows: 196557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 198000 rows
# Valid rows: 197557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 199000 rows
# Valid rows: 198557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 200000 rows
# Valid rows: 199557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 201000 rows
# Valid rows: 200557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 202000 rows
# Valid rows: 201557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 203000 rows
# Valid rows: 202557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 204000 rows
# Valid rows: 203557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 205000 rows
# Valid rows: 204557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 206000 rows
# Valid rows: 205557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 207000 rows
# Valid rows: 206557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 208000 rows
# Valid rows: 207557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 209000 rows
# Valid rows: 208557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 210000 rows
# Valid rows: 209557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 211000 rows
# Valid rows: 210557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 212000 rows
# Valid rows: 211557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 213000 rows
# Valid rows: 212557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 214000 rows
# Valid rows: 213557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 215000 rows
# Valid rows: 214557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 216000 rows
# Valid rows: 215557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 217000 rows
# Valid rows: 216557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 218000 rows
# Valid rows: 217557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 219000 rows
# Valid rows: 218557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 220000 rows
# Valid rows: 219557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 221000 rows
# Valid rows: 220557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 222000 rows
# Valid rows: 221557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 223000 rows
# Valid rows: 222557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 224000 rows
# Valid rows: 223557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 225000 rows
# Valid rows: 224557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 226000 rows
# Valid rows: 225557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 227000 rows
# Valid rows: 226557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 228000 rows
# Valid rows: 227557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 229000 rows
# Valid rows: 228557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 230000 rows
# Valid rows: 229557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 231000 rows
# Valid rows: 230557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 232000 rows
# Valid rows: 231557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 233000 rows
# Valid rows: 232557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 234000 rows
# Valid rows: 233557
# Error rows: 443
# Inserted batch of 1000 rows
# Progress: Processed 235000 rows
# Valid rows: 234557
# Error rows: 443
# Inserted batch of 1000 rows
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Progress: Processed 236000 rows
# Valid rows: 235551
# Error rows: 449
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Inserted batch of 1000 rows
# Progress: Processed 237000 rows
# Valid rows: 236547
# Error rows: 453
# Inserted batch of 1000 rows
# Progress: Processed 238000 rows
# Valid rows: 237547
# Error rows: 453
# Inserted batch of 1000 rows
# Progress: Processed 239000 rows
# Valid rows: 238547
# Error rows: 453
# Inserted batch of 1000 rows
# Progress: Processed 240000 rows
# Valid rows: 239547
# Error rows: 453
# Inserted batch of 1000 rows
# Progress: Processed 241000 rows
# Valid rows: 240547
# Error rows: 453
# Inserted batch of 1000 rows
# Progress: Processed 242000 rows
# Valid rows: 241547
# Error rows: 453
# Inserted batch of 1000 rows
# Progress: Processed 243000 rows
# Valid rows: 242547
# Error rows: 453
# Inserted batch of 1000 rows
# ...
# Progress: Processed 833000 rows
# Valid rows: 832190
# Error rows: 210810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 834000 rows
# Valid rows: 833190
# Error rows: 211810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 835000 rows
# Valid rows: 834190
# Error rows: 212810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 836000 rows
# Valid rows: 835190
# Error rows: 213810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 837000 rows
# Valid rows: 836190
# Error rows: 214810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 838000 rows
# Valid rows: 837190
# Error rows: 215810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 839000 rows
# Valid rows: 838190
# Error rows: 216810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 840000 rows
# Valid rows: 839190
# Error rows: 217810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 841000 rows
# Valid rows: 840190
# Error rows: 218810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 842000 rows
# Valid rows: 841190
# Error rows: 219810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 843000 rows
# Valid rows: 842190
# Error rows: 220810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 844000 rows
# Valid rows: 843190
# Error rows: 221810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 845000 rows
# Valid rows: 844190
# Error rows: 222810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 846000 rows
# Valid rows: 845190
# Error rows: 223810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 847000 rows
# Valid rows: 846190
# Error rows: 224810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 848000 rows
# Valid rows: 847190
# Error rows: 225810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 849000 rows
# Valid rows: 848190
# Error rows: 226810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 850000 rows
# Valid rows: 849190
# Error rows: 227810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 851000 rows
# Valid rows: 850190
# Error rows: 228810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 852000 rows
# Valid rows: 851190
# Error rows: 229810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 853000 rows
# Valid rows: 852190
# Error rows: 230810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 854000 rows
# Valid rows: 853190
# Error rows: 231810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 855000 rows
# Valid rows: 854190
# Error rows: 232810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 856000 rows
# Valid rows: 855190
# Error rows: 233810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 857000 rows
# Valid rows: 856190
# Error rows: 234810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 858000 rows
# Valid rows: 857190
# Error rows: 235810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 859000 rows
# Valid rows: 858190
# Error rows: 236810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 860000 rows
# Valid rows: 859190
# Error rows: 237810
# Error inserting batch: {'code': '', 'details': None, 'hint': None, 'message': ''}
# Progress: Processed 861000 rows
# Valid rows: 860190
# Error rows: 238810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 862000 rows
# Valid rows: 861190
# Error rows: 239810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 863000 rows
# Valid rows: 862190
# Error rows: 240810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 864000 rows
# Valid rows: 863190
# Error rows: 241810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 865000 rows
# Valid rows: 864190
# Error rows: 242810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 866000 rows
# Valid rows: 865190
# Error rows: 243810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 867000 rows
# Valid rows: 866190
# Error rows: 244810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 868000 rows
# Valid rows: 867190
# Error rows: 245810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 869000 rows
# Valid rows: 868190
# Error rows: 246810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 870000 rows
# Valid rows: 869190
# Error rows: 247810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 871000 rows
# Valid rows: 870190
# Error rows: 248810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 872000 rows
# Valid rows: 871190
# Error rows: 249810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 873000 rows
# Valid rows: 872190
# Error rows: 250810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 874000 rows
# Valid rows: 873190
# Error rows: 251810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 875000 rows
# Valid rows: 874190
# Error rows: 252810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 876000 rows
# Valid rows: 875190
# Error rows: 253810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 877000 rows
# Valid rows: 876190
# Error rows: 254810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 878000 rows
# Valid rows: 877190
# Error rows: 255810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 879000 rows
# Valid rows: 878190
# Error rows: 256810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 880000 rows
# Valid rows: 879190
# Error rows: 257810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 881000 rows
# Valid rows: 880190
# Error rows: 258810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 882000 rows
# Valid rows: 881190
# Error rows: 259810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 883000 rows
# Valid rows: 882190
# Error rows: 260810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 884000 rows
# Valid rows: 883190
# Error rows: 261810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 885000 rows
# Valid rows: 884190
# Error rows: 262810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 886000 rows
# Valid rows: 885190
# Error rows: 263810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 887000 rows
# Valid rows: 886190
# Error rows: 264810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 888000 rows
# Valid rows: 887190
# Error rows: 265810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 889000 rows
# Valid rows: 888190
# Error rows: 266810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 890000 rows
# Valid rows: 889190
# Error rows: 267810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 891000 rows
# Valid rows: 890190
# Error rows: 268810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 892000 rows
# Valid rows: 891190
# Error rows: 269810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 893000 rows
# Valid rows: 892190
# Error rows: 270810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 894000 rows
# Valid rows: 893190
# Error rows: 271810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 895000 rows
# Valid rows: 894190
# Error rows: 272810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Progress: Processed 896000 rows
# Valid rows: 895190
# Error rows: 273810
# Error inserting batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
# Error inserting final batch: {'code': '53100', 'details': None, 'hint': 'Check free disk space.', 'message': 'could not extend file "base/5/29105.10": No space left on device'}
#
# File amplitude_export_chunk_9_anonymized.json complete!
# Total rows processed: 896927
# Valid rows inserted: 896117
# Error rows: 274927
#
# All files processing complete!
# Grand total rows processed: 13559328
# Grand total valid rows inserted: 13549835
# Grand total error rows: 286610
# CPU times: user 8h 5min 43s, sys: 7min 58s, total: 8h 13min 41s
# Wall time: 11h 19min 48s

# %%
# %%time
import ijson
import pandas as pd
import json
from pathlib import Path
from supabase import create_client, Client
from dotenv import load_dotenv
import os

# file_path = f"/Users/krish/Projects/CxC_Data/new_amplitude_export_2025.json"
file_path = f"/Users/krish/Projects/CxC_Data/2024/amplitude_export_chunk_1_anonymized.json"

# Important columns with their Supabase types
columns_keep = {
    # UUID fields
    'id': {'type': 'uuid', 'source': 'uuid', 'nullable': False},  
    'device_id': {'type': 'uuid', 'nullable': False},
    
    # Integer fields
    'amplitude_id': {'type': 'int8', 'nullable': False},
    'app': {'type': 'int8', 'nullable': False},
    'event_id': {'type': 'int8', 'nullable': False},
    'session_id': {'type': 'int8', 'nullable': False},
    
    # Text fields - some allowed to be null
    'city': {'type': 'text', 'nullable': True},
    'country': {'type': 'text', 'nullable': False},
    'device_family': {'type': 'text', 'nullable': True},
    'device_type': {'type': 'text', 'nullable': True},
    'dma': {'type': 'text', 'nullable': True},
    'event_type': {'type': 'text', 'nullable': False},
    'language': {'type': 'text', 'nullable': False},
    'os_name': {'type': 'text', 'nullable': False},
    'platform': {'type': 'text', 'nullable': False},
    'region': {'type': 'text', 'nullable': False},
    
    # JSON fields
    'user_properties': {'type': 'json', 'nullable': True},
    
    # Timestamp field
    'event_time': {'type': 'timestamp', 'nullable': False},
}

def clean_user_properties(props):
    """Convert 'EMPTY' string values to None in user_properties and remove trackingVersion"""
    if not isinstance(props, dict):
        return props
    
    cleaned = {}
    for key, value in props.items():
        # Skip trackingVersion field
        if key == 'trackingVersion':
            continue
            
        if isinstance(value, str) and value == "EMPTY":
            cleaned[key] = None
        elif isinstance(value, list):
            cleaned[key] = value  # Preserve lists (like roles) as is
        else:
            cleaned[key] = value
    return cleaned

def clean_empty_objects(data):
    """Convert empty nested objects to None in data column"""
    if not isinstance(data, dict):
        return data
    
    cleaned = {}
    for key, value in data.items():
        if isinstance(value, dict) and len(value) == 0:
            cleaned[key] = None
        else:
            cleaned[key] = value
    return cleaned

def is_empty_value(val):
    """Check if a value should be considered empty"""
    if pd.isna(val):  # Checks for None and NaN
        return True
    if isinstance(val, str) and val.strip() == "":  # Empty strings or whitespace
        return True
    if val == "None":  # String "None"
        return True
    if isinstance(val, (dict, list)) and len(val) == 0:  # Empty collections
        return True
    return False

def preprocess_row(row):
    # Convert row to DataFrame for easier handling
    df = pd.DataFrame([row])
    
    # Create id from uuid
    df['id'] = df['uuid']

    # Clean user_properties before validation
    if 'user_properties' in df.columns:
        df['user_properties'] = df['user_properties'].apply(clean_user_properties)
    
    # # Clean data column before validation
    # if 'data' in df.columns:
    #     df['data'] = df['data'].apply(clean_empty_objects)
    
    # Type validations
    for col, info in columns_keep.items():
        # Get the value for the current column
        val = df[col].iloc[0]
        
        # Skip empty value check for nullable fields
        if not info['nullable']:
            if is_empty_value(val):
                print(f"Row dropped: Empty value in non-nullable field {col}")
                return None
            
        # Handle special case for id field
        if col == 'id' and info['source'] == 'uuid':
            continue
            
        # UUID validation
        if info['type'] == 'uuid':
            if not isinstance(val, str) or len(val.split('-')) != 5:
                print(f"Row dropped: Invalid UUID format for {col}")
                return None
        
        # Integer validation
        elif info['type'] == 'int8':
            try:
                df[col] = pd.to_numeric(df[col], downcast='integer')
                if df[col].iloc[0] <= 0:
                    print(f"Row dropped: Invalid value for {col}")
                    return None
            except (ValueError, TypeError):
                print(f"Row dropped: Non-numeric {col}")
                return None
        
        # JSON validation
        elif info['type'] == 'json':
            if not info['nullable']:
                if not isinstance(val, dict):
                    print(f"Row dropped: Invalid JSON format for {col}")
                    return None
                if len(val) == 0:
                    print(f"Row dropped: Empty JSON object in {col}")
                    return None
            elif val is not None:  # For nullable JSON fields, validate only if not None
                if not isinstance(val, dict):
                    print(f"Row dropped: Invalid JSON format for {col}")
                    return None
        
        # Text validation
        elif info['type'] == 'text':
            if not info['nullable']:
                if not isinstance(val, str):
                    df[col] = str(val)  # Convert to string if possible
                if len(df[col].iloc[0].strip()) == 0:
                    print(f"Row dropped: Empty text in non-nullable field {col}")
                    return None
            elif val is not None:  # For nullable text fields, validate only if not None
                if not isinstance(val, str):
                    df[col] = str(val)
        
        # Timestamp validation
        elif info['type'] == 'timestamp':
            try:
                df[col] = pd.to_datetime(df[col])
            except (ValueError, TypeError):
                print(f"Row dropped: Invalid timestamp for {col}")
                return None
    
    # Location validation for US entries
    # if df['country'].iloc[0] == "United States":
    #     if pd.isnull(df['dma'].iloc[0]) or df['dma'].iloc[0].strip() == "":
    #         print("Row dropped: Missing DMA for US location")
    #         return None
    
    return df[columns_keep.keys()]

# Initialize Supabase client
os.environ.clear()
load_dotenv(override=True)
supabase: Client = create_client(
    supabase_url=os.getenv("SUPABASE_URL"),
    supabase_key=os.getenv("SUPABASE_KEY")
)

# Process rows in batches
batch_size = 1000  # Adjust based on your needs
processed_rows = []
total_rows = 0
valid_rows = 0
error_rows = 0

with open(file_path, "r") as f:
    objects = ijson.items(f, "item")
    
    for row in objects:
        total_rows += 1
        
        # Process the row
        processed_df = preprocess_row(row)
        
        if processed_df is not None:
            # Convert timestamp to ISO format - fixed version
            processed_df['event_time'] = processed_df['event_time'].iloc[0].strftime('%Y-%m-%dT%H:%M:%S.%fZ')
            
            # Convert row to dictionary
            row_dict = processed_df.iloc[0].to_dict()
            processed_rows.append(row_dict)
            valid_rows += 1
            
            # When batch is full, insert into Supabase
            if len(processed_rows) >= batch_size:
                try:
                    response = supabase.table('2024_1_federato_amplitude_data').insert(processed_rows).execute()
                    print(f"\nInserted batch of {len(processed_rows)} rows")
                    processed_rows = []  # Clear the batch
                except Exception as e:
                    print(f"\nError inserting batch: {e}")
                    error_rows += len(processed_rows)
                    processed_rows = []  # Clear the batch even if there's an error
        else:
            error_rows += 1
        
        # Print progress
        if total_rows % 1000 == 0:
            print(f"\nProgress: Processed {total_rows} rows")
            print(f"Valid rows: {valid_rows}")
            print(f"Error rows: {error_rows}")

# Insert any remaining rows
if processed_rows:
    try:
        response = supabase.table('2024_1_federato_amplitude_data').insert(processed_rows).execute()
        print(f"\nInserted final batch of {len(processed_rows)} rows")
    except Exception as e:
        print(f"\nError inserting final batch: {e}")
        error_rows += len(processed_rows)

# Print final statistics
print("\nProcessing complete!")
print(f"Total rows processed: {total_rows}")
print(f"Valid rows inserted: {valid_rows}")
print(f"Error rows: {error_rows}")
# Out:
# Inserted batch of 1000 rows
#
# Progress: Processed 1000 rows
# Valid rows: 1000
# Error rows: 0
#
# Inserted batch of 1000 rows
#
# Progress: Processed 2000 rows
# Valid rows: 2000
# Error rows: 0
#
# Inserted batch of 1000 rows
#
# Progress: Processed 3000 rows
# Valid rows: 3000
# Error rows: 0
#
# Inserted batch of 1000 rows
#
# Progress: Processed 4000 rows
# Valid rows: 4000
# Error rows: 0
#
# Inserted batch of 1000 rows
#
# Progress: Processed 5000 rows
# Valid rows: 5000
# Error rows: 0
#
# Inserted batch of 1000 rows
#
# Progress: Processed 6000 rows
# Valid rows: 6000
# Error rows: 0
#
# Inserted batch of 1000 rows
#
# Progress: Processed 7000 rows
# Valid rows: 7000
# Error rows: 0
#
# Inserted batch of 1000 rows
#
# Progress: Processed 8000 rows
# Valid rows: 8000
# Error rows: 0
#
# Inserted batch of 1000 rows
#
# Progress: Processed 9000 rows
# Valid rows: 9000
# Error rows: 0
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
#
# Progress: Processed 10000 rows
# Valid rows: 9998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 11000 rows
# Valid rows: 10998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 12000 rows
# Valid rows: 11998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 13000 rows
# Valid rows: 12998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 14000 rows
# Valid rows: 13998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 15000 rows
# Valid rows: 14998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 16000 rows
# Valid rows: 15998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 17000 rows
# Valid rows: 16998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 18000 rows
# Valid rows: 17998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 19000 rows
# Valid rows: 18998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 20000 rows
# Valid rows: 19998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 21000 rows
# Valid rows: 20998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 22000 rows
# Valid rows: 21998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 23000 rows
# Valid rows: 22998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 24000 rows
# Valid rows: 23998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 25000 rows
# Valid rows: 24998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 26000 rows
# Valid rows: 25998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 27000 rows
# Valid rows: 26998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 28000 rows
# Valid rows: 27998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 29000 rows
# Valid rows: 28998
# Error rows: 2
#
# Inserted batch of 1000 rows
#
# Progress: Processed 30000 rows
# Valid rows: 29998
# Error rows: 2
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
#
# Progress: Processed 31000 rows
# Valid rows: 30997
# Error rows: 3
#
# Inserted batch of 1000 rows
#
# Progress: Processed 32000 rows
# Valid rows: 31997
# Error rows: 3
#
# Inserted batch of 1000 rows
#
# Progress: Processed 33000 rows
# Valid rows: 32997
# Error rows: 3
#
# Inserted batch of 1000 rows
#
# Progress: Processed 34000 rows
# Valid rows: 33997
# Error rows: 3
#
# Inserted batch of 1000 rows
#
# Progress: Processed 35000 rows
# Valid rows: 34997
# Error rows: 3
#
# Inserted batch of 1000 rows
#
# Progress: Processed 36000 rows
# Valid rows: 35997
# Error rows: 3
#
# Inserted batch of 1000 rows
#
# Progress: Processed 37000 rows
# Valid rows: 36997
# Error rows: 3
#
# Inserted batch of 1000 rows
#
# Progress: Processed 38000 rows
# Valid rows: 37997
# Error rows: 3
#
# Inserted batch of 1000 rows
#
# Progress: Processed 39000 rows
# Valid rows: 38997
# Error rows: 3
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
#
# Progress: Processed 40000 rows
# Valid rows: 39996
# Error rows: 4
#
# Inserted batch of 1000 rows
#
# Progress: Processed 41000 rows
# Valid rows: 40996
# Error rows: 4
#
# Inserted batch of 1000 rows
#
# Progress: Processed 42000 rows
# Valid rows: 41996
# Error rows: 4
#
# Inserted batch of 1000 rows
#
# Progress: Processed 43000 rows
# Valid rows: 42996
# Error rows: 4
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
#
# Progress: Processed 44000 rows
# Valid rows: 43995
# Error rows: 5
#
# Inserted batch of 1000 rows
#
# Progress: Processed 45000 rows
# Valid rows: 44995
# Error rows: 5
#
# Inserted batch of 1000 rows
#
# Progress: Processed 46000 rows
# Valid rows: 45995
# Error rows: 5
#
# Inserted batch of 1000 rows
#
# Progress: Processed 47000 rows
# Valid rows: 46995
# Error rows: 5
#
# Inserted batch of 1000 rows
#
# Progress: Processed 48000 rows
# Valid rows: 47995
# Error rows: 5
#
# Inserted batch of 1000 rows
#
# Progress: Processed 49000 rows
# Valid rows: 48995
# Error rows: 5
#
# Inserted batch of 1000 rows
#
# Progress: Processed 50000 rows
# Valid rows: 49995
# Error rows: 5
#
# Inserted batch of 1000 rows
#
# Progress: Processed 51000 rows
# Valid rows: 50995
# Error rows: 5
#
# Inserted batch of 1000 rows
#
# Progress: Processed 52000 rows
# Valid rows: 51995
# Error rows: 5
#
# Inserted batch of 1000 rows
#
# Progress: Processed 53000 rows
# Valid rows: 52995
# Error rows: 5
#
# Inserted batch of 1000 rows
#
# Progress: Processed 54000 rows
# Valid rows: 53995
# Error rows: 5
#
# Inserted batch of 1000 rows
#
# Progress: Processed 55000 rows
# Valid rows: 54995
# Error rows: 5
#
# Inserted batch of 1000 rows
#
# Progress: Processed 56000 rows
# Valid rows: 55995
# Error rows: 5
#
# Inserted batch of 1000 rows
#
# Progress: Processed 57000 rows
# Valid rows: 56995
# Error rows: 5
#
# Inserted batch of 1000 rows
#
# Progress: Processed 58000 rows
# Valid rows: 57995
# Error rows: 5
#
# Inserted batch of 1000 rows
#
# Progress: Processed 59000 rows
# Valid rows: 58995
# Error rows: 5
#
# Inserted batch of 1000 rows
#
# Progress: Processed 60000 rows
# Valid rows: 59995
# Error rows: 5
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
#
# Progress: Processed 61000 rows
# Valid rows: 60994
# Error rows: 6
#
# Inserted batch of 1000 rows
#
# Progress: Processed 62000 rows
# Valid rows: 61994
# Error rows: 6
#
# Inserted batch of 1000 rows
#
# Progress: Processed 63000 rows
# Valid rows: 62994
# Error rows: 6
#
# Inserted batch of 1000 rows
#
# Progress: Processed 64000 rows
# Valid rows: 63994
# Error rows: 6
#
# Inserted batch of 1000 rows
#
# Progress: Processed 65000 rows
# Valid rows: 64994
# Error rows: 6
#
# Inserted batch of 1000 rows
#
# Progress: Processed 66000 rows
# Valid rows: 65994
# Error rows: 6
#
# Inserted batch of 1000 rows
#
# Progress: Processed 67000 rows
# Valid rows: 66994
# Error rows: 6
#
# Inserted batch of 1000 rows
#
# Progress: Processed 68000 rows
# Valid rows: 67994
# Error rows: 6
#
# Inserted batch of 1000 rows
#
# Progress: Processed 69000 rows
# Valid rows: 68994
# Error rows: 6
#
# Inserted batch of 1000 rows
#
# Progress: Processed 70000 rows
# Valid rows: 69994
# Error rows: 6
#
# Inserted batch of 1000 rows
#
# Progress: Processed 71000 rows
# Valid rows: 70994
# Error rows: 6
#
# Inserted batch of 1000 rows
#
# Progress: Processed 72000 rows
# Valid rows: 71994
# Error rows: 6
#
# Inserted batch of 1000 rows
#
# Progress: Processed 73000 rows
# Valid rows: 72994
# Error rows: 6
#
# Inserted batch of 1000 rows
#
# Progress: Processed 74000 rows
# Valid rows: 73994
# Error rows: 6
#
# Inserted batch of 1000 rows
#
# Progress: Processed 75000 rows
# Valid rows: 74994
# Error rows: 6
#
# Inserted batch of 1000 rows
#
# Progress: Processed 76000 rows
# Valid rows: 75994
# Error rows: 6
#
# Inserted batch of 1000 rows
#
# Progress: Processed 77000 rows
# Valid rows: 76994
# Error rows: 6
#
# Inserted batch of 1000 rows
#
# Progress: Processed 78000 rows
# Valid rows: 77994
# Error rows: 6
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
#
# Progress: Processed 79000 rows
# Valid rows: 78993
# Error rows: 7
#
# Inserted batch of 1000 rows
#
# Progress: Processed 80000 rows
# Valid rows: 79993
# Error rows: 7
#
# Inserted batch of 1000 rows
#
# Progress: Processed 81000 rows
# Valid rows: 80993
# Error rows: 7
#
# Inserted batch of 1000 rows
#
# Progress: Processed 82000 rows
# Valid rows: 81993
# Error rows: 7
#
# Inserted batch of 1000 rows
#
# Progress: Processed 83000 rows
# Valid rows: 82993
# Error rows: 7
#
# Inserted batch of 1000 rows
#
# Progress: Processed 84000 rows
# Valid rows: 83993
# Error rows: 7
#
# Inserted batch of 1000 rows
# Row dropped: Empty value in non-nullable field region
# Row dropped: Invalid value for event_id
#
# Progress: Processed 85000 rows
# Valid rows: 84991
# Error rows: 9
#
# Inserted batch of 1000 rows
#
# Progress: Processed 86000 rows
# Valid rows: 85991
# Error rows: 9
#
# Inserted batch of 1000 rows
#
# Progress: Processed 87000 rows
# Valid rows: 86991
# Error rows: 9
#
# Inserted batch of 1000 rows
#
# Progress: Processed 88000 rows
# Valid rows: 87991
# Error rows: 9
#
# Inserted batch of 1000 rows
# Row dropped: Empty value in non-nullable field region
#
# Progress: Processed 89000 rows
# Valid rows: 88990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 90000 rows
# Valid rows: 89990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 91000 rows
# Valid rows: 90990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 92000 rows
# Valid rows: 91990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 93000 rows
# Valid rows: 92990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 94000 rows
# Valid rows: 93990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 95000 rows
# Valid rows: 94990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 96000 rows
# Valid rows: 95990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 97000 rows
# Valid rows: 96990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 98000 rows
# Valid rows: 97990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 99000 rows
# Valid rows: 98990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 100000 rows
# Valid rows: 99990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 101000 rows
# Valid rows: 100990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 102000 rows
# Valid rows: 101990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 103000 rows
# Valid rows: 102990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 104000 rows
# Valid rows: 103990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 105000 rows
# Valid rows: 104990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 106000 rows
# Valid rows: 105990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 107000 rows
# Valid rows: 106990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 108000 rows
# Valid rows: 107990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 109000 rows
# Valid rows: 108990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 110000 rows
# Valid rows: 109990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 111000 rows
# Valid rows: 110990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 112000 rows
# Valid rows: 111990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 113000 rows
# Valid rows: 112990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 114000 rows
# Valid rows: 113990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 115000 rows
# Valid rows: 114990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 116000 rows
# Valid rows: 115990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 117000 rows
# Valid rows: 116990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 118000 rows
# Valid rows: 117990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 119000 rows
# Valid rows: 118990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 120000 rows
# Valid rows: 119990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 121000 rows
# Valid rows: 120990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 122000 rows
# Valid rows: 121990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 123000 rows
# Valid rows: 122990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 124000 rows
# Valid rows: 123990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 125000 rows
# Valid rows: 124990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 126000 rows
# Valid rows: 125990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 127000 rows
# Valid rows: 126990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 128000 rows
# Valid rows: 127990
# Error rows: 10
#
# Inserted batch of 1000 rows
#
# Progress: Processed 129000 rows
# Valid rows: 128990
# Error rows: 10
#
# Inserted batch of 1000 rows
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
#
# Progress: Processed 130000 rows
# Valid rows: 129946
# Error rows: 54
#
# Inserted batch of 1000 rows
#
# Progress: Processed 131000 rows
# Valid rows: 130946
# Error rows: 54
#
# Inserted batch of 1000 rows
#
# Progress: Processed 132000 rows
# Valid rows: 131946
# Error rows: 54
#
# Inserted batch of 1000 rows
#
# Progress: Processed 133000 rows
# Valid rows: 132946
# Error rows: 54
#
# Inserted batch of 1000 rows
#
# Progress: Processed 134000 rows
# Valid rows: 133946
# Error rows: 54
#
# Inserted batch of 1000 rows
#
# Progress: Processed 135000 rows
# Valid rows: 134946
# Error rows: 54
#
# Inserted batch of 1000 rows
#
# Progress: Processed 136000 rows
# Valid rows: 135946
# Error rows: 54
#
# Inserted batch of 1000 rows
#
# Progress: Processed 137000 rows
# Valid rows: 136946
# Error rows: 54
#
# Inserted batch of 1000 rows
#
# Progress: Processed 138000 rows
# Valid rows: 137946
# Error rows: 54
#
# Inserted batch of 1000 rows
#
# Progress: Processed 139000 rows
# Valid rows: 138946
# Error rows: 54
#
# Inserted batch of 1000 rows
#
# Progress: Processed 140000 rows
# Valid rows: 139946
# Error rows: 54
#
# Inserted batch of 1000 rows
#
# Progress: Processed 141000 rows
# Valid rows: 140946
# Error rows: 54
#
# Inserted batch of 1000 rows
#
# Progress: Processed 142000 rows
# Valid rows: 141946
# Error rows: 54
#
# Inserted batch of 1000 rows
#
# Progress: Processed 143000 rows
# Valid rows: 142946
# Error rows: 54
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
#
# Progress: Processed 144000 rows
# Valid rows: 143945
# Error rows: 55
#
# Inserted batch of 1000 rows
#
# Progress: Processed 145000 rows
# Valid rows: 144945
# Error rows: 55
#
# Inserted batch of 1000 rows
#
# Progress: Processed 146000 rows
# Valid rows: 145945
# Error rows: 55
#
# Inserted batch of 1000 rows
#
# Progress: Processed 147000 rows
# Valid rows: 146945
# Error rows: 55
#
# Inserted batch of 1000 rows
#
# Progress: Processed 148000 rows
# Valid rows: 147945
# Error rows: 55
#
# Inserted batch of 1000 rows
#
# Progress: Processed 149000 rows
# Valid rows: 148945
# Error rows: 55
#
# Inserted batch of 1000 rows
#
# Progress: Processed 150000 rows
# Valid rows: 149945
# Error rows: 55
#
# Inserted batch of 1000 rows
#
# Progress: Processed 151000 rows
# Valid rows: 150945
# Error rows: 55
#
# Inserted batch of 1000 rows
#
# Progress: Processed 152000 rows
# Valid rows: 151945
# Error rows: 55
#
# Inserted batch of 1000 rows
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
#
# Progress: Processed 153000 rows
# Valid rows: 152905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 154000 rows
# Valid rows: 153905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 155000 rows
# Valid rows: 154905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 156000 rows
# Valid rows: 155905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 157000 rows
# Valid rows: 156905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 158000 rows
# Valid rows: 157905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 159000 rows
# Valid rows: 158905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 160000 rows
# Valid rows: 159905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 161000 rows
# Valid rows: 160905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 162000 rows
# Valid rows: 161905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 163000 rows
# Valid rows: 162905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 164000 rows
# Valid rows: 163905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 165000 rows
# Valid rows: 164905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 166000 rows
# Valid rows: 165905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 167000 rows
# Valid rows: 166905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 168000 rows
# Valid rows: 167905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 169000 rows
# Valid rows: 168905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 170000 rows
# Valid rows: 169905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 171000 rows
# Valid rows: 170905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 172000 rows
# Valid rows: 171905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 173000 rows
# Valid rows: 172905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 174000 rows
# Valid rows: 173905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 175000 rows
# Valid rows: 174905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 176000 rows
# Valid rows: 175905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 177000 rows
# Valid rows: 176905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 178000 rows
# Valid rows: 177905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 179000 rows
# Valid rows: 178905
# Error rows: 95
#
# Inserted batch of 1000 rows
#
# Progress: Processed 180000 rows
# Valid rows: 179905
# Error rows: 95
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
#
# Progress: Processed 181000 rows
# Valid rows: 180901
# Error rows: 99
#
# Inserted batch of 1000 rows
#
# Progress: Processed 182000 rows
# Valid rows: 181901
# Error rows: 99
#
# Inserted batch of 1000 rows
#
# Progress: Processed 183000 rows
# Valid rows: 182901
# Error rows: 99
#
# Inserted batch of 1000 rows
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
#
# Progress: Processed 184000 rows
# Valid rows: 183824
# Error rows: 176
#
# Inserted batch of 1000 rows
#
# Progress: Processed 185000 rows
# Valid rows: 184824
# Error rows: 176
#
# Inserted batch of 1000 rows
#
# Progress: Processed 186000 rows
# Valid rows: 185824
# Error rows: 176
#
# Inserted batch of 1000 rows
#
# Progress: Processed 187000 rows
# Valid rows: 186824
# Error rows: 176
#
# Inserted batch of 1000 rows
#
# Progress: Processed 188000 rows
# Valid rows: 187824
# Error rows: 176
# Row dropped: Invalid value for event_id
#
# Inserted batch of 1000 rows
#
# Progress: Processed 189000 rows
# Valid rows: 188823
# Error rows: 177
#
# Inserted batch of 1000 rows
#
# Progress: Processed 190000 rows
# Valid rows: 189823
# Error rows: 177
#
# Inserted batch of 1000 rows
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
#
# Progress: Processed 191000 rows
# Valid rows: 190790
# Error rows: 210
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
#
# Inserted batch of 1000 rows
#
# Progress: Processed 192000 rows
# Valid rows: 191749
# Error rows: 251
#
# Inserted batch of 1000 rows
#
# Progress: Processed 193000 rows
# Valid rows: 192749
# Error rows: 251
#
# Inserted batch of 1000 rows
# Row dropped: Empty value in non-nullable field region
#
# Progress: Processed 194000 rows
# Valid rows: 193748
# Error rows: 252
# Row dropped: Empty value in non-nullable field region
#
# Inserted batch of 1000 rows
#
# Progress: Processed 195000 rows
# Valid rows: 194747
# Error rows: 253
#
# Inserted batch of 1000 rows
#
# Progress: Processed 196000 rows
# Valid rows: 195747
# Error rows: 253
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
#
# Progress: Processed 197000 rows
# Valid rows: 196742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 198000 rows
# Valid rows: 197742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 199000 rows
# Valid rows: 198742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 200000 rows
# Valid rows: 199742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 201000 rows
# Valid rows: 200742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 202000 rows
# Valid rows: 201742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 203000 rows
# Valid rows: 202742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 204000 rows
# Valid rows: 203742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 205000 rows
# Valid rows: 204742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 206000 rows
# Valid rows: 205742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 207000 rows
# Valid rows: 206742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 208000 rows
# Valid rows: 207742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 209000 rows
# Valid rows: 208742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 210000 rows
# Valid rows: 209742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 211000 rows
# Valid rows: 210742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 212000 rows
# Valid rows: 211742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 213000 rows
# Valid rows: 212742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 214000 rows
# Valid rows: 213742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 215000 rows
# Valid rows: 214742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 216000 rows
# Valid rows: 215742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 217000 rows
# Valid rows: 216742
# Error rows: 258
#
# Inserted batch of 1000 rows
#
# Progress: Processed 218000 rows
# Valid rows: 217742
# Error rows: 258
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
#
# Progress: Processed 219000 rows
# Valid rows: 218741
# Error rows: 259
#
# Inserted batch of 1000 rows
#
# Progress: Processed 220000 rows
# Valid rows: 219741
# Error rows: 259
#
# Inserted batch of 1000 rows
#
# Progress: Processed 221000 rows
# Valid rows: 220741
# Error rows: 259
#
# Inserted batch of 1000 rows
#
# Progress: Processed 222000 rows
# Valid rows: 221741
# Error rows: 259
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
#
# Progress: Processed 223000 rows
# Valid rows: 222739
# Error rows: 261
#
# Inserted batch of 1000 rows
#
# Progress: Processed 224000 rows
# Valid rows: 223739
# Error rows: 261
#
# Inserted batch of 1000 rows
#
# Progress: Processed 225000 rows
# Valid rows: 224739
# Error rows: 261
#
# Inserted batch of 1000 rows
#
# Progress: Processed 226000 rows
# Valid rows: 225739
# Error rows: 261
#
# Inserted batch of 1000 rows
#
# Progress: Processed 227000 rows
# Valid rows: 226739
# Error rows: 261
#
# Inserted batch of 1000 rows
#
# Progress: Processed 228000 rows
# Valid rows: 227739
# Error rows: 261
#
# Inserted batch of 1000 rows
#
# Progress: Processed 229000 rows
# Valid rows: 228739
# Error rows: 261
#
# Inserted batch of 1000 rows
#
# Progress: Processed 230000 rows
# Valid rows: 229739
# Error rows: 261
#
# Inserted batch of 1000 rows
#
# Progress: Processed 231000 rows
# Valid rows: 230739
# Error rows: 261
#
# Inserted batch of 1000 rows
#
# Progress: Processed 232000 rows
# Valid rows: 231739
# Error rows: 261
#
# Inserted batch of 1000 rows
#
# Progress: Processed 233000 rows
# Valid rows: 232739
# Error rows: 261
#
# Inserted batch of 1000 rows
#
# Progress: Processed 234000 rows
# Valid rows: 233739
# Error rows: 261
#
# Inserted batch of 1000 rows
#
# Progress: Processed 235000 rows
# Valid rows: 234739
# Error rows: 261
#
# Inserted batch of 1000 rows
#
# Progress: Processed 236000 rows
# Valid rows: 235739
# Error rows: 261
#
# Inserted batch of 1000 rows
#
# Progress: Processed 237000 rows
# Valid rows: 236739
# Error rows: 261
#
# Inserted batch of 1000 rows
#
# Progress: Processed 238000 rows
# Valid rows: 237739
# Error rows: 261
#
# Inserted batch of 1000 rows
#
# Progress: Processed 239000 rows
# Valid rows: 238739
# Error rows: 261
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
#
# Progress: Processed 240000 rows
# Valid rows: 239738
# Error rows: 262
#
# Inserted batch of 1000 rows
#
# Progress: Processed 241000 rows
# Valid rows: 240738
# Error rows: 262
#
# Inserted batch of 1000 rows
#
# Progress: Processed 242000 rows
# Valid rows: 241738
# Error rows: 262
#
# Inserted batch of 1000 rows
#
# Progress: Processed 243000 rows
# Valid rows: 242738
# Error rows: 262
#
# Inserted batch of 1000 rows
#
# Progress: Processed 244000 rows
# Valid rows: 243738
# Error rows: 262
#
# Inserted batch of 1000 rows
#
# Progress: Processed 245000 rows
# Valid rows: 244738
# Error rows: 262
#
# Inserted batch of 1000 rows
#
# Progress: Processed 246000 rows
# Valid rows: 245738
# Error rows: 262
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
#
# Progress: Processed 247000 rows
# Valid rows: 246732
# Error rows: 268
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
#
# Inserted batch of 1000 rows
#
# Progress: Processed 248000 rows
# Valid rows: 247729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 249000 rows
# Valid rows: 248729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 250000 rows
# Valid rows: 249729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 251000 rows
# Valid rows: 250729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 252000 rows
# Valid rows: 251729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 253000 rows
# Valid rows: 252729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 254000 rows
# Valid rows: 253729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 255000 rows
# Valid rows: 254729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 256000 rows
# Valid rows: 255729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 257000 rows
# Valid rows: 256729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 258000 rows
# Valid rows: 257729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 259000 rows
# Valid rows: 258729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 260000 rows
# Valid rows: 259729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 261000 rows
# Valid rows: 260729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 262000 rows
# Valid rows: 261729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 263000 rows
# Valid rows: 262729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 264000 rows
# Valid rows: 263729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 265000 rows
# Valid rows: 264729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 266000 rows
# Valid rows: 265729
# Error rows: 271
#
# Inserted batch of 1000 rows
#
# Progress: Processed 267000 rows
# Valid rows: 266729
# Error rows: 271
#
# Inserted batch of 1000 rows
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
#
# Progress: Processed 268000 rows
# Valid rows: 267711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 269000 rows
# Valid rows: 268711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 270000 rows
# Valid rows: 269711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 271000 rows
# Valid rows: 270711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 272000 rows
# Valid rows: 271711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 273000 rows
# Valid rows: 272711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 274000 rows
# Valid rows: 273711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 275000 rows
# Valid rows: 274711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 276000 rows
# Valid rows: 275711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 277000 rows
# Valid rows: 276711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 278000 rows
# Valid rows: 277711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 279000 rows
# Valid rows: 278711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 280000 rows
# Valid rows: 279711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 281000 rows
# Valid rows: 280711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 282000 rows
# Valid rows: 281711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 283000 rows
# Valid rows: 282711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 284000 rows
# Valid rows: 283711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 285000 rows
# Valid rows: 284711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 286000 rows
# Valid rows: 285711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 287000 rows
# Valid rows: 286711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 288000 rows
# Valid rows: 287711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 289000 rows
# Valid rows: 288711
# Error rows: 289
#
# Inserted batch of 1000 rows
#
# Progress: Processed 290000 rows
# Valid rows: 289711
# Error rows: 289
# Row dropped: Invalid value for event_id
#
# Inserted batch of 1000 rows
#
# Progress: Processed 291000 rows
# Valid rows: 290710
# Error rows: 290
#
# Inserted batch of 1000 rows
#
# Progress: Processed 292000 rows
# Valid rows: 291710
# Error rows: 290
#
# Inserted batch of 1000 rows
#
# Progress: Processed 293000 rows
# Valid rows: 292710
# Error rows: 290
#
# Inserted batch of 1000 rows
#
# Progress: Processed 294000 rows
# Valid rows: 293710
# Error rows: 290
#
# Inserted batch of 1000 rows
#
# Progress: Processed 295000 rows
# Valid rows: 294710
# Error rows: 290
#
# Inserted batch of 1000 rows
#
# Progress: Processed 296000 rows
# Valid rows: 295710
# Error rows: 290
#
# Inserted batch of 1000 rows
#
# Progress: Processed 297000 rows
# Valid rows: 296710
# Error rows: 290
#
# Inserted batch of 1000 rows
#
# Progress: Processed 298000 rows
# Valid rows: 297710
# Error rows: 290
#
# Inserted batch of 1000 rows
#
# Progress: Processed 299000 rows
# Valid rows: 298710
# Error rows: 290
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
#
# Progress: Processed 300000 rows
# Valid rows: 299708
# Error rows: 292
#
# Inserted batch of 1000 rows
#
# Progress: Processed 301000 rows
# Valid rows: 300708
# Error rows: 292
#
# Inserted batch of 1000 rows
#
# Progress: Processed 302000 rows
# Valid rows: 301708
# Error rows: 292
#
# Inserted batch of 1000 rows
#
# Progress: Processed 303000 rows
# Valid rows: 302708
# Error rows: 292
#
# Inserted batch of 1000 rows
# Row dropped: Empty value in non-nullable field region
#
# Progress: Processed 304000 rows
# Valid rows: 303707
# Error rows: 293
#
# Inserted batch of 1000 rows
#
# Progress: Processed 305000 rows
# Valid rows: 304707
# Error rows: 293
#
# Inserted batch of 1000 rows
#
# Progress: Processed 306000 rows
# Valid rows: 305707
# Error rows: 293
#
# Inserted batch of 1000 rows
#
# Progress: Processed 307000 rows
# Valid rows: 306707
# Error rows: 293
#
# Inserted batch of 1000 rows
#
# Progress: Processed 308000 rows
# Valid rows: 307707
# Error rows: 293
#
# Inserted batch of 1000 rows
#
# Progress: Processed 309000 rows
# Valid rows: 308707
# Error rows: 293
#
# Inserted batch of 1000 rows
#
# Progress: Processed 310000 rows
# Valid rows: 309707
# Error rows: 293
#
# Inserted batch of 1000 rows
#
# Progress: Processed 311000 rows
# Valid rows: 310707
# Error rows: 293
#
# Inserted batch of 1000 rows
#
# Progress: Processed 312000 rows
# Valid rows: 311707
# Error rows: 293
#
# Inserted batch of 1000 rows
#
# Progress: Processed 313000 rows
# Valid rows: 312707
# Error rows: 293
#
# Inserted batch of 1000 rows
#
# Progress: Processed 314000 rows
# Valid rows: 313707
# Error rows: 293
#
# Inserted batch of 1000 rows
#
# Progress: Processed 315000 rows
# Valid rows: 314707
# Error rows: 293
#
# Inserted batch of 1000 rows
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Invalid value for event_id
#
# Progress: Processed 316000 rows
# Valid rows: 315697
# Error rows: 303
#
# Inserted batch of 1000 rows
#
# Progress: Processed 317000 rows
# Valid rows: 316697
# Error rows: 303
#
# Inserted batch of 1000 rows
#
# Progress: Processed 318000 rows
# Valid rows: 317697
# Error rows: 303
#
# Inserted batch of 1000 rows
#
# Progress: Processed 319000 rows
# Valid rows: 318697
# Error rows: 303
#
# Inserted batch of 1000 rows
#
# Progress: Processed 320000 rows
# Valid rows: 319697
# Error rows: 303
#
# Inserted batch of 1000 rows
#
# Progress: Processed 321000 rows
# Valid rows: 320697
# Error rows: 303
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
#
# Progress: Processed 322000 rows
# Valid rows: 321691
# Error rows: 309
#
# Inserted batch of 1000 rows
#
# Progress: Processed 323000 rows
# Valid rows: 322691
# Error rows: 309
#
# Inserted batch of 1000 rows
#
# Progress: Processed 324000 rows
# Valid rows: 323691
# Error rows: 309
#
# Inserted batch of 1000 rows
#
# Progress: Processed 325000 rows
# Valid rows: 324691
# Error rows: 309
#
# Inserted batch of 1000 rows
#
# Progress: Processed 326000 rows
# Valid rows: 325691
# Error rows: 309
#
# Inserted batch of 1000 rows
#
# Progress: Processed 327000 rows
# Valid rows: 326691
# Error rows: 309
#
# Inserted batch of 1000 rows
#
# Progress: Processed 328000 rows
# Valid rows: 327691
# Error rows: 309
#
# Inserted batch of 1000 rows
#
# Progress: Processed 329000 rows
# Valid rows: 328691
# Error rows: 309
#
# Inserted batch of 1000 rows
#
# Progress: Processed 330000 rows
# Valid rows: 329691
# Error rows: 309
#
# Inserted batch of 1000 rows
#
# Progress: Processed 331000 rows
# Valid rows: 330691
# Error rows: 309
#
# Inserted batch of 1000 rows
#
# Progress: Processed 332000 rows
# Valid rows: 331691
# Error rows: 309
#
# Inserted batch of 1000 rows
#
# Progress: Processed 333000 rows
# Valid rows: 332691
# Error rows: 309
#
# Inserted batch of 1000 rows
#
# Progress: Processed 334000 rows
# Valid rows: 333691
# Error rows: 309
#
# ...
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
#
# Progress: Processed 746000 rows
# Valid rows: 745656
# Error rows: 344
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
# Row dropped: Empty value in non-nullable field region
#
# Inserted batch of 1000 rows
#
# Progress: Processed 747000 rows
# Valid rows: 746647
# Error rows: 353
#
# Inserted batch of 1000 rows
#
# Progress: Processed 748000 rows
# Valid rows: 747647
# Error rows: 353
#
# Inserted batch of 1000 rows
#
# Progress: Processed 749000 rows
# Valid rows: 748647
# Error rows: 353
#
# Inserted batch of 1000 rows
#
# Progress: Processed 750000 rows
# Valid rows: 749647
# Error rows: 353
#
# Inserted batch of 1000 rows
#
# Progress: Processed 751000 rows
# Valid rows: 750647
# Error rows: 353
#
# Inserted batch of 1000 rows
#
# Progress: Processed 752000 rows
# Valid rows: 751647
# Error rows: 353
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
#
# Progress: Processed 753000 rows
# Valid rows: 752642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 754000 rows
# Valid rows: 753642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 755000 rows
# Valid rows: 754642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 756000 rows
# Valid rows: 755642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 757000 rows
# Valid rows: 756642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 758000 rows
# Valid rows: 757642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 759000 rows
# Valid rows: 758642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 760000 rows
# Valid rows: 759642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 761000 rows
# Valid rows: 760642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 762000 rows
# Valid rows: 761642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 763000 rows
# Valid rows: 762642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 764000 rows
# Valid rows: 763642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 765000 rows
# Valid rows: 764642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 766000 rows
# Valid rows: 765642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 767000 rows
# Valid rows: 766642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 768000 rows
# Valid rows: 767642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 769000 rows
# Valid rows: 768642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 770000 rows
# Valid rows: 769642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 771000 rows
# Valid rows: 770642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 772000 rows
# Valid rows: 771642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 773000 rows
# Valid rows: 772642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 774000 rows
# Valid rows: 773642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 775000 rows
# Valid rows: 774642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 776000 rows
# Valid rows: 775642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 777000 rows
# Valid rows: 776642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 778000 rows
# Valid rows: 777642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 779000 rows
# Valid rows: 778642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 780000 rows
# Valid rows: 779642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 781000 rows
# Valid rows: 780642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 782000 rows
# Valid rows: 781642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 783000 rows
# Valid rows: 782642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 784000 rows
# Valid rows: 783642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 785000 rows
# Valid rows: 784642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 786000 rows
# Valid rows: 785642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 787000 rows
# Valid rows: 786642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 788000 rows
# Valid rows: 787642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 789000 rows
# Valid rows: 788642
# Error rows: 358
#
# Inserted batch of 1000 rows
#
# Progress: Processed 790000 rows
# Valid rows: 789642
# Error rows: 358
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
#
# Progress: Processed 791000 rows
# Valid rows: 790641
# Error rows: 359
#
# Inserted batch of 1000 rows
#
# Progress: Processed 792000 rows
# Valid rows: 791641
# Error rows: 359
#
# Inserted batch of 1000 rows
#
# Progress: Processed 793000 rows
# Valid rows: 792641
# Error rows: 359
#
# Inserted batch of 1000 rows
#
# Progress: Processed 794000 rows
# Valid rows: 793641
# Error rows: 359
#
# Inserted batch of 1000 rows
#
# Progress: Processed 795000 rows
# Valid rows: 794641
# Error rows: 359
#
# Inserted batch of 1000 rows
#
# Progress: Processed 796000 rows
# Valid rows: 795641
# Error rows: 359
#
# Inserted batch of 1000 rows
#
# Progress: Processed 797000 rows
# Valid rows: 796641
# Error rows: 359
#
# Inserted batch of 1000 rows
#
# Progress: Processed 798000 rows
# Valid rows: 797641
# Error rows: 359
#
# Inserted batch of 1000 rows
#
# Progress: Processed 799000 rows
# Valid rows: 798641
# Error rows: 359
#
# Inserted batch of 1000 rows
#
# Progress: Processed 800000 rows
# Valid rows: 799641
# Error rows: 359
#
# Inserted batch of 1000 rows
#
# Progress: Processed 801000 rows
# Valid rows: 800641
# Error rows: 359
#
# Inserted batch of 1000 rows
#
# Progress: Processed 802000 rows
# Valid rows: 801641
# Error rows: 359
#
# Inserted batch of 1000 rows
#
# Progress: Processed 803000 rows
# Valid rows: 802641
# Error rows: 359
#
# Inserted batch of 1000 rows
#
# Progress: Processed 804000 rows
# Valid rows: 803641
# Error rows: 359
#
# Inserted batch of 1000 rows
#
# Progress: Processed 805000 rows
# Valid rows: 804641
# Error rows: 359
#
# Inserted batch of 1000 rows
#
# Progress: Processed 806000 rows
# Valid rows: 805641
# Error rows: 359
#
# Inserted batch of 1000 rows
#
# Progress: Processed 807000 rows
# Valid rows: 806641
# Error rows: 359
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
#
# Progress: Processed 808000 rows
# Valid rows: 807640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 809000 rows
# Valid rows: 808640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 810000 rows
# Valid rows: 809640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 811000 rows
# Valid rows: 810640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 812000 rows
# Valid rows: 811640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 813000 rows
# Valid rows: 812640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 814000 rows
# Valid rows: 813640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 815000 rows
# Valid rows: 814640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 816000 rows
# Valid rows: 815640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 817000 rows
# Valid rows: 816640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 818000 rows
# Valid rows: 817640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 819000 rows
# Valid rows: 818640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 820000 rows
# Valid rows: 819640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 821000 rows
# Valid rows: 820640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 822000 rows
# Valid rows: 821640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 823000 rows
# Valid rows: 822640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 824000 rows
# Valid rows: 823640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 825000 rows
# Valid rows: 824640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 826000 rows
# Valid rows: 825640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 827000 rows
# Valid rows: 826640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 828000 rows
# Valid rows: 827640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 829000 rows
# Valid rows: 828640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 830000 rows
# Valid rows: 829640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 831000 rows
# Valid rows: 830640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 832000 rows
# Valid rows: 831640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 833000 rows
# Valid rows: 832640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 834000 rows
# Valid rows: 833640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 835000 rows
# Valid rows: 834640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 836000 rows
# Valid rows: 835640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 837000 rows
# Valid rows: 836640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 838000 rows
# Valid rows: 837640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 839000 rows
# Valid rows: 838640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 840000 rows
# Valid rows: 839640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 841000 rows
# Valid rows: 840640
# Error rows: 360
#
# Inserted batch of 1000 rows
#
# Progress: Processed 842000 rows
# Valid rows: 841640
# Error rows: 360
# Row dropped: Invalid value for event_id
#
# Inserted batch of 1000 rows
#
# Progress: Processed 843000 rows
# Valid rows: 842639
# Error rows: 361
#
# Inserted batch of 1000 rows
#
# Progress: Processed 844000 rows
# Valid rows: 843639
# Error rows: 361
#
# Inserted batch of 1000 rows
#
# Progress: Processed 845000 rows
# Valid rows: 844639
# Error rows: 361
#
# Inserted batch of 1000 rows
#
# Progress: Processed 846000 rows
# Valid rows: 845639
# Error rows: 361
#
# Inserted batch of 1000 rows
#
# Progress: Processed 847000 rows
# Valid rows: 846639
# Error rows: 361
#
# Inserted batch of 1000 rows
#
# Progress: Processed 848000 rows
# Valid rows: 847639
# Error rows: 361
#
# Inserted batch of 1000 rows
#
# Progress: Processed 849000 rows
# Valid rows: 848639
# Error rows: 361
#
# Inserted batch of 1000 rows
#
# Progress: Processed 850000 rows
# Valid rows: 849639
# Error rows: 361
#
# Inserted batch of 1000 rows
# Row dropped: Invalid value for event_id
# Row dropped: Empty value in non-nullable field region
#
# Progress: Processed 851000 rows
# Valid rows: 850637
# Error rows: 363
#
# Inserted batch of 1000 rows
#
# Progress: Processed 852000 rows
# Valid rows: 851637
# Error rows: 363
#
# Inserted batch of 1000 rows
#
# Progress: Processed 853000 rows
# Valid rows: 852637
# Error rows: 363
#
# Inserted batch of 1000 rows
#
# Progress: Processed 854000 rows
# Valid rows: 853637
# Error rows: 363
#
# Inserted batch of 1000 rows
#
# Progress: Processed 855000 rows
# Valid rows: 854637
# Error rows: 363
#
# Inserted batch of 1000 rows
#
# Progress: Processed 856000 rows
# Valid rows: 855637
# Error rows: 363
#
# Inserted batch of 1000 rows
#
# Progress: Processed 857000 rows
# Valid rows: 856637
# Error rows: 363
#
# Inserted batch of 1000 rows
#
# Progress: Processed 858000 rows
# Valid rows: 857637
# Error rows: 363
#
# Inserted batch of 1000 rows
#
# Progress: Processed 859000 rows
# Valid rows: 858637
# Error rows: 363
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
# Row dropped: Invalid value for event_id
#
# Inserted batch of 1000 rows
#
# Progress: Processed 860000 rows
# Valid rows: 859634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 861000 rows
# Valid rows: 860634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 862000 rows
# Valid rows: 861634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 863000 rows
# Valid rows: 862634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 864000 rows
# Valid rows: 863634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 865000 rows
# Valid rows: 864634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 866000 rows
# Valid rows: 865634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 867000 rows
# Valid rows: 866634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 868000 rows
# Valid rows: 867634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 869000 rows
# Valid rows: 868634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 870000 rows
# Valid rows: 869634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 871000 rows
# Valid rows: 870634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 872000 rows
# Valid rows: 871634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 873000 rows
# Valid rows: 872634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 874000 rows
# Valid rows: 873634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 875000 rows
# Valid rows: 874634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 876000 rows
# Valid rows: 875634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 877000 rows
# Valid rows: 876634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 878000 rows
# Valid rows: 877634
# Error rows: 366
#
# Inserted batch of 1000 rows
#
# Progress: Processed 879000 rows
# Valid rows: 878634
# Error rows: 366
# Row dropped: Invalid value for event_id
#
# Inserted batch of 1000 rows
#
# Progress: Processed 880000 rows
# Valid rows: 879633
# Error rows: 367
#
# Inserted batch of 1000 rows
#
# Progress: Processed 881000 rows
# Valid rows: 880633
# Error rows: 367
#
# Inserted batch of 1000 rows
#
# Progress: Processed 882000 rows
# Valid rows: 881633
# Error rows: 367
#
# Inserted batch of 1000 rows
#
# Progress: Processed 883000 rows
# Valid rows: 882633
# Error rows: 367
#
# Inserted final batch of 660 rows
#
# Processing complete!
# Total rows processed: 883027
# Valid rows inserted: 882660
# Error rows: 367
# CPU times: user 27min 25s, sys: 30.2 s, total: 27min 55s
# Wall time: 34min 19s

# %%
import os
from dotenv import load_dotenv
from supabase import create_client, Client
import time

# Initialize Supabase client
os.environ.clear()
load_dotenv(override=True)
supabase: Client = create_client(
    supabase_url=os.getenv("SUPABASE_URL"),
    supabase_key=os.getenv("SUPABASE_KEY")
)

try:
    # First, get total count of rows to update
    count_response = supabase.table('v2_federato_amplitude_data')\
        .select('id', count='exact')\
        .eq('dma', 'None')\
        .execute()
    total_rows = count_response.count
    print(f"Total rows to update: {total_rows}")

    # Process in batches of 1000
    batch_size = 1000
    updated_rows = 0

    while updated_rows < total_rows:
        # Get batch of IDs
        batch_response = supabase.table('v2_federato_amplitude_data')\
            .select('id')\
            .eq('dma', 'None')\
            .limit(batch_size)\
            .execute()
        
        if not batch_response.data:
            break

        # Update this batch
        ids = [row['id'] for row in batch_response.data]
        update_response = supabase.table('v2_federato_amplitude_data')\
            .update({"dma": None})\
            .in_('id', ids)\
            .execute()
        
        updated_rows += len(ids)
        print(f"Updated {updated_rows} out of {total_rows} rows")
        
        # Small delay to prevent overwhelming the database
        time.sleep(0.1)

    print("\nUpdate complete!")
    print(f"Total rows updated: {updated_rows}")

except Exception as e:
    print(f"Error occurred: {e}")
# Out:
# Error occurred: {'code': '57014', 'details': None, 'hint': None, 'message': 'canceling statement due to statement timeout'}

# %%
import os
from dotenv import load_dotenv
from supabase import create_client, Client

# Initialize Supabase client
os.environ.clear()
load_dotenv(override=True)
supabase: Client = create_client(
    supabase_url=os.getenv("SUPABASE_URL"),
    supabase_key=os.getenv("SUPABASE_KEY")
)

try:
    page_size = 500000  # 10x increase to 500,000 rows per page
    total_count = 0
    last_id = None
    
    while True:
        query = supabase.table('v2_federato_amplitude_data')\
            .select('id')\
            .order('id')\
            .limit(page_size)
            
        if last_id:
            query = query.gt('id', last_id)
            
        response = query.execute()
        
        if not response.data:
            break
            
        rows_in_page = len(response.data)
        total_count += rows_in_page
        last_id = response.data[-1]['id']
        
        print(f"Counted {total_count:,} rows so far...")  # Added thousands separator
    
    print(f"\nTotal rows in table: {total_count:,}")

except Exception as e:
    print(f"Error occurred: {e}")
# Out:
# Counted 1,000 rows so far...
# Counted 2,000 rows so far...
# Counted 3,000 rows so far...
# Counted 4,000 rows so far...
# Counted 5,000 rows so far...
# Counted 6,000 rows so far...
# Counted 7,000 rows so far...
# Counted 8,000 rows so far...
# Counted 9,000 rows so far...
# Counted 10,000 rows so far...
# Counted 11,000 rows so far...
# Counted 12,000 rows so far...
# Counted 13,000 rows so far...
# Counted 14,000 rows so far...
# Counted 15,000 rows so far...
# Counted 16,000 rows so far...
# Counted 17,000 rows so far...
# Counted 18,000 rows so far...
# Counted 19,000 rows so far...
# Counted 20,000 rows so far...
# Counted 21,000 rows so far...
# Counted 22,000 rows so far...
# Counted 23,000 rows so far...
# Counted 24,000 rows so far...
# Counted 25,000 rows so far...
# Counted 26,000 rows so far...
# Counted 27,000 rows so far...
# Counted 28,000 rows so far...
# Counted 29,000 rows so far...
# Counted 30,000 rows so far...
# Counted 31,000 rows so far...
# Counted 32,000 rows so far...
# Counted 33,000 rows so far...
# Counted 34,000 rows so far...
# Counted 35,000 rows so far...
# Counted 36,000 rows so far...
# Counted 37,000 rows so far...
# Counted 38,000 rows so far...
# Counted 39,000 rows so far...
# Counted 40,000 rows so far...
# Counted 41,000 rows so far...
# Counted 42,000 rows so far...
# Counted 43,000 rows so far...
# Counted 44,000 rows so far...
# Counted 45,000 rows so far...
# Counted 46,000 rows so far...
# Counted 47,000 rows so far...
# Counted 48,000 rows so far...
# Counted 49,000 rows so far...
# Counted 50,000 rows so far...
# Counted 51,000 rows so far...
# Counted 52,000 rows so far...
# Counted 53,000 rows so far...
# Counted 54,000 rows so far...
# Counted 55,000 rows so far...
# Counted 56,000 rows so far...
# Counted 57,000 rows so far...
# Counted 58,000 rows so far...
# Counted 59,000 rows so far...
# Counted 60,000 rows so far...
# Counted 61,000 rows so far...
# Counted 62,000 rows so far...
# Counted 63,000 rows so far...
# Counted 64,000 rows so far...
# Counted 65,000 rows so far...
# Counted 66,000 rows so far...
# Counted 67,000 rows so far...
# Counted 68,000 rows so far...
# Counted 69,000 rows so far...
# Counted 70,000 rows so far...
# Counted 71,000 rows so far...
# Counted 72,000 rows so far...
# Counted 73,000 rows so far...
# Counted 74,000 rows so far...
# Counted 75,000 rows so far...
# Counted 76,000 rows so far...
# Counted 77,000 rows so far...
# Counted 78,000 rows so far...
# Counted 79,000 rows so far...
# Counted 80,000 rows so far...
# Counted 81,000 rows so far...
# Counted 82,000 rows so far...
# Counted 83,000 rows so far...
# Counted 84,000 rows so far...
# Counted 85,000 rows so far...
# Counted 86,000 rows so far...
# Counted 87,000 rows so far...
# Counted 88,000 rows so far...
# Counted 89,000 rows so far...
# Counted 90,000 rows so far...
# Counted 91,000 rows so far...
# Counted 92,000 rows so far...
# Counted 93,000 rows so far...
# Counted 94,000 rows so far...
# Counted 95,000 rows so far...
# Counted 96,000 rows so far...
# Counted 97,000 rows so far...
# Counted 98,000 rows so far...
# Counted 99,000 rows so far...
# Counted 100,000 rows so far...
# Counted 101,000 rows so far...
# Counted 102,000 rows so far...
# Counted 103,000 rows so far...
# Counted 104,000 rows so far...
# Counted 105,000 rows so far...
# Counted 106,000 rows so far...
# Counted 107,000 rows so far...
# Counted 108,000 rows so far...
# Counted 109,000 rows so far...
# Counted 110,000 rows so far...
# Counted 111,000 rows so far...
# Counted 112,000 rows so far...
# Counted 113,000 rows so far...
# Counted 114,000 rows so far...
# Counted 115,000 rows so far...
# Counted 116,000 rows so far...
# Counted 117,000 rows so far...
# Counted 118,000 rows so far...
# Counted 119,000 rows so far...
# Counted 120,000 rows so far...
# Counted 121,000 rows so far...
# Counted 122,000 rows so far...
# Counted 123,000 rows so far...
# Counted 124,000 rows so far...
# Counted 125,000 rows so far...
# Counted 126,000 rows so far...
# Counted 127,000 rows so far...
# Counted 128,000 rows so far...
# Counted 129,000 rows so far...
# Counted 130,000 rows so far...
# Counted 131,000 rows so far...
# Counted 132,000 rows so far...
# Counted 133,000 rows so far...
# Counted 134,000 rows so far...
# Counted 135,000 rows so far...
# Counted 136,000 rows so far...
# Counted 137,000 rows so far...
# Counted 138,000 rows so far...
# Counted 139,000 rows so far...
# Counted 140,000 rows so far...
# Counted 141,000 rows so far...
# Counted 142,000 rows so far...
# Counted 143,000 rows so far...
# Counted 144,000 rows so far...
# Counted 145,000 rows so far...
# Counted 146,000 rows so far...
# Counted 147,000 rows so far...
# Counted 148,000 rows so far...
# Counted 149,000 rows so far...
# Counted 150,000 rows so far...
# Counted 151,000 rows so far...
# Counted 152,000 rows so far...
# Counted 153,000 rows so far...
# Counted 154,000 rows so far...
# Counted 155,000 rows so far...
# Counted 156,000 rows so far...
# Counted 157,000 rows so far...
# Counted 158,000 rows so far...
# Counted 159,000 rows so far...
# Counted 160,000 rows so far...
# Counted 161,000 rows so far...
# Counted 162,000 rows so far...
# Counted 163,000 rows so far...
# Counted 164,000 rows so far...
# Counted 165,000 rows so far...
# Counted 166,000 rows so far...
# Counted 167,000 rows so far...
# Counted 168,000 rows so far...
# Counted 169,000 rows so far...
# Counted 170,000 rows so far...
# Counted 171,000 rows so far...
# Counted 172,000 rows so far...
# Counted 173,000 rows so far...
# Counted 174,000 rows so far...
# Counted 175,000 rows so far...
# Counted 176,000 rows so far...
# Counted 177,000 rows so far...
# Counted 178,000 rows so far...
# Counted 179,000 rows so far...
# Counted 180,000 rows so far...
# Counted 181,000 rows so far...
# Counted 182,000 rows so far...
# Counted 183,000 rows so far...
# Counted 184,000 rows so far...
# Counted 185,000 rows so far...
# Counted 186,000 rows so far...
# Counted 187,000 rows so far...
# Counted 188,000 rows so far...
# Counted 189,000 rows so far...
# Counted 190,000 rows so far...
# Counted 191,000 rows so far...
# Counted 192,000 rows so far...
# Counted 193,000 rows so far...
# Counted 194,000 rows so far...
# Counted 195,000 rows so far...
# Counted 196,000 rows so far...
# Counted 197,000 rows so far...
# Counted 198,000 rows so far...
# Counted 199,000 rows so far...
# Counted 200,000 rows so far...
# Counted 201,000 rows so far...
# Counted 202,000 rows so far...
# Counted 203,000 rows so far...
# Counted 204,000 rows so far...
# Counted 205,000 rows so far...
# Counted 206,000 rows so far...
# Counted 207,000 rows so far...
# Counted 208,000 rows so far...
# Counted 209,000 rows so far...
# Counted 210,000 rows so far...
# Counted 211,000 rows so far...
# Counted 212,000 rows so far...
# Counted 213,000 rows so far...
# Counted 214,000 rows so far...
# Counted 215,000 rows so far...
# Counted 216,000 rows so far...
# Counted 217,000 rows so far...
# Counted 218,000 rows so far...
# Counted 219,000 rows so far...
# Counted 220,000 rows so far...
# Counted 221,000 rows so far...
# Counted 222,000 rows so far...
# Counted 223,000 rows so far...
# Counted 224,000 rows so far...
# Counted 225,000 rows so far...
# Counted 226,000 rows so far...
# Counted 227,000 rows so far...
# Counted 228,000 rows so far...
# Counted 229,000 rows so far...
# Counted 230,000 rows so far...
# Counted 231,000 rows so far...
# Counted 232,000 rows so far...
# Counted 233,000 rows so far...
# Counted 234,000 rows so far...
# Counted 235,000 rows so far...
# Counted 236,000 rows so far...
# Counted 237,000 rows so far...
# Counted 238,000 rows so far...
# Counted 239,000 rows so far...
# Counted 240,000 rows so far...
# Counted 241,000 rows so far...
# Counted 242,000 rows so far...
# Counted 243,000 rows so far...
# Counted 244,000 rows so far...
# Counted 245,000 rows so far...
# Counted 246,000 rows so far...
# Counted 247,000 rows so far...
# Counted 248,000 rows so far...
# Counted 249,000 rows so far...
# Counted 250,000 rows so far...
# Counted 251,000 rows so far...
# Counted 252,000 rows so far...
# Counted 253,000 rows so far...
# Counted 254,000 rows so far...
# Counted 255,000 rows so far...
# Counted 256,000 rows so far...
# Counted 257,000 rows so far...
# Counted 258,000 rows so far...
# Counted 259,000 rows so far...
# Counted 260,000 rows so far...
# Counted 261,000 rows so far...
# Counted 262,000 rows so far...
# Counted 263,000 rows so far...
# Counted 264,000 rows so far...
# Counted 265,000 rows so far...
# Counted 266,000 rows so far...
# Counted 267,000 rows so far...
# Counted 268,000 rows so far...
# Counted 269,000 rows so far...
# Counted 270,000 rows so far...
# Counted 271,000 rows so far...
# Counted 272,000 rows so far...
# Counted 273,000 rows so far...
# Counted 274,000 rows so far...
# Counted 275,000 rows so far...
# Counted 276,000 rows so far...
# Counted 277,000 rows so far...
# Counted 278,000 rows so far...
# Counted 279,000 rows so far...
# Counted 280,000 rows so far...
# Counted 281,000 rows so far...
# Counted 282,000 rows so far...
# Counted 283,000 rows so far...
# Counted 284,000 rows so far...
# Counted 285,000 rows so far...
# Counted 286,000 rows so far...
# Counted 287,000 rows so far...
# Counted 288,000 rows so far...
# Counted 289,000 rows so far...
# Counted 290,000 rows so far...
# Counted 291,000 rows so far...
# Counted 292,000 rows so far...
# Counted 293,000 rows so far...
# Counted 294,000 rows so far...
# Counted 295,000 rows so far...
# Counted 296,000 rows so far...
# Counted 297,000 rows so far...
# Counted 298,000 rows so far...
# Counted 299,000 rows so far...
# Counted 300,000 rows so far...
# Counted 301,000 rows so far...
# Counted 302,000 rows so far...
# Counted 303,000 rows so far...
# Counted 304,000 rows so far...
# Counted 305,000 rows so far...
# Counted 306,000 rows so far...
# Counted 307,000 rows so far...
# Counted 308,000 rows so far...
# Counted 309,000 rows so far...
# Counted 310,000 rows so far...
# Counted 311,000 rows so far...
# Counted 312,000 rows so far...
# Counted 313,000 rows so far...
# Counted 314,000 rows so far...
# Counted 315,000 rows so far...
# Counted 316,000 rows so far...
# Counted 317,000 rows so far...
# Counted 318,000 rows so far...
# Counted 319,000 rows so far...
# Counted 320,000 rows so far...
# Counted 321,000 rows so far...
# Counted 322,000 rows so far...
# Counted 323,000 rows so far...
# Counted 324,000 rows so far...
# Counted 325,000 rows so far...
# Counted 326,000 rows so far...
# Counted 327,000 rows so far...
# Counted 328,000 rows so far...
# Counted 329,000 rows so far...
# Counted 330,000 rows so far...
# Counted 331,000 rows so far...
# Counted 332,000 rows so far...
# Counted 333,000 rows so far...
# Counted 334,000 rows so far...
# Counted 335,000 rows so far...
# Counted 336,000 rows so far...
# Counted 337,000 rows so far...
# Counted 338,000 rows so far...
# Counted 339,000 rows so far...
# Counted 340,000 rows so far...
# Counted 341,000 rows so far...
# Counted 342,000 rows so far...
# Counted 343,000 rows so far...
# Counted 344,000 rows so far...
# Counted 345,000 rows so far...
# Counted 346,000 rows so far...
# Counted 347,000 rows so far...
# Counted 348,000 rows so far...
# Counted 349,000 rows so far...
# Counted 350,000 rows so far...
# Counted 351,000 rows so far...
# Counted 352,000 rows so far...
# Counted 353,000 rows so far...
# Counted 354,000 rows so far...
# Counted 355,000 rows so far...
# Counted 356,000 rows so far...
# Counted 357,000 rows so far...
# Counted 358,000 rows so far...
# Counted 359,000 rows so far...
# Counted 360,000 rows so far...
# Counted 361,000 rows so far...
# Counted 362,000 rows so far...
# Counted 363,000 rows so far...
# Counted 364,000 rows so far...
# Counted 365,000 rows so far...
# Counted 366,000 rows so far...
# Counted 367,000 rows so far...
# Counted 368,000 rows so far...
# Counted 369,000 rows so far...
# Counted 370,000 rows so far...
# Counted 371,000 rows so far...
# Counted 372,000 rows so far...
# Counted 373,000 rows so far...
# Counted 374,000 rows so far...
# Counted 375,000 rows so far...
# Counted 376,000 rows so far...
# Counted 377,000 rows so far...
# Counted 378,000 rows so far...
# Counted 379,000 rows so far...
# Counted 380,000 rows so far...
# Counted 381,000 rows so far...
# Counted 382,000 rows so far...
# Counted 383,000 rows so far...
# Counted 384,000 rows so far...
# Counted 385,000 rows so far...
# Counted 386,000 rows so far...
# Counted 387,000 rows so far...
# Counted 388,000 rows so far...
# Counted 389,000 rows so far...
# Counted 390,000 rows so far...
# Counted 391,000 rows so far...
# Counted 392,000 rows so far...
# Counted 393,000 rows so far...
# Counted 394,000 rows so far...
# Counted 395,000 rows so far...
# Counted 396,000 rows so far...
# Counted 397,000 rows so far...
# Counted 398,000 rows so far...
# Counted 399,000 rows so far...
# Counted 400,000 rows so far...
# Counted 401,000 rows so far...
# Counted 402,000 rows so far...
# Counted 403,000 rows so far...
# Counted 404,000 rows so far...
# Counted 405,000 rows so far...
# Counted 406,000 rows so far...
# Counted 407,000 rows so far...
# Counted 408,000 rows so far...
# Counted 409,000 rows so far...
# Counted 410,000 rows so far...
# Counted 411,000 rows so far...
# Counted 412,000 rows so far...
# Counted 413,000 rows so far...
# Counted 414,000 rows so far...
# Counted 415,000 rows so far...
# Counted 416,000 rows so far...
# Counted 417,000 rows so far...
# Counted 418,000 rows so far...
# Counted 419,000 rows so far...
# Counted 420,000 rows so far...
# Counted 421,000 rows so far...
# Counted 422,000 rows so far...
# Counted 423,000 rows so far...
# Counted 424,000 rows so far...
# Counted 425,000 rows so far...
# Counted 426,000 rows so far...
# Counted 427,000 rows so far...
# Counted 428,000 rows so far...
# Counted 429,000 rows so far...
# Counted 430,000 rows so far...
# Counted 431,000 rows so far...
# Counted 432,000 rows so far...
# Counted 433,000 rows so far...
# Counted 434,000 rows so far...
# Counted 435,000 rows so far...
# Counted 436,000 rows so far...
# Counted 437,000 rows so far...
# Counted 438,000 rows so far...
# Counted 439,000 rows so far...
# Counted 440,000 rows so far...
# Counted 441,000 rows so far...
# Counted 442,000 rows so far...
# Counted 443,000 rows so far...
# Counted 444,000 rows so far...
# Counted 445,000 rows so far...
# Counted 446,000 rows so far...
# Counted 447,000 rows so far...
# Counted 448,000 rows so far...
# Counted 449,000 rows so far...
# Counted 450,000 rows so far...
# Counted 451,000 rows so far...
# Counted 452,000 rows so far...
# Counted 453,000 rows so far...
# Counted 454,000 rows so far...
# Counted 455,000 rows so far...
# Counted 456,000 rows so far...
# Counted 457,000 rows so far...
# Counted 458,000 rows so far...
# Counted 459,000 rows so far...
# Counted 460,000 rows so far...
# Counted 461,000 rows so far...
# Counted 462,000 rows so far...
# Counted 463,000 rows so far...
# Counted 464,000 rows so far...
# Counted 465,000 rows so far...
# Counted 466,000 rows so far...
# Counted 467,000 rows so far...
# Counted 468,000 rows so far...
# Counted 469,000 rows so far...
# Counted 470,000 rows so far...
# Counted 471,000 rows so far...
# Counted 472,000 rows so far...
# Counted 473,000 rows so far...
# Counted 474,000 rows so far...
# Counted 475,000 rows so far...
# Counted 476,000 rows so far...
# Counted 477,000 rows so far...
# Counted 478,000 rows so far...
# Counted 479,000 rows so far...
# Counted 480,000 rows so far...
# Counted 481,000 rows so far...
# Counted 482,000 rows so far...
# Counted 483,000 rows so far...
# Counted 484,000 rows so far...
# Counted 485,000 rows so far...
# Counted 486,000 rows so far...
# Counted 487,000 rows so far...
# Counted 488,000 rows so far...
# Counted 489,000 rows so far...
# Counted 490,000 rows so far...
# Counted 491,000 rows so far...
# Counted 492,000 rows so far...
# Counted 493,000 rows so far...
# Counted 494,000 rows so far...
# Counted 495,000 rows so far...
# Counted 496,000 rows so far...
# Counted 497,000 rows so far...
# Counted 498,000 rows so far...
# Counted 499,000 rows so far...
# Counted 500,000 rows so far...
# Counted 501,000 rows so far...
# Counted 502,000 rows so far...
# Counted 503,000 rows so far...
# Counted 504,000 rows so far...
# Counted 505,000 rows so far...
# Counted 506,000 rows so far...
# Counted 507,000 rows so far...
# Counted 508,000 rows so far...
# Counted 509,000 rows so far...
# Counted 510,000 rows so far...
# Counted 511,000 rows so far...
# Counted 512,000 rows so far...
# Counted 513,000 rows so far...
# Counted 514,000 rows so far...
# Counted 515,000 rows so far...
# Counted 516,000 rows so far...
# Counted 517,000 rows so far...
# Counted 518,000 rows so far...
# Counted 519,000 rows so far...
# Counted 520,000 rows so far...
# Counted 521,000 rows so far...
# Counted 522,000 rows so far...
# Counted 523,000 rows so far...
# Counted 524,000 rows so far...
# Counted 525,000 rows so far...
# Counted 526,000 rows so far...
# Counted 527,000 rows so far...
# Counted 528,000 rows so far...
# Counted 529,000 rows so far...
# Counted 530,000 rows so far...
# Counted 531,000 rows so far...
# Counted 532,000 rows so far...
# Counted 533,000 rows so far...
# Counted 534,000 rows so far...
# Counted 535,000 rows so far...
# Counted 536,000 rows so far...
# Counted 537,000 rows so far...
# Counted 538,000 rows so far...
# Counted 539,000 rows so far...
# Counted 540,000 rows so far...
# Counted 541,000 rows so far...
# Counted 542,000 rows so far...
# Counted 543,000 rows so far...
# Counted 544,000 rows so far...
# Counted 545,000 rows so far...
# Counted 546,000 rows so far...
# Counted 547,000 rows so far...
# Counted 548,000 rows so far...
# Counted 549,000 rows so far...
# Counted 550,000 rows so far...
# Counted 551,000 rows so far...
# Counted 552,000 rows so far...
# Counted 553,000 rows so far...
# Counted 554,000 rows so far...
# Counted 555,000 rows so far...
# Counted 556,000 rows so far...
# Counted 557,000 rows so far...
# Counted 558,000 rows so far...
# Counted 559,000 rows so far...
# Counted 560,000 rows so far...
# Counted 561,000 rows so far...
# Counted 562,000 rows so far...
# Counted 563,000 rows so far...
# Counted 564,000 rows so far...
# Counted 565,000 rows so far...
# Counted 566,000 rows so far...
# Counted 567,000 rows so far...
# Counted 568,000 rows so far...
# Counted 569,000 rows so far...
# Counted 570,000 rows so far...
# Counted 571,000 rows so far...
# Counted 572,000 rows so far...
# Counted 573,000 rows so far...
# Counted 574,000 rows so far...
# Counted 575,000 rows so far...
# Counted 576,000 rows so far...
# Counted 577,000 rows so far...
# Counted 578,000 rows so far...
# Counted 579,000 rows so far...
# Counted 580,000 rows so far...
# Counted 581,000 rows so far...
# Counted 582,000 rows so far...
# Counted 583,000 rows so far...
# Counted 584,000 rows so far...
# Counted 585,000 rows so far...
# Counted 586,000 rows so far...
# Counted 587,000 rows so far...
# Counted 588,000 rows so far...
# Counted 589,000 rows so far...
# Counted 590,000 rows so far...
# Counted 591,000 rows so far...
# Counted 592,000 rows so far...
# Counted 593,000 rows so far...
# Counted 594,000 rows so far...
# Counted 595,000 rows so far...
# Counted 596,000 rows so far...
# Counted 597,000 rows so far...
# Counted 598,000 rows so far...
# Counted 599,000 rows so far...
# Counted 600,000 rows so far...
# Counted 601,000 rows so far...
# Counted 602,000 rows so far...
# Counted 603,000 rows so far...
# Counted 604,000 rows so far...
# Counted 605,000 rows so far...
# Counted 606,000 rows so far...
# Counted 607,000 rows so far...
# Counted 608,000 rows so far...
# Counted 609,000 rows so far...
# Counted 610,000 rows so far...
# Counted 611,000 rows so far...
# Counted 612,000 rows so far...
# Counted 613,000 rows so far...
# Counted 614,000 rows so far...
# Counted 615,000 rows so far...
# Counted 616,000 rows so far...
# Counted 617,000 rows so far...
# Counted 618,000 rows so far...
# Counted 619,000 rows so far...
# Counted 620,000 rows so far...
# Counted 621,000 rows so far...
# Counted 622,000 rows so far...
# Counted 623,000 rows so far...
# Counted 624,000 rows so far...
# Counted 625,000 rows so far...
# Counted 626,000 rows so far...
# Counted 627,000 rows so far...
# Counted 628,000 rows so far...
# Counted 629,000 rows so far...
# Counted 630,000 rows so far...
# Counted 631,000 rows so far...
# Counted 632,000 rows so far...
# Counted 633,000 rows so far...
# Counted 634,000 rows so far...
# Counted 635,000 rows so far...
# Counted 636,000 rows so far...
# Counted 637,000 rows so far...
# Counted 638,000 rows so far...
# Counted 639,000 rows so far...
# Counted 640,000 rows so far...
# Counted 641,000 rows so far...
# Counted 642,000 rows so far...
# Counted 643,000 rows so far...
# Counted 644,000 rows so far...
# Counted 645,000 rows so far...
# Counted 646,000 rows so far...
# Counted 647,000 rows so far...
# Counted 648,000 rows so far...
# Counted 649,000 rows so far...
# Counted 650,000 rows so far...
# Counted 651,000 rows so far...
# Counted 652,000 rows so far...
# Counted 653,000 rows so far...
# Counted 654,000 rows so far...
# Counted 655,000 rows so far...
# Counted 656,000 rows so far...
# Counted 657,000 rows so far...
# Counted 658,000 rows so far...
# Counted 659,000 rows so far...
# Counted 660,000 rows so far...
# Counted 661,000 rows so far...
# Counted 662,000 rows so far...
# Counted 663,000 rows so far...
# Counted 664,000 rows so far...
# Counted 665,000 rows so far...
# Counted 666,000 rows so far...
# Counted 667,000 rows so far...
# Counted 668,000 rows so far...
# Counted 669,000 rows so far...
# Counted 670,000 rows so far...
# Counted 671,000 rows so far...
# Counted 672,000 rows so far...
# Counted 673,000 rows so far...
# Counted 674,000 rows so far...
# Counted 675,000 rows so far...
# Counted 676,000 rows so far...
# Counted 677,000 rows so far...
# Counted 678,000 rows so far...
# Counted 679,000 rows so far...
# Counted 680,000 rows so far...
# Counted 681,000 rows so far...
# Counted 682,000 rows so far...
# Counted 683,000 rows so far...
# Counted 684,000 rows so far...
# Counted 685,000 rows so far...
# Counted 686,000 rows so far...
# Counted 687,000 rows so far...
# Counted 688,000 rows so far...
# Counted 689,000 rows so far...
# Counted 690,000 rows so far...
# Counted 691,000 rows so far...
# Counted 692,000 rows so far...
# Counted 693,000 rows so far...
# Counted 694,000 rows so far...
# Counted 695,000 rows so far...
# Counted 696,000 rows so far...
# Counted 697,000 rows so far...
# Counted 698,000 rows so far...
# Counted 699,000 rows so far...
# Counted 700,000 rows so far...
# Counted 701,000 rows so far...
# Counted 702,000 rows so far...
# Counted 703,000 rows so far...
# Counted 704,000 rows so far...
# Counted 705,000 rows so far...
# Counted 706,000 rows so far...
# Counted 707,000 rows so far...
# Counted 708,000 rows so far...
# Counted 709,000 rows so far...
# Counted 710,000 rows so far...
# Counted 711,000 rows so far...
# Counted 712,000 rows so far...
# Counted 713,000 rows so far...
# Counted 714,000 rows so far...
# Counted 715,000 rows so far...
# Counted 716,000 rows so far...
# Counted 717,000 rows so far...
# Counted 718,000 rows so far...
# Counted 719,000 rows so far...
# Counted 720,000 rows so far...
# Counted 721,000 rows so far...
# Counted 722,000 rows so far...
# Counted 723,000 rows so far...
# Counted 724,000 rows so far...
# Counted 725,000 rows so far...
# Counted 726,000 rows so far...
# Counted 727,000 rows so far...
# Counted 728,000 rows so far...
# Counted 729,000 rows so far...
# Counted 730,000 rows so far...
# Counted 731,000 rows so far...
# Counted 732,000 rows so far...
# Counted 733,000 rows so far...
# Counted 734,000 rows so far...
# Counted 735,000 rows so far...
# Counted 736,000 rows so far...
# Counted 737,000 rows so far...
# Counted 738,000 rows so far...
# Counted 739,000 rows so far...
# Counted 740,000 rows so far...
# Counted 741,000 rows so far...
# Counted 742,000 rows so far...
# Counted 743,000 rows so far...
# Counted 744,000 rows so far...
# Counted 745,000 rows so far...
# Counted 746,000 rows so far...
# Counted 747,000 rows so far...
# Counted 748,000 rows so far...
# Counted 749,000 rows so far...
# Counted 750,000 rows so far...
# Counted 751,000 rows so far...
# Counted 752,000 rows so far...
# Counted 753,000 rows so far...
# Counted 754,000 rows so far...
# Counted 755,000 rows so far...
# Counted 756,000 rows so far...
# Counted 757,000 rows so far...
# Counted 758,000 rows so far...
# Counted 759,000 rows so far...
# Counted 760,000 rows so far...
# Counted 761,000 rows so far...
# Counted 762,000 rows so far...
# Counted 763,000 rows so far...
# Counted 764,000 rows so far...
# Counted 765,000 rows so far...
# Counted 766,000 rows so far...
# Counted 767,000 rows so far...
# Counted 768,000 rows so far...
# Counted 769,000 rows so far...
# Counted 770,000 rows so far...
# Counted 771,000 rows so far...
# Counted 772,000 rows so far...
# Counted 773,000 rows so far...
# Counted 774,000 rows so far...
# Counted 775,000 rows so far...
# Counted 776,000 rows so far...
# Counted 777,000 rows so far...
# Counted 778,000 rows so far...
# Counted 779,000 rows so far...
# Counted 780,000 rows so far...
# Counted 781,000 rows so far...
# Counted 782,000 rows so far...
# Counted 783,000 rows so far...
# Counted 784,000 rows so far...
# Counted 785,000 rows so far...
# Counted 786,000 rows so far...
# Counted 787,000 rows so far...
# Counted 788,000 rows so far...
# Counted 789,000 rows so far...
# Counted 790,000 rows so far...
# Counted 791,000 rows so far...
# Counted 792,000 rows so far...
# Counted 793,000 rows so far...
# Counted 794,000 rows so far...
# Counted 795,000 rows so far...
# Counted 796,000 rows so far...
# Counted 797,000 rows so far...
# Counted 798,000 rows so far...
# Counted 799,000 rows so far...
# Counted 800,000 rows so far...
# Counted 801,000 rows so far...
# Counted 802,000 rows so far...
# Counted 803,000 rows so far...
# Counted 804,000 rows so far...
# Counted 805,000 rows so far...
# Counted 806,000 rows so far...
# Counted 807,000 rows so far...
# Counted 808,000 rows so far...
# Counted 809,000 rows so far...
# Counted 810,000 rows so far...
# Counted 811,000 rows so far...
# Counted 812,000 rows so far...
# Counted 813,000 rows so far...
# Counted 814,000 rows so far...
# Counted 815,000 rows so far...
# Counted 816,000 rows so far...
# Counted 817,000 rows so far...
# Counted 818,000 rows so far...
# Counted 819,000 rows so far...
# Counted 820,000 rows so far...
# Counted 821,000 rows so far...
# Counted 822,000 rows so far...
# Counted 823,000 rows so far...
# Counted 824,000 rows so far...
# Counted 825,000 rows so far...
# Counted 826,000 rows so far...
# Counted 827,000 rows so far...
# Counted 828,000 rows so far...
# Counted 829,000 rows so far...
# Counted 830,000 rows so far...
# Counted 831,000 rows so far...
# Counted 832,000 rows so far...
# Counted 833,000 rows so far...
# Counted 834,000 rows so far...
# Counted 835,000 rows so far...
# Counted 836,000 rows so far...
# Counted 837,000 rows so far...
# Counted 838,000 rows so far...
# Counted 839,000 rows so far...
# Counted 840,000 rows so far...
# Counted 841,000 rows so far...
# Counted 842,000 rows so far...
# Counted 843,000 rows so far...
# Counted 844,000 rows so far...
# Counted 845,000 rows so far...
# Counted 846,000 rows so far...
# Counted 847,000 rows so far...
# Counted 848,000 rows so far...
# Counted 849,000 rows so far...
# Counted 850,000 rows so far...
# Counted 851,000 rows so far...
# Counted 852,000 rows so far...
# Counted 853,000 rows so far...
# Counted 854,000 rows so far...
# Counted 855,000 rows so far...
# Counted 856,000 rows so far...
# Counted 857,000 rows so far...
# Counted 858,000 rows so far...
# Counted 859,000 rows so far...
# Counted 860,000 rows so far...
# Counted 861,000 rows so far...
# Counted 862,000 rows so far...
# Counted 863,000 rows so far...
# Counted 864,000 rows so far...
# Counted 865,000 rows so far...
# Counted 866,000 rows so far...
# Counted 867,000 rows so far...
# Counted 868,000 rows so far...
# Counted 869,000 rows so far...
# Counted 870,000 rows so far...
# Counted 871,000 rows so far...
# Counted 872,000 rows so far...
# Counted 873,000 rows so far...
# Counted 874,000 rows so far...
# Counted 875,000 rows so far...
# Counted 876,000 rows so far...
# Counted 877,000 rows so far...
# Counted 878,000 rows so far...
# Counted 879,000 rows so far...
# Counted 880,000 rows so far...
# Counted 881,000 rows so far...
# Counted 882,000 rows so far...
# Counted 883,000 rows so far...
# Counted 884,000 rows so far...
# Counted 885,000 rows so far...
# Counted 886,000 rows so far...
# Counted 887,000 rows so far...
# Counted 888,000 rows so far...
# Counted 889,000 rows so far...
# Counted 890,000 rows so far...
# Counted 891,000 rows so far...
# Counted 892,000 rows so far...
# Counted 893,000 rows so far...
# Counted 894,000 rows so far...
# Counted 895,000 rows so far...
# Counted 896,000 rows so far...
# Counted 897,000 rows so far...
# Counted 898,000 rows so far...
# Counted 899,000 rows so far...
# Counted 900,000 rows so far...
# Counted 901,000 rows so far...
# Counted 902,000 rows so far...
# Counted 903,000 rows so far...
# Counted 904,000 rows so far...
# Counted 905,000 rows so far...
# Counted 906,000 rows so far...
# Counted 907,000 rows so far...
# Counted 908,000 rows so far...
# Counted 909,000 rows so far...
# Counted 910,000 rows so far...
# Counted 911,000 rows so far...
# Counted 912,000 rows so far...
# Counted 913,000 rows so far...
# Counted 914,000 rows so far...
# Counted 915,000 rows so far...
# Counted 916,000 rows so far...
# Counted 917,000 rows so far...
# Counted 918,000 rows so far...
# Counted 919,000 rows so far...
# Counted 920,000 rows so far...
# Counted 921,000 rows so far...
# Counted 922,000 rows so far...
# Counted 923,000 rows so far...
# Counted 924,000 rows so far...
# Counted 925,000 rows so far...
# Counted 926,000 rows so far...
# Counted 927,000 rows so far...
# Counted 928,000 rows so far...
# Counted 929,000 rows so far...
# Counted 930,000 rows so far...
# Counted 931,000 rows so far...
# Counted 932,000 rows so far...
# Counted 933,000 rows so far...
# Counted 934,000 rows so far...
# Counted 935,000 rows so far...
# Counted 936,000 rows so far...
# Counted 937,000 rows so far...
# Counted 938,000 rows so far...
# Counted 939,000 rows so far...
# Counted 940,000 rows so far...
# Counted 941,000 rows so far...
# Counted 942,000 rows so far...
# Counted 943,000 rows so far...
# Counted 944,000 rows so far...
# Counted 945,000 rows so far...
# Counted 946,000 rows so far...
# Counted 947,000 rows so far...
# Counted 948,000 rows so far...
# Counted 949,000 rows so far...
# Counted 950,000 rows so far...
# Counted 951,000 rows so far...
# Counted 952,000 rows so far...
# Counted 953,000 rows so far...
# Counted 954,000 rows so far...
# Counted 955,000 rows so far...
# Counted 956,000 rows so far...
# Counted 957,000 rows so far...
# Counted 958,000 rows so far...
# Counted 959,000 rows so far...
# Counted 960,000 rows so far...
# Counted 961,000 rows so far...
# Counted 962,000 rows so far...
# Counted 963,000 rows so far...
# Counted 964,000 rows so far...
# Counted 965,000 rows so far...
# Counted 966,000 rows so far...
# Counted 967,000 rows so far...
# Counted 968,000 rows so far...
# Counted 969,000 rows so far...
# Counted 970,000 rows so far...
# Counted 971,000 rows so far...
# Counted 972,000 rows so far...
# Counted 973,000 rows so far...
# Counted 974,000 rows so far...
# Counted 975,000 rows so far...
# Counted 976,000 rows so far...
# Counted 977,000 rows so far...
# Counted 978,000 rows so far...
# Counted 979,000 rows so far...
# Counted 980,000 rows so far...
# Counted 981,000 rows so far...
# Counted 982,000 rows so far...
# Counted 983,000 rows so far...
# Counted 984,000 rows so far...
# Counted 985,000 rows so far...
# Counted 986,000 rows so far...
# Counted 987,000 rows so far...
# Counted 988,000 rows so far...
# Counted 989,000 rows so far...
# Counted 990,000 rows so far...
# Counted 991,000 rows so far...
# Counted 992,000 rows so far...
# Counted 993,000 rows so far...
# Counted 994,000 rows so far...
# Counted 995,000 rows so far...
# Counted 996,000 rows so far...
# Counted 997,000 rows so far...
# Counted 998,000 rows so far...
# Counted 999,000 rows so far...
# Counted 1,000,000 rows so far...
# Counted 1,001,000 rows so far...
# Counted 1,002,000 rows so far...
# Counted 1,003,000 rows so far...
# Counted 1,004,000 rows so far...
# Counted 1,005,000 rows so far...
# Counted 1,006,000 rows so far...
# Counted 1,007,000 rows so far...
# Counted 1,008,000 rows so far...
# Counted 1,009,000 rows so far...
# Counted 1,010,000 rows so far...
# Counted 1,011,000 rows so far...
# Counted 1,012,000 rows so far...
# Counted 1,013,000 rows so far...
# Counted 1,014,000 rows so far...
# Counted 1,015,000 rows so far...
# Counted 1,016,000 rows so far...
# Counted 1,017,000 rows so far...
# Counted 1,018,000 rows so far...
# Counted 1,019,000 rows so far...
# Counted 1,020,000 rows so far...
# Counted 1,021,000 rows so far...
# Counted 1,022,000 rows so far...
# Counted 1,023,000 rows so far...
# Counted 1,024,000 rows so far...
# Counted 1,025,000 rows so far...
# Counted 1,026,000 rows so far...
# Counted 1,027,000 rows so far...
# Counted 1,028,000 rows so far...
# Counted 1,029,000 rows so far...
# Counted 1,030,000 rows so far...
# Counted 1,031,000 rows so far...
# Counted 1,032,000 rows so far...
# Counted 1,033,000 rows so far...
# Counted 1,034,000 rows so far...
# Counted 1,035,000 rows so far...
# Counted 1,036,000 rows so far...
# Counted 1,037,000 rows so far...
# Counted 1,038,000 rows so far...
# Counted 1,039,000 rows so far...
# Counted 1,040,000 rows so far...
# Counted 1,041,000 rows so far...
# Counted 1,042,000 rows so far...
# Counted 1,043,000 rows so far...
# Counted 1,044,000 rows so far...
# Counted 1,045,000 rows so far...
# Counted 1,046,000 rows so far...
# Counted 1,047,000 rows so far...
# Counted 1,048,000 rows so far...
# Counted 1,049,000 rows so far...
# Counted 1,050,000 rows so far...
# Counted 1,051,000 rows so far...
# Counted 1,052,000 rows so far...
# Counted 1,053,000 rows so far...
# Counted 1,054,000 rows so far...
# Counted 1,055,000 rows so far...
# Counted 1,056,000 rows so far...
# Counted 1,057,000 rows so far...
# Counted 1,058,000 rows so far...
# Counted 1,059,000 rows so far...
# Counted 1,060,000 rows so far...
# Counted 1,061,000 rows so far...
# Counted 1,062,000 rows so far...
# Counted 1,063,000 rows so far...
# Counted 1,064,000 rows so far...
# Counted 1,065,000 rows so far...
# Counted 1,066,000 rows so far...
# Counted 1,067,000 rows so far...
# Counted 1,068,000 rows so far...
# Counted 1,069,000 rows so far...
# Counted 1,070,000 rows so far...
# Counted 1,071,000 rows so far...
# Counted 1,072,000 rows so far...
# Counted 1,073,000 rows so far...
# Counted 1,074,000 rows so far...
# Counted 1,075,000 rows so far...
# Counted 1,076,000 rows so far...
# Counted 1,077,000 rows so far...
# Counted 1,078,000 rows so far...
# Counted 1,079,000 rows so far...
# Counted 1,080,000 rows so far...
# Counted 1,081,000 rows so far...
# Counted 1,082,000 rows so far...
# Counted 1,083,000 rows so far...
# Counted 1,084,000 rows so far...
# Counted 1,085,000 rows so far...
# Counted 1,086,000 rows so far...
# Counted 1,087,000 rows so far...
# Counted 1,088,000 rows so far...
# Counted 1,089,000 rows so far...
# Counted 1,090,000 rows so far...
# Counted 1,091,000 rows so far...
# Counted 1,092,000 rows so far...
# Counted 1,093,000 rows so far...
# Counted 1,094,000 rows so far...
# Counted 1,095,000 rows so far...
# Counted 1,096,000 rows so far...
# Counted 1,097,000 rows so far...
# Counted 1,098,000 rows so far...
# Counted 1,099,000 rows so far...
# Counted 1,100,000 rows so far...
# Counted 1,101,000 rows so far...
# Counted 1,102,000 rows so far...
# Counted 1,103,000 rows so far...
# Counted 1,104,000 rows so far...
# Counted 1,105,000 rows so far...
# Counted 1,106,000 rows so far...
# Counted 1,107,000 rows so far...
# Counted 1,108,000 rows so far...
# Counted 1,109,000 rows so far...
# Counted 1,110,000 rows so far...
# Counted 1,111,000 rows so far...
# Counted 1,112,000 rows so far...
# Counted 1,113,000 rows so far...
# Counted 1,114,000 rows so far...
# Counted 1,115,000 rows so far...
# Counted 1,116,000 rows so far...
# Counted 1,117,000 rows so far...
# Counted 1,118,000 rows so far...
# Counted 1,119,000 rows so far...
# Counted 1,120,000 rows so far...
# Counted 1,121,000 rows so far...
# Counted 1,122,000 rows so far...
# Counted 1,123,000 rows so far...
# Counted 1,124,000 rows so far...
# Counted 1,125,000 rows so far...
# Counted 1,126,000 rows so far...
# Counted 1,127,000 rows so far...
# Counted 1,128,000 rows so far...
# Counted 1,129,000 rows so far...
# Counted 1,130,000 rows so far...
# Counted 1,131,000 rows so far...
# Counted 1,132,000 rows so far...
# Counted 1,133,000 rows so far...
# Counted 1,134,000 rows so far...
# Counted 1,135,000 rows so far...
# Counted 1,136,000 rows so far...
# Counted 1,137,000 rows so far...
# Counted 1,138,000 rows so far...
# Counted 1,139,000 rows so far...
# Counted 1,140,000 rows so far...
# Counted 1,141,000 rows so far...
# Counted 1,142,000 rows so far...
# Counted 1,143,000 rows so far...
# Counted 1,144,000 rows so far...
# Counted 1,145,000 rows so far...
# Counted 1,146,000 rows so far...
# Counted 1,147,000 rows so far...
# Counted 1,148,000 rows so far...
# Counted 1,149,000 rows so far...
# Counted 1,150,000 rows so far...
# Counted 1,151,000 rows so far...
# Counted 1,152,000 rows so far...
# Counted 1,153,000 rows so far...
# Counted 1,154,000 rows so far...
# Counted 1,155,000 rows so far...
# Counted 1,156,000 rows so far...
# Counted 1,157,000 rows so far...
# Counted 1,158,000 rows so far...
# Counted 1,159,000 rows so far...
# Counted 1,160,000 rows so far...
# Counted 1,161,000 rows so far...
# Counted 1,162,000 rows so far...
# Counted 1,163,000 rows so far...
# Counted 1,164,000 rows so far...
# Counted 1,165,000 rows so far...
# Counted 1,166,000 rows so far...
# Counted 1,167,000 rows so far...
# Counted 1,168,000 rows so far...
# Counted 1,169,000 rows so far...
# Counted 1,170,000 rows so far...
# Counted 1,171,000 rows so far...
# Counted 1,172,000 rows so far...
# Counted 1,173,000 rows so far...
# Counted 1,174,000 rows so far...
# Counted 1,175,000 rows so far...
# Counted 1,176,000 rows so far...
# Counted 1,177,000 rows so far...
# Counted 1,178,000 rows so far...
# Counted 1,179,000 rows so far...
# Counted 1,180,000 rows so far...
# Counted 1,181,000 rows so far...
# Counted 1,182,000 rows so far...
# Counted 1,183,000 rows so far...
# Counted 1,184,000 rows so far...
# Counted 1,185,000 rows so far...
# Counted 1,186,000 rows so far...
# Counted 1,187,000 rows so far...
# Counted 1,188,000 rows so far...
# Counted 1,189,000 rows so far...
# Counted 1,190,000 rows so far...
# Counted 1,191,000 rows so far...
# Counted 1,192,000 rows so far...
# Counted 1,193,000 rows so far...
# Counted 1,194,000 rows so far...
# Counted 1,195,000 rows so far...
# Counted 1,196,000 rows so far...
# Counted 1,197,000 rows so far...
# Counted 1,198,000 rows so far...
# Counted 1,199,000 rows so far...
# Counted 1,200,000 rows so far...
# Counted 1,201,000 rows so far...
# Counted 1,202,000 rows so far...
# Counted 1,203,000 rows so far...
# Counted 1,204,000 rows so far...
# Counted 1,205,000 rows so far...
# Counted 1,206,000 rows so far...
# Counted 1,207,000 rows so far...
# Counted 1,208,000 rows so far...
# Counted 1,209,000 rows so far...
# Counted 1,210,000 rows so far...
# Counted 1,211,000 rows so far...
# Counted 1,212,000 rows so far...
# Counted 1,213,000 rows so far...
# Counted 1,214,000 rows so far...
# Counted 1,215,000 rows so far...
# Counted 1,216,000 rows so far...
# Counted 1,217,000 rows so far...
# Counted 1,218,000 rows so far...
# Counted 1,219,000 rows so far...
# Counted 1,220,000 rows so far...
# Counted 1,221,000 rows so far...
# Counted 1,222,000 rows so far...
# Counted 1,223,000 rows so far...
# Counted 1,224,000 rows so far...
# Counted 1,225,000 rows so far...
# Counted 1,226,000 rows so far...
# Counted 1,227,000 rows so far...
# Counted 1,228,000 rows so far...
# Counted 1,229,000 rows so far...
# Counted 1,230,000 rows so far...
# Counted 1,231,000 rows so far...
# Counted 1,232,000 rows so far...
# Counted 1,233,000 rows so far...
# Counted 1,234,000 rows so far...
# Counted 1,235,000 rows so far...
# Counted 1,236,000 rows so far...
# Counted 1,237,000 rows so far...
# Counted 1,238,000 rows so far...
# Counted 1,239,000 rows so far...
# Counted 1,240,000 rows so far...
# Counted 1,241,000 rows so far...
# Counted 1,242,000 rows so far...
# Counted 1,243,000 rows so far...
# Counted 1,244,000 rows so far...
# Counted 1,245,000 rows so far...
# Counted 1,246,000 rows so far...
# Counted 1,247,000 rows so far...
# Counted 1,248,000 rows so far...
# Counted 1,249,000 rows so far...
# Counted 1,250,000 rows so far...
# Counted 1,251,000 rows so far...
# Counted 1,252,000 rows so far...
# Counted 1,253,000 rows so far...
# Counted 1,254,000 rows so far...
# Counted 1,255,000 rows so far...
# Counted 1,256,000 rows so far...
# Counted 1,257,000 rows so far...
# Counted 1,258,000 rows so far...
# Counted 1,259,000 rows so far...
# Counted 1,260,000 rows so far...
# Counted 1,261,000 rows so far...
# Counted 1,262,000 rows so far...
# Counted 1,263,000 rows so far...
# Counted 1,264,000 rows so far...
# Counted 1,265,000 rows so far...
# Counted 1,266,000 rows so far...
# Counted 1,267,000 rows so far...
# Counted 1,268,000 rows so far...
# Counted 1,269,000 rows so far...
# Counted 1,270,000 rows so far...
# Counted 1,271,000 rows so far...
# Counted 1,272,000 rows so far...
# Counted 1,273,000 rows so far...
# Counted 1,274,000 rows so far...
# Counted 1,275,000 rows so far...
# Counted 1,276,000 rows so far...
# Counted 1,277,000 rows so far...
# Counted 1,278,000 rows so far...
# Counted 1,279,000 rows so far...
# Counted 1,280,000 rows so far...
# Counted 1,281,000 rows so far...
# Counted 1,282,000 rows so far...
# Counted 1,283,000 rows so far...
# Counted 1,284,000 rows so far...
# Counted 1,285,000 rows so far...
# Counted 1,286,000 rows so far...
# Counted 1,287,000 rows so far...
# Counted 1,288,000 rows so far...
# Counted 1,289,000 rows so far...
# Counted 1,290,000 rows so far...
# Counted 1,291,000 rows so far...
# Counted 1,292,000 rows so far...
# Counted 1,293,000 rows so far...
# Counted 1,294,000 rows so far...
# Counted 1,295,000 rows so far...
# Counted 1,296,000 rows so far...
# Counted 1,297,000 rows so far...
# Counted 1,298,000 rows so far...
# Counted 1,299,000 rows so far...
# Counted 1,300,000 rows so far...
# Counted 1,301,000 rows so far...
# Counted 1,302,000 rows so far...
# Counted 1,303,000 rows so far...
# Counted 1,304,000 rows so far...
# Counted 1,305,000 rows so far...
# Counted 1,306,000 rows so far...
# Counted 1,307,000 rows so far...
# Counted 1,308,000 rows so far...
# Counted 1,309,000 rows so far...
# Counted 1,310,000 rows so far...
# Counted 1,311,000 rows so far...
# Counted 1,312,000 rows so far...
# Counted 1,313,000 rows so far...
# Counted 1,314,000 rows so far...
# Counted 1,315,000 rows so far...
# Counted 1,316,000 rows so far...
# Counted 1,317,000 rows so far...
# Counted 1,318,000 rows so far...
# Counted 1,319,000 rows so far...
# Counted 1,320,000 rows so far...
# Counted 1,321,000 rows so far...
# Counted 1,322,000 rows so far...
# Counted 1,323,000 rows so far...
# Counted 1,324,000 rows so far...
# Counted 1,325,000 rows so far...
# Counted 1,326,000 rows so far...
# Counted 1,327,000 rows so far...
# Counted 1,328,000 rows so far...
# Counted 1,329,000 rows so far...
# Counted 1,330,000 rows so far...
# Counted 1,331,000 rows so far...
# Counted 1,332,000 rows so far...
# Counted 1,333,000 rows so far...
# Counted 1,334,000 rows so far...
# Counted 1,335,000 rows so far...
# Counted 1,336,000 rows so far...
# Counted 1,337,000 rows so far...
# Counted 1,338,000 rows so far...
# Counted 1,339,000 rows so far...
# Counted 1,340,000 rows so far...
# Counted 1,341,000 rows so far...
# Counted 1,342,000 rows so far...
# Counted 1,343,000 rows so far...
# Counted 1,344,000 rows so far...
# Counted 1,345,000 rows so far...
# Counted 1,346,000 rows so far...
# Counted 1,347,000 rows so far...
# Counted 1,348,000 rows so far...
# Counted 1,349,000 rows so far...
# Counted 1,350,000 rows so far...
# Counted 1,351,000 rows so far...
# Counted 1,352,000 rows so far...
# Counted 1,353,000 rows so far...
# Counted 1,354,000 rows so far...
# Counted 1,355,000 rows so far...
# Counted 1,356,000 rows so far...
# Counted 1,357,000 rows so far...
# Counted 1,358,000 rows so far...
# Counted 1,359,000 rows so far...
# Counted 1,360,000 rows so far...
# Counted 1,361,000 rows so far...
# Counted 1,362,000 rows so far...
# Counted 1,363,000 rows so far...
# Counted 1,364,000 rows so far...
# Counted 1,365,000 rows so far...
# Counted 1,366,000 rows so far...
# Counted 1,367,000 rows so far...
# Counted 1,368,000 rows so far...
# Counted 1,369,000 rows so far...
# Counted 1,370,000 rows so far...
# Counted 1,371,000 rows so far...
# Counted 1,372,000 rows so far...
# Counted 1,373,000 rows so far...
# Counted 1,374,000 rows so far...
# Counted 1,375,000 rows so far...
# Counted 1,376,000 rows so far...
# Counted 1,377,000 rows so far...
# Counted 1,378,000 rows so far...
# Counted 1,379,000 rows so far...
# Counted 1,380,000 rows so far...
# Counted 1,381,000 rows so far...
# Counted 1,382,000 rows so far...
# Counted 1,383,000 rows so far...
# Counted 1,384,000 rows so far...
# Counted 1,385,000 rows so far...
# Counted 1,386,000 rows so far...
# Counted 1,387,000 rows so far...
# Counted 1,388,000 rows so far...
# Counted 1,389,000 rows so far...
# Counted 1,390,000 rows so far...
# Counted 1,391,000 rows so far...
# Counted 1,392,000 rows so far...
# Counted 1,393,000 rows so far...
# Counted 1,394,000 rows so far...
# Counted 1,395,000 rows so far...
# Counted 1,396,000 rows so far...
# Counted 1,397,000 rows so far...
# Counted 1,398,000 rows so far...
# Counted 1,399,000 rows so far...
# Counted 1,400,000 rows so far...
# Counted 1,401,000 rows so far...
# Counted 1,402,000 rows so far...
# Counted 1,403,000 rows so far...
# Counted 1,404,000 rows so far...
# Counted 1,405,000 rows so far...
# Counted 1,406,000 rows so far...
# Counted 1,407,000 rows so far...
# Counted 1,408,000 rows so far...
# Counted 1,409,000 rows so far...
# Counted 1,410,000 rows so far...
# Counted 1,411,000 rows so far...
# Counted 1,412,000 rows so far...
# Counted 1,413,000 rows so far...
# Counted 1,414,000 rows so far...
# Counted 1,415,000 rows so far...
# Counted 1,416,000 rows so far...
# Counted 1,417,000 rows so far...
# Counted 1,418,000 rows so far...
# Counted 1,419,000 rows so far...
# Counted 1,420,000 rows so far...
# Counted 1,421,000 rows so far...
# Counted 1,422,000 rows so far...
# Counted 1,423,000 rows so far...
# Counted 1,424,000 rows so far...
# Counted 1,425,000 rows so far...
# Counted 1,426,000 rows so far...
# Counted 1,427,000 rows so far...
# Counted 1,428,000 rows so far...
# Counted 1,429,000 rows so far...
# Counted 1,430,000 rows so far...
# Counted 1,431,000 rows so far...
# Counted 1,432,000 rows so far...
# Counted 1,433,000 rows so far...
# Counted 1,434,000 rows so far...
# Counted 1,435,000 rows so far...
# Counted 1,436,000 rows so far...
# Counted 1,437,000 rows so far...
# Counted 1,438,000 rows so far...
# Counted 1,439,000 rows so far...
# Counted 1,440,000 rows so far...
# Counted 1,441,000 rows so far...
# Counted 1,442,000 rows so far...
# Counted 1,443,000 rows so far...
# Counted 1,444,000 rows so far...
# Counted 1,445,000 rows so far...
# Counted 1,446,000 rows so far...
# Counted 1,447,000 rows so far...
# Counted 1,448,000 rows so far...
# Counted 1,449,000 rows so far...
# Counted 1,450,000 rows so far...
# Counted 1,451,000 rows so far...
# Counted 1,452,000 rows so far...
# Counted 1,453,000 rows so far...
# Counted 1,454,000 rows so far...
# Counted 1,455,000 rows so far...
# Counted 1,456,000 rows so far...
# Counted 1,457,000 rows so far...
# Counted 1,458,000 rows so far...
# Counted 1,459,000 rows so far...
# Counted 1,460,000 rows so far...
# Counted 1,461,000 rows so far...
# Counted 1,462,000 rows so far...
# Counted 1,463,000 rows so far...
# Counted 1,464,000 rows so far...
# Counted 1,465,000 rows so far...
# Counted 1,466,000 rows so far...
# Counted 1,467,000 rows so far...
# Counted 1,468,000 rows so far...
# Counted 1,469,000 rows so far...
# Counted 1,470,000 rows so far...
# Counted 1,471,000 rows so far...
# Counted 1,472,000 rows so far...
# Counted 1,473,000 rows so far...
# Counted 1,474,000 rows so far...
# Counted 1,475,000 rows so far...
# Counted 1,476,000 rows so far...
# Counted 1,477,000 rows so far...
# Counted 1,478,000 rows so far...
# Counted 1,479,000 rows so far...
# Counted 1,480,000 rows so far...
# Counted 1,481,000 rows so far...
# Counted 1,482,000 rows so far...
# Counted 1,483,000 rows so far...
# Counted 1,484,000 rows so far...
# Counted 1,485,000 rows so far...
# Counted 1,486,000 rows so far...
# Counted 1,487,000 rows so far...
# Counted 1,488,000 rows so far...
# Counted 1,489,000 rows so far...
# Counted 1,490,000 rows so far...
# Counted 1,491,000 rows so far...
# Counted 1,492,000 rows so far...
# Counted 1,493,000 rows so far...
# Counted 1,494,000 rows so far...
# Counted 1,495,000 rows so far...
# Counted 1,496,000 rows so far...
# Counted 1,497,000 rows so far...
# Counted 1,498,000 rows so far...
# Counted 1,499,000 rows so far...
# Counted 1,500,000 rows so far...
# Counted 1,501,000 rows so far...
# Counted 1,502,000 rows so far...
# Counted 1,503,000 rows so far...
# Counted 1,504,000 rows so far...
# Counted 1,505,000 rows so far...
# Counted 1,506,000 rows so far...
# Counted 1,507,000 rows so far...
# Counted 1,508,000 rows so far...
# Counted 1,509,000 rows so far...
# Counted 1,510,000 rows so far...
# Counted 1,511,000 rows so far...
# Counted 1,512,000 rows so far...
# Counted 1,513,000 rows so far...
# Counted 1,514,000 rows so far...
# Counted 1,515,000 rows so far...
# Counted 1,516,000 rows so far...
# Counted 1,517,000 rows so far...
# Counted 1,518,000 rows so far...
# ...
# Counted 9,519,000 rows so far...
# Counted 9,520,000 rows so far...
# Counted 9,521,000 rows so far...
# Counted 9,522,000 rows so far...
# Counted 9,523,000 rows so far...
# Counted 9,524,000 rows so far...
# Counted 9,525,000 rows so far...
# Counted 9,526,000 rows so far...
# Counted 9,527,000 rows so far...
# Counted 9,528,000 rows so far...
# Counted 9,529,000 rows so far...
# Counted 9,530,000 rows so far...
# Counted 9,531,000 rows so far...
# Counted 9,532,000 rows so far...
# Counted 9,533,000 rows so far...
# Counted 9,534,000 rows so far...
# Counted 9,535,000 rows so far...
# Counted 9,536,000 rows so far...
# Counted 9,537,000 rows so far...
# Counted 9,538,000 rows so far...
# Counted 9,539,000 rows so far...
# Counted 9,540,000 rows so far...
# Counted 9,541,000 rows so far...
# Counted 9,542,000 rows so far...
# Counted 9,543,000 rows so far...
# Counted 9,544,000 rows so far...
# Counted 9,545,000 rows so far...
# Counted 9,546,000 rows so far...
# Counted 9,547,000 rows so far...
# Counted 9,548,000 rows so far...
# Counted 9,549,000 rows so far...
# Counted 9,550,000 rows so far...
# Counted 9,551,000 rows so far...
# Counted 9,552,000 rows so far...
# Counted 9,553,000 rows so far...
# Counted 9,554,000 rows so far...
# Counted 9,555,000 rows so far...
# Counted 9,556,000 rows so far...
# Counted 9,557,000 rows so far...
# Counted 9,558,000 rows so far...
# Counted 9,559,000 rows so far...
# Counted 9,560,000 rows so far...
# Counted 9,561,000 rows so far...
# Counted 9,562,000 rows so far...
# Counted 9,563,000 rows so far...
# Counted 9,564,000 rows so far...
# Counted 9,565,000 rows so far...
# Counted 9,566,000 rows so far...
# Counted 9,567,000 rows so far...
# Counted 9,568,000 rows so far...
# Counted 9,569,000 rows so far...
# Counted 9,570,000 rows so far...
# Counted 9,571,000 rows so far...
# Counted 9,572,000 rows so far...
# Counted 9,573,000 rows so far...
# Counted 9,574,000 rows so far...
# Counted 9,575,000 rows so far...
# Counted 9,576,000 rows so far...
# Counted 9,577,000 rows so far...
# Counted 9,578,000 rows so far...
# Counted 9,579,000 rows so far...
# Counted 9,580,000 rows so far...
# Counted 9,581,000 rows so far...
# Counted 9,582,000 rows so far...
# Counted 9,583,000 rows so far...
# Counted 9,584,000 rows so far...
# Counted 9,585,000 rows so far...
# Counted 9,586,000 rows so far...
# Counted 9,587,000 rows so far...
# Counted 9,588,000 rows so far...
# Counted 9,589,000 rows so far...
# Counted 9,590,000 rows so far...
# Counted 9,591,000 rows so far...
# Counted 9,592,000 rows so far...
# Counted 9,593,000 rows so far...
# Counted 9,594,000 rows so far...
# Counted 9,595,000 rows so far...
# Counted 9,596,000 rows so far...
# Counted 9,597,000 rows so far...
# Counted 9,598,000 rows so far...
# Counted 9,599,000 rows so far...
# Counted 9,600,000 rows so far...
# Counted 9,601,000 rows so far...
# Counted 9,602,000 rows so far...
# Counted 9,603,000 rows so far...
# Counted 9,604,000 rows so far...
# Counted 9,605,000 rows so far...
# Counted 9,606,000 rows so far...
# Counted 9,607,000 rows so far...
# Counted 9,608,000 rows so far...
# Counted 9,609,000 rows so far...
# Counted 9,610,000 rows so far...
# Counted 9,611,000 rows so far...
# Counted 9,612,000 rows so far...
# Counted 9,613,000 rows so far...
# Counted 9,614,000 rows so far...
# Counted 9,615,000 rows so far...
# Counted 9,616,000 rows so far...
# Counted 9,617,000 rows so far...
# Counted 9,618,000 rows so far...
# Counted 9,619,000 rows so far...
# Counted 9,620,000 rows so far...
# Counted 9,621,000 rows so far...
# Counted 9,622,000 rows so far...
# Counted 9,623,000 rows so far...
# Counted 9,624,000 rows so far...
# Counted 9,625,000 rows so far...
# Counted 9,626,000 rows so far...
# Counted 9,627,000 rows so far...
# Counted 9,628,000 rows so far...
# Counted 9,629,000 rows so far...
# Counted 9,630,000 rows so far...
# Counted 9,631,000 rows so far...
# Counted 9,632,000 rows so far...
# Counted 9,633,000 rows so far...
# Counted 9,634,000 rows so far...
# Counted 9,635,000 rows so far...
# Counted 9,636,000 rows so far...
# Counted 9,637,000 rows so far...
# Counted 9,638,000 rows so far...
# Counted 9,639,000 rows so far...
# Counted 9,640,000 rows so far...
# Counted 9,641,000 rows so far...
# Counted 9,642,000 rows so far...
# Counted 9,643,000 rows so far...
# Counted 9,644,000 rows so far...
# Counted 9,645,000 rows so far...
# Counted 9,646,000 rows so far...
# Counted 9,647,000 rows so far...
# Counted 9,648,000 rows so far...
# Counted 9,649,000 rows so far...
# Counted 9,650,000 rows so far...
# Counted 9,651,000 rows so far...
# Counted 9,652,000 rows so far...
# Counted 9,653,000 rows so far...
# Counted 9,654,000 rows so far...
# Counted 9,655,000 rows so far...
# Counted 9,656,000 rows so far...
# Counted 9,657,000 rows so far...
# Counted 9,658,000 rows so far...
# Counted 9,659,000 rows so far...
# Counted 9,660,000 rows so far...
# Counted 9,661,000 rows so far...
# Counted 9,662,000 rows so far...
# Counted 9,663,000 rows so far...
# Counted 9,664,000 rows so far...
# Counted 9,665,000 rows so far...
# Counted 9,666,000 rows so far...
# Counted 9,667,000 rows so far...
# Counted 9,668,000 rows so far...
# Counted 9,669,000 rows so far...
# Counted 9,670,000 rows so far...
# Counted 9,671,000 rows so far...
# Counted 9,672,000 rows so far...
# Counted 9,673,000 rows so far...
# Counted 9,674,000 rows so far...
# Counted 9,675,000 rows so far...
# Counted 9,676,000 rows so far...
# Counted 9,677,000 rows so far...
# Counted 9,678,000 rows so far...
# Counted 9,679,000 rows so far...
# Counted 9,680,000 rows so far...
# Counted 9,681,000 rows so far...
# Counted 9,682,000 rows so far...
# Counted 9,683,000 rows so far...
# Counted 9,684,000 rows so far...
# Counted 9,685,000 rows so far...
# Counted 9,686,000 rows so far...
# Counted 9,687,000 rows so far...
# Counted 9,688,000 rows so far...
# Counted 9,689,000 rows so far...
# Counted 9,690,000 rows so far...
# Counted 9,691,000 rows so far...
# Counted 9,692,000 rows so far...
# Counted 9,693,000 rows so far...
# Counted 9,694,000 rows so far...
# Counted 9,695,000 rows so far...
# Counted 9,696,000 rows so far...
# Counted 9,697,000 rows so far...
# Counted 9,698,000 rows so far...
# Counted 9,699,000 rows so far...
# Counted 9,700,000 rows so far...
# Counted 9,701,000 rows so far...
# Counted 9,702,000 rows so far...
# Counted 9,703,000 rows so far...
# Counted 9,704,000 rows so far...
# Counted 9,705,000 rows so far...
# Counted 9,706,000 rows so far...
# Counted 9,707,000 rows so far...
# Counted 9,708,000 rows so far...
# Counted 9,709,000 rows so far...
# Counted 9,710,000 rows so far...
# Counted 9,711,000 rows so far...
# Counted 9,712,000 rows so far...
# Counted 9,713,000 rows so far...
# Counted 9,714,000 rows so far...
# Counted 9,715,000 rows so far...
# Counted 9,716,000 rows so far...
# Counted 9,717,000 rows so far...
# Counted 9,718,000 rows so far...
# Counted 9,719,000 rows so far...
# Counted 9,720,000 rows so far...
# Counted 9,721,000 rows so far...
# Counted 9,722,000 rows so far...
# Counted 9,723,000 rows so far...
# Counted 9,724,000 rows so far...
# Counted 9,725,000 rows so far...
# Counted 9,726,000 rows so far...
# Counted 9,727,000 rows so far...
# Counted 9,728,000 rows so far...
# Counted 9,729,000 rows so far...
# Counted 9,730,000 rows so far...
# Counted 9,731,000 rows so far...
# Counted 9,732,000 rows so far...
# Counted 9,733,000 rows so far...
# Counted 9,734,000 rows so far...
# Counted 9,735,000 rows so far...
# Counted 9,736,000 rows so far...
# Counted 9,737,000 rows so far...
# Counted 9,738,000 rows so far...
# Counted 9,739,000 rows so far...
# Counted 9,740,000 rows so far...
# Counted 9,741,000 rows so far...
# Counted 9,742,000 rows so far...
# Counted 9,743,000 rows so far...
# Counted 9,744,000 rows so far...
# Counted 9,745,000 rows so far...
# Counted 9,746,000 rows so far...
# Counted 9,747,000 rows so far...
# Counted 9,748,000 rows so far...
# Counted 9,749,000 rows so far...
# Counted 9,750,000 rows so far...
# Counted 9,751,000 rows so far...
# Counted 9,752,000 rows so far...
# Counted 9,753,000 rows so far...
# Counted 9,754,000 rows so far...
# Counted 9,755,000 rows so far...
# Counted 9,756,000 rows so far...
# Counted 9,757,000 rows so far...
# Counted 9,758,000 rows so far...
# Counted 9,759,000 rows so far...
# Counted 9,760,000 rows so far...
# Counted 9,761,000 rows so far...
# Counted 9,762,000 rows so far...
# Counted 9,763,000 rows so far...
# Counted 9,764,000 rows so far...
# Counted 9,765,000 rows so far...
# Counted 9,766,000 rows so far...
# Counted 9,767,000 rows so far...
# Counted 9,768,000 rows so far...
# Counted 9,769,000 rows so far...
# Counted 9,770,000 rows so far...
# Counted 9,771,000 rows so far...
# Counted 9,772,000 rows so far...
# Counted 9,773,000 rows so far...
# Counted 9,774,000 rows so far...
# Counted 9,775,000 rows so far...
# Counted 9,776,000 rows so far...
# Counted 9,777,000 rows so far...
# Counted 9,778,000 rows so far...
# Counted 9,779,000 rows so far...
# Counted 9,780,000 rows so far...
# Counted 9,781,000 rows so far...
# Counted 9,782,000 rows so far...
# Counted 9,783,000 rows so far...
# Counted 9,784,000 rows so far...
# Counted 9,785,000 rows so far...
# Counted 9,786,000 rows so far...
# Counted 9,787,000 rows so far...
# Counted 9,788,000 rows so far...
# Counted 9,789,000 rows so far...
# Counted 9,790,000 rows so far...
# Counted 9,791,000 rows so far...
# Counted 9,792,000 rows so far...
# Counted 9,793,000 rows so far...
# Counted 9,794,000 rows so far...
# Counted 9,795,000 rows so far...
# Counted 9,796,000 rows so far...
# Counted 9,797,000 rows so far...
# Counted 9,798,000 rows so far...
# Counted 9,799,000 rows so far...
# Counted 9,800,000 rows so far...
# Counted 9,801,000 rows so far...
# Counted 9,802,000 rows so far...
# Counted 9,803,000 rows so far...
# Counted 9,804,000 rows so far...
# Counted 9,805,000 rows so far...
# Counted 9,806,000 rows so far...
# Counted 9,807,000 rows so far...
# Counted 9,808,000 rows so far...
# Counted 9,809,000 rows so far...
# Counted 9,810,000 rows so far...
# Counted 9,811,000 rows so far...
# Counted 9,812,000 rows so far...
# Counted 9,813,000 rows so far...
# Counted 9,814,000 rows so far...
# Counted 9,815,000 rows so far...
# Counted 9,816,000 rows so far...
# Counted 9,817,000 rows so far...
# Counted 9,818,000 rows so far...
# Counted 9,819,000 rows so far...
# Counted 9,820,000 rows so far...
# Counted 9,821,000 rows so far...
# Counted 9,822,000 rows so far...
# Counted 9,823,000 rows so far...
# Counted 9,824,000 rows so far...
# Counted 9,825,000 rows so far...
# Counted 9,826,000 rows so far...
# Counted 9,827,000 rows so far...
# Counted 9,828,000 rows so far...
# Counted 9,829,000 rows so far...
# Counted 9,830,000 rows so far...
# Counted 9,831,000 rows so far...
# Counted 9,832,000 rows so far...
# Counted 9,833,000 rows so far...
# Counted 9,834,000 rows so far...
# Counted 9,835,000 rows so far...
# Counted 9,836,000 rows so far...
# Counted 9,837,000 rows so far...
# Counted 9,838,000 rows so far...
# Counted 9,839,000 rows so far...
# Counted 9,840,000 rows so far...
# Counted 9,841,000 rows so far...
# Counted 9,842,000 rows so far...
# Counted 9,843,000 rows so far...
# Counted 9,844,000 rows so far...
# Counted 9,845,000 rows so far...
# Counted 9,846,000 rows so far...
# Counted 9,847,000 rows so far...
# Counted 9,848,000 rows so far...
# Counted 9,849,000 rows so far...
# Counted 9,850,000 rows so far...
# Counted 9,851,000 rows so far...
# Counted 9,852,000 rows so far...
# Counted 9,853,000 rows so far...
# Counted 9,854,000 rows so far...
# Counted 9,855,000 rows so far...
# Counted 9,856,000 rows so far...
# Counted 9,857,000 rows so far...
# Counted 9,858,000 rows so far...
# Counted 9,859,000 rows so far...
# Counted 9,860,000 rows so far...
# Counted 9,861,000 rows so far...
# Counted 9,862,000 rows so far...
# Counted 9,863,000 rows so far...
# Counted 9,864,000 rows so far...
# Counted 9,865,000 rows so far...
# Counted 9,866,000 rows so far...
# Counted 9,867,000 rows so far...
# Counted 9,868,000 rows so far...
# Counted 9,869,000 rows so far...
# Counted 9,870,000 rows so far...
# Counted 9,871,000 rows so far...
# Counted 9,872,000 rows so far...
# Counted 9,873,000 rows so far...
# Counted 9,874,000 rows so far...
# Counted 9,875,000 rows so far...
# Counted 9,876,000 rows so far...
# Counted 9,877,000 rows so far...
# Counted 9,878,000 rows so far...
# Counted 9,879,000 rows so far...
# Counted 9,880,000 rows so far...
# Counted 9,881,000 rows so far...
# Counted 9,882,000 rows so far...
# Counted 9,883,000 rows so far...
# Counted 9,884,000 rows so far...
# Counted 9,885,000 rows so far...
# Counted 9,886,000 rows so far...
# Counted 9,887,000 rows so far...
# Counted 9,888,000 rows so far...
# Counted 9,889,000 rows so far...
# Counted 9,890,000 rows so far...
# Counted 9,891,000 rows so far...
# Counted 9,892,000 rows so far...
# Counted 9,893,000 rows so far...
# Counted 9,894,000 rows so far...
# Counted 9,895,000 rows so far...
# Counted 9,896,000 rows so far...
# Counted 9,897,000 rows so far...
# Counted 9,898,000 rows so far...
# Counted 9,899,000 rows so far...
# Counted 9,900,000 rows so far...
# Counted 9,901,000 rows so far...
# Counted 9,902,000 rows so far...
# Counted 9,903,000 rows so far...
# Counted 9,904,000 rows so far...
# Counted 9,905,000 rows so far...
# Counted 9,906,000 rows so far...
# Counted 9,907,000 rows so far...
# Counted 9,908,000 rows so far...
# Counted 9,909,000 rows so far...
# Counted 9,910,000 rows so far...
# Counted 9,911,000 rows so far...
# Counted 9,912,000 rows so far...
# Counted 9,913,000 rows so far...
# Counted 9,914,000 rows so far...
# Counted 9,915,000 rows so far...
# Counted 9,916,000 rows so far...
# Counted 9,917,000 rows so far...
# Counted 9,918,000 rows so far...
# Counted 9,919,000 rows so far...
# Counted 9,920,000 rows so far...
# Counted 9,921,000 rows so far...
# Counted 9,922,000 rows so far...
# Counted 9,923,000 rows so far...
# Counted 9,924,000 rows so far...
# Counted 9,925,000 rows so far...
# Counted 9,926,000 rows so far...
# Counted 9,927,000 rows so far...
# Counted 9,928,000 rows so far...
# Counted 9,929,000 rows so far...
# Counted 9,930,000 rows so far...
# Counted 9,931,000 rows so far...
# Counted 9,932,000 rows so far...
# Counted 9,933,000 rows so far...
# Counted 9,934,000 rows so far...
# Counted 9,935,000 rows so far...
# Counted 9,936,000 rows so far...
# Counted 9,937,000 rows so far...
# Counted 9,938,000 rows so far...
# Counted 9,939,000 rows so far...
# Counted 9,940,000 rows so far...
# Counted 9,941,000 rows so far...
# Counted 9,942,000 rows so far...
# Counted 9,943,000 rows so far...
# Counted 9,944,000 rows so far...
# Counted 9,945,000 rows so far...
# Counted 9,946,000 rows so far...
# Counted 9,947,000 rows so far...
# Counted 9,948,000 rows so far...
# Counted 9,949,000 rows so far...
# Counted 9,950,000 rows so far...
# Counted 9,951,000 rows so far...
# Counted 9,952,000 rows so far...
# Counted 9,953,000 rows so far...
# Counted 9,954,000 rows so far...
# Counted 9,955,000 rows so far...
# Counted 9,956,000 rows so far...
# Counted 9,957,000 rows so far...
# Counted 9,958,000 rows so far...
# Counted 9,959,000 rows so far...
# Counted 9,960,000 rows so far...
# Counted 9,961,000 rows so far...
# Counted 9,962,000 rows so far...
# Counted 9,963,000 rows so far...
# Counted 9,964,000 rows so far...
# Counted 9,965,000 rows so far...
# Counted 9,966,000 rows so far...
# Counted 9,967,000 rows so far...
# Counted 9,968,000 rows so far...
# Counted 9,969,000 rows so far...
# Counted 9,970,000 rows so far...
# Counted 9,971,000 rows so far...
# Counted 9,972,000 rows so far...
# Counted 9,973,000 rows so far...
# Counted 9,974,000 rows so far...
# Counted 9,975,000 rows so far...
# Counted 9,976,000 rows so far...
# Counted 9,977,000 rows so far...
# Counted 9,978,000 rows so far...
# Counted 9,979,000 rows so far...
# Counted 9,980,000 rows so far...
# Counted 9,981,000 rows so far...
# Counted 9,982,000 rows so far...
# Counted 9,983,000 rows so far...
# Counted 9,984,000 rows so far...
# Counted 9,985,000 rows so far...
# Counted 9,986,000 rows so far...
# Counted 9,987,000 rows so far...
# Counted 9,988,000 rows so far...
# Counted 9,989,000 rows so far...
# Counted 9,990,000 rows so far...
# Counted 9,991,000 rows so far...
# Counted 9,992,000 rows so far...
# Counted 9,993,000 rows so far...
# Counted 9,994,000 rows so far...
# Counted 9,995,000 rows so far...
# Counted 9,996,000 rows so far...
# Counted 9,997,000 rows so far...
# Counted 9,998,000 rows so far...
# Counted 9,999,000 rows so far...
# Error occurred: <ConnectionTerminated error_code:0, last_stream_id:19999, additional_data:None>
